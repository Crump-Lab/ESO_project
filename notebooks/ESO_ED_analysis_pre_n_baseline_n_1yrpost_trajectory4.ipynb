# %% [markdown]
# #### This document is for analysis on FACT-E emotional well being (EWB).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import re

# %% [markdown]
# # Preliminary

# %%
# Read the CSV file - linked file 
file_path = "Merged_TSQIC_REDCap_ACCESS.xlsx" 
df = pd.read_excel(file_path)
df
# Out:
#          id operation_date redcap_event_name   qol_date  age_diagnosis  \
# 0         1            NaT    baseline_arm_1        NaT            NaN
# 1         1     2011-08-26               NaN        NaT            NaN
# 2         1     2010-02-20               NaN        NaT            NaN
# 3         1     2009-05-27               NaN        NaT            NaN
# 4         1     2009-02-25               NaN        NaT            NaN
# ...     ...            ...               ...        ...            ...
# 11964  1788            NaT    baseline_arm_1        NaT            NaN
# 11965  1788            NaT    baseline_arm_1 2025-06-09            NaN
# 11966  1788            NaT    baseline_arm_1        NaT            NaN
# 11967  1789            NaT    baseline_arm_1        NaT            NaN
# 11968  1789            NaT    baseline_arm_1 2025-06-16            NaN
#
#              dob overall_primary_tumour overall_regional_ln  \
# 0     1949-08-04                    NaN                 NaN
# 1            NaT                    NaN                 NaN
# 2            NaT                    NaN                 NaN
# 3            NaT                    NaN                 NaN
# 4            NaT                    NaN                 NaN
# ...          ...                    ...                 ...
# 11964 1947-03-23                    NaN                 NaN
# 11965        NaT                    NaN                 NaN
# 11966        NaT                      3                   1
# 11967 1945-08-19                    NaN                 NaN
# 11968        NaT                    NaN                 NaN
#
#        overall_distant_metastasis  neotx___notx  ...  a_e5  a_e6  a_e7  a_c6  \
# 0                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 1                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 2                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 3                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 4                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# ...                           ...           ...  ...   ...   ...   ...   ...
# 11964                         NaN           NaN  ...   NaN   NaN   NaN   NaN
# 11965                         NaN           NaN  ...   0.0   2.0   0.0   2.0
# 11966                         0.0           NaN  ...   NaN   NaN   NaN   NaN
# 11967                         NaN           NaN  ...   NaN   NaN   NaN   NaN
# 11968                         NaN           NaN  ...   3.0   0.0   0.0   0.0
#
#        a_c2  a_act11  readmission_30d postop_comp   los  DischargeDate
# 0       NaN      NaN              NaN         0.0   NaN     2012-04-27
# 1       NaN      NaN              NaN         NaN   NaN     2011-08-26
# 2       NaN      NaN              NaN         NaN  16.0     2010-03-08
# 3       NaN      NaN              NaN         NaN   0.0     2009-05-27
# 4       NaN      NaN              NaN         NaN   8.0     2009-03-05
# ...     ...      ...              ...         ...   ...            ...
# 11964   NaN      NaN              NaN         NaN   NaN            NaT
# 11965   2.0      0.0              NaN         NaN   NaN            NaT
# 11966   NaN      NaN              NaN         NaN   NaN            NaT
# 11967   NaN      NaN              NaN         NaN   NaN            NaT
# 11968   4.0      0.0              NaN         NaN   NaN            NaT
#
# [11969 rows x 84 columns]

# %% [raw]
# from datetime import datetime, timedelta
#
# def preprocess_patient_data(df):
#     """
#     Preprocess patient data with two filtering steps:
#     1. Filter out patients under 18 years old (if age information is available)
#     2. Filter out patients with expectation_treatment == 1 (if information is available)
#     """
#
#     # Make a copy to avoid modifying original dataframe
#     df_processed = df.copy()
#
#     # Step 1: Age filtering (keep patients >= 18 years old)
#     print("Step 1: Filtering patients by age...")
#
#     # Get current date for age calculation
#     current_date = datetime.now()
#
#     # Group by patient id to check age information
#     patient_groups = df_processed.groupby('id')
#     patients_to_keep = []
#
#     for patient_id, group in patient_groups:
#         keep_patient = True
#
#         # Check dob column first
#         dob_available = group['dob'].notna().any()
#
#         if dob_available:
#             # Get the first non-null dob value
#             dob = group['dob'].dropna().iloc[0]
#             # Calculate age
#             age_years = (current_date - dob).days / 365.25
#
#             # Check if age is negative (invalid DOB data)
#             if age_years < 0:
#                 # Check age_diagnosis column as fallback
#                 age_diag_available = group['age_diagnosis'].notna().any()
#
#                 if age_diag_available:
#                     age_diagnosis = group['age_diagnosis'].dropna().iloc[0]
#                     if age_diagnosis < 18:
#                         keep_patient = False
#                         print(f"Patient {patient_id}: Filtered out (age from diagnosis: {age_diagnosis} years)")
#                 # If no age_diagnosis available, keep patient (no valid age info)
#
#             elif age_years < 18:
#                 keep_patient = False
#                 print(f"Patient {patient_id}: Filtered out (age from dob: {age_years:.1f} years)")
#
#         else:
#             # Check age_diagnosis column if dob is not available
#             age_diag_available = group['age_diagnosis'].notna().any()
#
#             if age_diag_available:
#                 # Get the first non-null age_diagnosis value
#                 age_diagnosis = group['age_diagnosis'].dropna().iloc[0]
#
#                 if age_diagnosis < 18:
#                     keep_patient = False
#                     print(f"Patient {patient_id}: Filtered out (age from diagnosis: {age_diagnosis} years)")
#
#         # If patient should be kept, add all their rows
#         if keep_patient:
#             patients_to_keep.extend(group.index.tolist())
#
#     # Filter dataframe to keep only selected patients
#     df_processed = df_processed.loc[patients_to_keep]
#     print(f"After age filtering: {len(df_processed)} rows remaining")
#
#     # Step 2: expectation_treatment filtering (keep only patients with expectation_treatment == 1)
#     print("\nStep 2: Filtering patients by expectation_treatment...")
#
#     # Group by patient id again for expectation_treatment check
#     patient_groups = df_processed.groupby('id')
#     patients_to_keep = []
#
#     for patient_id, group in patient_groups:
#         keep_patient = True
#
#         # Check if expectation_treatment column exists and has data for this patient
#         if 'expectation_treatment' in group.columns:
#             expectation_available = group['expectation_treatment'].notna().any()
#
#             if expectation_available:
#                 # Check if any row has expectation_treatment == 1
#                 has_expectation_treatment = (group['expectation_treatment'] == 1).any()
#
#                 if not has_expectation_treatment:
#                     keep_patient = False
#                     print(f"Patient {patient_id}: Filtered out (no expectation_treatment == 1)")
#
#         # If patient should be kept, add all their rows
#         if keep_patient:
#             patients_to_keep.extend(group.index.tolist())
#
#     # Filter dataframe to keep only selected patients
#     df_processed = df_processed.loc[patients_to_keep]
#     print(f"After expectation_treatment filtering: {len(df_processed)} rows remaining")
#
#     return df_processed
#
# # Optional: Function to get summary statistics
# def get_filtering_summary(df_original, df_filtered):
#     """
#     Print summary of filtering results
#     """
#     original_patients = df_original['id'].nunique()
#     filtered_patients = df_filtered['id'].nunique()
#     original_rows = len(df_original)
#     filtered_rows = len(df_filtered)
#
#     print(f"\n=== Filtering Summary ===")
#     print(f"Original patients: {original_patients}")
#     print(f"Filtered patients: {filtered_patients}")
#     print(f"Patients removed: {original_patients - filtered_patients}")
#     print(f"Original rows: {original_rows}")
#     print(f"Filtered rows: {filtered_rows}")
#     print(f"Rows removed: {original_rows - filtered_rows}")
#
# # Example usage:
# df_filtered = preprocess_patient_data(df)
# get_filtering_summary(df, df_filtered)

# %%
def preprocess_patient_data(df):
    """
    Preprocess patient data with expectation_treatment filtering:
    Filter out patients with expectation_treatment != 1 (if information is available)
    """
    
    # Make a copy to avoid modifying original dataframe
    df_processed = df.copy()
    
    # Step 1: expectation_treatment filtering (keep only patients with expectation_treatment == 1)
    print("Step 1: Filtering patients by expectation_treatment...")
    
    # Group by patient id again for expectation_treatment check
    patient_groups = df_processed.groupby('id')
    patients_to_keep = []
    
    for patient_id, group in patient_groups:
        keep_patient = True
        
        # Check if expectation_treatment column exists and has data for this patient
        if 'expectation_treatment' in group.columns:
            expectation_available = group['expectation_treatment'].notna().any()
            
            if expectation_available:
                # Check if any row has expectation_treatment == 1
                has_expectation_treatment = (group['expectation_treatment'] == 1).any()
                
                if not has_expectation_treatment:
                    keep_patient = False
                    print(f"Patient {patient_id}: Filtered out (no expectation_treatment == 1)")
        
        # If patient should be kept, add all their rows
        if keep_patient:
            patients_to_keep.extend(group.index.tolist())
    
    # Filter dataframe to keep only selected patients
    df_processed = df_processed.loc[patients_to_keep]
    print(f"After expectation_treatment filtering: {len(df_processed)} rows remaining")
    
    return df_processed

# Optional: Function to get summary statistics
def get_filtering_summary(df_original, df_filtered):
    """
    Print summary of filtering results
    """
    original_patients = df_original['id'].nunique()
    filtered_patients = df_filtered['id'].nunique()
    original_rows = len(df_original)
    filtered_rows = len(df_filtered)
    
    print(f"\n=== Filtering Summary ===")
    print(f"Original patients: {original_patients}")
    print(f"Filtered patients: {filtered_patients}")
    print(f"Patients removed: {original_patients - filtered_patients}")
    print(f"Original rows: {original_rows}")
    print(f"Filtered rows: {filtered_rows}")
    print(f"Rows removed: {original_rows - filtered_rows}")

# Example usage:
df_filtered = preprocess_patient_data(df)
get_filtering_summary(df, df_filtered)
# Out:
# Step 1: Filtering patients by expectation_treatment...
# Patient 8: Filtered out (no expectation_treatment == 1)
# Patient 59: Filtered out (no expectation_treatment == 1)
# Patient 1179: Filtered out (no expectation_treatment == 1)
# After expectation_treatment filtering: 11940 rows remaining
#
# === Filtering Summary ===
# Original patients: 1688
# Filtered patients: 1685
# Patients removed: 3
# Original rows: 11969
# Filtered rows: 11940
# Rows removed: 29

# %%
df = df_filtered.copy()
df
# Out:
#          id operation_date redcap_event_name   qol_date  age_diagnosis  \
# 0         1            NaT    baseline_arm_1        NaT            NaN
# 1         1     2011-08-26               NaN        NaT            NaN
# 2         1     2010-02-20               NaN        NaT            NaN
# 3         1     2009-05-27               NaN        NaT            NaN
# 4         1     2009-02-25               NaN        NaT            NaN
# ...     ...            ...               ...        ...            ...
# 11964  1788            NaT    baseline_arm_1        NaT            NaN
# 11965  1788            NaT    baseline_arm_1 2025-06-09            NaN
# 11966  1788            NaT    baseline_arm_1        NaT            NaN
# 11967  1789            NaT    baseline_arm_1        NaT            NaN
# 11968  1789            NaT    baseline_arm_1 2025-06-16            NaN
#
#              dob overall_primary_tumour overall_regional_ln  \
# 0     1949-08-04                    NaN                 NaN
# 1            NaT                    NaN                 NaN
# 2            NaT                    NaN                 NaN
# 3            NaT                    NaN                 NaN
# 4            NaT                    NaN                 NaN
# ...          ...                    ...                 ...
# 11964 1947-03-23                    NaN                 NaN
# 11965        NaT                    NaN                 NaN
# 11966        NaT                      3                   1
# 11967 1945-08-19                    NaN                 NaN
# 11968        NaT                    NaN                 NaN
#
#        overall_distant_metastasis  neotx___notx  ...  a_e5  a_e6  a_e7  a_c6  \
# 0                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 1                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 2                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 3                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# 4                             NaN           NaN  ...   NaN   NaN   NaN   NaN
# ...                           ...           ...  ...   ...   ...   ...   ...
# 11964                         NaN           NaN  ...   NaN   NaN   NaN   NaN
# 11965                         NaN           NaN  ...   0.0   2.0   0.0   2.0
# 11966                         0.0           NaN  ...   NaN   NaN   NaN   NaN
# 11967                         NaN           NaN  ...   NaN   NaN   NaN   NaN
# 11968                         NaN           NaN  ...   3.0   0.0   0.0   0.0
#
#        a_c2  a_act11  readmission_30d postop_comp   los  DischargeDate
# 0       NaN      NaN              NaN         0.0   NaN     2012-04-27
# 1       NaN      NaN              NaN         NaN   NaN     2011-08-26
# 2       NaN      NaN              NaN         NaN  16.0     2010-03-08
# 3       NaN      NaN              NaN         NaN   0.0     2009-05-27
# 4       NaN      NaN              NaN         NaN   8.0     2009-03-05
# ...     ...      ...              ...         ...   ...            ...
# 11964   NaN      NaN              NaN         NaN   NaN            NaT
# 11965   2.0      0.0              NaN         NaN   NaN            NaT
# 11966   NaN      NaN              NaN         NaN   NaN            NaT
# 11967   NaN      NaN              NaN         NaN   NaN            NaT
# 11968   4.0      0.0              NaN         NaN   NaN            NaT
#
# [11940 rows x 84 columns]

# %% [markdown]
# # Preliminary 2

# %%
df['id'].nunique()
# Out:
# 1685

# %%
df['redcap_event_name'].value_counts()
# Out:
# redcap_event_name
# baseline_arm_1           3862
# surgery_arm_1            3831
# preoperative_arm_1       1755
# 1_month_postop_arm_1      903
# 1_year_postop_arm_1       350
# 6_months_postop_arm_1     327
# 3_months_postop_arm_1     256
# Name: count, dtype: int64

# %% [markdown]
# # Analysis

# %%
# Step 1: Find eligible IDs (unchanged)
def find_eligible_ids(df):
    id_events = df.groupby('id')['redcap_event_name'].apply(set)
    eligible_ids = []
    for id_val, events in id_events.items():
        has_baseline = "baseline_arm_1" in events
        has_preop = "preoperative_arm_1" in events
        has_one_year = "1_year_postop_arm_1" in events
        if (has_baseline and has_one_year) or (has_preop and has_one_year):
            eligible_ids.append(id_val)
    return eligible_ids

# Step 2: Filter dataset (unchanged)
def filter_eligible_data(df, eligible_ids):
    return df[df['id'].isin(eligible_ids)].copy()

# Step 3: Calculate all subscale scores (unchanged)
def calculate_subscale_score(df, cols, reverse_items=None, subscale_name=""):
    """Calculate subscale scores according to FACT scoring guidelines, only if >=50% items are answered"""
    # Convert to numeric and handle reverse scoring
    for col in cols:
        df[f"{col}_score"] = pd.to_numeric(df[col], errors='coerce')
        if reverse_items and col in reverse_items:
            df[f"{col}_score"] = 4 - df[f"{col}_score"]
    
    # Calculate the number of items and the 50% threshold
    total_items = len(cols)
    min_items_required = total_items / 2  # 50% threshold
    
    # Count non-NaN items for each row
    score_cols = [f"{col}_score" for col in cols]
    num_answered_items = df[score_cols].notna().sum(axis=1)
    
    # Calculate subscale score only if >=50% items are answered
    df[f"{subscale_name}_subscale_score"] = np.where(
        num_answered_items >= min_items_required,
        (df[score_cols].sum(axis=1, skipna=True) * total_items) / 
        df[score_cols].notna().sum(axis=1),
        np.nan
    )
    return df

def calculate_all_scores(df):
    pwb_cols = [f"gp{i}" for i in range(1, 8)]
    swb_cols = [f"gs{i}" for i in range(1, 8)]
    ewb_cols = [f"ge{i}" for i in range(1, 7)]
    fwb_cols = [f"gf{i}" for i in range(1, 8)]
    ecs_cols = [f"a_hn{i}" for i in range(1, 6)] + ["a_hn7", "a_hn10"] + \
                [f"a_e{i}" for i in range(1, 8)] + ["a_c6", "a_c2", "a_act11"]

    pwb_reverse = pwb_cols
    ewb_reverse = [f"ge{i}" for i in range(1, 7) if i != 2]
    ecs_reverse = ["a_e1", "a_e2", "a_e3", "a_e4", "a_e5", "a_e7", "a_act11", 
                    "a_c2", "a_hn2", "a_hn3"]

    df = calculate_subscale_score(df, pwb_cols, pwb_reverse, "pwb")
    df = calculate_subscale_score(df, swb_cols, None, "swb")
    df = calculate_subscale_score(df, ewb_cols, ewb_reverse, "ewb")
    df = calculate_subscale_score(df, fwb_cols, None, "fwb")
    df = calculate_subscale_score(df, ecs_cols, ecs_reverse, "ecs")

    # Calculate composite scores with both conditions
    # 1. FACT-G Total (PWB + SWB + EWB + FWB)
    fact_g_items = pwb_cols + swb_cols + ewb_cols + fwb_cols  # 27 items
    fact_g_item_cols = [f"{col}_score" for col in fact_g_items]
    fact_g_num_answered = df[fact_g_item_cols].notna().sum(axis=1)
    fact_g_min_items = 22  # 80% of 27 items = 21.6, rounded up to 22
    
    df['fact_g_total'] = np.where(
        # Condition 1: All subscales must be non-NaN (already ensures 50% of items per subscale)
        (df["pwb_subscale_score"].notna()) & 
        (df["swb_subscale_score"].notna()) & 
        (df["ewb_subscale_score"].notna()) & 
        (df["fwb_subscale_score"].notna()) &
        # Condition 2: At least 80% of FACT-G items must be answered
        (fact_g_num_answered >= fact_g_min_items),
        df["pwb_subscale_score"] + df["swb_subscale_score"] + 
        df["ewb_subscale_score"] + df["fwb_subscale_score"],
        np.nan
    )
    
    # 2. FACT-E Total (FACT-G + ECS)
    fact_e_items = fact_g_items + ecs_cols  # 27 + 17 = 44 items
    fact_e_item_cols = [f"{col}_score" for col in fact_e_items]
    fact_e_num_answered = df[fact_e_item_cols].notna().sum(axis=1)
    fact_e_min_items = 36  # 80% of 44 items = 35.2, rounded up to 36
    
    df['fact_e_total'] = np.where(
        # Condition 1: FACT-G and ECS must be non-NaN
        (df['fact_g_total'].notna()) & 
        (df["ecs_subscale_score"].notna()) &
        # Condition 2: At least 80% of FACT-E items must be answered
        (fact_e_num_answered >= fact_e_min_items),
        df['fact_g_total'] + df["ecs_subscale_score"],
        np.nan
    )
    
    # 3. TOI (PWB + FWB + ECS)
    toi_items = pwb_cols + fwb_cols + ecs_cols  # 7 + 7 + 17 = 31 items
    toi_item_cols = [f"{col}_score" for col in toi_items]
    toi_num_answered = df[toi_item_cols].notna().sum(axis=1)
    toi_min_items = 25  # 80% of 31 items = 24.8, rounded up to 25
    
    df['toi'] = np.where(
        # Condition 1: PWB, FWB, and ECS must be non-NaN
        (df["pwb_subscale_score"].notna()) & 
        (df["fwb_subscale_score"].notna()) & 
        (df["ecs_subscale_score"].notna()) &
        # Condition 2: At least 80% of TOI items must be answered
        (toi_num_answered >= toi_min_items),
        df["pwb_subscale_score"] + df["fwb_subscale_score"] + df["ecs_subscale_score"],
        np.nan
    )

    return df

# Step 4: Analyze trajectory for all scores (fixed)
def analyze_trajectories(df):
    results = []
    unique_ids = df['id'].unique()
    
    score_types = ['pwb_subscale_score', 'swb_subscale_score', 'ewb_subscale_score',
                    'fwb_subscale_score', 'ecs_subscale_score', 'fact_g_total',
                    'fact_e_total', 'toi']
    
    for id_val in unique_ids:
        id_data = df[df['id'] == id_val]
        events = id_data['redcap_event_name'].unique()
        print(f"\nID {id_val} has events: {events}")
        
        event_scores = id_data.groupby('redcap_event_name')[score_types].mean().reset_index()
        
        baseline_score = event_scores[event_scores['redcap_event_name'] == 'baseline_arm_1']
        preop_score = event_scores[event_scores['redcap_event_name'] == 'preoperative_arm_1']
        one_year_score = event_scores[event_scores['redcap_event_name'] == '1_year_postop_arm_1']
        
        # Skip if no one-year data
        if one_year_score.empty:
            continue
            
        # Get values for each timepoint (or NaN if missing)
        one_year_values = one_year_score[score_types].iloc[0].to_dict() if not one_year_score.empty else {k: np.nan for k in score_types}
        
        # Print scores
        if not baseline_score.empty:
            baseline_values = baseline_score[score_types].iloc[0].to_dict()
            print(f"Baseline score: [{', '.join([f'{k}: {v:.1f}' for k, v in baseline_values.items() if pd.notna(v)])}]")
        else:
            print("Baseline score: [nan]")
            
        if not preop_score.empty:
            preop_values = preop_score[score_types].iloc[0].to_dict()
            print(f"Preop score: [{', '.join([f'{k}: {v:.1f}' for k, v in preop_values.items() if pd.notna(v)])}]")
        else:
            print("Preop score: [nan]")
            
        print(f"1-year score: [{', '.join([f'{k}: {v:.1f}' for k, v in one_year_values.items() if pd.notna(v)])}]")

        # Determine which baseline to use (fixed logic)
        baseline_type = None
        baseline_values = None
        
        # Check if baseline_score exists and has non-NaN values
        if not baseline_score.empty:
            baseline_values_temp = baseline_score[score_types].iloc[0].to_dict()
            # Check if at least one score is non-NaN
            if any(pd.notna(val) for val in baseline_values_temp.values()):
                baseline_type = 'baseline_arm_1'
                baseline_values = baseline_values_temp
                print(f"Using baseline score: {', '.join([f'{k}: {v:.1f}' for k, v in baseline_values.items() if pd.notna(v)])}")
        
        # If baseline is not valid, fall back to preop
        if baseline_values is None and not preop_score.empty:
            preop_values_temp = preop_score[score_types].iloc[0].to_dict()
            if any(pd.notna(val) for val in preop_values_temp.values()):
                baseline_type = 'preoperative_arm_1'
                baseline_values = preop_values_temp
                print(f"Using preop score as baseline: {', '.join([f'{k}: {v:.1f}' for k, v in baseline_values.items() if pd.notna(v)])}")
        
        # Skip if no valid baseline
        if baseline_values is None:
            continue
        
        # Calculate improvements
        result = {'id': id_val, 'baseline_type': baseline_type}
        for score_type in score_types:
            result.update({
                f'{score_type}_baseline': baseline_values[score_type],
                f'{score_type}_one_year': one_year_values[score_type]
            })
        
        results.append(result)
    
    return pd.DataFrame(results)

# Main function (unchanged)
def analyze_patient_outcomes(df):
    required_cols = ['id', 'redcap_event_name'] + \
                    [f"gp{i}" for i in range(1, 8)] + \
                    [f"gs{i}" for i in range(1, 8)] + \
                    [f"ge{i}" for i in range(1, 7)] + \
                    [f"gf{i}" for i in range(1, 8)] + \
                    [f"a_hn{i}" for i in range(1, 6)] + ["a_hn7", "a_hn10"] + \
                    [f"a_e{i}" for i in range(1, 8)] + ["a_c6", "a_c2", "a_act11"]
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        print(f"Warning: Missing columns: {missing_cols}")
    
    eligible_ids = find_eligible_ids(df)
    print(f"Found {len(eligible_ids)} eligible IDs")
    
    filtered_df = filter_eligible_data(df, eligible_ids)
    print(f"Filtered dataframe shape: {filtered_df.shape}")
    
    filtered_df = calculate_all_scores(filtered_df)
    
    score_cols = [col for col in filtered_df.columns if col.endswith('_score') or col.endswith('_total')]
    print(f"Created score columns: {score_cols}")
    
    score_types = ['pwb_subscale_score', 'swb_subscale_score', 'ewb_subscale_score',
                    'fwb_subscale_score', 'ecs_subscale_score', 'fact_g_total',
                    'fact_e_total', 'toi']
    for score_type in score_types:
        non_nan_count = filtered_df[score_type].notna().sum()
        print(f"Non-NaN {score_type}: {non_nan_count} out of {len(filtered_df)}")
    
    results_df = analyze_trajectories(filtered_df)
    
    if not results_df.empty:
        print(f"\nAnalysis complete for {len(results_df)} patients:")
        for score_type in score_types:
            # Count patients with valid baseline scores for this score type
            valid_baselines = results_df[f'{score_type}_baseline'].notna().sum()
            print(f"Patients with valid {score_type} baseline: {valid_baselines} out of {len(results_df)}")
    return filtered_df, results_df

# Example usage
filtered_df, results_df = analyze_patient_outcomes(df)

results_df.to_csv("results.csv", index=False)
# Out:
# Found 167 eligible IDs
# Filtered dataframe shape: (2235, 84)
# Created score columns: ['cci_total', 'gp1_score', 'gp2_score', 'gp3_score', 'gp4_score', 'gp5_score', 'gp6_score', 'gp7_score', 'pwb_subscale_score', 'gs1_score', 'gs2_score', 'gs3_score', 'gs4_score', 'gs5_score', 'gs6_score', 'gs7_score', 'swb_subscale_score', 'ge1_score', 'ge2_score', 'ge3_score', 'ge4_score', 'ge5_score', 'ge6_score', 'ewb_subscale_score', 'gf1_score', 'gf2_score', 'gf3_score', 'gf4_score', 'gf5_score', 'gf6_score', 'gf7_score', 'fwb_subscale_score', 'a_hn1_score', 'a_hn2_score', 'a_hn3_score', 'a_hn4_score', 'a_hn5_score', 'a_hn7_score', 'a_hn10_score', 'a_e1_score', 'a_e2_score', 'a_e3_score', 'a_e4_score', 'a_e5_score', 'a_e6_score', 'a_e7_score', 'a_c6_score', 'a_c2_score', 'a_act11_score', 'ecs_subscale_score', 'fact_g_total', 'fact_e_total']
# Non-NaN pwb_subscale_score: 622 out of 2235
# Non-NaN swb_subscale_score: 615 out of 2235
# Non-NaN ewb_subscale_score: 621 out of 2235
# Non-NaN fwb_subscale_score: 624 out of 2235
# Non-NaN ecs_subscale_score: 614 out of 2235
# Non-NaN fact_g_total: 610 out of 2235
# Non-NaN fact_e_total: 599 out of 2235
# Non-NaN toi: 601 out of 2235
#
# ID 32 has events: ['baseline_arm_1' 'surgery_arm_1' '1_month_postop_arm_1'
#  'preoperative_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.5, swb_subscale_score: 22.0, ewb_subscale_score: 6.0, fwb_subscale_score: 19.0, ecs_subscale_score: 46.0, fact_g_total: 71.5, fact_e_total: 117.5, toi: 89.5]
# Preop score: []
# 1-year score: [pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 24.0, fwb_subscale_score: 25.0, ecs_subscale_score: 55.0, fact_g_total: 104.0, fact_e_total: 159.0, toi: 107.0]
# Using baseline score: pwb_subscale_score: 24.5, swb_subscale_score: 22.0, ewb_subscale_score: 6.0, fwb_subscale_score: 19.0, ecs_subscale_score: 46.0, fact_g_total: 71.5, fact_e_total: 117.5, toi: 89.5
#
# ID 76 has events: ['1_month_postop_arm_1' 'baseline_arm_1' 'surgery_arm_1'
#  'preoperative_arm_1' '1_year_postop_arm_1' '3_months_postop_arm_1']
# Baseline score: []
# Preop score: [pwb_subscale_score: 7.0, swb_subscale_score: 23.0, ewb_subscale_score: 14.0, fwb_subscale_score: 15.0, ecs_subscale_score: 36.0, fact_g_total: 59.0, fact_e_total: 95.0, toi: 58.0]
# 1-year score: [pwb_subscale_score: 7.0, swb_subscale_score: 21.0, ewb_subscale_score: 11.0, fwb_subscale_score: 10.0, ecs_subscale_score: 48.0, fact_g_total: 49.0, fact_e_total: 97.0, toi: 65.0]
# Using preop score as baseline: pwb_subscale_score: 7.0, swb_subscale_score: 23.0, ewb_subscale_score: 14.0, fwb_subscale_score: 15.0, ecs_subscale_score: 36.0, fact_g_total: 59.0, fact_e_total: 95.0, toi: 58.0
#
# ID 125 has events: ['surgery_arm_1' 'baseline_arm_1' '1_month_postop_arm_1'
#  '1_year_postop_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 17.5, ewb_subscale_score: 21.0, fwb_subscale_score: 8.0, ecs_subscale_score: 52.0, fact_g_total: 67.5, fact_e_total: 119.5, toi: 81.0]
# Preop score: [pwb_subscale_score: 14.0, swb_subscale_score: 15.2, ewb_subscale_score: 16.0, fwb_subscale_score: 9.0, ecs_subscale_score: 34.0, fact_g_total: 54.2, fact_e_total: 88.2, toi: 57.0]
# 1-year score: [pwb_subscale_score: 22.0, swb_subscale_score: 21.0, ewb_subscale_score: 19.0, fwb_subscale_score: 13.0, ecs_subscale_score: 54.0, fact_g_total: 75.0, fact_e_total: 129.0, toi: 89.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 17.5, ewb_subscale_score: 21.0, fwb_subscale_score: 8.0, ecs_subscale_score: 52.0, fact_g_total: 67.5, fact_e_total: 119.5, toi: 81.0
#
# ID 151 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '3_months_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: []
#
# ID 160 has events: ['1_year_postop_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' 'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 20.0, ewb_subscale_score: 21.0, fwb_subscale_score: 20.0, ecs_subscale_score: 37.0, fact_g_total: 82.0, fact_e_total: 119.0, toi: 78.0]
# Preop score: [pwb_subscale_score: 28.0, swb_subscale_score: 19.8, ewb_subscale_score: 20.0, fwb_subscale_score: 20.0, ecs_subscale_score: 58.0, fact_g_total: 87.8, fact_e_total: 145.8, toi: 106.0]
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 22.0, ewb_subscale_score: 23.0, fwb_subscale_score: 22.0, ecs_subscale_score: 57.0, fact_g_total: 95.0, fact_e_total: 152.0, toi: 107.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 20.0, ewb_subscale_score: 21.0, fwb_subscale_score: 20.0, ecs_subscale_score: 37.0, fact_g_total: 82.0, fact_e_total: 119.0, toi: 78.0
#
# ID 198 has events: ['surgery_arm_1' 'baseline_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 25.0, swb_subscale_score: 13.0, ewb_subscale_score: 17.0, fwb_subscale_score: 21.0, ecs_subscale_score: 57.0, fact_g_total: 76.0, fact_e_total: 133.0, toi: 103.0]
# Preop score: [nan]
# 1-year score: [pwb_subscale_score: 26.5, swb_subscale_score: 18.0, ewb_subscale_score: 23.0, fwb_subscale_score: 20.5, ecs_subscale_score: 51.0, fact_g_total: 88.0, fact_e_total: 139.0, toi: 98.0]
# Using baseline score: pwb_subscale_score: 25.0, swb_subscale_score: 13.0, ewb_subscale_score: 17.0, fwb_subscale_score: 21.0, ecs_subscale_score: 57.0, fact_g_total: 76.0, fact_e_total: 133.0, toi: 103.0
#
# ID 230 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 19.0, swb_subscale_score: 23.0, ewb_subscale_score: 23.0, fwb_subscale_score: 11.0, ecs_subscale_score: 57.8, fact_g_total: 76.0, fact_e_total: 133.8]
# Preop score: []
# 1-year score: [pwb_subscale_score: 8.0, swb_subscale_score: 14.0, ewb_subscale_score: 10.0, fwb_subscale_score: 4.0, ecs_subscale_score: 17.0, fact_g_total: 36.0, fact_e_total: 53.0, toi: 29.0]
# Using baseline score: pwb_subscale_score: 19.0, swb_subscale_score: 23.0, ewb_subscale_score: 23.0, fwb_subscale_score: 11.0, ecs_subscale_score: 57.8, fact_g_total: 76.0, fact_e_total: 133.8
#
# ID 275 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '6_months_postop_arm_1' '1_month_postop_arm_1']
# Baseline score: [pwb_subscale_score: 22.2, swb_subscale_score: 23.0, ewb_subscale_score: 18.0, fwb_subscale_score: 24.0, ecs_subscale_score: 41.0, fact_g_total: 87.2, fact_e_total: 128.2, toi: 87.2]
# Preop score: []
# 1-year score: [pwb_subscale_score: 23.0, swb_subscale_score: 27.0, ewb_subscale_score: 23.0, fwb_subscale_score: 18.0, ecs_subscale_score: 55.0, fact_g_total: 91.0, fact_e_total: 146.0, toi: 96.0]
# Using baseline score: pwb_subscale_score: 22.2, swb_subscale_score: 23.0, ewb_subscale_score: 18.0, fwb_subscale_score: 24.0, ecs_subscale_score: 41.0, fact_g_total: 87.2, fact_e_total: 128.2, toi: 87.2
#
# ID 307 has events: ['surgery_arm_1' 'baseline_arm_1' '6_months_postop_arm_1'
#  '1_year_postop_arm_1' 'preoperative_arm_1' '1_month_postop_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 18.0, ewb_subscale_score: 19.2, fwb_subscale_score: 11.0, ecs_subscale_score: 36.0, fact_g_total: 69.2, fact_e_total: 105.2, toi: 68.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 22.0, swb_subscale_score: 23.3, ewb_subscale_score: 19.7, fwb_subscale_score: 13.7, ecs_subscale_score: 48.8, fact_g_total: 78.7, fact_e_total: 127.5, toi: 84.5]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 18.0, ewb_subscale_score: 19.2, fwb_subscale_score: 11.0, ecs_subscale_score: 36.0, fact_g_total: 69.2, fact_e_total: 105.2, toi: 68.0
#
# ID 335 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1' '1_month_postop_arm_1']
# Baseline score: [pwb_subscale_score: 26.8, ewb_subscale_score: 6.0, fwb_subscale_score: 12.6, ecs_subscale_score: 61.0, toi: 100.4]
# Preop score: []
# 1-year score: [pwb_subscale_score: 18.7, ewb_subscale_score: 20.0, fwb_subscale_score: 15.0, ecs_subscale_score: 46.0, toi: 79.7]
# Using baseline score: pwb_subscale_score: 26.8, ewb_subscale_score: 6.0, fwb_subscale_score: 12.6, ecs_subscale_score: 61.0, toi: 100.4
#
# ID 364 has events: ['surgery_arm_1' nan 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 19.0, ewb_subscale_score: 13.0, fwb_subscale_score: 24.0, ecs_subscale_score: 57.2, fact_g_total: 83.0, fact_e_total: 140.2, toi: 108.2]
# Preop score: [pwb_subscale_score: 24.0, swb_subscale_score: 20.0, ewb_subscale_score: 22.0, fwb_subscale_score: 23.0, ecs_subscale_score: 65.0, fact_g_total: 89.0, fact_e_total: 154.0, toi: 112.0]
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 13.0, ewb_subscale_score: 19.0, fwb_subscale_score: 21.0, ecs_subscale_score: 63.0, fact_g_total: 77.0, fact_e_total: 140.0, toi: 108.0]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 19.0, ewb_subscale_score: 13.0, fwb_subscale_score: 24.0, ecs_subscale_score: 57.2, fact_g_total: 83.0, fact_e_total: 140.2, toi: 108.2
#
# ID 391 has events: ['baseline_arm_1' 'surgery_arm_1' '6_months_postop_arm_1'
#  '1_year_postop_arm_1' 'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 22.2, ewb_subscale_score: 19.2, fwb_subscale_score: 23.0, ecs_subscale_score: 63.0, fact_g_total: 90.4, fact_e_total: 153.4, toi: 112.0]
#
# ID 416 has events: ['baseline_arm_1' '1_year_postop_arm_1' 'surgery_arm_1'
#  '1_month_postop_arm_1' 'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 19.0, swb_subscale_score: 15.2, ewb_subscale_score: 11.0, fwb_subscale_score: 9.0, ecs_subscale_score: 44.0, fact_g_total: 54.2, fact_e_total: 98.2, toi: 72.0]
#
# ID 419 has events: ['1_year_postop_arm_1' 'surgery_arm_1' 'preoperative_arm_1'
#  'baseline_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 27.0, ewb_subscale_score: 9.0, fwb_subscale_score: 26.0, ecs_subscale_score: 62.0, fact_g_total: 90.0, fact_e_total: 152.0, toi: 116.0]
#
# ID 429 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 23.3, ewb_subscale_score: 24.0, fwb_subscale_score: 25.0, ecs_subscale_score: 65.0, fact_g_total: 100.3, fact_e_total: 165.3, toi: 118.0]
#
# ID 441 has events: ['1_month_postop_arm_1' 'baseline_arm_1' '1_year_postop_arm_1'
#  'surgery_arm_1' 'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 19.0, ewb_subscale_score: 8.4, fwb_subscale_score: 12.0, ecs_subscale_score: 54.0, fact_g_total: 63.4, fact_e_total: 117.4, toi: 90.0]
#
# ID 442 has events: ['preoperative_arm_1' 'surgery_arm_1' '1_month_postop_arm_1'
#  'baseline_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 28.0, swb_subscale_score: 21.0, ewb_subscale_score: 20.0, fwb_subscale_score: 24.0, ecs_subscale_score: 50.0, fact_g_total: 93.0, fact_e_total: 143.0, toi: 102.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 19.0, ewb_subscale_score: 15.0, fwb_subscale_score: 14.0, ecs_subscale_score: 45.0, fact_g_total: 68.0, fact_e_total: 113.0, toi: 79.0]
# Using baseline score: pwb_subscale_score: 28.0, swb_subscale_score: 21.0, ewb_subscale_score: 20.0, fwb_subscale_score: 24.0, ecs_subscale_score: 50.0, fact_g_total: 93.0, fact_e_total: 143.0, toi: 102.0
#
# ID 449 has events: ['1_year_postop_arm_1' 'surgery_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 25.0, swb_subscale_score: 14.0, ewb_subscale_score: 23.0, fwb_subscale_score: 17.0, ecs_subscale_score: 43.0, fact_g_total: 79.0, fact_e_total: 122.0, toi: 85.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 19.8, ewb_subscale_score: 22.0, fwb_subscale_score: 19.0, ecs_subscale_score: 56.0, fact_g_total: 86.8, fact_e_total: 142.8, toi: 101.0]
# Using baseline score: pwb_subscale_score: 25.0, swb_subscale_score: 14.0, ewb_subscale_score: 23.0, fwb_subscale_score: 17.0, ecs_subscale_score: 43.0, fact_g_total: 79.0, fact_e_total: 122.0, toi: 85.0
#
# ID 471 has events: ['1_year_postop_arm_1' 'surgery_arm_1' 'baseline_arm_1' nan
#  'preoperative_arm_1' '6_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 26.8, swb_subscale_score: 27.3, ewb_subscale_score: 19.5, fwb_subscale_score: 21.8, ecs_subscale_score: 56.5, fact_g_total: 95.4, fact_e_total: 151.9, toi: 105.1]
# Preop score: [pwb_subscale_score: 14.0, swb_subscale_score: 26.6, ewb_subscale_score: 23.0, fwb_subscale_score: 9.0, ecs_subscale_score: 43.0, fact_g_total: 72.6, fact_e_total: 115.6, toi: 66.0]
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 28.0, ewb_subscale_score: 20.0, fwb_subscale_score: 22.0, ecs_subscale_score: 59.0, fact_g_total: 95.0, fact_e_total: 154.0, toi: 106.0]
# Using baseline score: pwb_subscale_score: 26.8, swb_subscale_score: 27.3, ewb_subscale_score: 19.5, fwb_subscale_score: 21.8, ecs_subscale_score: 56.5, fact_g_total: 95.4, fact_e_total: 151.9, toi: 105.1
#
# ID 481 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 26.0, swb_subscale_score: 4.7, ewb_subscale_score: 10.0, fwb_subscale_score: 6.0, ecs_subscale_score: 49.0, fact_g_total: 46.7, fact_e_total: 95.7, toi: 81.0]
# Preop score: [pwb_subscale_score: 28.0, swb_subscale_score: 4.0, ewb_subscale_score: 11.0, fwb_subscale_score: 11.0, ecs_subscale_score: 60.0, fact_g_total: 54.0, fact_e_total: 114.0, toi: 99.0]
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 17.5, ewb_subscale_score: 14.0, fwb_subscale_score: 13.0, ecs_subscale_score: 59.0, fact_g_total: 72.5, fact_e_total: 131.5, toi: 100.0]
# Using baseline score: pwb_subscale_score: 26.0, swb_subscale_score: 4.7, ewb_subscale_score: 10.0, fwb_subscale_score: 6.0, ecs_subscale_score: 49.0, fact_g_total: 46.7, fact_e_total: 95.7, toi: 81.0
#
# ID 491 has events: ['surgery_arm_1' nan 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 23.0, swb_subscale_score: 27.0, ewb_subscale_score: 19.0, fwb_subscale_score: 20.5, ecs_subscale_score: 51.5, fact_g_total: 89.5, fact_e_total: 141.0, toi: 95.0]
#
# ID 495 has events: ['preoperative_arm_1' '1_month_postop_arm_1' 'baseline_arm_1'
#  'surgery_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 16.0, fwb_subscale_score: 24.5, ecs_subscale_score: 64.5, fact_g_total: 104.0, toi: 108.0]
# Preop score: [pwb_subscale_score: 26.0, swb_subscale_score: 18.7, ewb_subscale_score: 17.0, fwb_subscale_score: 17.0, ecs_subscale_score: 64.0, fact_g_total: 78.7, fact_e_total: 142.7, toi: 107.0]
# 1-year score: [pwb_subscale_score: 27.0, swb_subscale_score: 26.0, ewb_subscale_score: 22.0, fwb_subscale_score: 23.0, ecs_subscale_score: 63.4, fact_g_total: 98.0, fact_e_total: 161.4, toi: 113.4]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 16.0, fwb_subscale_score: 24.5, ecs_subscale_score: 64.5, fact_g_total: 104.0, toi: 108.0
#
# ID 501 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 26.5, swb_subscale_score: 23.2, ewb_subscale_score: 15.5, fwb_subscale_score: 21.5, ecs_subscale_score: 59.5, fact_g_total: 86.8, fact_e_total: 146.2, toi: 107.5]
# Preop score: []
# 1-year score: [pwb_subscale_score: 23.0, swb_subscale_score: 27.0, ewb_subscale_score: 21.0, fwb_subscale_score: 20.0, ecs_subscale_score: 55.0, fact_g_total: 91.0, fact_e_total: 146.0, toi: 98.0]
# Using baseline score: pwb_subscale_score: 26.5, swb_subscale_score: 23.2, ewb_subscale_score: 15.5, fwb_subscale_score: 21.5, ecs_subscale_score: 59.5, fact_g_total: 86.8, fact_e_total: 146.2, toi: 107.5
#
# ID 505 has events: ['preoperative_arm_1' 'surgery_arm_1' 'baseline_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 16.3, swb_subscale_score: 18.3, ewb_subscale_score: 14.0, fwb_subscale_score: 9.5, ecs_subscale_score: 47.0, fact_g_total: 58.2, fact_e_total: 105.2, toi: 72.8]
# Preop score: []
# 1-year score: [pwb_subscale_score: 19.0, swb_subscale_score: 12.0, ewb_subscale_score: 9.0, fwb_subscale_score: 8.0, ecs_subscale_score: 50.0, fact_g_total: 48.0, fact_e_total: 98.0, toi: 77.0]
# Using baseline score: pwb_subscale_score: 16.3, swb_subscale_score: 18.3, ewb_subscale_score: 14.0, fwb_subscale_score: 9.5, ecs_subscale_score: 47.0, fact_g_total: 58.2, fact_e_total: 105.2, toi: 72.8
#
# ID 508 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 16.3, ewb_subscale_score: 14.0, fwb_subscale_score: 11.0, ecs_subscale_score: 39.0, fact_g_total: 62.3, fact_e_total: 101.3, toi: 71.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 19.0, ewb_subscale_score: 10.0, fwb_subscale_score: 11.0, ecs_subscale_score: 44.0, fact_g_total: 60.0, fact_e_total: 104.0, toi: 75.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 16.3, ewb_subscale_score: 14.0, fwb_subscale_score: 11.0, ecs_subscale_score: 39.0, fact_g_total: 62.3, fact_e_total: 101.3, toi: 71.0
#
# ID 512 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 19.8, ewb_subscale_score: 11.0, fwb_subscale_score: 21.0, ecs_subscale_score: 34.0, fact_g_total: 75.8, fact_e_total: 109.8, toi: 79.0]
#
# ID 513 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 7.0, swb_subscale_score: 26.8, ewb_subscale_score: 4.0, fwb_subscale_score: 7.0, ecs_subscale_score: 39.3, fact_g_total: 44.8, fact_e_total: 84.1, toi: 53.3]
# Preop score: []
# 1-year score: [pwb_subscale_score: 8.0, swb_subscale_score: 19.8, ewb_subscale_score: 4.0, fwb_subscale_score: 2.0, ecs_subscale_score: 35.0, fact_g_total: 33.8, fact_e_total: 68.8, toi: 45.0]
# Using baseline score: pwb_subscale_score: 7.0, swb_subscale_score: 26.8, ewb_subscale_score: 4.0, fwb_subscale_score: 7.0, ecs_subscale_score: 39.3, fact_g_total: 44.8, fact_e_total: 84.1, toi: 53.3
#
# ID 521 has events: ['preoperative_arm_1' 'baseline_arm_1' '1_month_postop_arm_1'
#  '1_year_postop_arm_1' 'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 16.3, swb_subscale_score: 19.0, ewb_subscale_score: 16.0, fwb_subscale_score: 15.0, ecs_subscale_score: 51.0, fact_g_total: 66.3, fact_e_total: 117.3, toi: 82.3]
# Preop score: [pwb_subscale_score: 15.5, swb_subscale_score: 24.3, ewb_subscale_score: 18.0, fwb_subscale_score: 18.5, ecs_subscale_score: 54.5, fact_g_total: 76.3, fact_e_total: 130.8, toi: 88.5]
# 1-year score: [pwb_subscale_score: 14.0, swb_subscale_score: 28.0, ewb_subscale_score: 23.0, fwb_subscale_score: 18.0, ecs_subscale_score: 46.0, fact_g_total: 83.0, fact_e_total: 129.0, toi: 78.0]
# Using baseline score: pwb_subscale_score: 16.3, swb_subscale_score: 19.0, ewb_subscale_score: 16.0, fwb_subscale_score: 15.0, ecs_subscale_score: 51.0, fact_g_total: 66.3, fact_e_total: 117.3, toi: 82.3
#
# ID 525 has events: ['6_months_postop_arm_1' '3_months_postop_arm_1' 'surgery_arm_1'
#  'preoperative_arm_1' '1_year_postop_arm_1' 'baseline_arm_1']
# Baseline score: [pwb_subscale_score: 12.0, swb_subscale_score: 27.4, ewb_subscale_score: 6.0, fwb_subscale_score: 4.0, ecs_subscale_score: 31.0, fact_g_total: 49.4, fact_e_total: 80.4, toi: 47.0]
# Preop score: [pwb_subscale_score: 13.0, swb_subscale_score: 24.5, ewb_subscale_score: 14.0, fwb_subscale_score: 7.0, ecs_subscale_score: 58.0, fact_g_total: 58.5, fact_e_total: 116.5, toi: 78.0]
# 1-year score: [pwb_subscale_score: 21.0, swb_subscale_score: 28.0, ecs_subscale_score: 22.0]
# Using baseline score: pwb_subscale_score: 12.0, swb_subscale_score: 27.4, ewb_subscale_score: 6.0, fwb_subscale_score: 4.0, ecs_subscale_score: 31.0, fact_g_total: 49.4, fact_e_total: 80.4, toi: 47.0
#
# ID 533 has events: ['preoperative_arm_1' nan 'surgery_arm_1' 'baseline_arm_1'
#  '3_months_postop_arm_1' '1_year_postop_arm_1' '6_months_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 24.0, ewb_subscale_score: 20.0, fwb_subscale_score: 21.0, ecs_subscale_score: 53.0, fact_g_total: 90.0, fact_e_total: 143.0, toi: 99.0]
#
# ID 536 has events: ['preoperative_arm_1' 'surgery_arm_1' '3_months_postop_arm_1'
#  'baseline_arm_1' '1_year_postop_arm_1' '1_month_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.7, swb_subscale_score: 15.6, ewb_subscale_score: 18.0, fwb_subscale_score: 13.7, ecs_subscale_score: 46.7, fact_g_total: 70.9, fact_e_total: 117.6, toi: 84.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 13.0, ewb_subscale_score: 19.0, fwb_subscale_score: 11.0, ecs_subscale_score: 47.8, fact_g_total: 69.0, fact_e_total: 116.8, toi: 84.8]
# Using baseline score: pwb_subscale_score: 23.7, swb_subscale_score: 15.6, ewb_subscale_score: 18.0, fwb_subscale_score: 13.7, ecs_subscale_score: 46.7, fact_g_total: 70.9, fact_e_total: 117.6, toi: 84.0
#
# ID 537 has events: ['baseline_arm_1' 'preoperative_arm_1' '3_months_postop_arm_1'
#  '1_year_postop_arm_1' 'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 22.0, swb_subscale_score: 18.7, ewb_subscale_score: 12.0, fwb_subscale_score: 13.0, ecs_subscale_score: 46.5, fact_g_total: 65.7, fact_e_total: 112.2, toi: 81.5]
# Preop score: [pwb_subscale_score: 22.5, swb_subscale_score: 24.5, ewb_subscale_score: 19.0, fwb_subscale_score: 22.5, ecs_subscale_score: 62.5, fact_g_total: 88.5, fact_e_total: 151.0, toi: 107.5]
# 1-year score: [pwb_subscale_score: 23.0, swb_subscale_score: 23.0, ewb_subscale_score: 20.0, fwb_subscale_score: 19.0, ecs_subscale_score: 56.0, fact_g_total: 85.0, fact_e_total: 141.0, toi: 98.0]
# Using baseline score: pwb_subscale_score: 22.0, swb_subscale_score: 18.7, ewb_subscale_score: 12.0, fwb_subscale_score: 13.0, ecs_subscale_score: 46.5, fact_g_total: 65.7, fact_e_total: 112.2, toi: 81.5
#
# ID 539 has events: ['baseline_arm_1' 'preoperative_arm_1' '1_year_postop_arm_1'
#  'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 26.4, ewb_subscale_score: 18.5, fwb_subscale_score: 24.5, ecs_subscale_score: 48.5, fact_g_total: 96.4, fact_e_total: 144.9, toi: 100.0]
# Preop score: [pwb_subscale_score: 23.5, swb_subscale_score: 24.0, ewb_subscale_score: 22.0, fwb_subscale_score: 23.0, ecs_subscale_score: 61.5, fact_g_total: 92.5, fact_e_total: 154.0, toi: 108.0]
# 1-year score: [pwb_subscale_score: 23.3, swb_subscale_score: 25.0, ewb_subscale_score: 22.0, fwb_subscale_score: 22.0, ecs_subscale_score: 58.0, fact_g_total: 92.3, fact_e_total: 150.3, toi: 103.3]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 26.4, ewb_subscale_score: 18.5, fwb_subscale_score: 24.5, ecs_subscale_score: 48.5, fact_g_total: 96.4, fact_e_total: 144.9, toi: 100.0
#
# ID 543 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.0, swb_subscale_score: 22.0, ewb_subscale_score: 20.0, fwb_subscale_score: 13.0, ecs_subscale_score: 49.0, fact_g_total: 79.0, fact_e_total: 128.0, toi: 86.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 20.0, ewb_subscale_score: 21.0, fwb_subscale_score: 20.0, ecs_subscale_score: 59.0, fact_g_total: 89.0, fact_e_total: 148.0, toi: 107.0]
# Using baseline score: pwb_subscale_score: 24.0, swb_subscale_score: 22.0, ewb_subscale_score: 20.0, fwb_subscale_score: 13.0, ecs_subscale_score: 49.0, fact_g_total: 79.0, fact_e_total: 128.0, toi: 86.0
#
# ID 549 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'preoperative_arm_1'
#  'baseline_arm_1' '3_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.3, swb_subscale_score: 27.0, ewb_subscale_score: 20.3, fwb_subscale_score: 19.0, ecs_subscale_score: 49.0, fact_g_total: 93.7, fact_e_total: 142.5, toi: 96.0]
# Preop score: [pwb_subscale_score: 25.0, swb_subscale_score: 27.0, ewb_subscale_score: 24.0, fwb_subscale_score: 12.0, ecs_subscale_score: 58.0, fact_g_total: 88.0, fact_e_total: 146.0, toi: 95.0]
# 1-year score: [pwb_subscale_score: 21.0, swb_subscale_score: 25.0, ewb_subscale_score: 20.0, fwb_subscale_score: 17.0, ecs_subscale_score: 40.1, fact_g_total: 83.0, fact_e_total: 123.1, toi: 78.1]
# Using baseline score: pwb_subscale_score: 27.3, swb_subscale_score: 27.0, ewb_subscale_score: 20.3, fwb_subscale_score: 19.0, ecs_subscale_score: 49.0, fact_g_total: 93.7, fact_e_total: 142.5, toi: 96.0
#
# ID 551 has events: ['surgery_arm_1' 'preoperative_arm_1' 'baseline_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.5, swb_subscale_score: 28.0, ewb_subscale_score: 20.0, fwb_subscale_score: 25.0, ecs_subscale_score: 68.0, fact_g_total: 100.5, fact_e_total: 168.5, toi: 120.5]
# Preop score: [pwb_subscale_score: 25.0, swb_subscale_score: 28.0, ewb_subscale_score: 20.5, fwb_subscale_score: 26.0, ecs_subscale_score: 65.5, fact_g_total: 99.5, fact_e_total: 165.0, toi: 116.5]
# 1-year score: [pwb_subscale_score: 27.0, swb_subscale_score: 24.0, ewb_subscale_score: 23.0, fwb_subscale_score: 27.0, ecs_subscale_score: 54.0, fact_g_total: 101.0, fact_e_total: 155.0, toi: 108.0]
# Using baseline score: pwb_subscale_score: 27.5, swb_subscale_score: 28.0, ewb_subscale_score: 20.0, fwb_subscale_score: 25.0, ecs_subscale_score: 68.0, fact_g_total: 100.5, fact_e_total: 168.5, toi: 120.5
#
# ID 557 has events: ['surgery_arm_1' '1_year_postop_arm_1' '6_months_postop_arm_1'
#  'baseline_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 28.0, swb_subscale_score: 19.6, ewb_subscale_score: 22.0, fwb_subscale_score: 21.0, ecs_subscale_score: 59.0, fact_g_total: 90.6, fact_e_total: 149.6, toi: 108.0]
# Preop score: [pwb_subscale_score: 25.7, swb_subscale_score: 14.0, ewb_subscale_score: 24.0, fwb_subscale_score: 24.0, ecs_subscale_score: 59.0, fact_g_total: 87.7, fact_e_total: 146.7, toi: 108.7]
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 23.8, ewb_subscale_score: 21.0, fwb_subscale_score: 24.0, ecs_subscale_score: 51.0, fact_g_total: 96.8, fact_e_total: 147.8, toi: 103.0]
# Using baseline score: pwb_subscale_score: 28.0, swb_subscale_score: 19.6, ewb_subscale_score: 22.0, fwb_subscale_score: 21.0, ecs_subscale_score: 59.0, fact_g_total: 90.6, fact_e_total: 149.6, toi: 108.0
#
# ID 579 has events: ['surgery_arm_1' 'preoperative_arm_1' nan 'baseline_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 8.0, swb_subscale_score: 22.0, ewb_subscale_score: 5.0, fwb_subscale_score: 7.0, ecs_subscale_score: 30.0, fact_g_total: 42.0, fact_e_total: 72.0, toi: 45.0]
# Preop score: [pwb_subscale_score: 9.0, swb_subscale_score: 27.0, ewb_subscale_score: 24.0, fwb_subscale_score: 6.0, ecs_subscale_score: 47.0, fact_g_total: 66.0, fact_e_total: 113.0, toi: 62.0]
# 1-year score: [pwb_subscale_score: 18.0, swb_subscale_score: 23.3, ewb_subscale_score: 18.0, fwb_subscale_score: 16.3, ecs_subscale_score: 43.0, fact_g_total: 75.7, fact_e_total: 118.7, toi: 77.3]
# Using baseline score: pwb_subscale_score: 8.0, swb_subscale_score: 22.0, ewb_subscale_score: 5.0, fwb_subscale_score: 7.0, ecs_subscale_score: 30.0, fact_g_total: 42.0, fact_e_total: 72.0, toi: 45.0
#
# ID 589 has events: ['preoperative_arm_1' 'surgery_arm_1' '6_months_postop_arm_1' nan
#  '1_month_postop_arm_1' 'baseline_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 27.0, ewb_subscale_score: 16.0, fwb_subscale_score: 26.0, ecs_subscale_score: 37.0, fact_g_total: 90.0, fact_e_total: 127.0, toi: 84.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 20.0, ewb_subscale_score: 18.0, fwb_subscale_score: 23.0, ecs_subscale_score: 56.0, fact_g_total: 86.0, fact_e_total: 142.0, toi: 104.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 27.0, ewb_subscale_score: 16.0, fwb_subscale_score: 26.0, ecs_subscale_score: 37.0, fact_g_total: 90.0, fact_e_total: 127.0, toi: 84.0
#
# ID 592 has events: [nan 'surgery_arm_1' '1_year_postop_arm_1' '1_month_postop_arm_1'
#  'preoperative_arm_1' 'baseline_arm_1']
# Baseline score: [pwb_subscale_score: 26.0, swb_subscale_score: 23.0, ewb_subscale_score: 21.0, fwb_subscale_score: 13.0, ecs_subscale_score: 49.0, fact_g_total: 83.0, fact_e_total: 132.0, toi: 88.0]
# Preop score: [pwb_subscale_score: 26.0, swb_subscale_score: 25.0, ewb_subscale_score: 22.0, fwb_subscale_score: 21.0, ecs_subscale_score: 49.0, fact_g_total: 94.0, fact_e_total: 143.0, toi: 96.0]
# 1-year score: [pwb_subscale_score: 17.0, swb_subscale_score: 23.0, ewb_subscale_score: 17.0, fwb_subscale_score: 13.0, ecs_subscale_score: 39.0, fact_g_total: 70.0, fact_e_total: 109.0, toi: 69.0]
# Using baseline score: pwb_subscale_score: 26.0, swb_subscale_score: 23.0, ewb_subscale_score: 21.0, fwb_subscale_score: 13.0, ecs_subscale_score: 49.0, fact_g_total: 83.0, fact_e_total: 132.0, toi: 88.0
#
# ID 596 has events: ['1_year_postop_arm_1' 'baseline_arm_1' 'surgery_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 14.0, swb_subscale_score: 8.2, ewb_subscale_score: 8.0, fwb_subscale_score: 5.6, ecs_subscale_score: 31.0, fact_g_total: 35.8, fact_e_total: 66.8, toi: 50.6]
#
# ID 597 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '3_months_postop_arm_1' '1_month_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 15.2, swb_subscale_score: 19.0, ewb_subscale_score: 16.0, fwb_subscale_score: 12.0, ecs_subscale_score: 53.0, fact_g_total: 62.2, fact_e_total: 115.2, toi: 80.2]
#
# ID 613 has events: ['baseline_arm_1' 'preoperative_arm_1' '3_months_postop_arm_1'
#  '1_year_postop_arm_1' 'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 27.0, ewb_subscale_score: 13.0, fwb_subscale_score: 17.0, ecs_subscale_score: 36.0, fact_g_total: 78.0, fact_e_total: 114.0, toi: 74.0]
# Preop score: [pwb_subscale_score: 21.0, swb_subscale_score: 27.0, ewb_subscale_score: 13.0, fwb_subscale_score: 17.0, ecs_subscale_score: 36.0, fact_g_total: 78.0, fact_e_total: 114.0, toi: 74.0]
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 28.0, ewb_subscale_score: 24.0, fwb_subscale_score: 27.0, ecs_subscale_score: 64.0, fact_g_total: 104.0, fact_e_total: 168.0, toi: 116.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 27.0, ewb_subscale_score: 13.0, fwb_subscale_score: 17.0, ecs_subscale_score: 36.0, fact_g_total: 78.0, fact_e_total: 114.0, toi: 74.0
#
# ID 629 has events: ['surgery_arm_1' 'preoperative_arm_1' 'baseline_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.5, swb_subscale_score: 26.8, ewb_subscale_score: 18.0, fwb_subscale_score: 22.0, ecs_subscale_score: 60.0, fact_g_total: 91.3, fact_e_total: 151.3, toi: 106.5]
# Preop score: [pwb_subscale_score: 24.0, swb_subscale_score: 28.0, ewb_subscale_score: 17.0, fwb_subscale_score: 18.0, ecs_subscale_score: 54.0, fact_g_total: 87.0, fact_e_total: 141.0, toi: 96.0]
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 25.7, ewb_subscale_score: 21.0, fwb_subscale_score: 20.0, ecs_subscale_score: 52.0, fact_g_total: 91.7, fact_e_total: 143.7, toi: 97.0]
# Using baseline score: pwb_subscale_score: 24.5, swb_subscale_score: 26.8, ewb_subscale_score: 18.0, fwb_subscale_score: 22.0, ecs_subscale_score: 60.0, fact_g_total: 91.3, fact_e_total: 151.3, toi: 106.5
#
# ID 634 has events: ['6_months_postop_arm_1' nan 'surgery_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 19.0, swb_subscale_score: 18.5, ewb_subscale_score: 14.0, fwb_subscale_score: 12.0, ecs_subscale_score: 42.0, fact_g_total: 63.5, fact_e_total: 105.5, toi: 73.0]
# Preop score: [pwb_subscale_score: 21.0, swb_subscale_score: 23.0, ewb_subscale_score: 18.0, fwb_subscale_score: 19.0, ecs_subscale_score: 45.0, fact_g_total: 81.0, fact_e_total: 126.0, toi: 85.0]
# 1-year score: [pwb_subscale_score: 9.0, swb_subscale_score: 22.0, ewb_subscale_score: 13.0, fwb_subscale_score: 13.0, ecs_subscale_score: 24.0, fact_g_total: 57.0, fact_e_total: 81.0, toi: 46.0]
# Using baseline score: pwb_subscale_score: 19.0, swb_subscale_score: 18.5, ewb_subscale_score: 14.0, fwb_subscale_score: 12.0, ecs_subscale_score: 42.0, fact_g_total: 63.5, fact_e_total: 105.5, toi: 73.0
#
# ID 644 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '3_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 25.0, swb_subscale_score: 21.0, ewb_subscale_score: 14.0, fwb_subscale_score: 19.0, ecs_subscale_score: 48.0, fact_g_total: 79.0, fact_e_total: 127.0, toi: 92.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 21.0, ewb_subscale_score: 21.0, fwb_subscale_score: 15.0, ecs_subscale_score: 53.0, fact_g_total: 83.0, fact_e_total: 136.0, toi: 94.0]
# Using baseline score: pwb_subscale_score: 25.0, swb_subscale_score: 21.0, ewb_subscale_score: 14.0, fwb_subscale_score: 19.0, ecs_subscale_score: 48.0, fact_g_total: 79.0, fact_e_total: 127.0, toi: 92.0
#
# ID 649 has events: ['3_months_postop_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1' 'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 26.0, swb_subscale_score: 21.0, ewb_subscale_score: 6.2, fwb_subscale_score: 16.0, ecs_subscale_score: 48.5, fact_g_total: 75.0, fact_e_total: 126.0, toi: 90.5]
# Preop score: [pwb_subscale_score: 21.0, swb_subscale_score: 18.7, ewb_subscale_score: 14.0, fwb_subscale_score: 17.0, ecs_subscale_score: 57.0, fact_g_total: 70.7, fact_e_total: 127.7, toi: 95.0]
# 1-year score: []
# Using baseline score: pwb_subscale_score: 26.0, swb_subscale_score: 21.0, ewb_subscale_score: 6.2, fwb_subscale_score: 16.0, ecs_subscale_score: 48.5, fact_g_total: 75.0, fact_e_total: 126.0, toi: 90.5
#
# ID 659 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 22.5, ewb_subscale_score: 20.5, fwb_subscale_score: 13.5, ecs_subscale_score: 59.5, fact_g_total: 79.5, fact_e_total: 139.0, toi: 96.0]
# Preop score: [pwb_subscale_score: 13.0, swb_subscale_score: 22.0, ewb_subscale_score: 22.0, fwb_subscale_score: 13.0, ecs_subscale_score: 65.0, fact_g_total: 70.0, fact_e_total: 135.0, toi: 91.0]
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 24.0, ewb_subscale_score: 7.0, fwb_subscale_score: 5.0, ecs_subscale_score: 58.0, fact_g_total: 56.0, fact_e_total: 114.0, toi: 83.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 22.5, ewb_subscale_score: 20.5, fwb_subscale_score: 13.5, ecs_subscale_score: 59.5, fact_g_total: 79.5, fact_e_total: 139.0, toi: 96.0
#
# ID 663 has events: ['6_months_postop_arm_1' 'surgery_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.3, swb_subscale_score: 22.2, ewb_subscale_score: 14.0, fwb_subscale_score: 12.0, ecs_subscale_score: 32.9, fact_g_total: 71.5, fact_e_total: 104.4, toi: 68.2]
# Preop score: [pwb_subscale_score: 7.0, swb_subscale_score: 23.0, ewb_subscale_score: 8.0, fwb_subscale_score: 10.0, ecs_subscale_score: 50.0, fact_g_total: 48.0, fact_e_total: 98.0, toi: 67.0]
# 1-year score: [pwb_subscale_score: 17.0, swb_subscale_score: 23.0, ewb_subscale_score: 10.0, fwb_subscale_score: 14.0, ecs_subscale_score: 51.0, fact_g_total: 64.0, fact_e_total: 115.0, toi: 82.0]
# Using baseline score: pwb_subscale_score: 23.3, swb_subscale_score: 22.2, ewb_subscale_score: 14.0, fwb_subscale_score: 12.0, ecs_subscale_score: 32.9, fact_g_total: 71.5, fact_e_total: 104.4, toi: 68.2
#
# ID 665 has events: ['6_months_postop_arm_1' nan 'surgery_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 13.0, swb_subscale_score: 17.0, ewb_subscale_score: 11.0, fwb_subscale_score: 8.0, ecs_subscale_score: 50.0, fact_g_total: 49.0, fact_e_total: 99.0, toi: 71.0]
# Preop score: [pwb_subscale_score: 10.0, swb_subscale_score: 16.0, ewb_subscale_score: 11.0, fwb_subscale_score: 3.0, ecs_subscale_score: 30.8, fact_g_total: 40.0, fact_e_total: 70.8, toi: 43.8]
# 1-year score: [pwb_subscale_score: 18.0, swb_subscale_score: 24.0, ewb_subscale_score: 14.0, fwb_subscale_score: 10.0, ecs_subscale_score: 32.0, fact_g_total: 66.0, fact_e_total: 98.0, toi: 60.0]
# Using baseline score: pwb_subscale_score: 13.0, swb_subscale_score: 17.0, ewb_subscale_score: 11.0, fwb_subscale_score: 8.0, ecs_subscale_score: 50.0, fact_g_total: 49.0, fact_e_total: 99.0, toi: 71.0
#
# ID 668 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 22.0, swb_subscale_score: 21.0, ewb_subscale_score: 22.0, fwb_subscale_score: 19.0, ecs_subscale_score: 53.0, fact_g_total: 84.0, fact_e_total: 137.0, toi: 94.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 8.0, swb_subscale_score: 12.0, ewb_subscale_score: 12.0, fwb_subscale_score: 9.0, ecs_subscale_score: 37.4, fact_g_total: 41.0, fact_e_total: 78.4, toi: 54.4]
# Using baseline score: pwb_subscale_score: 22.0, swb_subscale_score: 21.0, ewb_subscale_score: 22.0, fwb_subscale_score: 19.0, ecs_subscale_score: 53.0, fact_g_total: 84.0, fact_e_total: 137.0, toi: 94.0
#
# ID 671 has events: ['preoperative_arm_1' nan 'baseline_arm_1' 'surgery_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 25.0, swb_subscale_score: 14.0, ewb_subscale_score: 17.0, fwb_subscale_score: 19.0, ecs_subscale_score: 51.0, fact_g_total: 75.0, fact_e_total: 126.0, toi: 95.0]
# Preop score: [pwb_subscale_score: 14.5, swb_subscale_score: 17.5, ewb_subscale_score: 13.5, fwb_subscale_score: 8.2, ecs_subscale_score: 37.5, fact_g_total: 53.7, fact_e_total: 91.2, toi: 60.2]
# 1-year score: [pwb_subscale_score: 22.0, swb_subscale_score: 26.0, ewb_subscale_score: 21.0, fwb_subscale_score: 17.0, ecs_subscale_score: 54.0, fact_g_total: 86.0, fact_e_total: 140.0, toi: 93.0]
# Using baseline score: pwb_subscale_score: 25.0, swb_subscale_score: 14.0, ewb_subscale_score: 17.0, fwb_subscale_score: 19.0, ecs_subscale_score: 51.0, fact_g_total: 75.0, fact_e_total: 126.0, toi: 95.0
#
# ID 673 has events: ['3_months_postop_arm_1' 'surgery_arm_1' '1_year_postop_arm_1'
#  'baseline_arm_1' 'preoperative_arm_1' '1_month_postop_arm_1'
#  '6_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 26.0, ewb_subscale_score: 19.0, fwb_subscale_score: 26.0, ecs_subscale_score: 43.0, fact_g_total: 94.0, fact_e_total: 137.0, toi: 92.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 18.0, swb_subscale_score: 15.0, ewb_subscale_score: 16.0, fwb_subscale_score: 13.0, ecs_subscale_score: 44.0, fact_g_total: 62.0, fact_e_total: 106.0, toi: 75.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 26.0, ewb_subscale_score: 19.0, fwb_subscale_score: 26.0, ecs_subscale_score: 43.0, fact_g_total: 94.0, fact_e_total: 137.0, toi: 92.0
#
# ID 682 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'preoperative_arm_1'
#  'baseline_arm_1']
# Baseline score: [pwb_subscale_score: 28.0, swb_subscale_score: 26.6, ewb_subscale_score: 24.0, fwb_subscale_score: 28.0, ecs_subscale_score: 58.0, fact_g_total: 106.6, fact_e_total: 164.6, toi: 114.0]
# Preop score: [pwb_subscale_score: 16.0, swb_subscale_score: 22.2, ewb_subscale_score: 20.0, fwb_subscale_score: 12.0, ecs_subscale_score: 52.0, fact_g_total: 70.2, fact_e_total: 122.2, toi: 80.0]
# 1-year score: [pwb_subscale_score: 13.0, swb_subscale_score: 9.0, ewb_subscale_score: 16.0, fwb_subscale_score: 9.0, ecs_subscale_score: 30.0, fact_g_total: 47.0, fact_e_total: 77.0, toi: 52.0]
# Using baseline score: pwb_subscale_score: 28.0, swb_subscale_score: 26.6, ewb_subscale_score: 24.0, fwb_subscale_score: 28.0, ecs_subscale_score: 58.0, fact_g_total: 106.6, fact_e_total: 164.6, toi: 114.0
#
# ID 689 has events: ['baseline_arm_1' 'surgery_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 27.0, ewb_subscale_score: 24.0, fwb_subscale_score: 20.0, ecs_subscale_score: 53.0, fact_g_total: 97.0, fact_e_total: 150.0, toi: 99.0]
#
# ID 690 has events: ['1_year_postop_arm_1' '6_months_postop_arm_1' 'surgery_arm_1'
#  'baseline_arm_1' 'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 24.0, ewb_subscale_score: 22.0, fwb_subscale_score: 26.0, ecs_subscale_score: 60.0, fact_g_total: 98.0, fact_e_total: 158.0, toi: 112.0]
#
# ID 695 has events: ['1_month_postop_arm_1' 'surgery_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 22.4, ewb_subscale_score: 22.0, fwb_subscale_score: 27.0, ecs_subscale_score: 44.0, fact_g_total: 98.4, fact_e_total: 142.4, toi: 98.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 22.0, swb_subscale_score: 28.0, ewb_subscale_score: 15.0, fwb_subscale_score: 6.0, ecs_subscale_score: 50.0, fact_g_total: 71.0, fact_e_total: 121.0, toi: 78.0]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 22.4, ewb_subscale_score: 22.0, fwb_subscale_score: 27.0, ecs_subscale_score: 44.0, fact_g_total: 98.4, fact_e_total: 142.4, toi: 98.0
#
# ID 698 has events: ['baseline_arm_1' 'surgery_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1' '6_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 26.0, ewb_subscale_score: 11.0, fwb_subscale_score: 25.0, ecs_subscale_score: 50.0, fact_g_total: 85.0, fact_e_total: 135.0, toi: 98.0]
# Preop score: [pwb_subscale_score: 22.0, swb_subscale_score: 26.0, ewb_subscale_score: 17.0, fwb_subscale_score: 16.0, ecs_subscale_score: 56.0, fact_g_total: 81.0, fact_e_total: 137.0, toi: 94.0]
# 1-year score: [pwb_subscale_score: 18.0, swb_subscale_score: 26.0, ewb_subscale_score: 16.0, fwb_subscale_score: 22.0, ecs_subscale_score: 47.0, fact_g_total: 82.0, fact_e_total: 129.0, toi: 87.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 26.0, ewb_subscale_score: 11.0, fwb_subscale_score: 25.0, ecs_subscale_score: 50.0, fact_g_total: 85.0, fact_e_total: 135.0, toi: 98.0
#
# ID 702 has events: ['surgery_arm_1' 'baseline_arm_1' '1_month_postop_arm_1'
#  '1_year_postop_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 17.0, swb_subscale_score: 19.8, ewb_subscale_score: 13.0, fwb_subscale_score: 9.0, ecs_subscale_score: 43.0, fact_g_total: 58.8, fact_e_total: 101.8, toi: 69.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 24.0, ewb_subscale_score: 12.0, fwb_subscale_score: 10.0, ecs_subscale_score: 46.0, fact_g_total: 66.0, fact_e_total: 112.0, toi: 76.0]
# Using baseline score: pwb_subscale_score: 17.0, swb_subscale_score: 19.8, ewb_subscale_score: 13.0, fwb_subscale_score: 9.0, ecs_subscale_score: 43.0, fact_g_total: 58.8, fact_e_total: 101.8, toi: 69.0
#
# ID 704 has events: ['surgery_arm_1' 'baseline_arm_1' '1_year_postop_arm_1'
#  'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 19.0, swb_subscale_score: 13.0, ewb_subscale_score: 16.0, fwb_subscale_score: 18.0, ecs_subscale_score: 41.4, fact_g_total: 66.0, fact_e_total: 107.4, toi: 78.4]
# Preop score: []
# 1-year score: [pwb_subscale_score: 19.0, swb_subscale_score: 22.0, ewb_subscale_score: 22.0, fwb_subscale_score: 11.0, ecs_subscale_score: 41.0, fact_g_total: 74.0, fact_e_total: 115.0, toi: 71.0]
# Using baseline score: pwb_subscale_score: 19.0, swb_subscale_score: 13.0, ewb_subscale_score: 16.0, fwb_subscale_score: 18.0, ecs_subscale_score: 41.4, fact_g_total: 66.0, fact_e_total: 107.4, toi: 78.4
#
# ID 706 has events: ['surgery_arm_1' 'preoperative_arm_1' 'baseline_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 7.0, swb_subscale_score: 12.6, ewb_subscale_score: 12.0, fwb_subscale_score: 4.0, ecs_subscale_score: 44.6, fact_g_total: 35.6, fact_e_total: 80.2, toi: 55.6]
# Preop score: [pwb_subscale_score: 11.0, swb_subscale_score: 18.7, ewb_subscale_score: 13.0, fwb_subscale_score: 7.0, ecs_subscale_score: 53.0, fact_g_total: 49.7, fact_e_total: 102.7, toi: 71.0]
# 1-year score: [pwb_subscale_score: 14.0, swb_subscale_score: 14.0, ewb_subscale_score: 19.0, fwb_subscale_score: 10.0, fact_g_total: 57.0]
# Using baseline score: pwb_subscale_score: 7.0, swb_subscale_score: 12.6, ewb_subscale_score: 12.0, fwb_subscale_score: 4.0, ecs_subscale_score: 44.6, fact_g_total: 35.6, fact_e_total: 80.2, toi: 55.6
#
# ID 708 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '3_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.5, swb_subscale_score: 18.2, ewb_subscale_score: 17.0, fwb_subscale_score: 22.0, ecs_subscale_score: 57.0, fact_g_total: 81.7, fact_e_total: 138.7, toi: 103.5]
# Preop score: [pwb_subscale_score: 23.0, swb_subscale_score: 21.0, ewb_subscale_score: 18.0, fwb_subscale_score: 18.0, ecs_subscale_score: 63.0, fact_g_total: 80.0, fact_e_total: 143.0, toi: 104.0]
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 20.0, ewb_subscale_score: 19.0, fwb_subscale_score: 21.0, ecs_subscale_score: 48.0, fact_g_total: 85.0, fact_e_total: 133.0, toi: 94.0]
# Using baseline score: pwb_subscale_score: 24.5, swb_subscale_score: 18.2, ewb_subscale_score: 17.0, fwb_subscale_score: 22.0, ecs_subscale_score: 57.0, fact_g_total: 81.7, fact_e_total: 138.7, toi: 103.5
#
# ID 712 has events: ['surgery_arm_1' '1_year_postop_arm_1' '6_months_postop_arm_1'
#  '3_months_postop_arm_1' 'baseline_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 2.8, swb_subscale_score: 26.8, ewb_subscale_score: 11.0, fwb_subscale_score: 4.0, ecs_subscale_score: 24.4, fact_g_total: 44.6, fact_e_total: 69.1, toi: 31.2]
# Preop score: []
# 1-year score: [pwb_subscale_score: 15.0, swb_subscale_score: 22.2, ewb_subscale_score: 16.0, fwb_subscale_score: 8.0, ecs_subscale_score: 52.0, fact_g_total: 61.2, fact_e_total: 113.2, toi: 75.0]
# Using baseline score: pwb_subscale_score: 2.8, swb_subscale_score: 26.8, ewb_subscale_score: 11.0, fwb_subscale_score: 4.0, ecs_subscale_score: 24.4, fact_g_total: 44.6, fact_e_total: 69.1, toi: 31.2
#
# ID 718 has events: ['baseline_arm_1' 'surgery_arm_1' '1_year_postop_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 16.0, swb_subscale_score: 21.0, ewb_subscale_score: 23.0, fwb_subscale_score: 18.0, ecs_subscale_score: 51.0, fact_g_total: 78.0, fact_e_total: 129.0, toi: 85.0]
#
# ID 725 has events: ['1_year_postop_arm_1' 'surgery_arm_1' nan 'baseline_arm_1'
#  'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 18.0, swb_subscale_score: 28.0, ewb_subscale_score: 21.0, fwb_subscale_score: 23.0, ecs_subscale_score: 62.0, fact_g_total: 90.0, fact_e_total: 152.0, toi: 103.0]
#
# ID 730 has events: ['baseline_arm_1' 'surgery_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 28.0, ewb_subscale_score: 24.0, fwb_subscale_score: 27.0, ecs_subscale_score: 61.0, fact_g_total: 105.0, fact_e_total: 166.0, toi: 114.0]
#
# ...
# Baseline score: [pwb_subscale_score: 18.7, swb_subscale_score: 21.0, ewb_subscale_score: 18.0, fwb_subscale_score: 17.0, ecs_subscale_score: 33.0, fact_g_total: 74.7, fact_e_total: 107.7, toi: 68.7]
# Preop score: []
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 23.5, ewb_subscale_score: 23.5, fwb_subscale_score: 22.7, ecs_subscale_score: 60.5, fact_g_total: 93.7, fact_e_total: 154.2, toi: 107.2]
# Using baseline score: pwb_subscale_score: 18.7, swb_subscale_score: 21.0, ewb_subscale_score: 18.0, fwb_subscale_score: 17.0, ecs_subscale_score: 33.0, fact_g_total: 74.7, fact_e_total: 107.7, toi: 68.7
#
# ID 1398 has events: ['1_month_postop_arm_1' 'baseline_arm_1' 'surgery_arm_1'
#  '6_months_postop_arm_1' 'preoperative_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: [pwb_subscale_score: 28.0, swb_subscale_score: 26.0, ewb_subscale_score: 15.0, fwb_subscale_score: 25.0, ecs_subscale_score: 46.0, fact_g_total: 94.0, fact_e_total: 140.0, toi: 99.0]
# 1-year score: [pwb_subscale_score: 25.0, swb_subscale_score: 28.0, ecs_subscale_score: 49.9]
# Using preop score as baseline: pwb_subscale_score: 28.0, swb_subscale_score: 26.0, ewb_subscale_score: 15.0, fwb_subscale_score: 25.0, ecs_subscale_score: 46.0, fact_g_total: 94.0, fact_e_total: 140.0, toi: 99.0
#
# ID 1405 has events: ['surgery_arm_1' 'preoperative_arm_1' 'baseline_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.0, swb_subscale_score: 26.0, ewb_subscale_score: 14.0, fwb_subscale_score: 26.0, ecs_subscale_score: 52.0, fact_g_total: 90.0, fact_e_total: 142.0, toi: 102.0]
# Preop score: [pwb_subscale_score: 15.2, swb_subscale_score: 23.0, ewb_subscale_score: 20.0, fwb_subscale_score: 18.0, ecs_subscale_score: 39.0, fact_g_total: 76.2, fact_e_total: 115.2, toi: 72.2]
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 28.0, ewb_subscale_score: 17.0, fwb_subscale_score: 15.0, ecs_subscale_score: 27.0, fact_g_total: 84.0, fact_e_total: 111.0, toi: 66.0]
# Using baseline score: pwb_subscale_score: 24.0, swb_subscale_score: 26.0, ewb_subscale_score: 14.0, fwb_subscale_score: 26.0, ecs_subscale_score: 52.0, fact_g_total: 90.0, fact_e_total: 142.0, toi: 102.0
#
# ID 1413 has events: ['surgery_arm_1' 'baseline_arm_1' '1_month_postop_arm_1'
#  'preoperative_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 21.0, fwb_subscale_score: 28.0, ecs_subscale_score: 59.0, fact_g_total: 104.0, fact_e_total: 163.0, toi: 114.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 28.0, ewb_subscale_score: 15.0, fwb_subscale_score: 19.0, ecs_subscale_score: 48.0, fact_g_total: 86.0, fact_e_total: 134.0, toi: 91.0]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 21.0, fwb_subscale_score: 28.0, ecs_subscale_score: 59.0, fact_g_total: 104.0, fact_e_total: 163.0, toi: 114.0
#
# ID 1426 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '6_months_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 17.0, swb_subscale_score: 24.0, ewb_subscale_score: 15.0, fwb_subscale_score: 15.0, ecs_subscale_score: 61.0, fact_g_total: 71.0, fact_e_total: 132.0, toi: 93.0]
#
# ID 1433 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'baseline_arm_1'
#  '1_month_postop_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 19.0, ewb_subscale_score: 17.0, fwb_subscale_score: 24.0, ecs_subscale_score: 44.0, fact_g_total: 83.0, fact_e_total: 127.0, toi: 91.0]
# Preop score: [pwb_subscale_score: 20.0, swb_subscale_score: 25.0, ewb_subscale_score: 18.0, fwb_subscale_score: 20.0, ecs_subscale_score: 32.0, fact_g_total: 83.0, fact_e_total: 115.0, toi: 72.0]
# 1-year score: [pwb_subscale_score: 23.0, swb_subscale_score: 21.0, ewb_subscale_score: 19.0, fwb_subscale_score: 24.0, ecs_subscale_score: 42.0, fact_g_total: 87.0, fact_e_total: 129.0, toi: 89.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 19.0, ewb_subscale_score: 17.0, fwb_subscale_score: 24.0, ecs_subscale_score: 44.0, fact_g_total: 83.0, fact_e_total: 127.0, toi: 91.0
#
# ID 1438 has events: ['surgery_arm_1' 'preoperative_arm_1' '1_month_postop_arm_1'
#  '1_year_postop_arm_1' 'baseline_arm_1']
# Baseline score: []
# Preop score: [pwb_subscale_score: 18.5, swb_subscale_score: 17.5, ewb_subscale_score: 8.5, fwb_subscale_score: 15.0, ecs_subscale_score: 39.0, fact_g_total: 59.5, fact_e_total: 98.5, toi: 72.5]
# 1-year score: [pwb_subscale_score: 22.6, swb_subscale_score: 23.5, ewb_subscale_score: 18.6, fwb_subscale_score: 18.0, ecs_subscale_score: 43.0, fact_g_total: 82.7, fact_e_total: 125.7, toi: 83.6]
# Using preop score as baseline: pwb_subscale_score: 18.5, swb_subscale_score: 17.5, ewb_subscale_score: 8.5, fwb_subscale_score: 15.0, ecs_subscale_score: 39.0, fact_g_total: 59.5, fact_e_total: 98.5, toi: 72.5
#
# ID 1447 has events: ['baseline_arm_1' 'surgery_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 27.0, ewb_subscale_score: 9.0, fwb_subscale_score: 20.0, ecs_subscale_score: 60.0, fact_g_total: 79.0, fact_e_total: 139.0, toi: 103.0]
# Preop score: [pwb_subscale_score: 2.0, swb_subscale_score: 22.0, ewb_subscale_score: 6.0, fwb_subscale_score: 11.0, ecs_subscale_score: 33.0, fact_g_total: 41.0, fact_e_total: 74.0, toi: 46.0]
# 1-year score: [pwb_subscale_score: 11.0, swb_subscale_score: 24.0, ewb_subscale_score: 8.0, fwb_subscale_score: 16.0, ecs_subscale_score: 33.0, fact_g_total: 59.0, fact_e_total: 92.0, toi: 60.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 27.0, ewb_subscale_score: 9.0, fwb_subscale_score: 20.0, ecs_subscale_score: 60.0, fact_g_total: 79.0, fact_e_total: 139.0, toi: 103.0
#
# ID 1475 has events: ['baseline_arm_1' 'preoperative_arm_1' 'surgery_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 20.0, ewb_subscale_score: 22.0, fwb_subscale_score: 12.0, ecs_subscale_score: 45.0, fact_g_total: 74.0, fact_e_total: 119.0, toi: 77.0]
#
# ID 1511 has events: ['baseline_arm_1' '1_year_postop_arm_1' 'surgery_arm_1'
#  'preoperative_arm_1' '3_months_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 20.0, swb_subscale_score: 19.6, ewb_subscale_score: 5.0, fwb_subscale_score: 9.3, ecs_subscale_score: 35.0, fact_g_total: 53.9, fact_e_total: 88.9, toi: 64.3]
#
# ID 1527 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 2.8, swb_subscale_score: 28.0, ewb_subscale_score: 10.0, fwb_subscale_score: 26.0, ecs_subscale_score: 55.0, fact_g_total: 66.8, fact_e_total: 121.8, toi: 83.8]
# Preop score: [pwb_subscale_score: 8.0, swb_subscale_score: 23.0, ewb_subscale_score: 18.0, fwb_subscale_score: 5.0, ecs_subscale_score: 47.0, fact_g_total: 54.0, fact_e_total: 101.0, toi: 60.0]
# 1-year score: [pwb_subscale_score: 10.0, swb_subscale_score: 25.7, ewb_subscale_score: 10.0, fwb_subscale_score: 4.0, ecs_subscale_score: 34.0, fact_g_total: 49.7, fact_e_total: 83.7, toi: 48.0]
# Using baseline score: pwb_subscale_score: 2.8, swb_subscale_score: 28.0, ewb_subscale_score: 10.0, fwb_subscale_score: 26.0, ecs_subscale_score: 55.0, fact_g_total: 66.8, fact_e_total: 121.8, toi: 83.8
#
# ID 1531 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1' '6_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 24.0, swb_subscale_score: 22.0, ewb_subscale_score: 18.0, fwb_subscale_score: 17.0, ecs_subscale_score: 58.0, fact_g_total: 81.0, fact_e_total: 139.0, toi: 99.0]
# Preop score: []
# 1-year score: [pwb_subscale_score: 15.0, swb_subscale_score: 22.2, ewb_subscale_score: 13.0, fwb_subscale_score: 8.0, ecs_subscale_score: 51.0, fact_g_total: 58.2, fact_e_total: 109.2, toi: 74.0]
# Using baseline score: pwb_subscale_score: 24.0, swb_subscale_score: 22.0, ewb_subscale_score: 18.0, fwb_subscale_score: 17.0, ecs_subscale_score: 58.0, fact_g_total: 81.0, fact_e_total: 139.0, toi: 99.0
#
# ID 1560 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '3_months_postop_arm_1' '6_months_postop_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 15.0, fwb_subscale_score: 20.0, ecs_subscale_score: 64.0, fact_g_total: 90.0, fact_e_total: 154.0, toi: 111.0]
# Preop score: [ewb_subscale_score: 20.4, fwb_subscale_score: 17.0]
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 26.8, ewb_subscale_score: 18.0, fwb_subscale_score: 22.0, ecs_subscale_score: 59.0, fact_g_total: 92.8, fact_e_total: 151.8, toi: 107.0]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 28.0, ewb_subscale_score: 15.0, fwb_subscale_score: 20.0, ecs_subscale_score: 64.0, fact_g_total: 90.0, fact_e_total: 154.0, toi: 111.0
#
# ID 1566 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '6_months_postop_arm_1' '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: []
# Preop score: [pwb_subscale_score: 23.0, swb_subscale_score: 24.0, ewb_subscale_score: 18.0, fwb_subscale_score: 18.0, ecs_subscale_score: 67.0, fact_g_total: 83.0, fact_e_total: 150.0, toi: 108.0]
# 1-year score: [pwb_subscale_score: 19.0, swb_subscale_score: 19.0, ewb_subscale_score: 15.0, fwb_subscale_score: 16.0, ecs_subscale_score: 38.0, fact_g_total: 69.0, fact_e_total: 107.0, toi: 73.0]
# Using preop score as baseline: pwb_subscale_score: 23.0, swb_subscale_score: 24.0, ewb_subscale_score: 18.0, fwb_subscale_score: 18.0, ecs_subscale_score: 67.0, fact_g_total: 83.0, fact_e_total: 150.0, toi: 108.0
#
# ID 1571 has events: ['6_months_postop_arm_1' '3_months_postop_arm_1' 'preoperative_arm_1'
#  'surgery_arm_1' nan 'baseline_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 26.0, swb_subscale_score: 28.0, ewb_subscale_score: 16.0, fwb_subscale_score: 25.0, ecs_subscale_score: 58.0, fact_g_total: 95.0, fact_e_total: 153.0, toi: 109.0]
# Preop score: [pwb_subscale_score: 12.0, swb_subscale_score: 25.7, ewb_subscale_score: 18.0, fwb_subscale_score: 9.0, ecs_subscale_score: 35.0, fact_g_total: 64.7, fact_e_total: 99.7, toi: 56.0]
# 1-year score: [pwb_subscale_score: 16.0, swb_subscale_score: 28.0, ewb_subscale_score: 15.0, fwb_subscale_score: 10.0, ecs_subscale_score: 35.0, fact_g_total: 69.0, fact_e_total: 104.0, toi: 61.0]
# Using baseline score: pwb_subscale_score: 26.0, swb_subscale_score: 28.0, ewb_subscale_score: 16.0, fwb_subscale_score: 25.0, ecs_subscale_score: 58.0, fact_g_total: 95.0, fact_e_total: 153.0, toi: 109.0
#
# ID 1572 has events: ['1_year_postop_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '3_months_postop_arm_1' '6_months_postop_arm_1'
#  'surgery_arm_1']
# Baseline score: [pwb_subscale_score: 27.0, swb_subscale_score: 13.0, ewb_subscale_score: 19.0, fwb_subscale_score: 20.0, ecs_subscale_score: 62.0, fact_g_total: 79.0, fact_e_total: 141.0, toi: 109.0]
# Preop score: [pwb_subscale_score: 21.0, swb_subscale_score: 16.0, ewb_subscale_score: 18.0, fwb_subscale_score: 21.0, ecs_subscale_score: 63.0, fact_g_total: 76.0, fact_e_total: 139.0, toi: 105.0]
# 1-year score: [pwb_subscale_score: 24.0, swb_subscale_score: 21.0, ewb_subscale_score: 18.0, fwb_subscale_score: 15.0, ecs_subscale_score: 37.0, fact_g_total: 78.0, fact_e_total: 115.0, toi: 76.0]
# Using baseline score: pwb_subscale_score: 27.0, swb_subscale_score: 13.0, ewb_subscale_score: 19.0, fwb_subscale_score: 20.0, ecs_subscale_score: 62.0, fact_g_total: 79.0, fact_e_total: 141.0, toi: 109.0
#
# ID 1587 has events: ['surgery_arm_1' 'preoperative_arm_1' '1_year_postop_arm_1'
#  'baseline_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 12.8, swb_subscale_score: 17.5, ewb_subscale_score: 13.0, fwb_subscale_score: 9.0, ecs_subscale_score: 32.0, fact_g_total: 52.3, fact_e_total: 84.3, toi: 53.8]
#
# ID 1590 has events: ['baseline_arm_1' '1_year_postop_arm_1' 'surgery_arm_1'
#  'preoperative_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 21.0, swb_subscale_score: 21.0, ewb_subscale_score: 11.0, fwb_subscale_score: 18.7, ecs_subscale_score: 66.0, fact_g_total: 71.7, fact_e_total: 137.7, toi: 105.7]
#
# ID 1615 has events: ['surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_month_postop_arm_1' '1_year_postop_arm_1']
# Baseline score: [pwb_subscale_score: 23.0, swb_subscale_score: 24.0, ewb_subscale_score: 16.0, fwb_subscale_score: 12.0, ecs_subscale_score: 51.0, fact_g_total: 75.0, fact_e_total: 126.0, toi: 86.0]
# Preop score: [pwb_subscale_score: 17.0, swb_subscale_score: 22.0, ewb_subscale_score: 12.0, fwb_subscale_score: 9.0, ecs_subscale_score: 32.0, fact_g_total: 60.0, fact_e_total: 92.0, toi: 58.0]
# 1-year score: [pwb_subscale_score: 19.0, swb_subscale_score: 22.0, ewb_subscale_score: 20.0, fwb_subscale_score: 13.0, ecs_subscale_score: 37.0, fact_g_total: 74.0, fact_e_total: 111.0, toi: 69.0]
# Using baseline score: pwb_subscale_score: 23.0, swb_subscale_score: 24.0, ewb_subscale_score: 16.0, fwb_subscale_score: 12.0, ecs_subscale_score: 51.0, fact_g_total: 75.0, fact_e_total: 126.0, toi: 86.0
#
# ID 1648 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'baseline_arm_1'
#  'preoperative_arm_1' '1_month_postop_arm_1' '6_months_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 28.0, swb_subscale_score: 0.0, ewb_subscale_score: 20.0, fwb_subscale_score: 0.0, ecs_subscale_score: 40.0, fact_g_total: 48.0, fact_e_total: 88.0, toi: 68.0]
#
# ID 1653 has events: ['1_year_postop_arm_1' 'surgery_arm_1' '1_month_postop_arm_1'
#  'baseline_arm_1' 'preoperative_arm_1']
# Baseline score: [pwb_subscale_score: 21.0, swb_subscale_score: 19.0, ewb_subscale_score: 18.0, fwb_subscale_score: 24.0, ecs_subscale_score: 30.0, fact_g_total: 82.0, fact_e_total: 112.0, toi: 75.0]
# Preop score: [pwb_subscale_score: 28.0, swb_subscale_score: 23.0, ewb_subscale_score: 18.0, fwb_subscale_score: 26.0, ecs_subscale_score: 55.0, fact_g_total: 95.0, fact_e_total: 150.0, toi: 109.0]
# 1-year score: [pwb_subscale_score: 26.0, swb_subscale_score: 21.0, ewb_subscale_score: 16.0, fwb_subscale_score: 28.0, ecs_subscale_score: 62.0, fact_g_total: 91.0, fact_e_total: 153.0, toi: 116.0]
# Using baseline score: pwb_subscale_score: 21.0, swb_subscale_score: 19.0, ewb_subscale_score: 18.0, fwb_subscale_score: 24.0, ecs_subscale_score: 30.0, fact_g_total: 82.0, fact_e_total: 112.0, toi: 75.0
#
# ID 1664 has events: ['surgery_arm_1' '1_year_postop_arm_1' 'preoperative_arm_1'
#  'baseline_arm_1' '1_month_postop_arm_1' '3_months_postop_arm_1']
# Baseline score: [pwb_subscale_score: 28.0, swb_subscale_score: 18.7, ewb_subscale_score: 12.0, fwb_subscale_score: 15.0, fact_g_total: 73.7]
# Preop score: []
# 1-year score: []
# Using baseline score: pwb_subscale_score: 28.0, swb_subscale_score: 18.7, ewb_subscale_score: 12.0, fwb_subscale_score: 15.0, fact_g_total: 73.7
#
# ID 1690 has events: [nan 'surgery_arm_1' 'baseline_arm_1' 'preoperative_arm_1'
#  '1_year_postop_arm_1']
# Baseline score: []
# Preop score: []
# 1-year score: [pwb_subscale_score: 22.0, swb_subscale_score: 25.7, ewb_subscale_score: 22.0, fwb_subscale_score: 16.0, ecs_subscale_score: 58.4, fact_g_total: 85.7, fact_e_total: 144.1, toi: 96.4]
#
# Analysis complete for 124 patients:
# Patients with valid pwb_subscale_score baseline: 124 out of 124
# Patients with valid swb_subscale_score baseline: 120 out of 124
# Patients with valid ewb_subscale_score baseline: 122 out of 124
# Patients with valid fwb_subscale_score baseline: 123 out of 124
# Patients with valid ecs_subscale_score baseline: 120 out of 124
# Patients with valid fact_g_total baseline: 120 out of 124
# Patients with valid fact_e_total baseline: 116 out of 124
# Patients with valid toi baseline: 115 out of 124

# %%
results_df
# Out:
#        id       baseline_type  pwb_subscale_score_baseline  \
# 0      32      baseline_arm_1                         24.5
# 1      76  preoperative_arm_1                          7.0
# 2     125      baseline_arm_1                         21.0
# 3     160      baseline_arm_1                         21.0
# 4     198      baseline_arm_1                         25.0
# ..    ...                 ...                          ...
# 119  1571      baseline_arm_1                         26.0
# 120  1572      baseline_arm_1                         27.0
# 121  1615      baseline_arm_1                         23.0
# 122  1653      baseline_arm_1                         21.0
# 123  1664      baseline_arm_1                         28.0
#
#      pwb_subscale_score_one_year  swb_subscale_score_baseline  \
# 0                           27.0                    22.000000
# 1                            7.0                    23.000000
# 2                           22.0                    17.500000
# 3                           28.0                    20.000000
# 4                           26.5                    13.000000
# ..                           ...                          ...
# 119                         16.0                    28.000000
# 120                         24.0                    13.000000
# 121                         19.0                    24.000000
# 122                         26.0                    19.000000
# 123                          NaN                    18.666667
#
#      swb_subscale_score_one_year  ewb_subscale_score_baseline  \
# 0                           28.0                          6.0
# 1                           21.0                         14.0
# 2                           21.0                         21.0
# 3                           22.0                         21.0
# 4                           18.0                         17.0
# ..                           ...                          ...
# 119                         28.0                         16.0
# 120                         21.0                         19.0
# 121                         22.0                         16.0
# 122                         21.0                         18.0
# 123                          NaN                         12.0
#
#      ewb_subscale_score_one_year  fwb_subscale_score_baseline  \
# 0                           24.0                         19.0
# 1                           11.0                         15.0
# 2                           19.0                          8.0
# 3                           23.0                         20.0
# 4                           23.0                         21.0
# ..                           ...                          ...
# 119                         15.0                         25.0
# 120                         18.0                         20.0
# 121                         20.0                         12.0
# 122                         16.0                         24.0
# 123                          NaN                         15.0
#
#      fwb_subscale_score_one_year  ecs_subscale_score_baseline  \
# 0                           25.0                         46.0
# 1                           10.0                         36.0
# 2                           13.0                         52.0
# 3                           22.0                         37.0
# 4                           20.5                         57.0
# ..                           ...                          ...
# 119                         10.0                         58.0
# 120                         15.0                         62.0
# 121                         13.0                         51.0
# 122                         28.0                         30.0
# 123                          NaN                          NaN
#
#      ecs_subscale_score_one_year  fact_g_total_baseline  \
# 0                           55.0              71.500000
# 1                           48.0              59.000000
# 2                           54.0              67.500000
# 3                           57.0              82.000000
# 4                           51.0              76.000000
# ..                           ...                    ...
# 119                         35.0              95.000000
# 120                         37.0              79.000000
# 121                         37.0              75.000000
# 122                         62.0              82.000000
# 123                          NaN              73.666667
#
#      fact_g_total_one_year  fact_e_total_baseline  fact_e_total_one_year  \
# 0                    104.0                  117.5                  159.0
# 1                     49.0                   95.0                   97.0
# 2                     75.0                  119.5                  129.0
# 3                     95.0                  119.0                  152.0
# 4                     88.0                  133.0                  139.0
# ..                     ...                    ...                    ...
# 119                   69.0                  153.0                  104.0
# 120                   78.0                  141.0                  115.0
# 121                   74.0                  126.0                  111.0
# 122                   91.0                  112.0                  153.0
# 123                    NaN                    NaN                    NaN
#
#      toi_baseline  toi_one_year
# 0            89.5         107.0
# 1            58.0          65.0
# 2            81.0          89.0
# 3            78.0         107.0
# 4           103.0          98.0
# ..            ...           ...
# 119         109.0          61.0
# 120         109.0          76.0
# 121          86.0          69.0
# 122          75.0         116.0
# 123           NaN           NaN
#
# [124 rows x 18 columns]

# %%
filtered_df
# Out:
#          id operation_date     redcap_event_name   qol_date  age_diagnosis  \
# 235      32            NaT        baseline_arm_1        NaT            NaN
# 236      32     2007-11-15         surgery_arm_1        NaT            NaN
# 237      32            NaT  1_month_postop_arm_1        NaT            NaN
# 238      32            NaT         surgery_arm_1        NaT            NaN
# 239      32            NaT        baseline_arm_1        NaT            NaN
# ...     ...            ...                   ...        ...            ...
# 11537  1690            NaT    preoperative_arm_1        NaT            NaN
# 11538  1690            NaT   1_year_postop_arm_1        NaT            NaN
# 11539  1690            NaT        baseline_arm_1        NaT            NaN
# 11540  1690            NaT         surgery_arm_1        NaT            NaN
# 11541  1690            NaT   1_year_postop_arm_1 2025-03-31            NaN
#
#              dob overall_primary_tumour overall_regional_ln  \
# 235   1977-09-24                    NaN                 NaN
# 236          NaT                    NaN                 NaN
# 237          NaT                    NaN                 NaN
# 238          NaT                    NaN                 NaN
# 239          NaT                    NaN                 NaN
# ...          ...                    ...                 ...
# 11537        NaT                    NaN                 NaN
# 11538        NaT                    NaN                 NaN
# 11539 1977-08-25                    NaN                 NaN
# 11540        NaT                    NaN                 NaN
# 11541        NaT                    NaN                 NaN
#
#        overall_distant_metastasis  neotx___notx  ...  a_e5_score  a_e6_score  \
# 235                           NaN           NaN  ...         NaN         NaN
# 236                           NaN           NaN  ...         NaN         NaN
# 237                           NaN           NaN  ...         NaN         NaN
# 238                           NaN           NaN  ...         NaN         NaN
# 239                           NaN           NaN  ...         4.0         2.0
# ...                           ...           ...  ...         ...         ...
# 11537                         NaN           0.0  ...         NaN         NaN
# 11538                         NaN           NaN  ...         NaN         NaN
# 11539                         NaN           NaN  ...         NaN         NaN
# 11540                         NaN           NaN  ...         NaN         NaN
# 11541                         NaN           NaN  ...         3.0         4.0
#
#        a_e7_score  a_c6_score  a_c2_score  a_act11_score  ecs_subscale_score  \
# 235           NaN         NaN         NaN            NaN                 NaN
# 236           NaN         NaN         NaN            NaN                 NaN
# 237           NaN         NaN         NaN            NaN                 NaN
# 238           NaN         NaN         NaN            NaN                 NaN
# 239           4.0         3.0         2.0            2.0             46.0000
# ...           ...         ...         ...            ...                 ...
# 11537         NaN         NaN         NaN            NaN                 NaN
# 11538         NaN         NaN         NaN            NaN                 NaN
# 11539         NaN         NaN         NaN            NaN                 NaN
# 11540         NaN         NaN         NaN            NaN                 NaN
# 11541         4.0         NaN         4.0            4.0             58.4375
#
#       fact_g_total fact_e_total      toi
# 235            NaN          NaN      NaN
# 236            NaN          NaN      NaN
# 237            NaN          NaN      NaN
# 238            NaN          NaN      NaN
# 239      71.500000   117.500000  89.5000
# ...            ...          ...      ...
# 11537          NaN          NaN      NaN
# 11538          NaN          NaN      NaN
# 11539          NaN          NaN      NaN
# 11540          NaN          NaN      NaN
# 11541    85.666667   144.104167  96.4375
#
# [2235 rows x 136 columns]

# %%
filtered_df['id'].nunique()
# Out:
# 167

# %%
results_df['id'].nunique()
# Out:
# 124

# %% [markdown]
# # Data set up

# %%
results_df = pd.read_csv("results.csv")

# %%
results_df
# Out:
#        id       baseline_type  pwb_subscale_score_baseline  \
# 0      32      baseline_arm_1                         24.5
# 1      76  preoperative_arm_1                          7.0
# 2     125      baseline_arm_1                         21.0
# 3     160      baseline_arm_1                         21.0
# 4     198      baseline_arm_1                         25.0
# ..    ...                 ...                          ...
# 119  1571      baseline_arm_1                         26.0
# 120  1572      baseline_arm_1                         27.0
# 121  1615      baseline_arm_1                         23.0
# 122  1653      baseline_arm_1                         21.0
# 123  1664      baseline_arm_1                         28.0
#
#      pwb_subscale_score_one_year  swb_subscale_score_baseline  \
# 0                           27.0                    22.000000
# 1                            7.0                    23.000000
# 2                           22.0                    17.500000
# 3                           28.0                    20.000000
# 4                           26.5                    13.000000
# ..                           ...                          ...
# 119                         16.0                    28.000000
# 120                         24.0                    13.000000
# 121                         19.0                    24.000000
# 122                         26.0                    19.000000
# 123                          NaN                    18.666667
#
#      swb_subscale_score_one_year  ewb_subscale_score_baseline  \
# 0                           28.0                          6.0
# 1                           21.0                         14.0
# 2                           21.0                         21.0
# 3                           22.0                         21.0
# 4                           18.0                         17.0
# ..                           ...                          ...
# 119                         28.0                         16.0
# 120                         21.0                         19.0
# 121                         22.0                         16.0
# 122                         21.0                         18.0
# 123                          NaN                         12.0
#
#      ewb_subscale_score_one_year  fwb_subscale_score_baseline  \
# 0                           24.0                         19.0
# 1                           11.0                         15.0
# 2                           19.0                          8.0
# 3                           23.0                         20.0
# 4                           23.0                         21.0
# ..                           ...                          ...
# 119                         15.0                         25.0
# 120                         18.0                         20.0
# 121                         20.0                         12.0
# 122                         16.0                         24.0
# 123                          NaN                         15.0
#
#      fwb_subscale_score_one_year  ecs_subscale_score_baseline  \
# 0                           25.0                         46.0
# 1                           10.0                         36.0
# 2                           13.0                         52.0
# 3                           22.0                         37.0
# 4                           20.5                         57.0
# ..                           ...                          ...
# 119                         10.0                         58.0
# 120                         15.0                         62.0
# 121                         13.0                         51.0
# 122                         28.0                         30.0
# 123                          NaN                          NaN
#
#      ecs_subscale_score_one_year  fact_g_total_baseline  \
# 0                           55.0              71.500000
# 1                           48.0              59.000000
# 2                           54.0              67.500000
# 3                           57.0              82.000000
# 4                           51.0              76.000000
# ..                           ...                    ...
# 119                         35.0              95.000000
# 120                         37.0              79.000000
# 121                         37.0              75.000000
# 122                         62.0              82.000000
# 123                          NaN              73.666667
#
#      fact_g_total_one_year  fact_e_total_baseline  fact_e_total_one_year  \
# 0                    104.0                  117.5                  159.0
# 1                     49.0                   95.0                   97.0
# 2                     75.0                  119.5                  129.0
# 3                     95.0                  119.0                  152.0
# 4                     88.0                  133.0                  139.0
# ..                     ...                    ...                    ...
# 119                   69.0                  153.0                  104.0
# 120                   78.0                  141.0                  115.0
# 121                   74.0                  126.0                  111.0
# 122                   91.0                  112.0                  153.0
# 123                    NaN                    NaN                    NaN
#
#      toi_baseline  toi_one_year
# 0            89.5         107.0
# 1            58.0          65.0
# 2            81.0          89.0
# 3            78.0         107.0
# 4           103.0          98.0
# ..            ...           ...
# 119         109.0          61.0
# 120         109.0          76.0
# 121          86.0          69.0
# 122          75.0         116.0
# 123           NaN           NaN
#
# [124 rows x 18 columns]

# %%
# Load results_df before the filtering
results_df_original = pd.read_csv("results.csv")

# Select relevant columns for FACT-E (baseline and 12-month only)
results_df_facte = results_df_original[['id', 'baseline_type', 'fact_e_total_baseline', 'fact_e_total_one_year']]

# Rename columns
results_df_facte = results_df_facte.rename(columns={
    "fact_e_total_baseline": "Baseline",
    "fact_e_total_one_year": "12mo"
})

print(f"Total patients in results_df: {len(results_df_facte)}")

# Check baseline FACT-E availability
has_baseline = results_df_facte['Baseline'].notna().sum()
print(f"\nPatients with valid baseline FACT-E: {has_baseline}")

# Check 12-month availability
has_12mo = results_df_facte['12mo'].notna().sum()
print(f"Patients with 12-month FACT-E: {has_12mo}")

# Baseline but NO 12-month
has_baseline_only = (results_df_facte['Baseline'].notna() & 
                     results_df_facte['12mo'].isna()).sum()
print(f"\nPatients with baseline FACT-E but NO 12-month: {has_baseline_only}")

# 12-month but NO baseline
has_12mo_only = (results_df_facte['Baseline'].isna() & 
                 results_df_facte['12mo'].notna()).sum()
print(f"Patients with 12-month FACT-E but NO baseline: {has_12mo_only}")

# Both baseline AND 12-month
has_both = (results_df_facte['Baseline'].notna() & 
            results_df_facte['12mo'].notna()).sum()
print(f"Patients with baseline FACT-E AND 12-month: {has_both}")
# Out:
# Total patients in results_df: 124
#
# Patients with valid baseline FACT-E: 116
# Patients with 12-month FACT-E: 114
#
# Patients with baseline FACT-E but NO 12-month: 8
# Patients with 12-month FACT-E but NO baseline: 6
# Patients with baseline FACT-E AND 12-month: 108

# %%
# Select relevant columns for baseline and 12-month analysis
results_df = results_df[['id', 'baseline_type', 'fact_e_total_baseline', 'fact_e_total_one_year']]

# Rename columns to match timepoints
results_df = results_df.rename(columns={
    "fact_e_total_baseline": "Baseline",
    "fact_e_total_one_year": "12mo"
})

# Filter to patients who have baseline AND 12-month follow-up
has_baseline = results_df["Baseline"].notna()
has_12mo = results_df["12mo"].notna()
results_df = results_df[has_baseline & has_12mo]

print(f"Patients with valid baseline and 12-month follow-up: {len(results_df)}")
# Out:
# Patients with valid baseline and 12-month follow-up: 108

# %%
# Set 'id' column as the index
results_df = results_df.set_index("id")

# Rename the index and columns
results_df.index.name = "id"
results_df.columns.name = "Timepoint"

results_df

score_comparison = results_df.copy()
score_comparison
# Out:
# Timepoint       baseline_type  Baseline   12mo
# id
# 32             baseline_arm_1     117.5  159.0
# 76         preoperative_arm_1      95.0   97.0
# 125            baseline_arm_1     119.5  129.0
# 160            baseline_arm_1     119.0  152.0
# 198            baseline_arm_1     133.0  139.0
# ...                       ...       ...    ...
# 1566       preoperative_arm_1     150.0  107.0
# 1571           baseline_arm_1     153.0  104.0
# 1572           baseline_arm_1     141.0  115.0
# 1615           baseline_arm_1     126.0  111.0
# 1653           baseline_arm_1     112.0  153.0
#
# [108 rows x 3 columns]

# %% [raw]
# # Export score_comparison to CSV for R
# score_comparison.to_csv('score_comparison.csv')
#
# # Also export a version without the index for easier R reading
# score_comparison_for_r = score_comparison.reset_index()
# score_comparison_for_r.to_csv('score_comparison_for_r.csv', index=False)

# %%
score_comparison['baseline_type'].value_counts()
# Out:
# baseline_type
# baseline_arm_1        96
# preoperative_arm_1    12
# Name: count, dtype: int64

# %%
# Start with the 108 patients from score_comparison (FACT-E cohort)
eligible_patient_ids = score_comparison.index.tolist()

# Load the original results_df
results_df_original = pd.read_csv("results.csv")

# Filter to only the 108 eligible patients
results_df_filtered = results_df_original[results_df_original['id'].isin(eligible_patient_ids)].copy()

# Define all score types
score_types = ['fact_e_total', 'pwb_subscale_score', 'swb_subscale_score', 
               'ewb_subscale_score', 'fwb_subscale_score', 'ecs_subscale_score']

# Select relevant columns
cols_to_keep = ['id', 'baseline_type']
for score_type in score_types:
    cols_to_keep.extend([f'{score_type}_baseline', f'{score_type}_one_year'])

# Create extended dataframe
score_comparison_extended = results_df_filtered[cols_to_keep].copy()

# Rename columns to use consistent naming
rename_dict = {'baseline_type': 'baseline_type'}
for score_type in score_types:
    rename_dict[f'{score_type}_baseline'] = f'{score_type}_Baseline'
    rename_dict[f'{score_type}_one_year'] = f'{score_type}_12mo'

score_comparison_extended = score_comparison_extended.rename(columns=rename_dict)

# Set id as index
score_comparison_extended = score_comparison_extended.set_index('id')
score_comparison_extended.index.name = 'id'

# Display summary
print(f"Extended score_comparison shape: {score_comparison_extended.shape}")
print(f"Number of patients: {len(score_comparison_extended)}")
print(f"\nColumns: {list(score_comparison_extended.columns)}")

# Check completeness for each domain
print(f"\n{'='*80}")
print("DATA COMPLETENESS BY DOMAIN (Baseline + 12mo)")
print(f"{'='*80}")
for score_type in score_types:
    baseline_col = f'{score_type}_Baseline'
    mo12_col = f'{score_type}_12mo'
    
    n_baseline = score_comparison_extended[baseline_col].notna().sum()
    n_12mo = score_comparison_extended[mo12_col].notna().sum()
    n_both = (score_comparison_extended[baseline_col].notna() & 
              score_comparison_extended[mo12_col].notna()).sum()
    
    print(f"{score_type:25} Baseline: {n_baseline:3}/108  |  12mo: {n_12mo:3}/108  |  Both: {n_both:3}/108")

# Update score_comparison to the extended version
score_comparison = score_comparison_extended.copy()
print(f"\n{'='*80}")
print(f"Updated 'score_comparison' with all 6 domains for {len(score_comparison)} patients")
print(f"{'='*80}")
# Out:
# Extended score_comparison shape: (108, 13)
# Number of patients: 108
#
# Columns: ['baseline_type', 'fact_e_total_Baseline', 'fact_e_total_12mo', 'pwb_subscale_score_Baseline', 'pwb_subscale_score_12mo', 'swb_subscale_score_Baseline', 'swb_subscale_score_12mo', 'ewb_subscale_score_Baseline', 'ewb_subscale_score_12mo', 'fwb_subscale_score_Baseline', 'fwb_subscale_score_12mo', 'ecs_subscale_score_Baseline', 'ecs_subscale_score_12mo']
#
# ================================================================================
# DATA COMPLETENESS BY DOMAIN (Baseline + 12mo)
# ================================================================================
# fact_e_total              Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
# pwb_subscale_score        Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
# swb_subscale_score        Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
# ewb_subscale_score        Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
# fwb_subscale_score        Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
# ecs_subscale_score        Baseline: 108/108  |  12mo: 108/108  |  Both: 108/108
#
# ================================================================================
# Updated 'score_comparison' with all 6 domains for 108 patients
# ================================================================================

# %%
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  fwb_subscale_score_12mo  \
# id
# 32                           19.0                     25.0
# 76                           15.0                     10.0
# 125                           8.0                     13.0
# 160                          20.0                     22.0
# 198                          21.0                     20.5
# ...                           ...                      ...
# 1566                         18.0                     16.0
# 1571                         25.0                     10.0
# 1572                         20.0                     15.0
# 1615                         12.0                     13.0
# 1653                         24.0                     28.0
#
#       ecs_subscale_score_Baseline  ecs_subscale_score_12mo
# id
# 32                           46.0                     55.0
# 76                           36.0                     48.0
# 125                          52.0                     54.0
# 160                          37.0                     57.0
# 198                          57.0                     51.0
# ...                           ...                      ...
# 1566                         67.0                     38.0
# 1571                         58.0                     35.0
# 1572                         62.0                     37.0
# 1615                         51.0                     37.0
# 1653                         30.0                     62.0
#
# [108 rows x 13 columns]

# %% [markdown]
# # Characteristic by class - 0) FACT E baseline

# %%
score_comparison

# %%
def preprocess_facte_baseline(score_comparison):
    """
    Preprocess baseline FACT-E score: z-score standardization (no imputation needed as no missing values)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    # Check for missing values
    n_missing = score_comparison['fact_e_total_Baseline'].isna().sum()
    n_total = len(score_comparison)
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - FACT-E Baseline")
    print("="*80)
    print(f"Total patients: {n_total}")
    print(f"Missing FACT-E baseline: {n_missing}")
    print(f"Complete FACT-E baseline: {n_total - n_missing}")
    
    if n_missing > 0:
        print(f"\nWARNING: {n_missing} patients have missing baseline FACT-E")
    else:
        print(f"\n✓ No missing values - proceeding with z-score standardization")
    
    # Calculate mean and SD
    mean_facte = score_comparison['fact_e_total_Baseline'].mean()
    sd_facte = score_comparison['fact_e_total_Baseline'].std()
    
    print(f"\nBaseline FACT-E statistics:")
    print(f"  Mean: {mean_facte:.2f}")
    print(f"  SD: {sd_facte:.2f}")
    print(f"  Min: {score_comparison['fact_e_total_Baseline'].min():.2f}")
    print(f"  Max: {score_comparison['fact_e_total_Baseline'].max():.2f}")
    
    # Z-score standardization
    score_comparison['fact_e_total_Baseline_std'] = (
        (score_comparison['fact_e_total_Baseline'] - mean_facte) / sd_facte
    )
    
    print(f"\nStandardized FACT-E statistics:")
    print(f"  Mean: {score_comparison['fact_e_total_Baseline_std'].mean():.2f}")
    print(f"  SD: {score_comparison['fact_e_total_Baseline_std'].std():.2f}")
    print(f"  Min: {score_comparison['fact_e_total_Baseline_std'].min():.2f}")
    print(f"  Max: {score_comparison['fact_e_total_Baseline_std'].max():.2f}")
    
    print("\n✓ Created column: 'fact_e_total_Baseline_std'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': n_total,
        'n_missing': n_missing,
        'n_complete': n_total - n_missing,
        'mean': mean_facte,
        'sd': sd_facte,
        'min': score_comparison['fact_e_total_Baseline'].min(),
        'max': score_comparison['fact_e_total_Baseline'].max(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
baseline_summaries = preprocess_facte_baseline(score_comparison)

# Update score_comparison with preprocessed data
score_comparison = baseline_summaries['preprocessed_data']

score_comparison[['fact_e_total_Baseline', 'fact_e_total_Baseline_std']]

# %%
baseline_summaries

# %%
score_comparison

# %%
baseline_summaries

# %% [markdown]
# # Characteristic by class - 1) BMI

# %%
score_comparison

# %%
def preprocess_bmi(score_comparison, filtered_df):
    """
    Preprocess BMI: median imputation for missing/outliers + z-score standardization
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - BMI")
    print("="*80)
    
    # Get eligible patient IDs from score_comparison
    eligible_patient_ids = score_comparison.index.tolist()
    
    # Create dataframe with patient IDs
    bmi_prep = pd.DataFrame({'patient_id': eligible_patient_ids})
    
    # Merge with filtered_df to get BMI
    bmi_prep = bmi_prep.merge(
        filtered_df[["id", "bmi"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(f"Total patients: {len(eligible_patient_ids)}")
    
    # Calculate median BMI from all non-missing values
    median_bmi = bmi_prep['bmi'].median()
    print(f"\nMedian BMI (for imputation): {median_bmi:.2f}")
    
    # Find patient IDs where all BMI values are missing
    patients_all_missing = bmi_prep.groupby('patient_id')['bmi'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute BMI for those patients
    mask = bmi_prep['patient_id'].isin(patients_to_impute)
    bmi_prep.loc[mask, 'bmi'] = median_bmi
    print(f"Imputed {len(patients_to_impute)} missing patients with median BMI: {median_bmi:.2f}")
    
    # Replace BMI outliers with median (outside range 7-186)
    outlier_mask = (bmi_prep['bmi'] < 7) | (bmi_prep['bmi'] > 186)
    outlier_unique_patients = bmi_prep.loc[outlier_mask, 'patient_id'].nunique()
    outlier_count = outlier_mask.sum()
    bmi_prep.loc[outlier_mask, 'bmi'] = median_bmi
    print(f"Replaced {outlier_count} outlier BMI values from {outlier_unique_patients} unique patients with median BMI: {median_bmi:.2f}")
    
    # Remove NA and duplicates (critical because filtered_df has multiple rows per patient)
    bmi_prep_clean = bmi_prep.dropna(subset=["bmi"])
    bmi_prep_clean = bmi_prep_clean.drop_duplicates()
    
    # Calculate mean and SD for z-score standardization
    mean_bmi = bmi_prep_clean['bmi'].mean()
    sd_bmi = bmi_prep_clean['bmi'].std()
    
    print(f"\nBMI statistics:")
    print(f"  N: {len(bmi_prep_clean)}")
    print(f"  Mean: {mean_bmi:.2f}")
    print(f"  SD: {sd_bmi:.2f}")
    print(f"  Min: {bmi_prep_clean['bmi'].min():.2f}")
    print(f"  Max: {bmi_prep_clean['bmi'].max():.2f}")
    
    # Z-score standardization
    bmi_prep_clean['bmi_std'] = (bmi_prep_clean['bmi'] - mean_bmi) / sd_bmi
    
    print(f"\nStandardized BMI statistics:")
    print(f"  Mean: {bmi_prep_clean['bmi_std'].mean():.2f}")
    print(f"  SD: {bmi_prep_clean['bmi_std'].std():.2f}")
    print(f"  Min: {bmi_prep_clean['bmi_std'].min():.2f}")
    print(f"  Max: {bmi_prep_clean['bmi_std'].max():.2f}")
    
    # Merge back to score_comparison
    bmi_final = bmi_prep_clean[['patient_id', 'bmi', 'bmi_std']].drop_duplicates(subset=['patient_id'])
    bmi_final = bmi_final.set_index('patient_id')
    
    score_comparison = score_comparison.merge(
        bmi_final[['bmi', 'bmi_std']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created columns: 'bmi' and 'bmi_std'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(eligible_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_outliers': outlier_unique_patients,
        'median': median_bmi,
        'mean': mean_bmi,
        'sd': sd_bmi,
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
bmi_summaries = preprocess_bmi(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = bmi_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of BMI (original and standardized):")
print(score_comparison[['bmi', 'bmi_std']].head(10))

# %%
score_comparison

# %%
bmi_summaries

# %% [markdown]
# # Characteristic by class - 2) smoking

# %%
score_comparison

# %%
def preprocess_smoking(score_comparison, filtered_df):
    """
    Preprocess smoking: collapse categories + MICE imputation for missing
    Smoking is categorical: 0=Never, 1=Ever (collapsed from 1,2,3), 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Smoking")
    print("="*80)
    print("Preparing smoking data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get smoking
    smoking_prep = pd.DataFrame({'patient_id': all_patient_ids})
    smoking_prep = smoking_prep.merge(
        filtered_df[["id", "smoking"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(smoking_prep['smoking'].value_counts())
    
    # Find patient IDs where all smoking values are missing
    patients_all_missing = smoking_prep.groupby('patient_id')['smoking'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute smoking for those patients with 9999 (unknown)
    mask = smoking_prep['patient_id'].isin(patients_to_impute)
    smoking_prep.loc[mask, 'smoking'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with smoking=9999 (unknown)")
    
    # Remove NA and duplicates
    smoking_prep_clean = smoking_prep.dropna(subset=["smoking"])
    smoking_prep_clean = smoking_prep_clean.drop_duplicates()
    
    print(smoking_prep_clean['smoking'].value_counts())
    
    # Collapse smoking variable
    print("\nCollapsing smoking variable...")
    smoking_prep_clean['smoking_collapsed'] = smoking_prep_clean['smoking'].copy()
    smoking_prep_clean.loc[smoking_prep_clean['smoking'].isin([1, 2, 3]), 'smoking_collapsed'] = 1  # Ever Smoked
    smoking_prep_clean.loc[smoking_prep_clean['smoking'] == 0, 'smoking_collapsed'] = 0  # Never Smoked
    smoking_prep_clean.loc[smoking_prep_clean['smoking'] == 9999, 'smoking_collapsed'] = 9999  # Unknown
    
    print("Smoking collapsed - Value counts:")
    print(smoking_prep_clean['smoking_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for smoking=9999...")
    
    # Replace 9999 with NaN for imputation
    smoking_prep_clean['smoking_collapsed_for_imputation'] = smoking_prep_clean['smoking_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    smoking_prep_clean = smoking_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(smoking_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = smoking_prep_clean[['smoking_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_smoking = completed_data['smoking_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    smoking_imputation_map = dict(zip(smoking_prep_clean['patient_id'], imputed_smoking))
    
    print("Smoking after MICE imputation - Value counts:")
    print(pd.Series(imputed_smoking).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed smoking values
    smoking_final = pd.DataFrame({
        'patient_id': list(smoking_imputation_map.keys()),
        'smoking_collapsed_imputed': list(smoking_imputation_map.values())
    })
    smoking_final = smoking_final.set_index('patient_id')
    
    # Calculate summary statistics
    smoking_data = smoking_final['smoking_collapsed_imputed']
    n_never = (smoking_data == 0).sum()
    n_ever = (smoking_data == 1).sum()
    total = len(smoking_data)
    
    print(f"\nFinal smoking distribution:")
    print(f"  N: {total}")
    print(f"  Never (0): {n_never} ({n_never/total*100:.1f}%)")
    print(f"  Ever (1): {n_ever} ({n_ever/total*100:.1f}%)")
    print(f"  Mean: {smoking_data.mean():.2f}")
    print(f"  SD: {smoking_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        smoking_final[['smoking_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'smoking_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_never': n_never,
        'n_ever': n_ever,
        'mean': smoking_data.mean(),
        'sd': smoking_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
smoking_summaries = preprocess_smoking(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = smoking_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of smoking (imputed):")
print(score_comparison[['smoking_collapsed_imputed']].head(10))

# %%
score_comparison

# %%
smoking_summaries

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 3) alcohol consumption

# %%
score_comparison

# %%
def preprocess_alcohol(score_comparison, filtered_df):
    """
    Preprocess alcohol: collapse categories + MICE imputation for missing
    Alcohol is categorical: 0=Non-drinker, 1=Ever drank (collapsed from 1,2), 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Alcohol")
    print("="*80)
    print("Preparing alcohol data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get alcohol
    alcohol_prep = pd.DataFrame({'patient_id': all_patient_ids})
    alcohol_prep = alcohol_prep.merge(
        filtered_df[["id", "alcohol"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(alcohol_prep['alcohol'].value_counts())
    
    # Find patient IDs where all alcohol values are missing
    patients_all_missing = alcohol_prep.groupby('patient_id')['alcohol'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute alcohol for those patients with 9999 (unknown)
    mask = alcohol_prep['patient_id'].isin(patients_to_impute)
    alcohol_prep.loc[mask, 'alcohol'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with alcohol=9999 (unknown)")
    
    # Remove NA and duplicates
    alcohol_prep_clean = alcohol_prep.dropna(subset=["alcohol"])
    alcohol_prep_clean = alcohol_prep_clean.drop_duplicates()
    
    print(alcohol_prep_clean['alcohol'].value_counts())
    
    # Collapse alcohol variable
    print("\nCollapsing alcohol variable...")
    alcohol_prep_clean['alcohol_collapsed'] = alcohol_prep_clean['alcohol'].copy()
    alcohol_prep_clean.loc[alcohol_prep_clean['alcohol'].isin([1, 2]), 'alcohol_collapsed'] = 1  # Ever Drank
    alcohol_prep_clean.loc[alcohol_prep_clean['alcohol'] == 0, 'alcohol_collapsed'] = 0  # Non-Drinker
    alcohol_prep_clean.loc[alcohol_prep_clean['alcohol'] == 9999, 'alcohol_collapsed'] = 9999  # Unknown
    
    print("Alcohol collapsed - Value counts:")
    print(alcohol_prep_clean['alcohol_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for alcohol=9999...")
    
    # Replace 9999 with NaN for imputation
    alcohol_prep_clean['alcohol_collapsed_for_imputation'] = alcohol_prep_clean['alcohol_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    alcohol_prep_clean = alcohol_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(alcohol_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = alcohol_prep_clean[['alcohol_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_alcohol = completed_data['alcohol_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    alcohol_imputation_map = dict(zip(alcohol_prep_clean['patient_id'], imputed_alcohol))
    
    print("Alcohol after MICE imputation - Value counts:")
    print(pd.Series(imputed_alcohol).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed alcohol values
    alcohol_final = pd.DataFrame({
        'patient_id': list(alcohol_imputation_map.keys()),
        'alcohol_collapsed_imputed': list(alcohol_imputation_map.values())
    })
    alcohol_final = alcohol_final.set_index('patient_id')
    
    # Calculate summary statistics
    alcohol_data = alcohol_final['alcohol_collapsed_imputed']
    n_non_drinker = (alcohol_data == 0).sum()
    n_ever_drank = (alcohol_data == 1).sum()
    total = len(alcohol_data)
    
    print(f"\nFinal alcohol distribution:")
    print(f"  N: {total}")
    print(f"  Non-drinker (0): {n_non_drinker} ({n_non_drinker/total*100:.1f}%)")
    print(f"  Ever drank (1): {n_ever_drank} ({n_ever_drank/total*100:.1f}%)")
    print(f"  Mean: {alcohol_data.mean():.2f}")
    print(f"  SD: {alcohol_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        alcohol_final[['alcohol_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'alcohol_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_non_drinker': n_non_drinker,
        'n_ever_drank': n_ever_drank,
        'mean': alcohol_data.mean(),
        'sd': alcohol_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
alcohol_summaries = preprocess_alcohol(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = alcohol_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of alcohol (imputed):")
print(score_comparison[['alcohol_collapsed_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 4) level of tumor (level_tumor)

# %%
score_comparison

# %%
def preprocess_level_tumor(score_comparison, filtered_df):
    """
    Preprocess level_tumor: collapse categories + MICE imputation for missing
    Tumor level is categorical: 1=Cardia/GEJ (5,6,7), 2=Lower Esophagus (4), 3=Middle/Upper Esophagus (1,2,3), 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Tumor Level")
    print("="*80)
    print("Preparing tumor level data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get level_tumor
    level_prep = pd.DataFrame({'patient_id': all_patient_ids})
    level_prep = level_prep.merge(
        filtered_df[["id", "level_tumor"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(level_prep['level_tumor'].value_counts())
    
    # Find patient IDs where all level_tumor values are missing
    patients_all_missing = level_prep.groupby('patient_id')['level_tumor'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute level_tumor for those patients with 9999 (unknown)
    mask = level_prep['patient_id'].isin(patients_to_impute)
    level_prep.loc[mask, 'level_tumor'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with level_tumor=9999 (unknown)")
    
    # Remove NA and duplicates
    level_prep_clean = level_prep.dropna(subset=["level_tumor"])
    level_prep_clean = level_prep_clean.drop_duplicates()
    
    print(level_prep_clean['level_tumor'].value_counts())
    
    # Collapse level_tumor variable
    print("\nCollapsing level_tumor variable...")
    level_prep_clean['level_tumor_collapsed'] = level_prep_clean['level_tumor'].copy()
    level_prep_clean.loc[level_prep_clean['level_tumor'].isin([5, 6, 7]), 'level_tumor_collapsed'] = 1  # Cardia/GEJ
    level_prep_clean.loc[level_prep_clean['level_tumor'] == 4, 'level_tumor_collapsed'] = 2  # Lower Esophagus
    level_prep_clean.loc[level_prep_clean['level_tumor'].isin([1, 2, 3]), 'level_tumor_collapsed'] = 3  # Middle or Upper Esophagus
    level_prep_clean.loc[level_prep_clean['level_tumor'] == 9999, 'level_tumor_collapsed'] = 9999  # Unknown
    
    print("Level tumor collapsed - Value counts:")
    print(level_prep_clean['level_tumor_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for level_tumor=9999...")
    
    # Replace 9999 with NaN for imputation
    level_prep_clean['level_tumor_collapsed_for_imputation'] = level_prep_clean['level_tumor_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    level_prep_clean = level_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(level_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = level_prep_clean[['level_tumor_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_level = completed_data['level_tumor_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    level_imputation_map = dict(zip(level_prep_clean['patient_id'], imputed_level))
    
    print("Level tumor after MICE imputation - Value counts:")
    print(pd.Series(imputed_level).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed level_tumor values
    level_final = pd.DataFrame({
        'patient_id': list(level_imputation_map.keys()),
        'level_tumor_collapsed_imputed': list(level_imputation_map.values())
    })
    level_final = level_final.set_index('patient_id')
    
    # Calculate summary statistics
    level_data = level_final['level_tumor_collapsed_imputed']
    n_cardia_gej = (level_data == 1).sum()
    n_lower_esoph = (level_data == 2).sum()
    n_middle_upper = (level_data == 3).sum()
    total = len(level_data)
    
    print(f"\nFinal tumor level distribution:")
    print(f"  N: {total}")
    print(f"  Cardia/GEJ (1): {n_cardia_gej} ({n_cardia_gej/total*100:.1f}%)")
    print(f"  Lower Esoph (2): {n_lower_esoph} ({n_lower_esoph/total*100:.1f}%)")
    print(f"  Middle/Upper (3): {n_middle_upper} ({n_middle_upper/total*100:.1f}%)")
    print(f"  Mean: {level_data.mean():.2f}")
    print(f"  SD: {level_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        level_final[['level_tumor_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'level_tumor_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_cardia_gej': n_cardia_gej,
        'n_lower_esoph': n_lower_esoph,
        'n_middle_upper': n_middle_upper,
        'mean': level_data.mean(),
        'sd': level_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
level_tumor_summaries = preprocess_level_tumor(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = level_tumor_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of level_tumor (imputed):")
print(score_comparison[['level_tumor_collapsed_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 5) histology (path_histology)

# %%
score_comparison

# %%
def preprocess_histology(score_comparison, filtered_df):
    """
    Preprocess histology: collapse categories + MICE imputation for missing
    Histology is categorical: 0=No carcinoma (1), 1=Adenocarcinoma (4), 2=SCC (5), 3=Other (2,3,6,7,8), 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Histology")
    print("="*80)
    print("Preparing histology data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get histology columns
    histology_prep = pd.DataFrame({'patient_id': all_patient_ids})
    histology_prep = histology_prep.merge(
        filtered_df[["id", "path_histology___noca", "path_histology___hgd", "path_histology___cis", 
                        "path_histology___adeno", "path_histology___scc", "path_histology___nec", 
                        "path_histology___other"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    # Create histology mapping
    histology_mapping = {
        "path_histology___noca": 1,
        "path_histology___hgd": 2,
        "path_histology___cis": 3,
        "path_histology___adeno": 4,
        "path_histology___scc": 5,
        "path_histology___nec": 6,
        "path_histology___other": 7
    }
    
    # Assign histology
    def assign_histology(row):
        active_cols = [col for col in histology_mapping.keys() if row[col] == 1]
        if len(active_cols) == 1:
            return histology_mapping[active_cols[0]]
        elif len(active_cols) > 1:
            return 8  # mixed
        else:
            return None  # missing/NaN
    
    histology_prep['histology'] = histology_prep.apply(assign_histology, axis=1)
    
    # Group by patient_id and check if patient has multiple different histology types
    patient_histology = histology_prep.groupby('patient_id')['histology'].apply(
        lambda x: 8 if len(set(x.dropna())) > 1 else x.dropna().iloc[0] if len(x.dropna()) > 0 else None
    ).reset_index()
    patient_histology.columns = ['patient_id', 'final_histology']
    
    # Merge back
    histology_prep = histology_prep.merge(patient_histology[['patient_id', 'final_histology']], on='patient_id', how='left')
    
    # Drop the individual histology columns and rename final_histology
    histology_prep = histology_prep.drop(columns=[
        "path_histology___noca",
        "path_histology___hgd",
        "path_histology___cis",
        "path_histology___adeno",
        "path_histology___scc",
        "path_histology___nec",
        "path_histology___other",
        "histology"
    ]).rename(columns={"final_histology": "path_histology"})
    
    print(histology_prep['path_histology'].value_counts())
    
    # Find patient IDs where all path_histology values are missing
    patients_all_missing = histology_prep.groupby('patient_id')['path_histology'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute path_histology for those patients with 9999 (unknown)
    mask = histology_prep['patient_id'].isin(patients_to_impute)
    histology_prep.loc[mask, 'path_histology'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with path_histology=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in path_histology
    histology_prep_clean = histology_prep.dropna(subset=["path_histology"])
    histology_prep_clean = histology_prep_clean.drop_duplicates()
    
    print(histology_prep_clean['path_histology'].value_counts())
    
    # Collapse path_histology variable
    print("\nCollapsing path_histology variable...")
    histology_prep_clean['path_histology_collapsed'] = histology_prep_clean['path_histology'].copy()
    histology_prep_clean.loc[histology_prep_clean['path_histology'] == 1, 'path_histology_collapsed'] = 0  # No carcinoma
    histology_prep_clean.loc[histology_prep_clean['path_histology'] == 4, 'path_histology_collapsed'] = 1  # Adenocarcinoma
    histology_prep_clean.loc[histology_prep_clean['path_histology'] == 5, 'path_histology_collapsed'] = 2  # SCC
    # All other options except 9999 become "Other"
    other_mask = (~histology_prep_clean['path_histology'].isin([1, 4, 5, 9999])) & (~histology_prep_clean['path_histology'].isna())
    histology_prep_clean.loc[other_mask, 'path_histology_collapsed'] = 3  # Other
    histology_prep_clean.loc[histology_prep_clean['path_histology'] == 9999, 'path_histology_collapsed'] = 9999  # Unknown
    
    print("Path histology collapsed - Value counts:")
    print(histology_prep_clean['path_histology_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for path_histology=9999...")
    
    # Replace 9999 with NaN for imputation
    histology_prep_clean['path_histology_collapsed_for_imputation'] = histology_prep_clean['path_histology_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    histology_prep_clean = histology_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(histology_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = histology_prep_clean[['path_histology_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_histology = completed_data['path_histology_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    histology_imputation_map = dict(zip(histology_prep_clean['patient_id'], imputed_histology))
    
    print("Path histology after MICE imputation - Value counts:")
    print(pd.Series(imputed_histology).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed histology values
    histology_final = pd.DataFrame({
        'patient_id': list(histology_imputation_map.keys()),
        'path_histology_collapsed_imputed': list(histology_imputation_map.values())
    })
    histology_final = histology_final.set_index('patient_id')
    
    # Calculate summary statistics
    histology_data = histology_final['path_histology_collapsed_imputed']
    n_no_carcinoma = (histology_data == 0).sum()
    n_adeno = (histology_data == 1).sum()
    n_scc = (histology_data == 2).sum()
    n_other = (histology_data == 3).sum()
    total = len(histology_data)
    
    print(f"\nFinal histology distribution:")
    print(f"  N: {total}")
    print(f"  No Carcinoma (0): {n_no_carcinoma} ({n_no_carcinoma/total*100:.1f}%)")
    print(f"  Adenocarcinoma (1): {n_adeno} ({n_adeno/total*100:.1f}%)")
    print(f"  SCC (2): {n_scc} ({n_scc/total*100:.1f}%)")
    print(f"  Other (3): {n_other} ({n_other/total*100:.1f}%)")
    print(f"  Mean: {histology_data.mean():.2f}")
    print(f"  SD: {histology_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        histology_final[['path_histology_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'path_histology_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_no_carcinoma': n_no_carcinoma,
        'n_adeno': n_adeno,
        'n_scc': n_scc,
        'n_other': n_other,
        'mean': histology_data.mean(),
        'sd': histology_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
histology_summaries = preprocess_histology(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = histology_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of histology (imputed):")
print(score_comparison[['path_histology_collapsed_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 6) pathological stage (path_esoph_stage)

# %%
score_comparison

# %%
def preprocess_path_stage(score_comparison, filtered_df):
    """
    Preprocess path_esoph_stage: collapse categories + MICE imputation for missing
    Path stage is categorical: 0=Stage 0, 1=Stage I (1a,1b,1c), 2=Stage II (2a,2b), 3=Stage III (3a,3b), 4=Stage IV (4a,4b), 5=pCR, 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Pathological Stage")
    print("="*80)
    print("Preparing pathological stage data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get path_esoph_stage
    stage_prep = pd.DataFrame({'patient_id': all_patient_ids})
    stage_prep = stage_prep.merge(
        filtered_df[["id", "path_esoph_stage"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(stage_prep['path_esoph_stage'].value_counts())
    
    # Find patient IDs where all path_esoph_stage values are missing
    patients_all_missing = stage_prep.groupby('patient_id')['path_esoph_stage'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute path_esoph_stage for those patients with 9999 (unknown)
    mask = stage_prep['patient_id'].isin(patients_to_impute)
    stage_prep.loc[mask, 'path_esoph_stage'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with path_esoph_stage=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in path_esoph_stage
    stage_prep_clean = stage_prep.dropna(subset=["path_esoph_stage"])
    stage_prep_clean = stage_prep_clean.drop_duplicates()
    
    print(stage_prep_clean['path_esoph_stage'].value_counts())
    
    # Collapse path_esoph_stage variable
    print("\nCollapsing path_esoph_stage variable...")
    stage_prep_clean['path_esoph_stage_collapsed'] = stage_prep_clean['path_esoph_stage'].copy()
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'] == 0, 'path_esoph_stage_collapsed'] = 0  # Stage 0
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'].isin(['1a', '1b', '1c']), 'path_esoph_stage_collapsed'] = 1  # Stage I
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'].isin(['2a', '2b']), 'path_esoph_stage_collapsed'] = 2  # Stage II
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'].isin(['3a', '3b']), 'path_esoph_stage_collapsed'] = 3  # Stage III
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'].isin(['4a', '4b']), 'path_esoph_stage_collapsed'] = 4  # Stage IV
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'] == 5, 'path_esoph_stage_collapsed'] = 5  # pCR
    stage_prep_clean.loc[stage_prep_clean['path_esoph_stage'] == 9999, 'path_esoph_stage_collapsed'] = 9999  # Unknown
    
    stage_prep_clean['path_esoph_stage_collapsed'] = pd.to_numeric(stage_prep_clean['path_esoph_stage_collapsed'], errors='coerce')
    
    print("Path esoph stage collapsed - Value counts:")
    print(stage_prep_clean['path_esoph_stage_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for path_esoph_stage=9999...")
    
    # Replace 9999 with NaN for imputation
    stage_prep_clean['path_esoph_stage_collapsed_for_imputation'] = stage_prep_clean['path_esoph_stage_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    stage_prep_clean = stage_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(stage_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = stage_prep_clean[['path_esoph_stage_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_stage = completed_data['path_esoph_stage_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    stage_imputation_map = dict(zip(stage_prep_clean['patient_id'], imputed_stage))
    
    print("Path esoph stage after MICE imputation - Value counts:")
    print(pd.Series(imputed_stage).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed stage values
    stage_final = pd.DataFrame({
        'patient_id': list(stage_imputation_map.keys()),
        'path_esoph_stage_collapsed_imputed': list(stage_imputation_map.values())
    })
    stage_final = stage_final.set_index('patient_id')
    
    # Calculate summary statistics
    stage_data = stage_final['path_esoph_stage_collapsed_imputed']
    n_stage0 = (stage_data == 0).sum()
    n_stage1 = (stage_data == 1).sum()
    n_stage2 = (stage_data == 2).sum()
    n_stage3 = (stage_data == 3).sum()
    n_stage4 = (stage_data == 4).sum()
    n_pcr = (stage_data == 5).sum()
    total = len(stage_data)
    
    print(f"\nFinal pathological stage distribution:")
    print(f"  N: {total}")
    print(f"  Stage 0 (0): {n_stage0} ({n_stage0/total*100:.1f}%)")
    print(f"  Stage I (1): {n_stage1} ({n_stage1/total*100:.1f}%)")
    print(f"  Stage II (2): {n_stage2} ({n_stage2/total*100:.1f}%)")
    print(f"  Stage III (3): {n_stage3} ({n_stage3/total*100:.1f}%)")
    print(f"  Stage IV (4): {n_stage4} ({n_stage4/total*100:.1f}%)")
    print(f"  pCR (5): {n_pcr} ({n_pcr/total*100:.1f}%)")
    print(f"  Mean: {stage_data.mean():.2f}")
    print(f"  SD: {stage_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        stage_final[['path_esoph_stage_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'path_esoph_stage_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_stage0': n_stage0,
        'n_stage1': n_stage1,
        'n_stage2': n_stage2,
        'n_stage3': n_stage3,
        'n_stage4': n_stage4,
        'n_pcr': n_pcr,
        'mean': stage_data.mean(),
        'sd': stage_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
path_stage_summaries = preprocess_path_stage(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = path_stage_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of path_esoph_stage (imputed):")
print(score_comparison[['path_esoph_stage_collapsed_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 7) surgery type (procedure123456/abdomen+chest)

# %%
score_comparison

# %%
def preprocess_surgery_approach(score_comparison, filtered_df):
    """
    Preprocess surgery_approach: combine abdomen_approach and chest_approach + MICE imputation for missing
    Surgery approach is categorical: 0=Open, 1=Minimally Invasive, 9999=Unknown (then imputed with MICE)
    Built from abdomen_approach and chest_approach
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Surgery Approach")
    print("="*80)
    print("Preparing surgery approach data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # ========== Process abdomen_approach ==========
    print("\n--- Processing abdomen_approach ---")
    abdomen_prep = pd.DataFrame({'patient_id': all_patient_ids})
    abdomen_prep = abdomen_prep.merge(
        filtered_df[["id", "abdomen_approach"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(abdomen_prep['abdomen_approach'].value_counts())
    
    # Find patient IDs where all abdomen_approach values are missing
    patients_all_missing_abdomen = abdomen_prep.groupby('patient_id')['abdomen_approach'].apply(lambda x: x.isna().all())
    patients_to_impute_abdomen = patients_all_missing_abdomen[patients_all_missing_abdomen].index
    
    # Impute abdomen_approach for those patients with 9999 (unknown)
    mask = abdomen_prep['patient_id'].isin(patients_to_impute_abdomen)
    abdomen_prep.loc[mask, 'abdomen_approach'] = 9999.0
    print(f"Imputed {len(patients_to_impute_abdomen)} unique patients with abdomen_approach=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in abdomen_approach
    abdomen_prep_clean = abdomen_prep.dropna(subset=["abdomen_approach"])
    abdomen_prep_clean = abdomen_prep_clean.drop_duplicates()
    
    # Check for duplicate patient IDs and keep first, drop last
    duplicate_ids = abdomen_prep_clean['patient_id'][abdomen_prep_clean['patient_id'].duplicated()].unique()
    if len(duplicate_ids) > 0:
        print(f"Found {len(duplicate_ids)} patients with duplicate abdomen_approach entries")
        for patient_id in duplicate_ids:
            patient_rows = abdomen_prep_clean[abdomen_prep_clean['patient_id'] == patient_id]
            last_index = patient_rows.index[-1]
            abdomen_prep_clean = abdomen_prep_clean.drop(index=last_index)
            print(f"Dropped last occurrence for patient {patient_id}")
    
    print(abdomen_prep_clean['abdomen_approach'].value_counts())
    
    # ========== Process chest_approach ==========
    print("\n--- Processing chest_approach ---")
    chest_prep = pd.DataFrame({'patient_id': all_patient_ids})
    chest_prep = chest_prep.merge(
        filtered_df[["id", "chest_approach"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(chest_prep['chest_approach'].value_counts())
    
    # Find patient IDs where all chest_approach values are missing
    patients_all_missing_chest = chest_prep.groupby('patient_id')['chest_approach'].apply(lambda x: x.isna().all())
    patients_to_impute_chest = patients_all_missing_chest[patients_all_missing_chest].index
    
    # Impute chest_approach for those patients with 9999 (unknown)
    mask = chest_prep['patient_id'].isin(patients_to_impute_chest)
    chest_prep.loc[mask, 'chest_approach'] = 9999.0
    print(f"Imputed {len(patients_to_impute_chest)} unique patients with chest_approach=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in chest_approach
    chest_prep_clean = chest_prep.dropna(subset=["chest_approach"])
    chest_prep_clean = chest_prep_clean.drop_duplicates()
    
    # Check for duplicate patient IDs and keep first, drop last
    duplicate_ids = chest_prep_clean['patient_id'][chest_prep_clean['patient_id'].duplicated()].unique()
    if len(duplicate_ids) > 0:
        print(f"Found {len(duplicate_ids)} patients with duplicate chest_approach entries")
        for patient_id in duplicate_ids:
            patient_rows = chest_prep_clean[chest_prep_clean['patient_id'] == patient_id]
            last_index = patient_rows.index[-1]
            chest_prep_clean = chest_prep_clean.drop(index=last_index)
            print(f"Dropped last occurrence for patient {patient_id}")
    
    print(chest_prep_clean['chest_approach'].value_counts())
    
    # ========== Merge abdomen and chest approaches ==========
    print("\n--- Creating surgery approach classification ---")
    surgery_prep = abdomen_prep_clean.merge(
        chest_prep_clean[['patient_id', 'chest_approach']], 
        on='patient_id', 
        how='left'
    )
    
    surgery_prep['surgery_approach'] = 9999  # Default to missing
    
    # Define conditions for minimally invasive
    minimally_invasive_abdomen = surgery_prep['abdomen_approach'] == 2  # LAP
    minimally_invasive_chest = surgery_prep['chest_approach'].isin([2, 4])  # VATS or Prone
    
    # Define conditions for open (takes priority)
    open_abdomen = surgery_prep['abdomen_approach'].isin([1, 3])  # Open or LAP to Open
    open_chest = surgery_prep['chest_approach'].isin([1, 3])  # Open or VATS to Open
    
    # Define conditions for missing data
    missing_abdomen = surgery_prep['abdomen_approach'].isin([4, 9999]) | surgery_prep['abdomen_approach'].isna()
    missing_chest = surgery_prep['chest_approach'].isin([5, 9999]) | surgery_prep['chest_approach'].isna()
    
    # Classify surgery approach
    # Open takes priority
    surgery_prep.loc[open_abdomen | open_chest, 'surgery_approach'] = 0  # Open
    
    # Minimally invasive (only if not already classified as open)
    surgery_prep.loc[(surgery_prep['surgery_approach'] != 0) &
                        (minimally_invasive_abdomen | minimally_invasive_chest), 'surgery_approach'] = 1  # Minimally Invasive
    
    # Missing only if both approaches are missing/NA and not already classified
    surgery_prep.loc[(surgery_prep['surgery_approach'] == 9999) &
                        missing_abdomen & missing_chest, 'surgery_approach'] = 9999  # Missing
    
    print(f"Surgery approach - Value counts:\n{surgery_prep['surgery_approach'].value_counts()}")
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for surgery_approach=9999...")
    
    # Replace 9999 with NaN for imputation
    surgery_prep['surgery_approach_for_imputation'] = surgery_prep['surgery_approach'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    surgery_prep = surgery_prep.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(surgery_prep)} unique patients")
    
    # Create dataset for MICE
    mice_data = surgery_prep[['surgery_approach_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_surgery = completed_data['surgery_approach_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    surgery_imputation_map = dict(zip(surgery_prep['patient_id'], imputed_surgery))
    
    print("Surgery approach after MICE imputation - Value counts:")
    print(pd.Series(imputed_surgery).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed surgery values
    surgery_final = pd.DataFrame({
        'patient_id': list(surgery_imputation_map.keys()),
        'surgery_approach_imputed': list(surgery_imputation_map.values())
    })
    surgery_final = surgery_final.set_index('patient_id')
    
    # Calculate summary statistics
    surgery_data = surgery_final['surgery_approach_imputed']
    n_open = (surgery_data == 0).sum()
    n_minimally_invasive = (surgery_data == 1).sum()
    total = len(surgery_data)
    
    print(f"\nFinal surgery approach distribution:")
    print(f"  N: {total}")
    print(f"  Open (0): {n_open} ({n_open/total*100:.1f}%)")
    print(f"  Minimally Invasive (1): {n_minimally_invasive} ({n_minimally_invasive/total*100:.1f}%)")
    print(f"  Mean: {surgery_data.mean():.2f}")
    print(f"  SD: {surgery_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        surgery_final[['surgery_approach_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'surgery_approach_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing_abdomen': len(patients_to_impute_abdomen),
        'n_missing_chest': len(patients_to_impute_chest),
        'n_open': n_open,
        'n_minimally_invasive': n_minimally_invasive,
        'mean': surgery_data.mean(),
        'sd': surgery_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
surgery_approach_summaries = preprocess_surgery_approach(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = surgery_approach_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of surgery_approach (imputed):")
print(score_comparison[['surgery_approach_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 8) Neoadjuvant treatment

# %%
score_comparison

# %%
def preprocess_neotx(score_comparison, filtered_df):
    """
    Preprocess neotx: collapse categories + MICE imputation for missing
    Neotx is categorical: 0=None (1), 1=Chemotherapy (2), 2=Chemoradiotherapy (4), 3=Other (3,5,6,7), 9999=Unknown (then imputed with MICE)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    import miceforest as mf
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Neoadjuvant Treatment")
    print("="*80)
    print("Preparing neoadjuvant treatment data for MICE imputation...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get neotx columns
    neotx_prep = pd.DataFrame({'patient_id': all_patient_ids})
    neotx_prep = neotx_prep.merge(
        filtered_df[["id", "neotx___notx", "neotx___chemo", "neotx___rads", 
                        "neotx___chemorads", "neotx___immuno", "neotx___other"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    # Create neotx mapping
    neotx_mapping = {
        "neotx___notx": 1,
        "neotx___chemo": 2,
        "neotx___rads": 3,
        "neotx___chemorads": 4,
        "neotx___immuno": 5,
        "neotx___other": 6
    }
    
    # Assign neotx
    def assign_neotx(row):
        active_cols = [col for col in neotx_mapping.keys() if row[col] == 1]
        if len(active_cols) == 1:
            return neotx_mapping[active_cols[0]]
        elif len(active_cols) > 1:
            return 7  # mixed
        else:
            return None  # missing/NaN
    
    neotx_prep['neotx'] = neotx_prep.apply(assign_neotx, axis=1)
    
    # Group by patient_id and check if patient has multiple different neotx types
    patient_neotx = neotx_prep.groupby('patient_id')['neotx'].apply(
        lambda x: 7 if len(set(x.dropna())) > 1 else x.dropna().iloc[0] if len(x.dropna()) > 0 else None
    ).reset_index()
    patient_neotx.columns = ['patient_id', 'final_neotx']
    
    # Merge back
    neotx_prep = neotx_prep.merge(patient_neotx[['patient_id', 'final_neotx']], on='patient_id', how='left')
    
    # Drop the individual neotx columns and rename final_neotx
    neotx_prep = neotx_prep.drop(columns=[
        "neotx___notx",
        "neotx___chemo",
        "neotx___rads",
        "neotx___chemorads",
        "neotx___immuno",
        "neotx___other",
        "neotx"
    ]).rename(columns={"final_neotx": "neotx"})
    
    print(neotx_prep['neotx'].value_counts())
    
    # Find patient IDs where all neotx values are missing
    patients_all_missing = neotx_prep.groupby('patient_id')['neotx'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute neotx for those patients with 9999 (unknown)
    mask = neotx_prep['patient_id'].isin(patients_to_impute)
    neotx_prep.loc[mask, 'neotx'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with neotx=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in neotx
    neotx_prep_clean = neotx_prep.dropna(subset=["neotx"])
    neotx_prep_clean = neotx_prep_clean.drop_duplicates()
    
    print(neotx_prep_clean['neotx'].value_counts())
    
    # Collapse neotx variable
    print("\nCollapsing neotx variable...")
    neotx_prep_clean['neotx_collapsed'] = neotx_prep_clean['neotx'].copy()
    neotx_prep_clean.loc[neotx_prep_clean['neotx'] == 1, 'neotx_collapsed'] = 0  # None
    neotx_prep_clean.loc[neotx_prep_clean['neotx'] == 2, 'neotx_collapsed'] = 1  # Chemotherapy
    neotx_prep_clean.loc[neotx_prep_clean['neotx'] == 4, 'neotx_collapsed'] = 2  # Chemoradiotherapy
    neotx_prep_clean.loc[neotx_prep_clean['neotx'].isin([3, 5, 6, 7]), 'neotx_collapsed'] = 3  # Other
    neotx_prep_clean.loc[neotx_prep_clean['neotx'] == 9999, 'neotx_collapsed'] = 9999  # Unknown
    
    print("Neotx collapsed - Value counts:")
    print(neotx_prep_clean['neotx_collapsed'].value_counts())
    
    # Perform MICE imputation ONCE
    print("\nPerforming MICE imputation for neotx=9999...")
    
    # Replace 9999 with NaN for imputation
    neotx_prep_clean['neotx_collapsed_for_imputation'] = neotx_prep_clean['neotx_collapsed'].replace(9999, np.nan)
    
    # Merge baseline FACT-E for imputation model
    neotx_prep_clean = neotx_prep_clean.merge(
        score_comparison[['fact_e_total_Baseline']],
        left_on='patient_id',
        right_index=True,
        how='left'
    )
    
    print(f"Running MICE on {len(neotx_prep_clean)} unique patients")
    
    # Create dataset for MICE
    mice_data = neotx_prep_clean[['neotx_collapsed_for_imputation', 'fact_e_total_Baseline']].copy()
    
    # MICE imputation
    mice_imputer = mf.ImputationKernel(
        mice_data,
        datasets=3,
        random_state=42
    )
    
    mice_imputer.mice(iterations=3, verbose=True)
    
    # Get completed dataset
    completed_data = mice_imputer.complete_data(0)
    
    # Extract imputed values
    imputed_neotx = completed_data['neotx_collapsed_for_imputation'].round().astype(int)
    
    # Create mapping dictionary for all patients
    neotx_imputation_map = dict(zip(neotx_prep_clean['patient_id'], imputed_neotx))
    
    print("Neotx after MICE imputation - Value counts:")
    print(pd.Series(imputed_neotx).value_counts())
    print("\n" + "="*80)
    
    # Create final dataframe with imputed neotx values
    neotx_final = pd.DataFrame({
        'patient_id': list(neotx_imputation_map.keys()),
        'neotx_collapsed_imputed': list(neotx_imputation_map.values())
    })
    neotx_final = neotx_final.set_index('patient_id')
    
    # Calculate summary statistics
    neotx_data = neotx_final['neotx_collapsed_imputed']
    n_none = (neotx_data == 0).sum()
    n_chemo = (neotx_data == 1).sum()
    n_chemorads = (neotx_data == 2).sum()
    n_other = (neotx_data == 3).sum()
    total = len(neotx_data)
    
    print(f"\nFinal neoadjuvant treatment distribution:")
    print(f"  N: {total}")
    print(f"  None (0): {n_none} ({n_none/total*100:.1f}%)")
    print(f"  Chemotherapy (1): {n_chemo} ({n_chemo/total*100:.1f}%)")
    print(f"  Chemoradiotherapy (2): {n_chemorads} ({n_chemorads/total*100:.1f}%)")
    print(f"  Other (3): {n_other} ({n_other/total*100:.1f}%)")
    print(f"  Mean: {neotx_data.mean():.2f}")
    print(f"  SD: {neotx_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        neotx_final[['neotx_collapsed_imputed']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'neotx_collapsed_imputed'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_none': n_none,
        'n_chemo': n_chemo,
        'n_chemorads': n_chemorads,
        'n_other': n_other,
        'mean': neotx_data.mean(),
        'sd': neotx_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
neotx_summaries = preprocess_neotx(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = neotx_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of neotx (imputed):")
print(score_comparison[['neotx_collapsed_imputed']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 9) age (age_diagnosis)

# %%
score_comparison

# %%
def preprocess_age(score_comparison, filtered_df):
    """
    Preprocess age: median imputation for missing + z-score standardization
    Age is continuous variable, missing values imputed with median
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Age at Diagnosis")
    print("="*80)
    print("Preparing age data...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get age_diagnosis
    age_prep = pd.DataFrame({'patient_id': all_patient_ids})
    age_prep = age_prep.merge(
        filtered_df[["id", "age_diagnosis"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    # Calculate median age from all non-missing values
    median_age = age_prep['age_diagnosis'].median()
    
    # Find patient IDs where all age values are missing
    patients_all_missing = age_prep.groupby('patient_id')['age_diagnosis'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute age for those patients
    mask = age_prep['patient_id'].isin(patients_to_impute)
    age_prep.loc[mask, 'age_diagnosis'] = median_age
    print(f"Imputed {len(patients_to_impute)} unique patients with median age: {median_age:.2f}")
    
    # Create a clean dataframe with no missing values in age
    age_prep_clean = age_prep.dropna(subset=["age_diagnosis"])
    age_prep_clean = age_prep_clean.drop_duplicates()
    
    print(f"Age range: {age_prep_clean['age_diagnosis'].min():.1f} - {age_prep_clean['age_diagnosis'].max():.1f}")
    print(f"Age mean: {age_prep_clean['age_diagnosis'].mean():.1f} (SD: {age_prep_clean['age_diagnosis'].std():.1f})")
    
    # Calculate mean and SD for z-score standardization
    mean_age = age_prep_clean['age_diagnosis'].mean()
    sd_age = age_prep_clean['age_diagnosis'].std()
    
    print(f"\nAge statistics after imputation:")
    print(f"  Mean: {mean_age:.2f}")
    print(f"  SD: {sd_age:.2f}")
    print(f"  Min: {age_prep_clean['age_diagnosis'].min():.2f}")
    print(f"  Max: {age_prep_clean['age_diagnosis'].max():.2f}")
    
    # Z-score standardization
    age_prep_clean['age_diagnosis_std'] = (age_prep_clean['age_diagnosis'] - mean_age) / sd_age
    
    print(f"\nStandardized age statistics:")
    print(f"  Mean: {age_prep_clean['age_diagnosis_std'].mean():.2f}")
    print(f"  SD: {age_prep_clean['age_diagnosis_std'].std():.2f}")
    print(f"  Min: {age_prep_clean['age_diagnosis_std'].min():.2f}")
    print(f"  Max: {age_prep_clean['age_diagnosis_std'].max():.2f}")
    
    # Create final dataframe
    age_final = age_prep_clean[['patient_id', 'age_diagnosis', 'age_diagnosis_std']].drop_duplicates(subset=['patient_id'])
    age_final = age_final.set_index('patient_id')
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        age_final[['age_diagnosis', 'age_diagnosis_std']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created columns: 'age_diagnosis' and 'age_diagnosis_std'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'median': median_age,
        'mean': mean_age,
        'sd': sd_age,
        'min': age_prep_clean['age_diagnosis'].min(),
        'max': age_prep_clean['age_diagnosis'].max(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
age_summaries = preprocess_age(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = age_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of age (original and standardized):")
print(score_comparison[['age_diagnosis', 'age_diagnosis_std']].head(10))

# %%
score_comparison

# %% [markdown]
# # Characteristic by class - 10) sex

# %%
score_comparison

# %%
def preprocess_gender(score_comparison, filtered_df):
    """
    Preprocess gender: handle missing values (no MICE needed if no missing)
    Gender is categorical: 1=Male, 2=Female, 9999=Unknown (if any missing)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Gender")
    print("="*80)
    print("Preparing gender data...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get gender
    gender_prep = pd.DataFrame({'patient_id': all_patient_ids})
    gender_prep = gender_prep.merge(
        filtered_df[["id", "gender"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    print(gender_prep['gender'].value_counts())
    
    # Find patient IDs where all gender values are missing
    patients_all_missing = gender_prep.groupby('patient_id')['gender'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute gender for those patients with 9999 (unknown)
    mask = gender_prep['patient_id'].isin(patients_to_impute)
    gender_prep.loc[mask, 'gender'] = 9999.0
    print(f"Imputed {len(patients_to_impute)} unique patients with gender=9999 (unknown)")
    
    # Create a clean dataframe with no missing values in gender
    gender_prep_clean = gender_prep.dropna(subset=["gender"])
    gender_prep_clean = gender_prep_clean.drop_duplicates()
    
    print(gender_prep_clean['gender'].value_counts())
    
    # Create final dataframe
    gender_final = gender_prep_clean[['patient_id', 'gender']].drop_duplicates(subset=['patient_id'])
    gender_final = gender_final.set_index('patient_id')
    
    # Calculate summary statistics
    gender_data = gender_final['gender']
    n_male = (gender_data == 1).sum()
    n_female = (gender_data == 2).sum()
    n_unknown = (gender_data == 9999).sum()
    total = len(gender_data)
    
    print(f"\nFinal gender distribution:")
    print(f"  N: {total}")
    print(f"  Male (1): {n_male} ({n_male/total*100:.1f}%)")
    print(f"  Female (2): {n_female} ({n_female/total*100:.1f}%)")
    print(f"  Unknown (9999): {n_unknown} ({n_unknown/total*100:.1f}%)")
    print(f"  Mean: {gender_data.mean():.2f}")
    print(f"  SD: {gender_data.std():.2f}")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        gender_final[['gender']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created column: 'gender'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'n_male': n_male,
        'n_female': n_female,
        'n_unknown': n_unknown,
        'mean': gender_data.mean(),
        'sd': gender_data.std(),
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
gender_summaries = preprocess_gender(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = gender_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of gender:")
print(score_comparison[['gender']].head(10))

# %%
score_comparison

# %% [markdown]
# # Characteristic by class - 11) charlson comorbidity index (cci_total)

# %%
score_comparison

# %%
def preprocess_cci(score_comparison, filtered_df):
    """
    Preprocess CCI: median imputation for missing + z-score standardization
    CCI is continuous variable, missing values imputed with median
    Also creates categorical version: 0=None (0), 1=Mild (1-2), 2=Moderate (3-4), 3=Severe (5+)
    
    Returns:
    - Dictionary with preprocessing results and statistics
    """
    
    print("="*80)
    print("STEP 2: PREDICTOR PREPROCESSING - Charlson Comorbidity Index")
    print("="*80)
    print("Preparing Charlson Comorbidity Index data...")
    
    # Get all unique patient IDs from score_comparison
    all_patient_ids = score_comparison.index.tolist()
    
    # Merge with filtered_df to get cci_total
    cci_prep = pd.DataFrame({'patient_id': all_patient_ids})
    cci_prep = cci_prep.merge(
        filtered_df[["id", "cci_total"]],
        left_on='patient_id',
        right_on='id',
        how='left'
    )
    
    # Calculate median CCI from all non-missing values
    median_cci = cci_prep['cci_total'].median()
    
    # Find patient IDs where all CCI values are missing
    patients_all_missing = cci_prep.groupby('patient_id')['cci_total'].apply(lambda x: x.isna().all())
    patients_to_impute = patients_all_missing[patients_all_missing].index
    
    # Impute CCI for those patients
    mask = cci_prep['patient_id'].isin(patients_to_impute)
    cci_prep.loc[mask, 'cci_total'] = median_cci
    print(f"Imputed {len(patients_to_impute)} unique patients with median CCI: {median_cci:.2f}")
    
    # Create a clean dataframe with no missing values in CCI
    cci_prep_clean = cci_prep.dropna(subset=["cci_total"])
    cci_prep_clean = cci_prep_clean.drop_duplicates()
    
    # Define the categorization function
    def categorize_cci(cci):
        if cci == 0:
            return 0  # "None"
        elif cci <= 2:
            return 1  # "Mild"
        elif cci <= 4:
            return 2  # "Moderate"
        else:
            return 3  # "Severe"
    
    # Apply the categorization function to create the categorical variable
    cci_prep_clean['cci_category_numeric'] = cci_prep_clean['cci_total'].apply(categorize_cci)
    
    print(f"\nCCI range: {cci_prep_clean['cci_total'].min():.1f} - {cci_prep_clean['cci_total'].max():.1f}")
    print(f"CCI mean: {cci_prep_clean['cci_total'].mean():.1f} (SD: {cci_prep_clean['cci_total'].std():.1f})")
    print("\nCCI categorical distribution:")
    print(cci_prep_clean['cci_category_numeric'].value_counts().sort_index())
    
    # Calculate mean and SD for z-score standardization
    mean_cci = cci_prep_clean['cci_total'].mean()
    sd_cci = cci_prep_clean['cci_total'].std()
    
    print(f"\nCCI statistics after imputation:")
    print(f"  Mean: {mean_cci:.2f}")
    print(f"  SD: {sd_cci:.2f}")
    print(f"  Min: {cci_prep_clean['cci_total'].min():.2f}")
    print(f"  Max: {cci_prep_clean['cci_total'].max():.2f}")
    
    # Z-score standardization
    cci_prep_clean['cci_total_std'] = (cci_prep_clean['cci_total'] - mean_cci) / sd_cci
    
    print(f"\nStandardized CCI statistics:")
    print(f"  Mean: {cci_prep_clean['cci_total_std'].mean():.2f}")
    print(f"  SD: {cci_prep_clean['cci_total_std'].std():.2f}")
    print(f"  Min: {cci_prep_clean['cci_total_std'].min():.2f}")
    print(f"  Max: {cci_prep_clean['cci_total_std'].max():.2f}")
    
    # Create final dataframe
    cci_final = cci_prep_clean[['patient_id', 'cci_total', 'cci_total_std', 'cci_category_numeric']].drop_duplicates(subset=['patient_id'])
    cci_final = cci_final.set_index('patient_id')
    
    # Calculate categorical summary statistics
    cci_cat_data = cci_final['cci_category_numeric']
    n_none = (cci_cat_data == 0).sum()
    n_mild = (cci_cat_data == 1).sum()
    n_moderate = (cci_cat_data == 2).sum()
    n_severe = (cci_cat_data == 3).sum()
    total = len(cci_cat_data)
    
    print(f"\nFinal CCI categorical distribution:")
    print(f"  None (0): {n_none} ({n_none/total*100:.1f}%)")
    print(f"  Mild (1): {n_mild} ({n_mild/total*100:.1f}%)")
    print(f"  Moderate (2): {n_moderate} ({n_moderate/total*100:.1f}%)")
    print(f"  Severe (3): {n_severe} ({n_severe/total*100:.1f}%)")
    
    # Merge back to score_comparison
    score_comparison = score_comparison.merge(
        cci_final[['cci_total', 'cci_total_std', 'cci_category_numeric']], 
        left_index=True, 
        right_index=True, 
        how='left'
    )
    
    print("\n✓ Created columns: 'cci_total', 'cci_total_std', 'cci_category_numeric'")
    print("="*80)
    
    # Return results dictionary
    results = {
        'n_total': len(all_patient_ids),
        'n_missing': len(patients_to_impute),
        'median': median_cci,
        'mean': mean_cci,
        'sd': sd_cci,
        'min': cci_prep_clean['cci_total'].min(),
        'max': cci_prep_clean['cci_total'].max(),
        'n_none': n_none,
        'n_mild': n_mild,
        'n_moderate': n_moderate,
        'n_severe': n_severe,
        'preprocessed_data': score_comparison
    }
    
    return results

# Run preprocessing
cci_summaries = preprocess_cci(score_comparison, filtered_df)

# Update score_comparison with preprocessed data
score_comparison = cci_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of CCI (original, standardized, and categorical):")
print(score_comparison[['cci_total', 'cci_total_std', 'cci_category_numeric']].head(10))

# %%
score_comparison

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # Characteristic by class - 12) 5 subscale scores baseline

# %%
score_comparison=pd.read_csv("score_comparison_preprocessed.csv", index_col='id')
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  path_histology_collapsed_imputed  \
# id                                 ...
# 32                           19.0  ...                                 0
# 76                           15.0  ...                                 1
# 125                           8.0  ...                                 1
# 160                          20.0  ...                                 1
# 198                          21.0  ...                                 3
# ...                           ...  ...                               ...
# 1566                         18.0  ...                                 1
# 1571                         25.0  ...                                 0
# 1572                         20.0  ...                                 3
# 1615                         12.0  ...                                 1
# 1653                         24.0  ...                                 1
#
#       path_esoph_stage_collapsed_imputed  surgery_approach_imputed  \
# id
# 32                                     4                         0
# 76                                     2                         1
# 125                                    3                         0
# 160                                    3                         0
# 198                                    2                         1
# ...                                  ...                       ...
# 1566                                   3                         1
# 1571                                   2                         0
# 1572                                   3                         0
# 1615                                   2                         1
# 1653                                   1                         1
#
#       neotx_collapsed_imputed  age_diagnosis  age_diagnosis_std  gender  \
# id
# 32                          1      29.722718          -3.924010     1.0
# 76                          1      57.597350          -0.759442     1.0
# 125                         1      64.110830          -0.019975     1.0
# 160                         1      50.804602          -1.530613     1.0
# 198                         1      66.229970           0.220608     2.0
# ...                       ...            ...                ...     ...
# 1566                        1      69.876863           0.634635     1.0
# 1571                        1      79.245980           1.698298     1.0
# 1572                        1      60.529648          -0.426542     1.0
# 1615                        1      55.623319          -0.983551     1.0
# 1653                        1      75.360890           1.257229     1.0
#
#       cci_total  cci_total_std  cci_category_numeric
# id
# 32          2.0      -1.324120                     1
# 76          4.0       0.044349                     2
# 125         4.0       0.044349                     2
# 160         4.0       0.044349                     2
# 198         4.0       0.044349                     2
# ...         ...            ...                   ...
# 1566        4.0       0.044349                     2
# 1571        6.0       1.412817                     3
# 1572        4.0       0.044349                     2
# 1615        4.0       0.044349                     2
# 1653        4.0       0.044349                     2
#
# [108 rows x 29 columns]

# %%
def preprocess_subscale_baselines(score_comparison):
    """
    Preprocess baseline subscale scores: z-score standardization (no imputation needed as no missing values)
    
    Returns:
    - Dictionary with preprocessing results and statistics for all 5 subscales
    """
    
    subscales = ['pwb_subscale_score', 'swb_subscale_score', 'ewb_subscale_score', 
                 'fwb_subscale_score', 'ecs_subscale_score']
    
    all_results = {}
    
    for subscale in subscales:
        baseline_col = f'{subscale}_Baseline'
        
        # Check for missing values
        n_missing = score_comparison[baseline_col].isna().sum()
        n_total = len(score_comparison)
        
        print("="*80)
        print(f"STEP 2: PREDICTOR PREPROCESSING - {subscale.upper()} Baseline")
        print("="*80)
        print(f"Total patients: {n_total}")
        print(f"Missing {subscale} baseline: {n_missing}")
        print(f"Complete {subscale} baseline: {n_total - n_missing}")
        
        if n_missing > 0:
            print(f"\nWARNING: {n_missing} patients have missing baseline {subscale}")
        else:
            print(f"\n✓ No missing values - proceeding with z-score standardization")
        
        # Calculate mean and SD
        mean_score = score_comparison[baseline_col].mean()
        sd_score = score_comparison[baseline_col].std()
        
        print(f"\nBaseline {subscale} statistics:")
        print(f"  Mean: {mean_score:.2f}")
        print(f"  SD: {sd_score:.2f}")
        print(f"  Min: {score_comparison[baseline_col].min():.2f}")
        print(f"  Max: {score_comparison[baseline_col].max():.2f}")
        
        # Z-score standardization
        score_comparison[f'{baseline_col}_std'] = (
            (score_comparison[baseline_col] - mean_score) / sd_score
        )
        
        print(f"\nStandardized {subscale} statistics:")
        print(f"  Mean: {score_comparison[f'{baseline_col}_std'].mean():.2f}")
        print(f"  SD: {score_comparison[f'{baseline_col}_std'].std():.2f}")
        print(f"  Min: {score_comparison[f'{baseline_col}_std'].min():.2f}")
        print(f"  Max: {score_comparison[f'{baseline_col}_std'].max():.2f}")
        
        print(f"\n✓ Created column: '{baseline_col}_std'")
        print("="*80)
        
        # Store results for this subscale
        all_results[subscale] = {
            'n_total': n_total,
            'n_missing': n_missing,
            'n_complete': n_total - n_missing,
            'mean': mean_score,
            'sd': sd_score,
            'min': score_comparison[baseline_col].min(),
            'max': score_comparison[baseline_col].max()
        }
    
    # Return results dictionary
    all_results['preprocessed_data'] = score_comparison
    return all_results

# Run preprocessing
subscale_summaries = preprocess_subscale_baselines(score_comparison)

# Update score_comparison with preprocessed data
score_comparison = subscale_summaries['preprocessed_data']

# Display first few rows to verify
print("\nFirst few rows of subscale scores (original and standardized):")
print(score_comparison[['pwb_subscale_score_Baseline', 'pwb_subscale_score_Baseline_std',
                         'swb_subscale_score_Baseline', 'swb_subscale_score_Baseline_std',
                         'ewb_subscale_score_Baseline', 'ewb_subscale_score_Baseline_std',
                         'fwb_subscale_score_Baseline', 'fwb_subscale_score_Baseline_std',
                         'ecs_subscale_score_Baseline', 'ecs_subscale_score_Baseline_std']].head(10))
# Out:
# ================================================================================
# STEP 2: PREDICTOR PREPROCESSING - PWB_SUBSCALE_SCORE Baseline
# ================================================================================
# Total patients: 108
# Missing pwb_subscale_score baseline: 0
# Complete pwb_subscale_score baseline: 108
#
# ✓ No missing values - proceeding with z-score standardization
#
# Baseline pwb_subscale_score statistics:
#   Mean: 22.66
#   SD: 5.26
#   Min: 2.80
#   Max: 28.00
#
# Standardized pwb_subscale_score statistics:
#   Mean: 0.00
#   SD: 1.00
#   Min: -3.78
#   Max: 1.01
#
# ✓ Created column: 'pwb_subscale_score_Baseline_std'
# ================================================================================
# ================================================================================
# STEP 2: PREDICTOR PREPROCESSING - SWB_SUBSCALE_SCORE Baseline
# ================================================================================
# Total patients: 108
# Missing swb_subscale_score baseline: 0
# Complete swb_subscale_score baseline: 108
#
# ✓ No missing values - proceeding with z-score standardization
#
# Baseline swb_subscale_score statistics:
#   Mean: 22.43
#   SD: 4.89
#   Min: 4.67
#   Max: 28.00
#
# Standardized swb_subscale_score statistics:
#   Mean: 0.00
#   SD: 1.00
#   Min: -3.63
#   Max: 1.14
#
# ✓ Created column: 'swb_subscale_score_Baseline_std'
# ================================================================================
# ================================================================================
# STEP 2: PREDICTOR PREPROCESSING - EWB_SUBSCALE_SCORE Baseline
# ================================================================================
# Total patients: 108
# Missing ewb_subscale_score baseline: 0
# Complete ewb_subscale_score baseline: 108
#
# ✓ No missing values - proceeding with z-score standardization
#
# Baseline ewb_subscale_score statistics:
#   Mean: 16.26
#   SD: 4.64
#   Min: 4.00
#   Max: 24.00
#
# Standardized ewb_subscale_score statistics:
#   Mean: 0.00
#   SD: 1.00
#   Min: -2.64
#   Max: 1.67
#
# ✓ Created column: 'ewb_subscale_score_Baseline_std'
# ================================================================================
# ================================================================================
# STEP 2: PREDICTOR PREPROCESSING - FWB_SUBSCALE_SCORE Baseline
# ================================================================================
# Total patients: 108
# Missing fwb_subscale_score baseline: 0
# Complete fwb_subscale_score baseline: 108
#
# ✓ No missing values - proceeding with z-score standardization
#
# Baseline fwb_subscale_score statistics:
#   Mean: 18.95
#   SD: 6.48
#   Min: 2.00
#   Max: 28.00
#
# Standardized fwb_subscale_score statistics:
#   Mean: 0.00
#   SD: 1.00
#   Min: -2.61
#   Max: 1.40
#
# ✓ Created column: 'fwb_subscale_score_Baseline_std'
# ================================================================================
# ================================================================================
# STEP 2: PREDICTOR PREPROCESSING - ECS_SUBSCALE_SCORE Baseline
# ================================================================================
# Total patients: 108
# Missing ecs_subscale_score baseline: 0
# Complete ecs_subscale_score baseline: 108
#
# ✓ No missing values - proceeding with z-score standardization
#
# Baseline ecs_subscale_score statistics:
#   Mean: 48.55
#   SD: 11.42
#   Min: 23.00
#   Max: 68.00
#
# Standardized ecs_subscale_score statistics:
#   Mean: 0.00
#   SD: 1.00
#   Min: -2.24
#   Max: 1.70
#
# ✓ Created column: 'ecs_subscale_score_Baseline_std'
# ================================================================================
#
# First few rows of subscale scores (original and standardized):
#      pwb_subscale_score_Baseline  pwb_subscale_score_Baseline_std  \
# id
# 32                     24.500000                         0.348883
# 76                      7.000000                        -2.977447
# 125                    21.000000                        -0.316383
# 160                    21.000000                        -0.316383
# 198                    25.000000                         0.443921
# 230                    19.000000                        -0.696535
# 275                    22.166667                        -0.094627
# 307                    21.000000                        -0.316383
# 364                    27.000000                         0.824073
# 442                    28.000000                         1.014149
#
#      swb_subscale_score_Baseline  swb_subscale_score_Baseline_std  \
# id
# 32                          22.0                        -0.088736
# 76                          23.0                         0.115846
# 125                         17.5                        -1.009355
# 160                         20.0                        -0.497900
# 198                         13.0                        -1.929973
# 230                         23.0                         0.115846
# 275                         23.0                         0.115846
# 307                         18.0                        -0.907064
# 364                         19.0                        -0.702482
# 442                         21.0                        -0.293318
#
#      ewb_subscale_score_Baseline  ewb_subscale_score_Baseline_std  \
# id
# 32                           6.0                        -2.212704
# 76                          14.0                        -0.487638
# 125                         21.0                         1.021796
# 160                         21.0                         1.021796
# 198                         17.0                         0.159263
# 230                         23.0                         1.453063
# 275                         18.0                         0.374896
# 307                         19.2                         0.633656
# 364                         13.0                        -0.703271
# 442                         20.0                         0.806163
#
#      fwb_subscale_score_Baseline  fwb_subscale_score_Baseline_std  \
# id
# 32                          19.0                         0.008454
# 76                          15.0                        -0.608789
# 125                          8.0                        -1.688964
# 160                         20.0                         0.162764
# 198                         21.0                         0.317075
# 230                         11.0                        -1.226032
# 275                         24.0                         0.780007
# 307                         11.0                        -1.226032
# 364                         24.0                         0.780007
# 442                         24.0                         0.780007
#
#      ecs_subscale_score_Baseline  ecs_subscale_score_Baseline_std
# id
# 32                     46.000000                        -0.223354
# 76                     36.000000                        -1.098848
# 125                    52.000000                         0.301943
# 160                    37.000000                        -1.011299
# 198                    57.000000                         0.739690
# 230                    57.800000                         0.809730
# 275                    41.000000                        -0.661101
# 307                    36.000000                        -1.098848
# 364                    57.181818                         0.755608
# 442                    50.000000                         0.126844

# %%
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  age_diagnosis_std  gender  cci_total  \
# id                                 ...
# 32                           19.0  ...          -3.924010     1.0        2.0
# 76                           15.0  ...          -0.759442     1.0        4.0
# 125                           8.0  ...          -0.019975     1.0        4.0
# 160                          20.0  ...          -1.530613     1.0        4.0
# 198                          21.0  ...           0.220608     2.0        4.0
# ...                           ...  ...                ...     ...        ...
# 1566                         18.0  ...           0.634635     1.0        4.0
# 1571                         25.0  ...           1.698298     1.0        6.0
# 1572                         20.0  ...          -0.426542     1.0        4.0
# 1615                         12.0  ...          -0.983551     1.0        4.0
# 1653                         24.0  ...           1.257229     1.0        4.0
#
#       cci_total_std  cci_category_numeric  pwb_subscale_score_Baseline_std  \
# id
# 32        -1.324120                     1                         0.348883
# 76         0.044349                     2                        -2.977447
# 125        0.044349                     2                        -0.316383
# 160        0.044349                     2                        -0.316383
# 198        0.044349                     2                         0.443921
# ...             ...                   ...                              ...
# 1566       0.044349                     2                         0.063769
# 1571       1.412817                     3                         0.633997
# 1572       0.044349                     2                         0.824073
# 1615       0.044349                     2                         0.063769
# 1653       0.044349                     2                        -0.316383
#
#       swb_subscale_score_Baseline_std  ewb_subscale_score_Baseline_std  \
# id
# 32                          -0.088736                        -2.212704
# 76                           0.115846                        -0.487638
# 125                         -1.009355                         1.021796
# 160                         -0.497900                         1.021796
# 198                         -1.929973                         0.159263
# ...                               ...                              ...
# 1566                         0.320427                         0.374896
# 1571                         1.138755                        -0.056371
# 1572                        -1.929973                         0.590529
# 1615                         0.320427                        -0.056371
# 1653                        -0.702482                         0.374896
#
#       fwb_subscale_score_Baseline_std  ecs_subscale_score_Baseline_std
# id
# 32                           0.008454                        -0.223354
# 76                          -0.608789                        -1.098848
# 125                         -1.688964                         0.301943
# 160                          0.162764                        -1.011299
# 198                          0.317075                         0.739690
# ...                               ...                              ...
# 1566                        -0.145857                         1.615185
# 1571                         0.934318                         0.827240
# 1572                         0.162764                         1.177437
# 1615                        -1.071721                         0.214394
# 1653                         0.780007                        -1.624145
#
# [108 rows x 34 columns]

# %% [raw]
# # Mid point: Save score_comparison to CSV
# score_comparison.to_csv("score_comparison_preprocessed.csv")
# pd.read_csv("score_comparison_preprocessed.csv", index_col='id')

# %% [markdown]
# # variable selection by Ridge

# %%
score_comparison=pd.read_csv("score_comparison_preprocessed.csv", index_col='id')
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  age_diagnosis_std  gender  cci_total  \
# id                                 ...
# 32                           19.0  ...          -3.924010     1.0        2.0
# 76                           15.0  ...          -0.759442     1.0        4.0
# 125                           8.0  ...          -0.019975     1.0        4.0
# 160                          20.0  ...          -1.530613     1.0        4.0
# 198                          21.0  ...           0.220608     2.0        4.0
# ...                           ...  ...                ...     ...        ...
# 1566                         18.0  ...           0.634635     1.0        4.0
# 1571                         25.0  ...           1.698298     1.0        6.0
# 1572                         20.0  ...          -0.426542     1.0        4.0
# 1615                         12.0  ...          -0.983551     1.0        4.0
# 1653                         24.0  ...           1.257229     1.0        4.0
#
#       cci_total_std  cci_category_numeric  pwb_subscale_score_Baseline_std  \
# id
# 32        -1.324120                     1                         0.348883
# 76         0.044349                     2                        -2.977447
# 125        0.044349                     2                        -0.316383
# 160        0.044349                     2                        -0.316383
# 198        0.044349                     2                         0.443921
# ...             ...                   ...                              ...
# 1566       0.044349                     2                         0.063769
# 1571       1.412817                     3                         0.633997
# 1572       0.044349                     2                         0.824073
# 1615       0.044349                     2                         0.063769
# 1653       0.044349                     2                        -0.316383
#
#       swb_subscale_score_Baseline_std  ewb_subscale_score_Baseline_std  \
# id
# 32                          -0.088736                        -2.212704
# 76                           0.115846                        -0.487638
# 125                         -1.009355                         1.021796
# 160                         -0.497900                         1.021796
# 198                         -1.929973                         0.159263
# ...                               ...                              ...
# 1566                         0.320427                         0.374896
# 1571                         1.138755                        -0.056371
# 1572                        -1.929973                         0.590529
# 1615                         0.320427                        -0.056371
# 1653                        -0.702482                         0.374896
#
#       fwb_subscale_score_Baseline_std  ecs_subscale_score_Baseline_std
# id
# 32                           0.008454                        -0.223354
# 76                          -0.608789                        -1.098848
# 125                         -1.688964                         0.301943
# 160                          0.162764                        -1.011299
# 198                          0.317075                         0.739690
# ...                               ...                              ...
# 1566                        -0.145857                         1.615185
# 1571                         0.934318                         0.827240
# 1572                         0.162764                         1.177437
# 1615                        -1.071721                         0.214394
# 1653                         0.780007                        -1.624145
#
# [108 rows x 34 columns]

# %%
def perform_nested_ridge_cv(score_comparison):
    """
    Perform nested 10-fold CV Ridge regression using ALL predictors.
    Ridge shrinks coefficients but does not perform variable selection.
    
    Returns:
    - Dictionary with results for each domain including:
        - All predictors used (no selection)
        - Nested CV performance (R², RMSE)
        - Final Ridge coefficients
    """
    from sklearn.linear_model import RidgeCV
    from sklearn.model_selection import KFold
    from sklearn.metrics import mean_squared_error, r2_score
    import warnings
    warnings.filterwarnings('ignore')
    
    print("="*80)
    print("STEP 3: NESTED RIDGE REGRESSION (ALL PREDICTORS)")
    print("="*80)
    print("Note: Ridge retains all predictors with L2 shrinkage - no variable selection")
    
    # Define the six FACT-E outcome domains (12-month outcomes)
    outcome_domains = [
        'fact_e_total_12mo',
        'pwb_subscale_score_12mo',
        'swb_subscale_score_12mo',
        'ewb_subscale_score_12mo',
        'fwb_subscale_score_12mo',
        'ecs_subscale_score_12mo'
    ]
    
    # Define predictor variables (17 baseline predictors - added 5 subscales)
    predictor_cols = [
        'fact_e_total_Baseline_std',       # Continuous (standardized)
        'pwb_subscale_score_Baseline_std', # Continuous (standardized)
        'swb_subscale_score_Baseline_std', # Continuous (standardized)
        'ewb_subscale_score_Baseline_std', # Continuous (standardized)
        'fwb_subscale_score_Baseline_std', # Continuous (standardized)
        'ecs_subscale_score_Baseline_std', # Continuous (standardized)
        'bmi_std',                          # Continuous (standardized)
        'age_diagnosis_std',                # Continuous (standardized)
        'cci_category_numeric',             # Categorical (0=None, 1=Mild, 2=Moderate, 3=Severe)
        'gender',                           # Categorical (1=Male, 2=Female, 9999=Unknown)
        'smoking_collapsed_imputed',        # Categorical (0=Never, 1=Ever)
        'alcohol_collapsed_imputed',        # Categorical (0=Non-drinker, 1=Ever drank)
        'level_tumor_collapsed_imputed',    # Categorical (1=Cardia/GEJ, 2=Lower, 3=Middle/Upper)
        'path_histology_collapsed_imputed', # Categorical (0=No carcinoma, 1=Adeno, 2=SCC, 3=Other)
        'path_esoph_stage_collapsed_imputed', # Categorical (0-5)
        'surgery_approach_imputed',         # Categorical (0=Open, 1=Minimally Invasive)
        'neotx_collapsed_imputed'           # Categorical (0=None, 1=Chemo, 2=Chemorads, 3=Other)
    ]
    
    # Check if all predictor columns exist
    missing_cols = [col for col in predictor_cols if col not in score_comparison.columns]
    if missing_cols:
        print(f"ERROR: Missing predictor columns: {missing_cols}")
        return None
    
    # Prepare predictor data
    X = score_comparison[predictor_cols].copy()
    
    # Check for any remaining missing values
    n_missing = X.isnull().sum().sum()
    if n_missing > 0:
        print(f"WARNING: Found {n_missing} missing values in predictors")
        print(X.isnull().sum())
        return None
    
    print(f"\nTotal patients: {len(X)}")
    print(f"Total predictors: {len(predictor_cols)} (6 FACT-E baselines + 11 clinical)")
    print(f"\nAll {len(predictor_cols)} predictors will be used (Ridge does not perform variable selection)")
    print(f"\nPredictors:")
    for i, col in enumerate(predictor_cols, 1):
        print(f"  {i}. {col}")
    
    # Results dictionary
    results = {}
    
    # Loop through each domain
    for outcome_domain in outcome_domains:
        print(f"\n{'='*80}")
        print(f"OUTCOME DOMAIN: {outcome_domain}")
        print(f"{'='*80}")
        
        # Get outcome variable
        y = score_comparison[outcome_domain].copy()
        
        # Remove any rows with missing outcome
        valid_idx = y.notna()
        X_domain = X[valid_idx].copy()
        y_domain = y[valid_idx].copy()
        
        print(f"Valid observations: {len(y_domain)} / {len(y)}")
        
        if len(y_domain) < 20:
            print(f"WARNING: Too few observations ({len(y_domain)}) for {outcome_domain}. Skipping.")
            continue
        
        # ========== NESTED CV FOR PERFORMANCE ESTIMATION ==========
        print(f"\n{'─'*80}")
        print(f"NESTED 10-FOLD CV (ALL {len(predictor_cols)} PREDICTORS)")
        print(f"{'─'*80}")
        print("Purpose: Get unbiased performance estimates using Ridge regression")
        
        # Outer loop: 10-fold CV for performance estimation
        outer_cv = KFold(n_splits=10, shuffle=True, random_state=42)
        
        # Inner loop: 10-fold CV for hyperparameter tuning
        inner_cv = KFold(n_splits=10, shuffle=True, random_state=42)
        
        # Store nested CV results
        nested_cv_r2_scores = []
        nested_cv_rmse_scores = []
        nested_cv_predictions = []
        nested_cv_true_values = []
        
        # Alpha range for Ridge (typically different from LASSO)
        alphas = np.logspace(-4, 3, 100)  # 0.0001 to 1000 
        
        # Outer CV loop
        for fold_idx, (train_idx, test_idx) in enumerate(outer_cv.split(X_domain), 1):
            X_train, X_test = X_domain.iloc[train_idx], X_domain.iloc[test_idx]
            y_train, y_test = y_domain.iloc[train_idx], y_domain.iloc[test_idx]
            
            # Inner CV: Tune alpha using RidgeCV
            ridge_cv = RidgeCV(alphas=alphas, cv=inner_cv)
            ridge_cv.fit(X_train, y_train)
            
            # Predict on outer test fold
            y_pred = ridge_cv.predict(X_test)
            
            # Calculate metrics
            r2 = r2_score(y_test, y_pred)
            rmse = np.sqrt(mean_squared_error(y_test, y_pred))
            
            nested_cv_r2_scores.append(r2)
            nested_cv_rmse_scores.append(rmse)
            nested_cv_predictions.extend(y_pred)
            nested_cv_true_values.extend(y_test)
            
            print(f"  Outer Fold {fold_idx}: R² = {r2:.4f}, RMSE = {rmse:.4f}, Best alpha = {ridge_cv.alpha_:.6f}")
        
        # Calculate mean nested CV performance
        mean_nested_cv_r2 = np.mean(nested_cv_r2_scores)
        mean_nested_cv_rmse = np.mean(nested_cv_rmse_scores)
        std_nested_cv_r2 = np.std(nested_cv_r2_scores)
        std_nested_cv_rmse = np.std(nested_cv_rmse_scores)
        
        print(f"\n✓ NESTED CV PERFORMANCE (unbiased estimates):")
        print(f"  Mean R²: {mean_nested_cv_r2:.4f} (SD: {std_nested_cv_r2:.4f})")
        print(f"  Mean RMSE: {mean_nested_cv_rmse:.4f} (SD: {std_nested_cv_rmse:.4f})")
        
        # ========== FIT FINAL RIDGE MODEL ON FULL DATA ==========
        print(f"\n{'─'*80}")
        print(f"FINAL RIDGE MODEL ON FULL DATA (ALL {len(predictor_cols)} PREDICTORS)")
        print(f"{'─'*80}")
        print("Purpose: Get coefficient estimates for OLS regression and nomogram")
        
        # Fit final Ridge model on all data
        ridge_cv_full = RidgeCV(alphas=alphas, cv=10)
        ridge_cv_full.fit(X_domain, y_domain)
        
        best_alpha_final = ridge_cv_full.alpha_
        
        # Calculate apparent performance (on training data - will be optimistic)
        y_pred_full = ridge_cv_full.predict(X_domain)
        apparent_r2 = r2_score(y_domain, y_pred_full)
        apparent_rmse = np.sqrt(mean_squared_error(y_domain, y_pred_full))
        
        # Create coefficient dataframe
        final_ridge_coefficients = pd.DataFrame({
            'Feature': predictor_cols,
            'Coefficient': ridge_cv_full.coef_,
            'Abs_Coefficient': np.abs(ridge_cv_full.coef_)
        })
        final_ridge_coefficients = final_ridge_coefficients.sort_values('Abs_Coefficient', ascending=False)
        
        print(f"\n✓ Final Ridge model fitted on all {len(predictor_cols)} predictors")
        print(f"  Best alpha: {best_alpha_final:.6f}")
        print(f"  Apparent R² (optimistic): {apparent_r2:.4f}")
        print(f"  Apparent RMSE (optimistic): {apparent_rmse:.4f}")
        
        print(f"\n✓ Ridge coefficients (ranked by absolute magnitude):")
        for idx, row in final_ridge_coefficients.iterrows():
            print(f"  {row['Feature']:<40} Coef: {row['Coefficient']:>10.4f}  |Coef|: {row['Abs_Coefficient']:>10.4f}")
        
        # ========== STORE RESULTS ==========
        results[outcome_domain] = {
            # Data info
            'n_observations': len(y_domain),
            
            # All features used (no selection with Ridge)
            'stable_features': predictor_cols,  # ALL predictors
            'n_stable_features': len(predictor_cols),
            
            # Nested CV performance (UNBIASED - primary metric for reporting)
            'nested_cv_r2_mean': mean_nested_cv_r2,
            'nested_cv_r2_std': std_nested_cv_r2,
            'nested_cv_rmse_mean': mean_nested_cv_rmse,
            'nested_cv_rmse_std': std_nested_cv_rmse,
            'nested_cv_r2_scores': nested_cv_r2_scores,
            'nested_cv_rmse_scores': nested_cv_rmse_scores,
            'nested_cv_predictions': nested_cv_predictions,
            'nested_cv_true_values': nested_cv_true_values,
            
            # Final Ridge model (for reference only)
            'final_ridge_coefficients': final_ridge_coefficients,
            'final_ridge_best_alpha': best_alpha_final,
            'apparent_r2': apparent_r2,
            'apparent_rmse': apparent_rmse
        }
        
        print(f"\n{'='*80}")
        print(f"✓ COMPLETED: {outcome_domain}")
        print(f"{'='*80}")
    
    # ========== FINAL SUMMARY ==========
    print(f"\n{'='*80}")
    print("STEP 3 COMPLETE: NESTED RIDGE REGRESSION")
    print(f"{'='*80}")
    
    # Summary table
    print("\nSUMMARY TABLE:")
    print("="*120)
    summary_rows = []
    for domain, res in results.items():
        summary_rows.append({
            'Domain': domain.replace('_12mo', ''),
            'N': res['n_observations'],
            'Features': res['n_stable_features'],
            'Nested CV R² (mean±SD)': f"{res['nested_cv_r2_mean']:.4f}±{res['nested_cv_r2_std']:.4f}",
            'Nested CV RMSE (mean±SD)': f"{res['nested_cv_rmse_mean']:.4f}±{res['nested_cv_rmse_std']:.4f}",
            'Apparent R² (optimistic)': f"{res['apparent_r2']:.4f}"
        })
    
    summary_df = pd.DataFrame(summary_rows)
    print(summary_df.to_string(index=False))
    print("="*120)
    
    print("\nNOTE:")
    print("  • Nested CV R²/RMSE = Unbiased performance estimates (use for reporting)")
    print("  • Apparent R²/RMSE = Optimistic estimates (use for comparison to show optimism)")
    print("  • All 17 predictors retained (Ridge L2 regularization, no variable selection)")
    print("  • All features will be used in Step 4 for final OLS regression")
    
    return results

# Run nested Ridge regression
ridge_results = perform_nested_ridge_cv(score_comparison)


# Save results
print("\n" + "="*80)
print("SAVING STEP 3 RESULTS...")
print("="*80)

for domain, res in ridge_results.items():
    domain_name = domain.replace('_12mo', '')
    
    # Save all coefficients
    res['final_ridge_coefficients'].to_csv(f"step3_ridge_coefficients_{domain_name}.csv", index=False)
    print(f"✓ Saved Ridge coefficients for {domain_name}")
    
    # Save feature list (all 17 predictors)
    features_df = pd.DataFrame({
        'Feature': res['stable_features']
    })
    features_df.to_csv(f"step3_all_features_{domain_name}.csv", index=False)
    print(f"✓ Saved all features for {domain_name} (will be used in Step 4)")
    
    # Save nested CV performance
    cv_performance = pd.DataFrame({
        'Metric': ['Nested_CV_R2_mean', 'Nested_CV_R2_std', 'Nested_CV_RMSE_mean', 'Nested_CV_RMSE_std',
                    'Apparent_R2', 'Apparent_RMSE', 'N_observations', 'N_features', 'Best_Alpha'],
        'Value': [res['nested_cv_r2_mean'], res['nested_cv_r2_std'], res['nested_cv_rmse_mean'], 
                    res['nested_cv_rmse_std'], res['apparent_r2'], res['apparent_rmse'],
                    res['n_observations'], res['n_stable_features'], res['final_ridge_best_alpha']]
    })
    cv_performance.to_csv(f"step3_nested_cv_performance_{domain_name}.csv", index=False)
    print(f"✓ Saved nested CV performance for {domain_name}")

print("="*80)
print("✓ STEP 3 COMPLETE - Ready for Step 4 (Final OLS Regression)")
print("="*80)
# Out:
# ================================================================================
# STEP 3: NESTED RIDGE REGRESSION (ALL PREDICTORS)
# ================================================================================
# Note: Ridge retains all predictors with L2 shrinkage - no variable selection
#
# Total patients: 108
# Total predictors: 17 (6 FACT-E baselines + 11 clinical)
#
# All 17 predictors will be used (Ridge does not perform variable selection)
#
# Predictors:
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# ================================================================================
# OUTCOME DOMAIN: fact_e_total_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = 0.0661, RMSE = 24.9211, Best alpha = 102.353102
#   Outer Fold 2: R² = -0.2339, RMSE = 16.8992, Best alpha = 319.926714
#   Outer Fold 3: R² = 0.1494, RMSE = 24.0497, Best alpha = 271.858824
#   Outer Fold 4: R² = -0.2451, RMSE = 36.7316, Best alpha = 141.747416
#   Outer Fold 5: R² = -0.3744, RMSE = 17.8489, Best alpha = 166.810054
#   Outer Fold 6: R² = -0.3215, RMSE = 23.4837, Best alpha = 141.747416
#   Outer Fold 7: R² = -0.0719, RMSE = 25.0586, Best alpha = 231.012970
#   Outer Fold 8: R² = 0.0982, RMSE = 28.6260, Best alpha = 376.493581
#   Outer Fold 9: R² = -0.0108, RMSE = 21.1239, Best alpha = 231.012970
#   Outer Fold 10: R² = 0.0516, RMSE = 31.1185, Best alpha = 166.810054
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: -0.0892 (SD: 0.1797)
#   Mean RMSE: 24.9861 (SD: 5.6852)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 271.858824
#   Apparent R² (optimistic): 0.1272
#   Apparent RMSE (optimistic): 24.3365
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   fwb_subscale_score_Baseline_std          Coef:     1.6375  |Coef|:     1.6375
#   pwb_subscale_score_Baseline_std          Coef:     1.5352  |Coef|:     1.5352
#   fact_e_total_Baseline_std                Coef:     1.1461  |Coef|:     1.1461
#   ewb_subscale_score_Baseline_std          Coef:     1.0621  |Coef|:     1.0621
#   age_diagnosis_std                        Coef:     1.0096  |Coef|:     1.0096
#   neotx_collapsed_imputed                  Coef:     0.9837  |Coef|:     0.9837
#   smoking_collapsed_imputed                Coef:    -0.6320  |Coef|:     0.6320
#   bmi_std                                  Coef:     0.6186  |Coef|:     0.6186
#   alcohol_collapsed_imputed                Coef:     0.5827  |Coef|:     0.5827
#   level_tumor_collapsed_imputed            Coef:     0.5305  |Coef|:     0.5305
#   path_histology_collapsed_imputed         Coef:    -0.4606  |Coef|:     0.4606
#   surgery_approach_imputed                 Coef:     0.4040  |Coef|:     0.4040
#   gender                                   Coef:    -0.2844  |Coef|:     0.2844
#   path_esoph_stage_collapsed_imputed       Coef:     0.2796  |Coef|:     0.2796
#   cci_category_numeric                     Coef:    -0.2519  |Coef|:     0.2519
#   ecs_subscale_score_Baseline_std          Coef:     0.2217  |Coef|:     0.2217
#   swb_subscale_score_Baseline_std          Coef:     0.1597  |Coef|:     0.1597
#
# ================================================================================
# ✓ COMPLETED: fact_e_total_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: pwb_subscale_score_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = 0.1454, RMSE = 5.0596, Best alpha = 62.802914
#   Outer Fold 2: R² = -1.2048, RMSE = 5.1288, Best alpha = 45.348785
#   Outer Fold 3: R² = 0.4210, RMSE = 3.8774, Best alpha = 102.353102
#   Outer Fold 4: R² = -0.2640, RMSE = 7.2126, Best alpha = 53.366992
#   Outer Fold 5: R² = 0.2078, RMSE = 3.1857, Best alpha = 86.974900
#   Outer Fold 6: R² = 0.1639, RMSE = 4.6994, Best alpha = 20.092330
#   Outer Fold 7: R² = 0.0264, RMSE = 5.3685, Best alpha = 102.353102
#   Outer Fold 8: R² = 0.1481, RMSE = 5.5336, Best alpha = 86.974900
#   Outer Fold 9: R² = 0.2281, RMSE = 5.3369, Best alpha = 32.745492
#   Outer Fold 10: R² = -0.3254, RMSE = 8.6709, Best alpha = 38.535286
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: -0.0453 (SD: 0.4415)
#   Mean RMSE: 5.4073 (SD: 1.4801)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 14.508288
#   Apparent R² (optimistic): 0.3278
#   Apparent RMSE (optimistic): 4.7730
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   pwb_subscale_score_Baseline_std          Coef:     1.5978  |Coef|:     1.5978
#   cci_category_numeric                     Coef:    -1.0969  |Coef|:     1.0969
#   age_diagnosis_std                        Coef:     1.0144  |Coef|:     1.0144
#   alcohol_collapsed_imputed                Coef:     0.9945  |Coef|:     0.9945
#   fwb_subscale_score_Baseline_std          Coef:     0.9765  |Coef|:     0.9765
#   ecs_subscale_score_Baseline_std          Coef:    -0.9426  |Coef|:     0.9426
#   bmi_std                                  Coef:     0.9335  |Coef|:     0.9335
#   smoking_collapsed_imputed                Coef:    -0.8877  |Coef|:     0.8877
#   swb_subscale_score_Baseline_std          Coef:    -0.8712  |Coef|:     0.8712
#   surgery_approach_imputed                 Coef:     0.7642  |Coef|:     0.7642
#   ewb_subscale_score_Baseline_std          Coef:     0.5547  |Coef|:     0.5547
#   gender                                   Coef:    -0.5124  |Coef|:     0.5124
#   path_esoph_stage_collapsed_imputed       Coef:     0.4004  |Coef|:     0.4004
#   neotx_collapsed_imputed                  Coef:     0.4004  |Coef|:     0.4004
#   level_tumor_collapsed_imputed            Coef:     0.2515  |Coef|:     0.2515
#   path_histology_collapsed_imputed         Coef:    -0.1147  |Coef|:     0.1147
#   fact_e_total_Baseline_std                Coef:     0.0530  |Coef|:     0.0530
#
# ================================================================================
# ✓ COMPLETED: pwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: swb_subscale_score_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = 0.0014, RMSE = 3.8336, Best alpha = 231.012970
#   Outer Fold 2: R² = 0.2052, RMSE = 4.5904, Best alpha = 120.450354
#   Outer Fold 3: R² = 0.1585, RMSE = 3.4627, Best alpha = 166.810054
#   Outer Fold 4: R² = -0.1731, RMSE = 5.3108, Best alpha = 86.974900
#   Outer Fold 5: R² = -0.5583, RMSE = 5.9660, Best alpha = 166.810054
#   Outer Fold 6: R² = -0.2460, RMSE = 6.6623, Best alpha = 62.802914
#   Outer Fold 7: R² = 0.2910, RMSE = 4.0773, Best alpha = 141.747416
#   Outer Fold 8: R² = 0.1304, RMSE = 3.4652, Best alpha = 166.810054
#   Outer Fold 9: R² = 0.0935, RMSE = 3.4498, Best alpha = 120.450354
#   Outer Fold 10: R² = 0.2522, RMSE = 5.4389, Best alpha = 231.012970
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: 0.0155 (SD: 0.2532)
#   Mean RMSE: 4.6257 (SD: 1.0994)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 196.304065
#   Apparent R² (optimistic): 0.1662
#   Apparent RMSE (optimistic): 4.4748
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   swb_subscale_score_Baseline_std          Coef:     0.5520  |Coef|:     0.5520
#   fact_e_total_Baseline_std                Coef:     0.2900  |Coef|:     0.2900
#   ecs_subscale_score_Baseline_std          Coef:     0.2806  |Coef|:     0.2806
#   fwb_subscale_score_Baseline_std          Coef:     0.2496  |Coef|:     0.2496
#   smoking_collapsed_imputed                Coef:    -0.2304  |Coef|:     0.2304
#   age_diagnosis_std                        Coef:     0.1829  |Coef|:     0.1829
#   path_esoph_stage_collapsed_imputed       Coef:     0.1820  |Coef|:     0.1820
#   path_histology_collapsed_imputed         Coef:     0.1435  |Coef|:     0.1435
#   neotx_collapsed_imputed                  Coef:     0.1284  |Coef|:     0.1284
#   pwb_subscale_score_Baseline_std          Coef:    -0.1128  |Coef|:     0.1128
#   level_tumor_collapsed_imputed            Coef:     0.0875  |Coef|:     0.0875
#   surgery_approach_imputed                 Coef:     0.0571  |Coef|:     0.0571
#   bmi_std                                  Coef:     0.0489  |Coef|:     0.0489
#   ewb_subscale_score_Baseline_std          Coef:    -0.0201  |Coef|:     0.0201
#   cci_category_numeric                     Coef:     0.0135  |Coef|:     0.0135
#   gender                                   Coef:    -0.0066  |Coef|:     0.0066
#   alcohol_collapsed_imputed                Coef:    -0.0020  |Coef|:     0.0020
#
# ================================================================================
# ✓ COMPLETED: swb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ewb_subscale_score_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = 0.0599, RMSE = 3.0413, Best alpha = 62.802914
#   Outer Fold 2: R² = -1.4277, RMSE = 3.7637, Best alpha = 196.304065
#   Outer Fold 3: R² = 0.1498, RMSE = 4.2313, Best alpha = 73.907220
#   Outer Fold 4: R² = -0.7135, RMSE = 6.2518, Best alpha = 32.745492
#   Outer Fold 5: R² = -0.2089, RMSE = 2.4764, Best alpha = 102.353102
#   Outer Fold 6: R² = -1.8267, RMSE = 4.2025, Best alpha = 62.802914
#   Outer Fold 7: R² = 0.0112, RMSE = 4.6645, Best alpha = 271.858824
#   Outer Fold 8: R² = 0.0230, RMSE = 5.8772, Best alpha = 231.012970
#   Outer Fold 9: R² = 0.1603, RMSE = 3.6936, Best alpha = 141.747416
#   Outer Fold 10: R² = 0.2001, RMSE = 5.1812, Best alpha = 166.810054
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: -0.3572 (SD: 0.6888)
#   Mean RMSE: 4.3383 (SD: 1.1301)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 196.304065
#   Apparent R² (optimistic): 0.2075
#   Apparent RMSE (optimistic): 4.1296
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   fwb_subscale_score_Baseline_std          Coef:     0.4248  |Coef|:     0.4248
#   ewb_subscale_score_Baseline_std          Coef:     0.4025  |Coef|:     0.4025
#   pwb_subscale_score_Baseline_std          Coef:     0.3373  |Coef|:     0.3373
#   fact_e_total_Baseline_std                Coef:     0.2698  |Coef|:     0.2698
#   bmi_std                                  Coef:     0.2574  |Coef|:     0.2574
#   neotx_collapsed_imputed                  Coef:     0.2130  |Coef|:     0.2130
#   age_diagnosis_std                        Coef:     0.1916  |Coef|:     0.1916
#   alcohol_collapsed_imputed                Coef:     0.1886  |Coef|:     0.1886
#   path_histology_collapsed_imputed         Coef:    -0.1332  |Coef|:     0.1332
#   swb_subscale_score_Baseline_std          Coef:    -0.1068  |Coef|:     0.1068
#   level_tumor_collapsed_imputed            Coef:     0.0822  |Coef|:     0.0822
#   cci_category_numeric                     Coef:     0.0671  |Coef|:     0.0671
#   path_esoph_stage_collapsed_imputed       Coef:     0.0664  |Coef|:     0.0664
#   gender                                   Coef:    -0.0635  |Coef|:     0.0635
#   surgery_approach_imputed                 Coef:     0.0487  |Coef|:     0.0487
#   ecs_subscale_score_Baseline_std          Coef:     0.0393  |Coef|:     0.0393
#   smoking_collapsed_imputed                Coef:    -0.0271  |Coef|:     0.0271
#
# ================================================================================
# ✓ COMPLETED: ewb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: fwb_subscale_score_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = -0.0508, RMSE = 3.6326, Best alpha = 102.353102
#   Outer Fold 2: R² = -0.0945, RMSE = 4.9839, Best alpha = 231.012970
#   Outer Fold 3: R² = 0.0843, RMSE = 6.9997, Best alpha = 849.753436
#   Outer Fold 4: R² = -0.1316, RMSE = 8.9980, Best alpha = 271.858824
#   Outer Fold 5: R² = -0.3723, RMSE = 4.3334, Best alpha = 73.907220
#   Outer Fold 6: R² = -0.6083, RMSE = 5.0881, Best alpha = 141.747416
#   Outer Fold 7: R² = -0.0512, RMSE = 6.8926, Best alpha = 166.810054
#   Outer Fold 8: R² = 0.1150, RMSE = 8.0827, Best alpha = 231.012970
#   Outer Fold 9: R² = -0.0390, RMSE = 6.0165, Best alpha = 271.858824
#   Outer Fold 10: R² = -0.0439, RMSE = 9.5743, Best alpha = 120.450354
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: -0.1192 (SD: 0.2053)
#   Mean RMSE: 6.4602 (SD: 1.8981)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 166.810054
#   Apparent R² (optimistic): 0.1492
#   Apparent RMSE (optimistic): 6.2715
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   fwb_subscale_score_Baseline_std          Coef:     0.6584  |Coef|:     0.6584
#   pwb_subscale_score_Baseline_std          Coef:     0.4737  |Coef|:     0.4737
#   age_diagnosis_std                        Coef:     0.3993  |Coef|:     0.3993
#   neotx_collapsed_imputed                  Coef:     0.3453  |Coef|:     0.3453
#   alcohol_collapsed_imputed                Coef:     0.3378  |Coef|:     0.3378
#   fact_e_total_Baseline_std                Coef:     0.3280  |Coef|:     0.3280
#   level_tumor_collapsed_imputed            Coef:     0.3112  |Coef|:     0.3112
#   ewb_subscale_score_Baseline_std          Coef:     0.1660  |Coef|:     0.1660
#   gender                                   Coef:    -0.1299  |Coef|:     0.1299
#   bmi_std                                  Coef:     0.1249  |Coef|:     0.1249
#   cci_category_numeric                     Coef:    -0.1234  |Coef|:     0.1234
#   path_histology_collapsed_imputed         Coef:    -0.1223  |Coef|:     0.1223
#   smoking_collapsed_imputed                Coef:    -0.0868  |Coef|:     0.0868
#   surgery_approach_imputed                 Coef:     0.0558  |Coef|:     0.0558
#   swb_subscale_score_Baseline_std          Coef:    -0.0284  |Coef|:     0.0284
#   ecs_subscale_score_Baseline_std          Coef:     0.0253  |Coef|:     0.0253
#   path_esoph_stage_collapsed_imputed       Coef:     0.0091  |Coef|:     0.0091
#
# ================================================================================
# ✓ COMPLETED: fwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ecs_subscale_score_12mo
# ================================================================================
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# NESTED 10-FOLD CV (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get unbiased performance estimates using Ridge regression
#   Outer Fold 1: R² = -0.0246, RMSE = 14.6770, Best alpha = 1000.000000
#   Outer Fold 2: R² = -0.0525, RMSE = 6.9844, Best alpha = 1000.000000
#   Outer Fold 3: R² = -0.0129, RMSE = 10.2339, Best alpha = 1000.000000
#   Outer Fold 4: R² = -0.0742, RMSE = 13.2388, Best alpha = 521.400829
#   Outer Fold 5: R² = -0.4278, RMSE = 8.7459, Best alpha = 1000.000000
#   Outer Fold 6: R² = -0.1077, RMSE = 8.7657, Best alpha = 1000.000000
#   Outer Fold 7: R² = -0.1082, RMSE = 10.6982, Best alpha = 376.493581
#   Outer Fold 8: R² = -0.0754, RMSE = 10.9998, Best alpha = 1000.000000
#   Outer Fold 9: R² = -0.4317, RMSE = 6.5580, Best alpha = 1000.000000
#   Outer Fold 10: R² = -0.0087, RMSE = 9.8205, Best alpha = 1000.000000
#
# ✓ NESTED CV PERFORMANCE (unbiased estimates):
#   Mean R²: -0.1324 (SD: 0.1524)
#   Mean RMSE: 10.0722 (SD: 2.4067)
#
# ────────────────────────────────────────────────────────────────────────────────
# FINAL RIDGE MODEL ON FULL DATA (ALL 17 PREDICTORS)
# ────────────────────────────────────────────────────────────────────────────────
# Purpose: Get coefficient estimates for OLS regression and nomogram
#
# ✓ Final Ridge model fitted on all 17 predictors
#   Best alpha: 1000.000000
#   Apparent R² (optimistic): 0.0185
#   Apparent RMSE (optimistic): 10.1836
#
# ✓ Ridge coefficients (ranked by absolute magnitude):
#   pwb_subscale_score_Baseline_std          Coef:     0.1554  |Coef|:     0.1554
#   path_histology_collapsed_imputed         Coef:    -0.1308  |Coef|:     0.1308
#   ewb_subscale_score_Baseline_std          Coef:     0.1126  |Coef|:     0.1126
#   fwb_subscale_score_Baseline_std          Coef:     0.0969  |Coef|:     0.0969
#   neotx_collapsed_imputed                  Coef:     0.0931  |Coef|:     0.0931
#   fact_e_total_Baseline_std                Coef:     0.0796  |Coef|:     0.0796
#   age_diagnosis_std                        Coef:     0.0683  |Coef|:     0.0683
#   smoking_collapsed_imputed                Coef:    -0.0682  |Coef|:     0.0682
#   surgery_approach_imputed                 Coef:     0.0560  |Coef|:     0.0560
#   cci_category_numeric                     Coef:    -0.0462  |Coef|:     0.0462
#   level_tumor_collapsed_imputed            Coef:     0.0392  |Coef|:     0.0392
#   alcohol_collapsed_imputed                Coef:     0.0276  |Coef|:     0.0276
#   gender                                   Coef:    -0.0181  |Coef|:     0.0181
#   bmi_std                                  Coef:     0.0146  |Coef|:     0.0146
#   ecs_subscale_score_Baseline_std          Coef:    -0.0090  |Coef|:     0.0090
#   path_esoph_stage_collapsed_imputed       Coef:    -0.0053  |Coef|:     0.0053
#   swb_subscale_score_Baseline_std          Coef:     0.0028  |Coef|:     0.0028
#
# ================================================================================
# ✓ COMPLETED: ecs_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# STEP 3 COMPLETE: NESTED RIDGE REGRESSION
# ================================================================================
#
# SUMMARY TABLE:
# ========================================================================================================================
#             Domain   N  Features Nested CV R² (mean±SD) Nested CV RMSE (mean±SD) Apparent R² (optimistic)
#       fact_e_total 108        17         -0.0892±0.1797           24.9861±5.6852                   0.1272
# pwb_subscale_score 108        17         -0.0453±0.4415            5.4073±1.4801                   0.3278
# swb_subscale_score 108        17          0.0155±0.2532            4.6257±1.0994                   0.1662
# ewb_subscale_score 108        17         -0.3572±0.6888            4.3383±1.1301                   0.2075
# fwb_subscale_score 108        17         -0.1192±0.2053            6.4602±1.8981                   0.1492
# ecs_subscale_score 108        17         -0.1324±0.1524           10.0722±2.4067                   0.0185
# ========================================================================================================================
#
# NOTE:
#   • Nested CV R²/RMSE = Unbiased performance estimates (use for reporting)
#   • Apparent R²/RMSE = Optimistic estimates (use for comparison to show optimism)
#   • All 17 predictors retained (Ridge L2 regularization, no variable selection)
#   • All features will be used in Step 4 for final OLS regression
#
# ================================================================================
# SAVING STEP 3 RESULTS...
# ================================================================================
# ✓ Saved Ridge coefficients for fact_e_total
# ✓ Saved all features for fact_e_total (will be used in Step 4)
# ✓ Saved nested CV performance for fact_e_total
# ✓ Saved Ridge coefficients for pwb_subscale_score
# ✓ Saved all features for pwb_subscale_score (will be used in Step 4)
# ✓ Saved nested CV performance for pwb_subscale_score
# ✓ Saved Ridge coefficients for swb_subscale_score
# ✓ Saved all features for swb_subscale_score (will be used in Step 4)
# ✓ Saved nested CV performance for swb_subscale_score
# ✓ Saved Ridge coefficients for ewb_subscale_score
# ✓ Saved all features for ewb_subscale_score (will be used in Step 4)
# ✓ Saved nested CV performance for ewb_subscale_score
# ✓ Saved Ridge coefficients for fwb_subscale_score
# ✓ Saved all features for fwb_subscale_score (will be used in Step 4)
# ✓ Saved nested CV performance for fwb_subscale_score
# ✓ Saved Ridge coefficients for ecs_subscale_score
# ✓ Saved all features for ecs_subscale_score (will be used in Step 4)
# ✓ Saved nested CV performance for ecs_subscale_score
# ================================================================================
# ✓ STEP 3 COMPLETE - Ready for Step 4 (Final OLS Regression)
# ================================================================================

# %%
ridge_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'nested_cv_r2_mean': -0.0892303261691116,
#   'nested_cv_r2_std': 0.179699894686157,
#   'nested_cv_rmse_mean': 24.98610761225858,
#   'nested_cv_rmse_std': 5.685154078044437,
#   'nested_cv_r2_scores': [0.06605796459239899,
#    -0.23387173218283408,
#    0.14936370413742872,
#    -0.24507514223964777,
#    -0.3743969600695416,
#    -0.3214802893036435,
#    -0.07189048665166098,
#    0.09815831516858464,
#    -0.010813247435900841,
#    0.05164461229370043],
#   'nested_cv_rmse_scores': [24.921124545158474,
#    16.89916132953017,
#    24.049716234587596,
#    36.731576328693,
#    17.84886677594742,
#    23.483701016333548,
#    25.058639163379244,
#    28.625952207540443,
#    21.123865486614683,
#    31.11847303480122],
#   'nested_cv_predictions': [127.3436440723833,
#    129.46714702905075,
#    133.1750145256125,
#    117.61827096149601,
#    131.81993188022201,
#    128.6264897737146,
#    127.17058475210906,
#    130.26332235044507,
#    116.11435516726041,
#    114.35759568056405,
#    130.06031716814033,
#    119.79697493434973,
#    116.6669228128514,
#    122.69303896372544,
#    125.3428086067477,
#    120.1349033152396,
#    132.29497282011687,
#    132.2334038235585,
#    120.95697947843273,
#    127.42056230349007,
#    128.6822145542463,
#    123.16227474601244,
#    128.79202708131484,
#    120.5734675251542,
#    128.3269207789618,
#    129.0713639175489,
#    126.73153991294785,
#    111.78547207728326,
#    128.41871905421016,
#    22.0,
#    13.0,
#    22.0,
#    24.0,
#    18.0,
#    13.0,
#    19.0,
#    16.0,
#    15.0,
#    25.0,
#    13.0,
#    11.0,
#    17.0,
#    11.0,
#    13.0,
#    21.0,
#    21.0,
#    21.0,
#    12.0,
#    13.0,
#    14.0,
#    11.0,
#    17.0,
#    23.0,
#    15.0,
#    8.0,
#    14.0,
#    27.0,
#    28.0,
#    22.0,
#    4.0,
#    4.0,
#    2.0,
#    27.0,
#    14.0,
#    9.0,
#    6.0,
#    22.0,
#    9.5,
#    15.0,
#    16.0,
#    28.0,
#    13.666666666666666,
#    19.0,
#    13.0,
#    10.0,
#    21.0,
#    16.0,
#    16.0,
#    19.0,
#    8.0,
#    16.0,
#    15.0,
#    22.0,
#    18.0,
#    21.0,
#    20.0,
#    18.0,
#    24.0,
#    16.333333333333332,
#    9.0,
#    21.0,
#    16.0,
#    23.0,
#    18.0,
#    7.0,
#    12.0,
#    18.0,
#    7.0,
#    21.0,
#    3.0,
#    22.666666666666664,
#    24.0,
#    16.0,
#    10.0,
#    5.0,
#    10.0,
#    24.0,
#    28.0,
#    16.0,
#    26.0,
#    18.0,
#    21.0,
#    27.0,
#    4.0,
#    8.0,
#    10.0,
#    13.0,
#    20.0,
#    27.0,
#    20.0,
#    13.0,
#    26.0,
#    28.0,
#    19.0,
#    18.0,
#    8.0,
#    22.0,
#    10.0,
#    28.0,
#    1.0,
#    26.0,
#    19.0,
#    2.0,
#    9.0,
#    22.0],
#   'final_ridge_coefficients':                                Feature  Coefficient  Abs_Coefficient
#   4      fwb_subscale_score_Baseline_std     0.658381         0.658381
#   1      pwb_subscale_score_Baseline_std     0.473705         0.473705
#   7                    age_diagnosis_std     0.399304         0.399304
#   16             neotx_collapsed_imputed     0.345340         0.345340
#   11           alcohol_collapsed_imputed     0.337755         0.337755
#   0            fact_e_total_Baseline_std     0.328041         0.328041
#   12       level_tumor_collapsed_imputed     0.311156         0.311156
#   3      ewb_subscale_score_Baseline_std     0.165986         0.165986
#   9                               gender    -0.129872         0.129872
#   6                              bmi_std     0.124933         0.124933
#   8                 cci_category_numeric    -0.123398         0.123398
#   13    path_histology_collapsed_imputed    -0.122329         0.122329
#   10           smoking_collapsed_imputed    -0.086824         0.086824
#   15            surgery_approach_imputed     0.055822         0.055822
#   2      swb_subscale_score_Baseline_std    -0.028389         0.028389
#   5      ecs_subscale_score_Baseline_std     0.025317         0.025317
#   14  path_esoph_stage_collapsed_imputed     0.009138         0.009138,
#   'final_ridge_best_alpha': 166.81005372000593,
#   'apparent_r2': 0.14918321315956884,
#   'apparent_rmse': 6.27145379393576},
#  'ecs_subscale_score_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'nested_cv_r2_mean': -0.132366015063451,
#   'nested_cv_r2_std': 0.15238955210737726,
#   'nested_cv_rmse_mean': 10.072232023766755,
#   'nested_cv_rmse_std': 2.4067206803372807,
#   'nested_cv_r2_scores': [-0.024596971472653273,
#    -0.05247437540632416,
#    -0.012914987632471231,
#    -0.07421445624693179,
#    -0.42775424534912365,
#    -0.1077276033154877,
#    -0.10819921818974909,
#    -0.07537598160758185,
#    -0.43169061590689495,
#    -0.008711695507292339],
#   'nested_cv_rmse_scores': [14.677028392847474,
#    6.984442891583406,
#    17.0,
#    35.0,
#    64.0,
#    51.0,
#    37.4,
#    50.0,
#    47.0,
#    49.0,
#    54.0,
#    38.0,
#    62.0,
#    48.84848484848485,
#    56.0,
#    39.0,
#    32.0,
#    48.0,
#    39.0,
#    52.0,
#    49.9375,
#    36.0,
#    44.0,
#    37.0,
#    57.0,
#    55.0,
#    63.0,
#    55.0,
#    46.0,
#    51.0,
#    43.0,
#    30.0,
#    55.25,
#    52.0,
#    49.0,
#    47.0,
#    52.0,
#    59.0,
#    57.0,
#    44.0,
#    46.0,
#    29.0,
#    60.5,
#    42.0,
#    33.0,
#    35.0,
#    58.0,
#    46.0,
#    51.0,
#    55.0,
#    42.0,
#    59.0,
#    60.0,
#    61.625,
#    56.0,
#    23.0,
#    51.0,
#    48.0,
#    54.0,
#    59.0,
#    54.0,
#    52.0,
#    44.0,
#    60.0,
#    54.0,
#    48.0,
#    43.0,
#    50.0,
#    58.0,
#    49.0,
#    62.0,
#    27.0,
#    43.0,
#    50.0,
#    44.0,
#    41.0,
#    59.0],
#   'final_ridge_coefficients':                                Feature  Coefficient  Abs_Coefficient
#   1      pwb_subscale_score_Baseline_std     0.155392         0.155392
#   13    path_histology_collapsed_imputed    -0.130805         0.130805
#   3      ewb_subscale_score_Baseline_std     0.112623         0.112623
#   4      fwb_subscale_score_Baseline_std     0.096886         0.096886
#   16             neotx_collapsed_imputed     0.093093         0.093093
#   0            fact_e_total_Baseline_std     0.079642         0.079642
#   7                    age_diagnosis_std     0.068311         0.068311
#   10           smoking_collapsed_imputed    -0.068215         0.068215
#   15            surgery_approach_imputed     0.055980         0.055980
#   8                 cci_category_numeric    -0.046242         0.046242
#   12       level_tumor_collapsed_imputed     0.039226         0.039226
#   11           alcohol_collapsed_imputed     0.027644         0.027644
#   9                               gender    -0.018089         0.018089
#   6                              bmi_std     0.014583         0.014583
#   5      ecs_subscale_score_Baseline_std    -0.008989         0.008989
#   14  path_esoph_stage_collapsed_imputed    -0.005283         0.005283
#   2      swb_subscale_score_Baseline_std     0.002803         0.002803,
#   'final_ridge_best_alpha': 1000.0,
#   'apparent_r2': 0.01847279198050822,
#   'apparent_rmse': 10.183636661996854}}

# %% [raw]
# import pickle
# with open('ridge_results.pkl', 'wb') as f:  # Save
#     pickle.dump(ridge_results, f)

# %% [markdown]
# # Final regression modeling

# %%
import pickle
with open('ridge_results.pkl', 'rb') as f:  # Load
    ridge_results = pickle.load(f)
ridge_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'nested_cv_r2_mean': -0.0892303261691116,
#   'nested_cv_r2_std': 0.179699894686157,
#   'nested_cv_rmse_mean': 24.98610761225858,
#   'nested_cv_rmse_std': 5.685154078044437,
#   'nested_cv_r2_scores': [0.06605796459239899,
#    -0.23387173218283408,
#    0.14936370413742872,
#    -0.24507514223964777,
#    -0.3743969600695416,
#    -0.3214802893036435,
#    -0.07189048665166098,
#    0.09815831516858464,
#    -0.010813247435900841,
#    0.05164461229370043],
#   'nested_cv_rmse_scores': [24.921124545158474,
#    16.89916132953017,
#    24.049716234587596,
#    36.731576328693,
#    17.84886677594742,
#    23.483701016333548,
#    25.058639163379244,
#    28.625952207540443,
#    21.123865486614683,
#    31.11847303480122],
#   'nested_cv_predictions': [127.3436440723833,
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  age_diagnosis_std  gender  cci_total  \
# id                                 ...
# 32                           19.0  ...          -3.924010     1.0        2.0
# 76                           15.0  ...          -0.759442     1.0        4.0
# 125                           8.0  ...          -0.019975     1.0        4.0
# 160                          20.0  ...          -1.530613     1.0        4.0
# 198                          21.0  ...           0.220608     2.0        4.0
# ...                           ...  ...                ...     ...        ...
# 1566                         18.0  ...           0.634635     1.0        4.0
# 1571                         25.0  ...           1.698298     1.0        6.0
# 1572                         20.0  ...          -0.426542     1.0        4.0
# 1615                         12.0  ...          -0.983551     1.0        4.0
# 1653                         24.0  ...           1.257229     1.0        4.0
#
#       cci_total_std  cci_category_numeric  pwb_subscale_score_Baseline_std  \
# id
# 32        -1.324120                     1                         0.348883
# 76         0.044349                     2                        -2.977447
# 125        0.044349                     2                        -0.316383
# 160        0.044349                     2                        -0.316383
# 198        0.044349                     2                         0.443921
# ...             ...                   ...                              ...
# 1566       0.044349                     2                         0.063769
# 1571       1.412817                     3                         0.633997
# 1572       0.044349                     2                         0.824073
# 1615       0.044349                     2                         0.063769
# 1653       0.044349                     2                        -0.316383
#
#       swb_subscale_score_Baseline_std  ewb_subscale_score_Baseline_std  \
# id
# 32                          -0.088736                        -2.212704
# 76                           0.115846                        -0.487638
# 125                         -1.009355                         1.021796
# 160                         -0.497900                         1.021796
# 198                         -1.929973                         0.159263
# ...                               ...                              ...
# 1566                         0.320427                         0.374896
# 1571                         1.138755                        -0.056371
# 1572                        -1.929973                         0.590529
# 1615                         0.320427                        -0.056371
# 1653                        -0.702482                         0.374896
#
#       fwb_subscale_score_Baseline_std  ecs_subscale_score_Baseline_std
# id
# 32                           0.008454                        -0.223354
# 76                          -0.608789                        -1.098848
# 125                         -1.688964                         0.301943
# 160                          0.162764                        -1.011299
# 198                          0.317075                         0.739690
# ...                               ...                              ...
# 1566                        -0.145857                         1.615185
# 1571                         0.934318                         0.827240
# 1572                         0.162764                         1.177437
# 1615                        -1.071721                         0.214394
# 1653                         0.780007                        -1.624145
#
# [108 rows x 34 columns]

# %%
def perform_final_ols_regression(score_comparison, ridge_results):
    """
    Step 4: Final OLS Regression Modeling
    
    Fit OLS regression using all features.
    This provides interpretable coefficients, confidence intervals, and p-values
    for nomogram construction and clinical interpretation.
    
    Args:
        score_comparison: DataFrame with all preprocessed data
        ridge_results: Dictionary from Step 3 containing all features for each domain

    Returns:
        Dictionary with OLS results for each domain including:
        - Regression coefficients with 95% CI and p-values
        - Model performance metrics (R², RMSE, Adjusted R²)
        - Fitted model object
        - Residuals for diagnostics
    """
    import statsmodels.api as sm
    from sklearn.metrics import mean_squared_error, r2_score
    import scipy.stats as stats
    
    print("="*80)
    print("STEP 4: FINAL OLS REGRESSION MODELING")
    print("="*80)
    print("Purpose: Fit interpretable OLS models using all features")
    print("Output: Coefficients (β), 95% CI, p-values for nomogram construction")
    
    # Results dictionary
    ols_results = {}
    
    # Loop through each domain
    for outcome_domain, ridge_res in ridge_results.items():
        print(f"\n{'='*80}")
        print(f"OUTCOME DOMAIN: {outcome_domain}")
        print(f"{'='*80}")
        
        # Get stable features from Step 3
        stable_features = ridge_res['stable_features']
        
        if len(stable_features) == 0:
            print("\n⚠ WARNING: No stable features identified in Step 3")
            print("   Skipping OLS regression for this domain")
            print("   Consider using a less stringent bootstrap threshold or more data")
            
            ols_results[outcome_domain] = {
                'n_observations': ridge_res['n_observations'],
                'stable_features': [],
                'n_stable_features': 0,
                'coefficients_table': None,
                'model_performance': None,
                'model': None,
                'skipped': True,
                'skip_reason': 'No stable features'
            }
            continue
        
        print(f"\nUsing all {len(stable_features)} features from Step 3 (Ridge retains all predictors):")
        for i, feature in enumerate(stable_features, 1):
            print(f"  {i}. {feature}")
        
        # Get outcome variable
        y = score_comparison[outcome_domain].copy()
        
        # Get predictor variables (ONLY stable features)
        X = score_comparison[stable_features].copy()
        
        # Remove any rows with missing outcome
        valid_idx = y.notna()
        X_clean = X[valid_idx].copy()
        y_clean = y[valid_idx].copy()
        
        print(f"\nValid observations: {len(y_clean)} / {len(y)}")
        
        # Add intercept
        X_clean_with_const = sm.add_constant(X_clean)
        
        # ========== FIT OLS REGRESSION ==========
        print(f"\n{'─'*80}")
        print("FITTING OLS REGRESSION MODEL")
        print(f"{'─'*80}")
        
        # Fit OLS model
        ols_model = sm.OLS(y_clean, X_clean_with_const).fit()
        
        # Get predictions
        y_pred = ols_model.predict(X_clean_with_const)
        
        # Calculate performance metrics
        r2 = r2_score(y_clean, y_pred)
        rmse = np.sqrt(mean_squared_error(y_clean, y_pred))
        adj_r2 = ols_model.rsquared_adj
        aic = ols_model.aic
        bic = ols_model.bic
        
        print(f"\n✓ MODEL PERFORMANCE (Apparent - optimistic):")
        print(f"  R²: {r2:.4f}")
        print(f"  Adjusted R²: {adj_r2:.4f}")
        print(f"  RMSE: {rmse:.4f}")
        print(f"  AIC: {aic:.2f}")
        print(f"  BIC: {bic:.2f}")
        print(f"  F-statistic: {ols_model.fvalue:.4f}")
        print(f"  Prob (F-statistic): {ols_model.f_pvalue:.4e}")
        
        # ========== EXTRACT COEFFICIENTS, CI, P-VALUES ==========
        print(f"\n{'─'*80}")
        print("REGRESSION COEFFICIENTS (for Nomogram)")
        print(f"{'─'*80}")
        
        # Create coefficients table
        coef_table = pd.DataFrame({
            'Feature': ['Intercept'] + stable_features,
            'Coefficient': ols_model.params.values,
            'Std_Error': ols_model.bse.values,
            'CI_Lower_95': ols_model.conf_int()[0].values,
            'CI_Upper_95': ols_model.conf_int()[1].values,
            't_statistic': ols_model.tvalues.values,
            'p_value': ols_model.pvalues.values
        })
        
        # Add significance stars
        def add_significance_stars(p):
            if p < 0.001:
                return '***'
            elif p < 0.01:
                return '**'
            elif p < 0.05:
                return '*'
            else:
                return ''
        
        coef_table['Significance'] = coef_table['p_value'].apply(add_significance_stars)
        
        # Display coefficients
        print("\nCoefficient | 95% CI | p-value")
        print("-" * 80)
        for idx, row in coef_table.iterrows():
            print(f"{row['Feature']:<40} "
                    f"β={row['Coefficient']:>8.4f} "
                    f"[{row['CI_Lower_95']:>7.4f}, {row['CI_Upper_95']:>7.4f}] "
                    f"p={row['p_value']:>7.4f} {row['Significance']}")
        
        print("\nSignificance: *** p<0.001, ** p<0.01, * p<0.05")
        
        # ========== MODEL DIAGNOSTICS ==========
        print(f"\n{'─'*80}")
        print("MODEL DIAGNOSTICS")
        print(f"{'─'*80}")
        
        # Calculate residuals
        residuals = ols_model.resid
        
        # Normality test (Shapiro-Wilk)
        if len(residuals) <= 5000:  # Shapiro-Wilk has sample size limit
            shapiro_stat, shapiro_p = stats.shapiro(residuals)
            print(f"Shapiro-Wilk test (normality): W={shapiro_stat:.4f}, p={shapiro_p:.4f}")
        else:
            print(f"Shapiro-Wilk test: Skipped (sample size > 5000)")
        
        # Durbin-Watson (independence)
        dw_stat = sm.stats.stattools.durbin_watson(residuals)
        print(f"Durbin-Watson (independence): {dw_stat:.4f} (ideal: ~2.0)")
        
        # Variance Inflation Factor (multicollinearity)
        if len(stable_features) > 1:
            from statsmodels.stats.outliers_influence import variance_inflation_factor
            vif_data = pd.DataFrame()
            vif_data["Feature"] = stable_features
            vif_data["VIF"] = [variance_inflation_factor(X_clean.values, i) for i in range(len(stable_features))]
            print(f"\nVariance Inflation Factors (multicollinearity):")
            for _, row in vif_data.iterrows():
                vif_concern = " (CONCERN: VIF > 10)" if row['VIF'] > 10 else ""
                print(f"  {row['Feature']:<40} VIF={row['VIF']:>8.4f}{vif_concern}")
        
        # ========== COMPARE WITH NESTED CV (from Step 3) ==========
        print(f"\n{'─'*80}")
        print("COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)")
        print(f"{'─'*80}")
        
        nested_cv_r2 = ridge_res['nested_cv_r2_mean']
        nested_cv_rmse = ridge_res['nested_cv_rmse_mean']
        
        if not np.isnan(nested_cv_r2):
            optimism_r2 = r2 - nested_cv_r2
            optimism_rmse = rmse - nested_cv_rmse
            
            print(f"\nMetric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism")
            print("-" * 80)
            print(f"R²                        {r2:>8.4f}          {nested_cv_r2:>8.4f}             {optimism_r2:>+8.4f}")
            print(f"RMSE                      {rmse:>8.4f}          {nested_cv_rmse:>8.4f}             {optimism_rmse:>+8.4f}")
            
            print(f"\nNote: Optimism = Apparent - Unbiased")
            print(f"      Positive optimism indicates overfitting on training data")
        else:
            print("\nNested CV results not available for comparison")
        
        # ========== STORE RESULTS ==========
        ols_results[outcome_domain] = {
            # Data info
            'n_observations': len(y_clean),
            'stable_features': stable_features,
            'n_stable_features': len(stable_features),
            
            # Coefficients table (for nomogram and reporting)
            'coefficients_table': coef_table,
            
            # Model performance
            'model_performance': {
                'r2': r2,
                'adjusted_r2': adj_r2,
                'rmse': rmse,
                'aic': aic,
                'bic': bic,
                'f_statistic': ols_model.fvalue,
                'f_pvalue': ols_model.f_pvalue
            },
            
            # Model object
            'model': ols_model,
            
            # Predictions and residuals
            'predictions': y_pred,
            'residuals': residuals,
            'y_true': y_clean,
            
            # Comparison with nested CV
            'nested_cv_r2': nested_cv_r2,
            'nested_cv_rmse': nested_cv_rmse,
            'optimism_r2': r2 - nested_cv_r2 if not np.isnan(nested_cv_r2) else np.nan,
            'optimism_rmse': rmse - nested_cv_rmse if not np.isnan(nested_cv_rmse) else np.nan,
            
            # Diagnostics
            'durbin_watson': dw_stat,
            
            'skipped': False
        }
        
        print(f"\n{'='*80}")
        print(f"✓ COMPLETED: {outcome_domain}")
        print(f"{'='*80}")
    
    # ========== FINAL SUMMARY ==========
    print(f"\n{'='*80}")
    print("STEP 4 COMPLETE: FINAL OLS REGRESSION MODELING")
    print(f"{'='*80}")
    
    # Summary table
    print("\nSUMMARY TABLE:")
    print("="*120)
    summary_rows = []
    for domain, res in ols_results.items():
        if res['skipped']:
            summary_rows.append({
                'Domain': domain.replace('_12mo', ''),
                'N': res['n_observations'],
                'Features': 0,
                'OLS R²': 'N/A',
                'OLS RMSE': 'N/A',
                'Nested CV R²': 'N/A',
                'Optimism (R²)': 'N/A'
            })
        else:
            nested_cv_r2_str = f"{res['nested_cv_r2']:.4f}" if not np.isnan(res['nested_cv_r2']) else 'N/A'
            optimism_str = f"{res['optimism_r2']:+.4f}" if not np.isnan(res['optimism_r2']) else 'N/A'
            
            summary_rows.append({
                'Domain': domain.replace('_12mo', ''),
                'N': res['n_observations'],
                'Features': res['n_stable_features'],
                'OLS R²': f"{res['model_performance']['r2']:.4f}",
                'OLS RMSE': f"{res['model_performance']['rmse']:.4f}",
                'Nested CV R²': nested_cv_r2_str,
                'Optimism (R²)': optimism_str
            })
    
    summary_df = pd.DataFrame(summary_rows)
    print(summary_df.to_string(index=False))
    print("="*120)
    
    print("\nNOTE:")
    print("  • OLS R²/RMSE = Apparent performance (optimistic)")
    print("  • Nested CV R² = Unbiased performance from Step 3 (use for reporting)")
    print("  • Optimism = OLS - Nested CV (shows degree of overfitting)")
    print("  • Coefficients will be used for nomogram construction (Step 5)")
    
    return ols_results

# Run final OLS regression
ols_results = perform_final_ols_regression(score_comparison, ridge_results)

# Save results
print("\n" + "="*80)
print("SAVING STEP 4 RESULTS...")
print("="*80)

for domain, res in ols_results.items():
    domain_name = domain.replace('_12mo', '')
    
    if res['skipped']:
        print(f"⚠ Skipped {domain_name} - no stable features")
        continue
    
    # Save coefficients table (IMPORTANT: for nomogram)
    res['coefficients_table'].to_csv(f"step4_ols_coefficients_{domain_name}.csv", index=False)
    print(f"✓ Saved OLS coefficients for {domain_name} (for nomogram)")
    
    # Save model performance comparison
    performance_df = pd.DataFrame({
        'Metric': ['N_observations', 'N_features', 'OLS_R2', 'OLS_Adjusted_R2', 'OLS_RMSE', 
                    'OLS_AIC', 'OLS_BIC', 'Nested_CV_R2', 'Nested_CV_RMSE', 
                    'Optimism_R2', 'Optimism_RMSE'],
        'Value': [
            res['n_observations'],
            res['n_stable_features'],
            res['model_performance']['r2'],
            res['model_performance']['adjusted_r2'],
            res['model_performance']['rmse'],
            res['model_performance']['aic'],
            res['model_performance']['bic'],
            res['nested_cv_r2'],
            res['nested_cv_rmse'],
            res['optimism_r2'],
            res['optimism_rmse']
        ]
    })
    performance_df.to_csv(f"step4_ols_performance_{domain_name}.csv", index=False)
    print(f"✓ Saved OLS performance comparison for {domain_name}")
    
    # Save predictions and residuals for diagnostics
    diagnostics_df = pd.DataFrame({
        'y_true': res['y_true'],
        'y_predicted': res['predictions'],
        'residuals': res['residuals']
    })
    diagnostics_df.to_csv(f"step4_ols_diagnostics_{domain_name}.csv", index=False)
    print(f"✓ Saved OLS diagnostics for {domain_name}")

print("="*80)
print("✓ STEP 4 COMPLETE - Ready for Step 5 (Nomogram Construction)")
print("="*80)
# Out:
# ================================================================================
# STEP 4: FINAL OLS REGRESSION MODELING
# ================================================================================
# Purpose: Fit interpretable OLS models using all features
# Output: Coefficients (β), 95% CI, p-values for nomogram construction
#
# ================================================================================
# OUTCOME DOMAIN: fact_e_total_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.2763
#   Adjusted R²: 0.1396
#   RMSE: 22.1596
#   AIC: 1011.72
#   BIC: 1060.00
#   F-statistic: 2.0215
#   Prob (F-statistic): 1.7704e-02
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β=132.3815 [102.9010, 161.8619] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-566.7260 [-1196.3030, 62.8509] p= 0.0771
# pwb_subscale_score_Baseline_std          β=132.3313 [-9.8150, 274.4777] p= 0.0677
# swb_subscale_score_Baseline_std          β=117.0441 [-14.3401, 248.4284] p= 0.0801
# ewb_subscale_score_Baseline_std          β=114.7569 [-10.6196, 240.1334] p= 0.0723
# fwb_subscale_score_Baseline_std          β=163.1294 [-12.2129, 338.4716] p= 0.0678
# ecs_subscale_score_Baseline_std          β=272.8426 [-34.1258, 579.8111] p= 0.0808
# bmi_std                                  β=  3.3649 [-2.1710,  8.9008] p= 0.2304
# age_diagnosis_std                        β=  7.4458 [ 1.2031, 13.6885] p= 0.0199 *
# cci_category_numeric                     β= -7.5772 [-16.7060,  1.5515] p= 0.1026
# gender                                   β= -5.7598 [-18.0679,  6.5483] p= 0.3550
# smoking_collapsed_imputed                β= -4.8946 [-15.7224,  5.9332] p= 0.3716
# alcohol_collapsed_imputed                β=  9.0237 [-1.7369, 19.7842] p= 0.0992
# level_tumor_collapsed_imputed            β=  4.8763 [-3.4042, 13.1567] p= 0.2451
# path_histology_collapsed_imputed         β= -3.4711 [-8.9872,  2.0449] p= 0.2145
# path_esoph_stage_collapsed_imputed       β=  2.4352 [-1.4138,  6.2842] p= 0.2120
# surgery_approach_imputed                 β=  4.1028 [-6.3552, 14.5609] p= 0.4378
# neotx_collapsed_imputed                  β=  1.9271 [-3.7293,  7.5835] p= 0.5002
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9819, p=0.1508
# Durbin-Watson (independence): 2.0575 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.2763           -0.0892              +0.3656
# RMSE                       22.1596           24.9861              -2.8265
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: fact_e_total_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: pwb_subscale_score_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.3735
#   Adjusted R²: 0.2551
#   RMSE: 4.6081
#   AIC: 672.50
#   BIC: 720.77
#   F-statistic: 3.1559
#   Prob (F-statistic): 2.1261e-04
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β= 22.7058 [16.5754, 28.8362] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-127.5905 [-258.5098,  3.3288] p= 0.0560
# pwb_subscale_score_Baseline_std          β= 30.7176 [ 1.1585, 60.2767] p= 0.0418 *
# swb_subscale_score_Baseline_std          β= 25.6195 [-1.7016, 52.9406] p= 0.0657
# ewb_subscale_score_Baseline_std          β= 25.8793 [-0.1925, 51.9511] p= 0.0517
# fwb_subscale_score_Baseline_std          β= 36.7137 [ 0.2516, 73.1757] p= 0.0485 *
# ecs_subscale_score_Baseline_std          β= 60.6856 [-3.1479, 124.5191] p= 0.0622
# bmi_std                                  β=  1.3180 [ 0.1669,  2.4692] p= 0.0253 *
# age_diagnosis_std                        β=  1.8024 [ 0.5043,  3.1006] p= 0.0070 **
# cci_category_numeric                     β= -2.0360 [-3.9343, -0.1377] p= 0.0358 *
# gender                                   β= -1.0442 [-3.6036,  1.5153] p= 0.4198
# smoking_collapsed_imputed                β= -1.0420 [-3.2936,  1.2097] p= 0.3604
# alcohol_collapsed_imputed                β=  1.9170 [-0.3206,  4.1546] p= 0.0922
# level_tumor_collapsed_imputed            β=  0.5399 [-1.1820,  2.2618] p= 0.5349
# path_histology_collapsed_imputed         β= -0.2220 [-1.3690,  0.9251] p= 0.7016
# path_esoph_stage_collapsed_imputed       β=  0.6908 [-0.1096,  1.4912] p= 0.0899
# surgery_approach_imputed                 β=  1.1199 [-1.0548,  3.2946] p= 0.3090
# neotx_collapsed_imputed                  β=  0.3783 [-0.7980,  1.5545] p= 0.5245
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9398, p=0.0001
# Durbin-Watson (independence): 1.9368 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.3735           -0.0453              +0.4188
# RMSE                        4.6081            5.4073              -0.7993
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: pwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: swb_subscale_score_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.2774
#   Adjusted R²: 0.1409
#   RMSE: 4.1658
#   AIC: 650.70
#   BIC: 698.98
#   F-statistic: 2.0325
#   Prob (F-statistic): 1.6993e-02
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β= 22.2591 [16.7170, 27.8011] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-73.4971 [-191.8516, 44.8575] p= 0.2205
# pwb_subscale_score_Baseline_std          β= 15.6710 [-11.0512, 42.3932] p= 0.2471
# swb_subscale_score_Baseline_std          β= 16.7128 [-7.9862, 41.4118] p= 0.1822
# ewb_subscale_score_Baseline_std          β= 14.5363 [-9.0333, 38.1059] p= 0.2237
# fwb_subscale_score_Baseline_std          β= 20.9542 [-12.0085, 53.9169] p= 0.2099
# ecs_subscale_score_Baseline_std          β= 36.7998 [-20.9074, 94.5070] p= 0.2085
# bmi_std                                  β=  0.3203 [-0.7204,  1.3610] p= 0.5425
# age_diagnosis_std                        β=  0.7363 [-0.4373,  1.9098] p= 0.2159
# cci_category_numeric                     β= -0.1056 [-1.8217,  1.6105] p= 0.9030
# gender                                   β= -0.7154 [-3.0292,  1.5984] p= 0.5406
# smoking_collapsed_imputed                β= -1.9387 [-3.9742,  0.0969] p= 0.0617
# alcohol_collapsed_imputed                β=  0.1569 [-1.8660,  2.1798] p= 0.8779
# level_tumor_collapsed_imputed            β=  0.4092 [-1.1474,  1.9659] p= 0.6028
# path_histology_collapsed_imputed         β=  0.5337 [-0.5033,  1.5707] p= 0.3093
# path_esoph_stage_collapsed_imputed       β=  0.2483 [-0.4753,  0.9719] p= 0.4971
# surgery_approach_imputed                 β= -0.1246 [-2.0907,  1.8414] p= 0.9001
# neotx_collapsed_imputed                  β=  0.1674 [-0.8960,  1.2307] p= 0.7553
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9473, p=0.0003
# Durbin-Watson (independence): 2.2454 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.2774            0.0155              +0.2619
# RMSE                        4.1658            4.6257              -0.4599
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: swb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ewb_subscale_score_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.3470
#   Adjusted R²: 0.2236
#   RMSE: 3.7485
#   AIC: 627.90
#   BIC: 676.18
#   F-statistic: 2.8130
#   Prob (F-statistic): 8.2260e-04
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β= 15.5359 [10.5490, 20.5229] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-92.4929 [-198.9921, 14.0064] p= 0.0879
# pwb_subscale_score_Baseline_std          β= 21.4893 [-2.5562, 45.5348] p= 0.0792
# swb_subscale_score_Baseline_std          β= 18.6013 [-3.6236, 40.8263] p= 0.0998
# ewb_subscale_score_Baseline_std          β= 19.4599 [-1.7488, 40.6685] p= 0.0716
# fwb_subscale_score_Baseline_std          β= 26.9994 [-2.6616, 56.6603] p= 0.0739
# ecs_subscale_score_Baseline_std          β= 44.6974 [-7.2294, 96.6242] p= 0.0907
# bmi_std                                  β=  0.8863 [-0.0501,  1.8228] p= 0.0633
# age_diagnosis_std                        β=  0.8719 [-0.1841,  1.9279] p= 0.1044
# cci_category_numeric                     β= -0.1200 [-1.6642,  1.4242] p= 0.8777
# gender                                   β= -0.7083 [-2.7904,  1.3737] p= 0.5009
# smoking_collapsed_imputed                β=  0.1486 [-1.6830,  1.9803] p= 0.8723
# alcohol_collapsed_imputed                β=  1.8064 [-0.0139,  3.6266] p= 0.0517
# level_tumor_collapsed_imputed            β=  0.6524 [-0.7483,  2.0531] p= 0.3573
# path_histology_collapsed_imputed         β= -0.6506 [-1.5837,  0.2825] p= 0.1694
# path_esoph_stage_collapsed_imputed       β=  0.5277 [-0.1234,  1.1788] p= 0.1108
# surgery_approach_imputed                 β=  0.4568 [-1.3122,  2.2259] p= 0.6092
# neotx_collapsed_imputed                  β=  0.4134 [-0.5434,  1.3702] p= 0.3930
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9889, p=0.5177
# Durbin-Watson (independence): 1.9875 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.3470           -0.3572              +0.7042
# RMSE                        3.7485            4.3383              -0.5898
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: ewb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: fwb_subscale_score_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.2773
#   Adjusted R²: 0.1408
#   RMSE: 5.7799
#   AIC: 721.44
#   BIC: 769.72
#   F-statistic: 2.0316
#   Prob (F-statistic): 1.7049e-02
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β= 18.0486 [10.3592, 25.7380] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-99.2122 [-263.4258, 65.0014] p= 0.2332
# pwb_subscale_score_Baseline_std          β= 23.4677 [-13.6086, 60.5440] p= 0.2118
# swb_subscale_score_Baseline_std          β= 20.1619 [-14.1073, 54.4311] p= 0.2456
# ewb_subscale_score_Baseline_std          β= 19.4366 [-13.2655, 52.1388] p= 0.2408
# fwb_subscale_score_Baseline_std          β= 29.7715 [-15.9633, 75.5063] p= 0.1992
# ecs_subscale_score_Baseline_std          β= 47.5501 [-32.5170, 127.6172] p= 0.2412
# bmi_std                                  β=  0.4226 [-1.0214,  1.8665] p= 0.5624
# age_diagnosis_std                        β=  2.0187 [ 0.3904,  3.6470] p= 0.0157 *
# cci_category_numeric                     β= -2.2073 [-4.5883,  0.1738] p= 0.0688
# gender                                   β= -1.4950 [-4.7054,  1.7153] p= 0.3573
# smoking_collapsed_imputed                β= -0.3670 [-3.1913,  2.4572] p= 0.7969
# alcohol_collapsed_imputed                β=  3.0719 [ 0.2652,  5.8786] p= 0.0323 *
# level_tumor_collapsed_imputed            β=  1.5922 [-0.5676,  3.7520] p= 0.1465
# path_histology_collapsed_imputed         β= -0.8857 [-2.3245,  0.5530] p= 0.2245
# path_esoph_stage_collapsed_imputed       β=  0.4116 [-0.5924,  1.4155] p= 0.4175
# surgery_approach_imputed                 β=  0.0771 [-2.6507,  2.8049] p= 0.9553
# neotx_collapsed_imputed                  β=  0.4525 [-1.0229,  1.9278] p= 0.5439
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9901, p=0.6187
# Durbin-Watson (independence): 2.0451 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.2773           -0.1192              +0.3966
# RMSE                        5.7799            6.4602              -0.6802
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: fwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ecs_subscale_score_12mo
# ================================================================================
#
# Using all 17 features from Step 3 (Ridge retains all predictors):
#   1. fact_e_total_Baseline_std
#   2. pwb_subscale_score_Baseline_std
#   3. swb_subscale_score_Baseline_std
#   4. ewb_subscale_score_Baseline_std
#   5. fwb_subscale_score_Baseline_std
#   6. ecs_subscale_score_Baseline_std
#   7. bmi_std
#   8. age_diagnosis_std
#   9. cci_category_numeric
#   10. gender
#   11. smoking_collapsed_imputed
#   12. alcohol_collapsed_imputed
#   13. level_tumor_collapsed_imputed
#   14. path_histology_collapsed_imputed
#   15. path_esoph_stage_collapsed_imputed
#   16. surgery_approach_imputed
#   17. neotx_collapsed_imputed
#
# Valid observations: 108 / 108
#
# ────────────────────────────────────────────────────────────────────────────────
# FITTING OLS REGRESSION MODEL
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ MODEL PERFORMANCE (Apparent - optimistic):
#   R²: 0.1522
#   Adjusted R²: -0.0080
#   RMSE: 9.4647
#   AIC: 827.97
#   BIC: 876.24
#   F-statistic: 0.9502
#   Prob (F-statistic): 5.1976e-01
#
# ────────────────────────────────────────────────────────────────────────────────
# REGRESSION COEFFICIENTS (for Nomogram)
# ────────────────────────────────────────────────────────────────────────────────
#
# Coefficient | 95% CI | p-value
# --------------------------------------------------------------------------------
# Intercept                                β= 53.8321 [41.2406, 66.4236] p= 0.0000 ***
# fact_e_total_Baseline_std                β=-173.9334 [-442.8347, 94.9678] p= 0.2021
# pwb_subscale_score_Baseline_std          β= 40.9858 [-19.7270, 101.6985] p= 0.1832
# swb_subscale_score_Baseline_std          β= 35.9486 [-20.1675, 92.0647] p= 0.2064
# ewb_subscale_score_Baseline_std          β= 35.4448 [-18.1053, 88.9949] p= 0.1919
# fwb_subscale_score_Baseline_std          β= 48.6907 [-26.2005, 123.5819] p= 0.1998
# ecs_subscale_score_Baseline_std          β= 83.1097 [-48.0009, 214.2203] p= 0.2112
# bmi_std                                  β=  0.4177 [-1.9468,  2.7822] p= 0.7264
# age_diagnosis_std                        β=  2.0165 [-0.6498,  4.6829] p= 0.1365
# cci_category_numeric                     β= -3.1084 [-7.0074,  0.7906] p= 0.1167
# gender                                   β= -1.7969 [-7.0539,  3.4600] p= 0.4988
# smoking_collapsed_imputed                β= -1.6956 [-6.3203,  2.9291] p= 0.4683
# alcohol_collapsed_imputed                β=  2.0715 [-2.5245,  6.6675] p= 0.3729
# level_tumor_collapsed_imputed            β=  1.6825 [-1.8542,  5.2192] p= 0.3471
# path_histology_collapsed_imputed         β= -2.2466 [-4.6026,  0.1094] p= 0.0614
# path_esoph_stage_collapsed_imputed       β=  0.5568 [-1.0872,  2.2008] p= 0.5028
# surgery_approach_imputed                 β=  2.5736 [-1.8932,  7.0404] p= 0.2554
# neotx_collapsed_imputed                  β=  0.5156 [-1.9003,  2.9316] p= 0.6726
#
# Significance: *** p<0.001, ** p<0.01, * p<0.05
#
# ────────────────────────────────────────────────────────────────────────────────
# MODEL DIAGNOSTICS
# ────────────────────────────────────────────────────────────────────────────────
# Shapiro-Wilk test (normality): W=0.9857, p=0.3053
# Durbin-Watson (independence): 2.0579 (ideal: ~2.0)
#
# Variance Inflation Factors (multicollinearity):
#   fact_e_total_Baseline_std                VIF=17972.3080 (CONCERN: VIF > 10)
#   pwb_subscale_score_Baseline_std          VIF=916.2582 (CONCERN: VIF > 10)
#   swb_subscale_score_Baseline_std          VIF=782.8781 (CONCERN: VIF > 10)
#   ewb_subscale_score_Baseline_std          VIF=710.9619 (CONCERN: VIF > 10)
#   fwb_subscale_score_Baseline_std          VIF=1395.8365 (CONCERN: VIF > 10)
#   ecs_subscale_score_Baseline_std          VIF=4271.7609 (CONCERN: VIF > 10)
#   bmi_std                                  VIF=  1.3581
#   age_diagnosis_std                        VIF=  1.7223
#   cci_category_numeric                     VIF= 14.0241 (CONCERN: VIF > 10)
#   gender                                   VIF=  9.3334
#   smoking_collapsed_imputed                VIF=  3.0024
#   alcohol_collapsed_imputed                VIF=  3.5443
#   level_tumor_collapsed_imputed            VIF=  9.5088
#   path_histology_collapsed_imputed         VIF=  3.7323
#   path_esoph_stage_collapsed_imputed       VIF=  4.4640
#   surgery_approach_imputed                 VIF=  1.9686
#   neotx_collapsed_imputed                  VIF=  3.7536
#
# ────────────────────────────────────────────────────────────────────────────────
# COMPARISON: OLS (Apparent) vs Nested CV (Unbiased)
# ────────────────────────────────────────────────────────────────────────────────
#
# Metric                    OLS (Apparent)    Nested CV (Unbiased)    Optimism
# --------------------------------------------------------------------------------
# R²                          0.1522           -0.1324              +0.2845
# RMSE                        9.4647           10.0722              -0.6075
#
# Note: Optimism = Apparent - Unbiased
#       Positive optimism indicates overfitting on training data
#
# ================================================================================
# ✓ COMPLETED: ecs_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# STEP 4 COMPLETE: FINAL OLS REGRESSION MODELING
# ================================================================================
#
# SUMMARY TABLE:
# ========================================================================================================================
#             Domain   N  Features OLS R² OLS RMSE Nested CV R² Optimism (R²)
#       fact_e_total 108        17 0.2763  22.1596      -0.0892       +0.3656
# pwb_subscale_score 108        17 0.3735   4.6081      -0.0453       +0.4188
# swb_subscale_score 108        17 0.2774   4.1658       0.0155       +0.2619
# ewb_subscale_score 108        17 0.3470   3.7485      -0.3572       +0.7042
# fwb_subscale_score 108        17 0.2773   5.7799      -0.1192       +0.3966
# ecs_subscale_score 108        17 0.1522   9.4647      -0.1324       +0.2845
# ========================================================================================================================
#
# NOTE:
#   • OLS R²/RMSE = Apparent performance (optimistic)
#   • Nested CV R² = Unbiased performance from Step 3 (use for reporting)
#   • Optimism = OLS - Nested CV (shows degree of overfitting)
#   • Coefficients will be used for nomogram construction (Step 5)
#
# ================================================================================
# SAVING STEP 4 RESULTS...
# ================================================================================
# ✓ Saved OLS coefficients for fact_e_total (for nomogram)
# ✓ Saved OLS performance comparison for fact_e_total
# ✓ Saved OLS diagnostics for fact_e_total
# ✓ Saved OLS coefficients for pwb_subscale_score (for nomogram)
# ✓ Saved OLS performance comparison for pwb_subscale_score
# ✓ Saved OLS diagnostics for pwb_subscale_score
# ✓ Saved OLS coefficients for swb_subscale_score (for nomogram)
# ✓ Saved OLS performance comparison for swb_subscale_score
# ✓ Saved OLS diagnostics for swb_subscale_score
# ✓ Saved OLS coefficients for ewb_subscale_score (for nomogram)
# ✓ Saved OLS performance comparison for ewb_subscale_score
# ✓ Saved OLS diagnostics for ewb_subscale_score
# ✓ Saved OLS coefficients for fwb_subscale_score (for nomogram)
# ✓ Saved OLS performance comparison for fwb_subscale_score
# ✓ Saved OLS diagnostics for fwb_subscale_score
# ✓ Saved OLS coefficients for ecs_subscale_score (for nomogram)
# ✓ Saved OLS performance comparison for ecs_subscale_score
# ✓ Saved OLS diagnostics for ecs_subscale_score
# ================================================================================
# ✓ STEP 4 COMPLETE - Ready for Step 5 (Nomogram Construction)
# ================================================================================

# %%
ols_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'coefficients_table':                                Feature  Coefficient   Std_Error  CI_Lower_95  \
#   0                            Intercept   132.381485   14.839100   102.901021
#   1            fact_e_total_Baseline_std  -566.726041  316.899899 -1196.303003
#   2      pwb_subscale_score_Baseline_std   132.331344   71.549904    -9.815029
#   3      swb_subscale_score_Baseline_std   117.044123   66.132750   -14.340128
#   4      ewb_subscale_score_Baseline_std   114.756885   63.108740   -10.619641
#   5      fwb_subscale_score_Baseline_std   163.129372   88.259184   -12.212903
#   6      ecs_subscale_score_Baseline_std   272.842637  154.513721   -34.125839
#   7                              bmi_std     3.364917    2.786527    -2.171006
#   8                    age_diagnosis_std     7.445813    3.142293     1.203099
#   9                 cci_category_numeric    -7.577218    4.594986   -16.705959
#   10                              gender    -5.759824    6.195341   -18.067950
#   11           smoking_collapsed_imputed    -4.894590    5.450199   -15.722362
#   12           alcohol_collapsed_imputed     9.023668    5.416375    -1.736906
#   13       level_tumor_collapsed_imputed     4.876258    4.167984    -3.404170
#   14    path_histology_collapsed_imputed    -3.471148    2.776536    -8.987222
#   15  path_esoph_stage_collapsed_imputed     2.435192    1.937428    -1.413846
#   16            surgery_approach_imputed     4.102823    5.264107    -6.355244
#   17             neotx_collapsed_imputed     1.927120    2.847170    -3.729281
#
#       CI_Upper_95  t_statistic       p_value Significance
#   0    161.861948     8.921126  5.023521e-14          ***
#   1     62.850921    -1.788344  7.708559e-02
#   2    274.477717     1.849497  6.766823e-02
#   3    248.428375     1.769836  8.014125e-02
#   4    240.133411     1.818399  7.232954e-02
#   5    338.471646     1.848299  6.784304e-02
#   6    579.811113     1.765815  8.081819e-02
#   7      8.900840     1.207566  2.303780e-01
#   8     13.688527     2.369548  1.994671e-02            *
#   9      1.551524    -1.649019  1.026302e-01
#   10     6.548302    -0.929703  3.550121e-01
#   11     5.933182    -0.898057  3.715514e-01
#   12    19.784242     1.665998  9.919093e-02
#   13    13.156686     1.169932  2.451172e-01
#   14     2.044927    -1.250172  2.144777e-01
#   15     6.284231     1.256920  2.120347e-01
#   16    14.560891     0.779396  4.377912e-01
#   17     7.583521     0.676854  5.002343e-01               ,
#   'model_performance': {'r2': 0.27632776983354124,
#    'adjusted_r2': 0.1396341263576545,
#    'rmse': 22.1596242105445,
#    'aic': 1011.7174543773223,
#    'bic': 1059.9958164655582,
#    'f_statistic': 2.0215114822240174,
#    'f_pvalue': 0.01770427925154303},
#   'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc3

#   'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc3df455cd0>,
#   'predictions': id
#   32      47.836180
#   76      45.781364
#   125     47.279833
#   160     46.870726
#   198     46.473802
#             ...
#   1566    48.639133
#   1571    49.104058
#   1572    43.855937
#   1615    47.260341
#   1653    52.838785
#   Length: 108, dtype: float64,
#   'residuals': id
#   32       7.163820
#   76       2.218636
#   125      6.720167
#   160     10.129274
#   198      4.526198
#             ...
#   1566   -10.639133
#   1571   -14.104058
#   1572    -6.855937
#   1615   -10.260341
#   1653     9.161215
#   Length: 108, dtype: float64,
#   'y_true': id
#   32      55.0
#   76      48.0
#   125     54.0
#   160     57.0
#   198     51.0
#           ...
#   1566    38.0
#   1571    35.0
#   1572    37.0
#   1615    37.0
#   1653    62.0
#   Name: ecs_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0.132366015063451,
#   'nested_cv_rmse': 10.072232023766755,
#   'optimism_r2': 0.2845348142016031,
#   'optimism_rmse': -0.6075414132671089,
#   'durbin_watson': 2.057877812829246,
#   'skipped': False}}

# %% [raw]
# import pickle
# with open('ols_results.pkl', 'wb') as f:
#     pickle.dump(ols_results, f)

# %% [markdown]
# # Nomogram construction

# %%
import pickle
with open('ols_results.pkl', 'rb') as f:
    ols_results = pickle.load(f)
ols_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'coefficients_table':                                Feature  Coefficient   Std_Error  CI_Lower_95  \
#   0                            Intercept   132.381485   14.839100   102.901021
#   1            fact_e_total_Baseline_std  -566.726041  316.899899 -1196.303003
#   2      pwb_subscale_score_Baseline_std   132.331344   71.549904    -9.815029
#   3      swb_subscale_score_Baseline_std   117.044123   66.132750   -14.340128
#   4      ewb_subscale_score_Baseline_std   114.756885   63.108740   -10.619641
#   5      fwb_subscale_score_Baseline_std   163.129372   88.259184   -12.212903
#   6      ecs_subscale_score_Baseline_std   272.842637  154.513721   -34.125839
#   7                              bmi_std     3.364917    2.786527    -2.171006
#   8                    age_diagnosis_std     7.445813    3.142293     1.203099
#   9                 cci_category_numeric    -7.577218    4.594986   -16.705959
#   10                              gender    -5.759824    6.195341   -18.067950
#   11           smoking_collapsed_imputed    -4.894590    5.450199   -15.722362
#   12           alcohol_collapsed_imputed     9.023668    5.416375    -1.736906
#   13       level_tumor_collapsed_imputed     4.876258    4.167984    -3.404170
#   14    path_histology_collapsed_imputed    -3.471148    2.776536    -8.987222
#   15  path_esoph_stage_collapsed_imputed     2.435192    1.937428    -1.413846
#   16            surgery_approach_imputed     4.102823    5.264107    -6.355244
#   17             neotx_collapsed_imputed     1.927120    2.847170    -3.729281
#
#       CI_Upper_95  t_statistic       p_value Significance
#   0    161.861948     8.921126  5.023521e-14          ***
#   1     62.850921    -1.788344  7.708559e-02
#   2    274.477717     1.849497  6.766823e-02
#   3    248.428375     1.769836  8.014125e-02
#   4    240.133411     1.818399  7.232954e-02
#   5    338.471646     1.848299  6.784304e-02
#   6    579.811113     1.765815  8.081819e-02
#   7      8.900840     1.207566  2.303780e-01
#   8     13.688527     2.369548  1.994671e-02            *
#   8      3.100579     2.758381  7.035425e-03           **
#   9     -0.137657    -2.130740  3.583764e-02            *
#   10     1.515272    -0.810503  4.197893e-01
#   11     1.209660    -0.919351  3.603693e-01
#   12     4.154648     1.702003  9.220688e-02
#   13     2.261771     0.622888  5.349332e-01
#   14     0.925091    -0.384439  7.015597e-01
#   15     1.491197     1.714629  8.985491e-02
#   16     3.294625     1.023048  3.090272e-01
#   17     1.554514     0.638912  5.245028e-01               ,
#   'model_performance': {'r2': 0.3734800478714332,
#    'adjusted_r2': 0.2551373902471483,
#    'rmse': 4.608050250314433,
#    'aic': 672.4965660958705,
#    'bic': 720.7749281841066,
#    'f_statistic': 3.155920742097583,
#    'f_pvalue': 0.00021260667606967784},
#   'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc3e8681950>,
#   'predictions': id
#   32      21.870557
#   76      15.254057
#   125     19.697812
#   160     20.008391
#   198     24.602639
#             ...
#   1566    20.536358
#   1571    22.051927
#   1572    24.926799
#   1615    19.242729
#   1653    24.227703
#   Length: 108, dtype: float64,
#   'residuals': id
#   32      5.129443
#   76     -8.254057
#   125     2.302188
#   160     7.991609
#   198     1.897361
#             ...
#   1566   -1.536358
#   1571   -6.051927
#   1572   -0.926799
#   1615   -0.242729
#   1653    1.772297
#   Length: 108, dtype: float64,
#   'y_true': id
#   32      27.0
#   76       7.0
#   125     22.0
#   160     28.0
#   198     26.5
#           ...
#   1566    19.0
#   1571    16.0
#   1572    24.0
#   1615    19.0
#   1653    26.0
#   Name: pwb_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0.045347812125048445,
#   'nested_cv_rmse': 5.4073328900063045,
#   'optimism_r2': 0.41882785999648164,
#   'optimism_rmse': -0.7992826396918717,
#   'durbin_watson': 1.9367625059581262,
#   'skipped': False},
#  'swb_subscale_score_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'coefficients_table':                                Feature  Coefficient  Std_Error  CI_Lower_95  \
#   0                            Intercept    22.259066   2.789612    16.717015
#   1            fact_e_total_Baseline_std   -73.497059  59.574218  -191.851640
#   2      pwb_subscale_score_Baseline_std    15.671029  13.450713   -11.051159
#   3      swb_subscale_score_Baseline_std    16.712802  12.432339    -7.986209
#   4      ewb_subscale_score_Baseline_std    14.536305  11.863853    -9.033310
#   5      fwb_subscale_score_Baseline_std    20.954173  16.591901   -12.008535
#   6      ecs_subscale_score_Baseline_std    36.799794  29.047135   -20.907409
#   7                              bmi_std     0.320271   0.523841    -0.720431
#   8                    age_diagnosis_std     0.736273   0.590722    -0.437298
#   9                 cci_category_numeric    -0.105595   0.863814    -1.821713
#   10                              gender    -0.715370   1.164666    -3.029182
#   11           smoking_collapsed_imputed    -1.938658   1.024586    -3.974178
#   12           alcohol_collapsed_imputed     0.156869   1.018228    -1.866018
#   13       level_tumor_collapsed_imputed     0.409236   0.783542    -1.147407
#   14    path_histology_collapsed_imputed     0.533718   0.521963    -0.503252
#   15  path_esoph_stage_collapsed_imputed     0.248312   0.364218    -0.475271
#   16            surgery_approach_imputed    -0.124639   0.989603    -2.090658
#   17             neotx_collapsed_imputed     0.167353   0.535241    -0.895997
#
#       CI_Upper_95  t_statistic       p_value Significance
#   0
#
#       CI_Upper_95  t_statistic       p_value Significance
#   0     66.423632     8.493560  3.886419e-13          ***
#   1     94.967830    -1.285041  2.020753e-01
#   2    101.698509     1.341158  1.832439e-01
#   3     92.064656     1.272685  2.064077e-01
#   4     88.994940     1.314981  1.918570e-01
#   5    123.581868     1.291641  1.997886e-01
#   6    214.220347     1.259334  2.111661e-01
#   7      2.782180     0.350967  7.264333e-01
#   8      4.682895     1.502508  1.364667e-01
#   9      0.790614    -1.583831  1.167400e-01
#   10     3.460035    -0.679085  4.988264e-01
#   11     2.929125    -0.728382  4.682705e-01
#   12     6.667538     0.895450  3.729353e-01
#   13     5.219226     0.945137  3.471196e-01
#   14     0.109404    -1.894420  6.138038e-02
#   15     2.200753     0.672836  5.027757e-01
#   16     7.040403     1.144655  2.553872e-01
#   17     2.931561     0.424016  6.725660e-01               ,
#   'model_performance': {'r2': 0.15216879913815207,
#    'adjusted_r2': -0.007977094357974668,
#    'rmse': 9.464690610499646,
#    'aic': 827.9654319908664,
#    'bic': 876.2437940791024,
#    'f_statistic': 0.9501885800264517,
#    'f_pvalue': 0.519760726268649},
#   'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc3df486990>,
#   'predictions': id
#   32      47.836180
#   76      45.781364
#   125     47.279833
#   160     46.870726
#   198     46.473802
#             ...
#   1566    48.639133
#   1571    49.104058
#   1572    43.855937
#   1615    47.260341
#   1653    52.838785
#   Length: 108, dtype: float64,
#   'residuals': id
#   32       7.163820
#   76       2.218636
#   125      6.720167
#   160     10.129274
#   198      4.526198
#             ...
#   1566   -10.639133
#   1571   -14.104058
#   1572    -6.855937
#   1615   -10.260341
#   1653     9.161215
#   Length: 108, dtype: float64,
#   'y_true': id
#   32      55.0
#   76      48.0
#   125     54.0
#   160     57.0
#   198     51.0
#           ...
#   1566    38.0
#   1571    35.0
#   1572    37.0
#   1615    37.0
#   1653    62.0
#   Name: ecs_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0.132366015063451,
#   'nested_cv_rmse': 10.072232023766755,
#   'optimism_r2': 0.2845348142016031,
#   'optimism_rmse': -0.6075414132671089,
#   'durbin_watson': 2.057877812829246,
#   'skipped': False}}

# %%
score_comparison=pd.read_csv("score_comparison_preprocessed.csv", index_col='id')
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  age_diagnosis_std  gender  cci_total  \
# id                                 ...
# 32                           19.0  ...          -3.924010     1.0        2.0
# 76                           15.0  ...          -0.759442     1.0        4.0
# 125                           8.0  ...          -0.019975     1.0        4.0
# 160                          20.0  ...          -1.530613     1.0        4.0
# 198                          21.0  ...           0.220608     2.0        4.0
# ...                           ...  ...                ...     ...        ...
# 1566                         18.0  ...           0.634635     1.0        4.0
# 1571                         25.0  ...           1.698298     1.0        6.0
# 1572                         20.0  ...          -0.426542     1.0        4.0
# 1615                         12.0  ...          -0.983551     1.0        4.0
# 1653                         24.0  ...           1.257229     1.0        4.0
#
#       cci_total_std  cci_category_numeric  pwb_subscale_score_Baseline_std  \
# id
# 32        -1.324120                     1                         0.348883
# 76         0.044349                     2                        -2.977447
# 125        0.044349                     2                        -0.316383
# 160        0.044349                     2                        -0.316383
# 198        0.044349                     2                         0.443921
# ...             ...                   ...                              ...
# 1566       0.044349                     2                         0.063769
# 1571       1.412817                     3                         0.633997
# 1572       0.044349                     2                         0.824073
# 1615       0.044349                     2                         0.063769
# 1653       0.044349                     2                        -0.316383
#
#       swb_subscale_score_Baseline_std  ewb_subscale_score_Baseline_std  \
# id
# 32                          -0.088736                        -2.212704
# 76                           0.115846                        -0.487638
# 125                         -1.009355                         1.021796
# 160                         -0.497900                         1.021796
# 198                         -1.929973                         0.159263
# ...                               ...                              ...
# 1566                         0.320427                         0.374896
# 1571                         1.138755                        -0.056371
# 1572                        -1.929973                         0.590529
# 1615                         0.320427                        -0.056371
# 1653                        -0.702482                         0.374896
#
#       fwb_subscale_score_Baseline_std  ecs_subscale_score_Baseline_std
# id
# 32                           0.008454                        -0.223354
# 76                          -0.608789                        -1.098848
# 125                         -1.688964                         0.301943
# 160                          0.162764                        -1.011299
# 198                          0.317075                         0.739690
# ...                               ...                              ...
# 1566                        -0.145857                         1.615185
# 1571                         0.934318                         0.827240
# 1572                         0.162764                         1.177437
# 1615                        -1.071721                         0.214394
# 1653                         0.780007                        -1.624145
#
# [108 rows x 34 columns]

# %% [markdown]
# ### option 1: original

# %%
#Option 1: original
def create_nomograms_for_all_domains(score_comparison, ols_results):
    """
    Step 5: Nomogram Construction (FIXED)
    
    Create visual nomograms for each domain using the OLS regression coefficients from Step 4.
    Nomograms allow clinicians to predict patient outcomes by summing point values.
    
    Args:
        score_comparison: DataFrame with all preprocessed data
        ols_results: Dictionary from Step 4 containing OLS coefficients
    
    Returns:
        Dictionary with nomogram data for each domain
    """
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    from matplotlib.patches import FancyBboxPatch
    import seaborn as sns
    
    print("="*80)
    print("STEP 5: NOMOGRAM CONSTRUCTION")
    print("="*80)
    print("Purpose: Create visual nomograms for clinical prediction")
    print("         Based on OLS coefficients from Step 4")
    
    # Results dictionary
    nomogram_results = {}
    
    # Loop through each domain
    for outcome_domain, ols_res in ols_results.items():
        print(f"\n{'='*80}")
        print(f"OUTCOME DOMAIN: {outcome_domain}")
        print(f"{'='*80}")
        
        if ols_res['skipped']:
            print("\n⚠ Skipping - no stable features for this domain")
            nomogram_results[outcome_domain] = {
                'skipped': True,
                'skip_reason': ols_res['skip_reason']
            }
            continue
        
        domain_name = outcome_domain.replace('_12mo', '')
        
        # Get coefficients (exclude intercept)
        coef_table = ols_res['coefficients_table'].copy()
        coef_table_no_intercept = coef_table[coef_table['Feature'] != 'Intercept'].copy()
        
        print(f"\nCreating nomogram with {len(coef_table_no_intercept)} predictors")
        
        # Get intercept
        intercept = coef_table[coef_table['Feature'] == 'Intercept']['Coefficient'].values[0]
        
        # ========== CALCULATE POINT SCALE ==========
        print(f"\n{'─'*80}")
        print("CALCULATING POINT SCALE")
        print(f"{'─'*80}")
        
        # Find the predictor with maximum absolute coefficient (for reference)
        max_abs_coef = coef_table_no_intercept['Coefficient'].abs().max()
        
        # Points scale: assign 100 points to the maximum absolute coefficient
        # Each predictor gets points proportional to its coefficient
        points_per_unit = 100 / max_abs_coef
        
        print(f"Maximum absolute coefficient: {max_abs_coef:.4f}")
        print(f"Points per unit coefficient: {points_per_unit:.4f}")
        
        # Calculate point ranges for each predictor
        nomogram_data = []
        all_possible_points = []  # Collect all possible points to determine range
        
        for idx, row in coef_table_no_intercept.iterrows():
            feature = row['Feature']
            coefficient = row['Coefficient']
            
            # Get feature data
            feature_values = score_comparison[feature].dropna()
            
            # Determine if continuous or categorical
            n_unique = feature_values.nunique()
            is_categorical = n_unique <= 10  # Heuristic: ≤10 unique values = categorical
            
            if is_categorical:
                # For categorical: list each category
                unique_vals = sorted(feature_values.unique())
                
                # FIXED: Calculate points relative to MINIMUM category (not 0)
                min_val = min(unique_vals)
                points_dict = {}
                
                for val in unique_vals:
                    points = (val - min_val) * coefficient * points_per_unit
                    points_dict[val] = points
                    all_possible_points.append(points)
                
                nomogram_data.append({
                    'feature': feature,
                    'coefficient': coefficient,
                    'is_categorical': True,
                    'categories': unique_vals,
                    'points_dict': points_dict,
                    'min_points': min(points_dict.values()),
                    'max_points': max(points_dict.values())
                })
                
                print(f"\n{feature} (categorical):")
                for val, pts in points_dict.items():
                    print(f"  Value {val}: {pts:.1f} points")
            
            else:
                # For continuous: show range
                min_val = feature_values.min()
                max_val = feature_values.max()
                mean_val = feature_values.mean()
                std_val = feature_values.std()
                
                # Calculate points at different values
                min_points = min_val * coefficient * points_per_unit
                max_points = max_val * coefficient * points_per_unit
                mean_points = mean_val * coefficient * points_per_unit
                
                all_possible_points.extend([min_points, max_points])
                
                nomogram_data.append({
                    'feature': feature,
                    'coefficient': coefficient,
                    'is_categorical': False,
                    'min_val': min_val,
                    'max_val': max_val,
                    'mean_val': mean_val,
                    'std_val': std_val,
                    'min_points': min_points,
                    'max_points': max_points,
                    'mean_points': mean_points,
                    'points_per_unit_value': coefficient * points_per_unit
                })
                
                print(f"\n{feature} (continuous):")
                print(f"  Range: [{min_val:.2f}, {max_val:.2f}]")
                print(f"  Points range: [{min_points:.1f}, {max_points:.1f}]")
                print(f"  Points per unit: {coefficient * points_per_unit:.2f}")
        
        # Determine the overall points scale range
        min_possible_point = min(all_possible_points)
        max_possible_point = max(all_possible_points)
        
        print(f"\nOverall points range across all predictors: [{min_possible_point:.1f}, {max_possible_point:.1f}]")
        
        # ========== CALCULATE TOTAL POINTS TO PREDICTED SCORE MAPPING ==========
        print(f"\n{'─'*80}")
        print("CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING")
        print(f"{'─'*80}")
        
        # Calculate minimum and maximum possible total points
        min_total_points = sum([d['min_points'] for d in nomogram_data])
        max_total_points = sum([d['max_points'] for d in nomogram_data])
        
        print(f"Minimum possible total points: {min_total_points:.1f}")
        print(f"Maximum possible total points: {max_total_points:.1f}")
        
        # Create mapping from total points to predicted outcome score
        # Predicted score = intercept + sum(coefficient * value)
        # Which translates to: intercept + (total_points / points_per_unit)
        
        points_range = np.linspace(min_total_points, max_total_points, 100)
        predicted_scores = intercept + (points_range / points_per_unit)
        
        print(f"Predicted outcome score range: [{predicted_scores.min():.1f}, {predicted_scores.max():.1f}]")
        
        # ========== CREATE NOMOGRAM VISUALIZATION ==========
        print(f"\n{'─'*80}")
        print("CREATING NOMOGRAM VISUALIZATION")
        print(f"{'─'*80}")
        
        # Calculate figure height based on number of predictors
        # Use more spacing for many predictors to avoid crowding
        spacing_per_predictor = 1.0 if len(nomogram_data) > 12 else 0.8
        fig_height = 2 + len(nomogram_data) * spacing_per_predictor + 2  # Points scale + predictors + outcome scale
        
        fig, ax = plt.subplots(figsize=(14, fig_height))
        ax.set_xlim(0, 100)
        ax.set_ylim(0, len(nomogram_data) + 3)
        ax.axis('off')
        
        # Title
        ax.text(50, len(nomogram_data) + 2.5, 
                f'Nomogram for Predicting {domain_name.upper()} at 12 Months',
                ha='center', va='top', fontsize=16, fontweight='bold')
        
        # Instructions
        instructions = "Instructions: (1) Locate patient values on each variable axis, (2) Draw line to Points axis, (3) Sum points from all variables, (4) Locate sum on Total Points line to find predicted score"
        ax.text(50, len(nomogram_data) + 1.8, instructions,
                ha='center', va='top', fontsize=9, style='italic', wrap=True)
        
        current_y = len(nomogram_data) + 1
        
        # ========== POINTS SCALE (TOP) ==========
        ax.text(0, current_y, 'Points', ha='left', va='center', fontsize=11, fontweight='bold')
        
        # Draw points scale line
        ax.plot([10, 95], [current_y - 0.15, current_y - 0.15], 'k-', linewidth=2)
        
        # Determine nice point values to show (can be negative)
        points_scale_range = max_possible_point - min_possible_point
        
        # Create nice intervals
        if points_scale_range > 0:
            interval = 10 if points_scale_range < 50 else 20 if points_scale_range < 100 else 50
            point_start = np.floor(min_possible_point / interval) * interval
            point_end = np.ceil(max_possible_point / interval) * interval
            point_values = np.arange(point_start, point_end + interval, interval)
        else:
            point_values = np.array([0, 50, 100])
        
        # Add point markers
        for pt in point_values:
            if min_possible_point <= pt <= max_possible_point:
                x_pos = 10 + ((pt - min_possible_point) / points_scale_range) * 85 if points_scale_range > 0 else 52.5
                ax.plot([x_pos, x_pos], [current_y - 0.15, current_y - 0.3], 'k-', linewidth=1)
                ax.text(x_pos, current_y - 0.45, f'{int(pt)}', ha='center', va='top', fontsize=8)
        
        current_y -= 1.2
        
        # ========== DRAW EACH PREDICTOR ==========
        for nom_data in nomogram_data:
            feature_name = nom_data['feature']
            
            # Clean feature name for display
            display_name = feature_name.replace('_std', '').replace('_collapsed_imputed', '').replace('_imputed', '').replace('_', ' ').title()
            
            # Adjust font size based on number of predictors
            label_fontsize = 9 if len(nomogram_data) > 12 else 10
            ax.text(0, current_y, display_name, ha='left', va='center', fontsize=label_fontsize)
            
            # Draw axis line
            ax.plot([10, 95], [current_y - 0.15, current_y - 0.15], 'k-', linewidth=1.5)
            
            if nom_data['is_categorical']:
                # Categorical variable: mark each category
                points_dict = nom_data['points_dict']
                
                for cat, pts in points_dict.items():
                    # Map points to x position on the overall points scale
                    x_pos = 10 + ((pts - min_possible_point) / points_scale_range) * 85 if points_scale_range > 0 else 52.5
                    
                    ax.plot([x_pos, x_pos], [current_y - 0.15, current_y - 0.3], 'k-', linewidth=1)
                    ax.text(x_pos, current_y - 0.45, f'{cat}', ha='center', va='top', fontsize=7)
            
            else:
                # Continuous variable: mark min, mean, max
                # Min
                x_min = 10 + ((nom_data['min_points'] - min_possible_point) / points_scale_range) * 85 if points_scale_range > 0 else 10
                ax.plot([x_min, x_min], [current_y - 0.15, current_y - 0.3], 'k-', linewidth=1)
                ax.text(x_min, current_y - 0.45, f'{nom_data["min_val"]:.1f}', ha='center', va='top', fontsize=7)
                
                # Mean
                x_mean = 10 + ((nom_data['mean_points'] - min_possible_point) / points_scale_range) * 85 if points_scale_range > 0 else 52.5
                ax.plot([x_mean, x_mean], [current_y - 0.15, current_y - 0.25], 'k-', linewidth=1)
                ax.text(x_mean, current_y - 0.38, f'{nom_data["mean_val"]:.1f}', ha='center', va='top', fontsize=7, style='italic')
                
                # Max
                x_max = 10 + ((nom_data['max_points'] - min_possible_point) / points_scale_range) * 85 if points_scale_range > 0 else 95
                ax.plot([x_max, x_max], [current_y - 0.15, current_y - 0.3], 'k-', linewidth=1)
                ax.text(x_max, current_y - 0.45, f'{nom_data["max_val"]:.1f}', ha='center', va='top', fontsize=7)
            
            current_y -= 0.9
        
        # ========== TOTAL POINTS SCALE ==========
        current_y -= 0.3
        ax.text(0, current_y, 'Total Points', ha='left', va='center', fontsize=11, fontweight='bold')
        
        # Draw total points scale line
        ax.plot([10, 95], [current_y - 0.15, current_y - 0.15], 'k-', linewidth=2)
        
        # Add total point markers
        total_points_range = max_total_points - min_total_points
        n_markers = min(11, max(5, int(total_points_range / 20) + 1))
        total_point_values = np.linspace(min_total_points, max_total_points, n_markers)
        
        for tp in total_point_values:
            x_pos = 10 + ((tp - min_total_points) / total_points_range) * 85 if total_points_range > 0 else 52.5
            ax.plot([x_pos, x_pos], [current_y - 0.15, current_y - 0.3], 'k-', linewidth=1)
            ax.text(x_pos, current_y - 0.45, f'{int(tp)}', ha='center', va='top', fontsize=8)
        
        current_y -= 1.2
        
        # ========== PREDICTED SCORE SCALE ==========
        ax.text(0, current_y, f'Predicted {domain_name.upper()}', ha='left', va='center', fontsize=11, fontweight='bold')
        
        # Draw predicted score scale line
        ax.plot([10, 95], [current_y - 0.15, current_y - 0.15], 'k-', linewidth=2, color='blue')
        
        # Add predicted score markers
        score_range = predicted_scores.max() - predicted_scores.min()
        n_score_markers = 11
        score_values = np.linspace(predicted_scores.min(), predicted_scores.max(), n_score_markers)
        
        for score in score_values:
            # Find corresponding total points
            idx = np.argmin(np.abs(predicted_scores - score))
            total_pts = points_range[idx]
            
            if total_points_range > 0:
                x_pos = 10 + ((total_pts - min_total_points) / total_points_range) * 85
            else:
                x_pos = 52.5
            
            ax.plot([x_pos, x_pos], [current_y - 0.15, current_y - 0.3], 'b-', linewidth=1)
            ax.text(x_pos, current_y - 0.45, f'{score:.1f}', ha='center', va='top', fontsize=8, color='blue')
        
        plt.tight_layout()
        
        # Save nomogram
        nomogram_filename = f"step5_nomogram_{domain_name}.png"
        plt.savefig(nomogram_filename, dpi=300, bbox_inches='tight')
        print(f"\n✓ Saved nomogram: {nomogram_filename}")
        plt.close()
        
        # ========== STORE RESULTS ==========
        nomogram_results[outcome_domain] = {
            'nomogram_data': nomogram_data,
            'intercept': intercept,
            'points_per_unit': points_per_unit,
            'min_possible_point': min_possible_point,
            'max_possible_point': max_possible_point,
            'min_total_points': min_total_points,
            'max_total_points': max_total_points,
            'predicted_score_range': (predicted_scores.min(), predicted_scores.max()),
            'nomogram_file': nomogram_filename,
            'skipped': False
        }
        
        # Create a scoring table for easy reference
        scoring_table = []
        for nom_data in nomogram_data:
            if nom_data['is_categorical']:
                for cat, pts in nom_data['points_dict'].items():
                    scoring_table.append({
                        'Feature': nom_data['feature'],
                        'Value': f"Category {cat}",
                        'Points': f"{pts:.1f}"
                    })
            else:
                scoring_table.append({
                    'Feature': nom_data['feature'],
                    'Value': f"Range: [{nom_data['min_val']:.2f}, {nom_data['max_val']:.2f}]",
                    'Points': f"[{nom_data['min_points']:.1f}, {nom_data['max_points']:.1f}]"
                })
        
        scoring_df = pd.DataFrame(scoring_table)
        scoring_filename = f"step5_nomogram_scoring_table_{domain_name}.csv"
        scoring_df.to_csv(scoring_filename, index=False)
        print(f"✓ Saved scoring table: {scoring_filename}")
        
        print(f"\n{'='*80}")
        print(f"✓ COMPLETED: {outcome_domain}")
        print(f"{'='*80}")
    
    # ========== FINAL SUMMARY ==========
    print(f"\n{'='*80}")
    print("STEP 5 COMPLETE: NOMOGRAM CONSTRUCTION")
    print(f"{'='*80}")
    
    print("\nGenerated nomograms:")
    for domain, res in nomogram_results.items():
        domain_name = domain.replace('_12mo', '')
        if res['skipped']:
            print(f"  ⚠ {domain_name}: Skipped (no stable features)")
        else:
            print(f"  ✓ {domain_name}: {res['nomogram_file']}")
            print(f"     Total points range: [{res['min_total_points']:.1f}, {res['max_total_points']:.1f}]")
    
    print("\nSteps:")
    print("  1. Locate patient's value on each predictor axis")
    print("  2. Draw a vertical line to the Points axis and record points (can be negative)")
    print("  3. Sum all points to get Total Points")
    print("  4. Locate Total Points on the bottom scale to find predicted outcome score")
    
    return nomogram_results

# Run nomogram construction
nomogram_results = create_nomograms_for_all_domains(score_comparison, ols_results)
# Out:
# ================================================================================
# STEP 5: NOMOGRAM CONSTRUCTION
# ================================================================================
# Purpose: Create visual nomograms for clinical prediction
#          Based on OLS coefficients from Step 4
#
# ================================================================================
# OUTCOME DOMAIN: fact_e_total_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 566.7260
# Points per unit coefficient: 0.1765
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-88.2, 23.7]
#   Points per unit: 23.35
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-75.1, 23.5]
#   Points per unit: 20.65
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-53.5, 33.8]
#   Points per unit: 20.25
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-75.3, 40.2]
#   Points per unit: 28.78
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-107.7, 82.0]
#   Points per unit: 48.14
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-1.2, 2.0]
#   Points per unit: 0.59
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-5.2, 2.9]
#   Points per unit: 1.31
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -1.3 points
#   Value 2: -2.7 points
#   Value 3: -4.0 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -1.0 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.9 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 1.6 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 0.9 points
#   Value 3: 1.7 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.6 points
#   Value 2: -1.2 points
#   Value 3: -1.8 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.4 points
#   Value 2: 0.9 points
#   Value 3: 1.3 points
#   Value 4: 1.7 points
#   Value 5: 2.1 points
#
# surgery_approach_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.7 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.3 points
#   Value 2: 0.7 points
#   Value 3: 1.0 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -157.9
# Maximum possible total points: 13.3
# Predicted outcome score range: [-762.5, 207.6]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_fact_e_total.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_fact_e_total.csv
#
# ================================================================================
# ✓ COMPLETED: fact_e_total_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: pwb_subscale_score_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 127.5905
# Points per unit coefficient: 0.7838
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-90.9, 24.4]
#   Points per unit: 24.08
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-73.0, 22.9]
#   Points per unit: 20.08
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-53.6, 33.8]
#   Points per unit: 20.28
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-75.2, 40.2]
#   Points per unit: 28.77
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-106.4, 81.0]
#   Points per unit: 47.56
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-2.1, 3.4]
#   Points per unit: 1.03
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-5.5, 3.1]
#   Points per unit: 1.41
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -1.6 points
#   Value 2: -3.2 points
#   Value 3: -4.8 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -0.8 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.8 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 1.5 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 0.4 points
#   Value 3: 0.8 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.2 points
#   Value 2: -0.3 points
#   Value 3: -0.5 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.5 points
#   Value 2: 1.1 points
#   Value 3: 1.6 points
#   Value 4: 2.2 points
#   Value 5: 2.7 points
#
# surgery_approach_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.9 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.3 points
#   Value 2: 0.6 points
#   Value 3: 0.9 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -157.8
# Maximum possible total points: 13.7
# Predicted outcome score range: [-178.7, 40.2]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_pwb_subscale_score.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_pwb_subscale_score.csv
#
# ================================================================================
# ✓ COMPLETED: pwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: swb_subscale_score_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 73.4971
# Points per unit coefficient: 1.3606
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-80.5, 21.6]
#   Points per unit: 21.32
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-82.7, 25.9]
#   Points per unit: 22.74
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-52.3, 33.0]
#   Points per unit: 19.78
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-74.5, 39.8]
#   Points per unit: 28.51
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-112.0, 85.3]
#   Points per unit: 50.07
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-0.9, 1.4]
#   Points per unit: 0.44
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-3.9, 2.2]
#   Points per unit: 1.00
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.1 points
#   Value 2: -0.3 points
#   Value 3: -0.4 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -1.0 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -2.6 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.2 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 0.6 points
#   Value 3: 1.1 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.7 points
#   Value 2: 1.5 points
#   Value 3: 2.2 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.3 points
#   Value 2: 0.7 points
#   Value 3: 1.0 points
#   Value 4: 1.4 points
#   Value 5: 1.7 points
#
# surgery_approach_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.2 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.2 points
#   Value 2: 0.5 points
#   Value 3: 0.7 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -155.1
# Maximum possible total points: 13.2
# Predicted outcome score range: [-91.7, 31.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_swb_subscale_score.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_swb_subscale_score.csv
#
# ================================================================================
# ✓ COMPLETED: swb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ewb_subscale_score_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 92.4929
# Points per unit coefficient: 1.0812
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-87.7, 23.6]
#   Points per unit: 23.23
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-73.1, 22.9]
#   Points per unit: 20.11
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-55.6, 35.1]
#   Points per unit: 21.04
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-76.3, 40.8]
#   Points per unit: 29.19
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-108.1, 82.3]
#   Points per unit: 48.33
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-2.0, 3.2]
#   Points per unit: 0.96
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-3.7, 2.1]
#   Points per unit: 0.94
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.1 points
#   Value 2: -0.3 points
#   Value 3: -0.4 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -0.8 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.2 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 2.0 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 0.7 points
#   Value 3: 1.4 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.7 points
#   Value 2: -1.4 points
#   Value 3: -2.1 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.6 points
#   Value 2: 1.1 points
#   Value 3: 1.7 points
#   Value 4: 2.3 points
#   Value 5: 2.9 points
#
# surgery_approach_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.5 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.4 points
#   Value 2: 0.9 points
#   Value 3: 1.3 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -153.9
# Maximum possible total points: 16.1
# Predicted outcome score range: [-126.8, 30.4]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_ewb_subscale_score.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_ewb_subscale_score.csv
#
# ================================================================================
# ✓ COMPLETED: ewb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: fwb_subscale_score_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 99.2122
# Points per unit coefficient: 1.0079
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-89.3, 24.0]
#   Points per unit: 23.65
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-73.9, 23.1]
#   Points per unit: 20.32
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-51.8, 32.7]
#   Points per unit: 19.59
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-78.5, 41.9]
#   Points per unit: 30.01
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-107.2, 81.6]
#   Points per unit: 47.93
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-0.9, 1.4]
#   Points per unit: 0.43
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-8.0, 4.5]
#   Points per unit: 2.03
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -2.2 points
#   Value 2: -4.4 points
#   Value 3: -6.7 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -1.5 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.4 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 3.1 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 1.6 points
#   Value 3: 3.2 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -0.9 points
#   Value 2: -1.8 points
#   Value 3: -2.7 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.4 points
#   Value 2: 0.8 points
#   Value 3: 1.2 points
#   Value 4: 1.7 points
#   Value 5: 2.1 points
#
# surgery_approach_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.1 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.5 points
#   Value 2: 0.9 points
#   Value 3: 1.4 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -164.8
# Maximum possible total points: 17.1
# Predicted outcome score range: [-145.5, 35.0]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_fwb_subscale_score.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_fwb_subscale_score.csv
#
# ================================================================================
# ✓ COMPLETED: fwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ecs_subscale_score_12mo
# ================================================================================
#
# Creating nomogram with 17 predictors
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING POINT SCALE
# ────────────────────────────────────────────────────────────────────────────────
# Maximum absolute coefficient: 173.9334
# Points per unit coefficient: 0.5749
#
# fact_e_total_Baseline_std (continuous):
#   Range: [-2.56, 2.02]
#   Points range: [255.9, -202.0]
#   Points per unit: -100.00
#
# pwb_subscale_score_Baseline_std (continuous):
#   Range: [-3.78, 1.01]
#   Points range: [-89.0, 23.9]
#   Points per unit: 23.56
#
# swb_subscale_score_Baseline_std (continuous):
#   Range: [-3.63, 1.14]
#   Points range: [-75.1, 23.5]
#   Points per unit: 20.67
#
# ewb_subscale_score_Baseline_std (continuous):
#   Range: [-2.64, 1.67]
#   Points range: [-53.9, 34.0]
#   Points per unit: 20.38
#
# fwb_subscale_score_Baseline_std (continuous):
#   Range: [-2.61, 1.40]
#   Points range: [-73.2, 39.1]
#   Points per unit: 27.99
#
# ecs_subscale_score_Baseline_std (continuous):
#   Range: [-2.24, 1.70]
#   Points range: [-106.9, 81.4]
#   Points per unit: 47.78
#
# bmi_std (continuous):
#   Range: [-2.04, 3.30]
#   Points range: [-0.5, 0.8]
#   Points per unit: 0.24
#
# age_diagnosis_std (continuous):
#   Range: [-3.92, 2.19]
#   Points range: [-4.5, 2.5]
#   Points per unit: 1.16
#
# cci_category_numeric (categorical):
#   Value 0: -0.0 points
#   Value 1: -1.8 points
#   Value 2: -3.6 points
#   Value 3: -5.4 points
#
# gender (categorical):
#   Value 1.0: -0.0 points
#   Value 2.0: -1.0 points
#
# smoking_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -1.0 points
#
# alcohol_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 1.2 points
#
# level_tumor_collapsed_imputed (categorical):
#   Value 1: 0.0 points
#   Value 2: 1.0 points
#   Value 3: 1.9 points
#
# path_histology_collapsed_imputed (categorical):
#   Value 0: -0.0 points
#   Value 1: -1.3 points
#   Value 2: -2.6 points
#   Value 3: -3.9 points
#
# path_esoph_stage_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.3 points
#   Value 2: 0.6 points
#   Value 3: 1.0 points
#   Value 4: 1.3 points
#   Value 5: 1.6 points
#
# surgery_approach_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 1.5 points
#
# neotx_collapsed_imputed (categorical):
#   Value 0: 0.0 points
#   Value 1: 0.3 points
#   Value 2: 0.6 points
#   Value 3: 0.9 points
#
# Overall points range across all predictors: [-202.0, 255.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CALCULATING TOTAL POINTS TO PREDICTED SCORE MAPPING
# ────────────────────────────────────────────────────────────────────────────────
# Minimum possible total points: -158.4
# Maximum possible total points: 10.4
# Predicted outcome score range: [-221.7, 71.9]
#
# ────────────────────────────────────────────────────────────────────────────────
# CREATING NOMOGRAM VISUALIZATION
# ────────────────────────────────────────────────────────────────────────────────
#
# ✓ Saved nomogram: step5_nomogram_ecs_subscale_score.png
# ✓ Saved scoring table: step5_nomogram_scoring_table_ecs_subscale_score.csv
#
# ================================================================================
# ✓ COMPLETED: ecs_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# STEP 5 COMPLETE: NOMOGRAM CONSTRUCTION
# ================================================================================
#
# Generated nomograms:
#   ✓ fact_e_total: step5_nomogram_fact_e_total.png
#      Total points range: [-157.9, 13.3]
#   ✓ pwb_subscale_score: step5_nomogram_pwb_subscale_score.png
#      Total points range: [-157.8, 13.7]
#   ✓ swb_subscale_score: step5_nomogram_swb_subscale_score.png
#      Total points range: [-155.1, 13.2]
#   ✓ ewb_subscale_score: step5_nomogram_ewb_subscale_score.png
#      Total points range: [-153.9, 16.1]
#   ✓ fwb_subscale_score: step5_nomogram_fwb_subscale_score.png
#      Total points range: [-164.8, 17.1]
#   ✓ ecs_subscale_score: step5_nomogram_ecs_subscale_score.png
#      Total points range: [-158.4, 10.4]
#
# Nomograms can be used for clinical prediction:
#   1. Locate patient's value on each predictor axis
#   2. Draw a vertical line to the Points axis and record points (can be negative)
#   3. Sum all points to get Total Points
#   4. Locate Total Points on the bottom scale to find predicted outcome score

# %%
nomogram_results
# Out:
# {'fact_e_total_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -566.7260410333959,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.96181046436087,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 132.33134438267254,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -88.16468677427324,
#     'max_points': 23.680535421557494,
#     'mean_points': 2.60438849526579e-15,
#     'points_per_unit_value': 23.35014359696144},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 117.04412346796744,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -75.06883260850317,
#     'max_points': 23.51834506560928,
#     'mean_points': 1.6920813565143844e-14,
#     'points_per_unit_value': 20.652681365151935},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 114.75688483510226,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.53801586816904,
#     'max_points': 33.78958068473842,
#     'mean_points': 6.713079260180223e-15,
#     'points_per_unit_value': 20.24909330544419},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 163.12937155724012,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -75.26657532504892,
#     'max_points': 40.21917314509581,
#     'mean_points': 2.6335130522981036e-15,
#     'points_per_unit_value': 28.784520164237044},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 272.8426374056435,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -107.69690746194529,
#     'max_points': 81.97583798595119,
#     'mean_points': 1.6233022404850796e-14,
#     'points_per_unit_value': 48.14365630845707},
#    {'feature': 'bmi_std',
#     'coefficient': 3.364916587290946,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -1.2139719868667807,
#     'max_points': 1.959554016457083,
#     'mean_points': 6.567496949527806e-16,
#     'points_per_unit_value': 0.5937465977662141},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 7.445813194454839,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -5.15548019299331,
#     'max_points': 2.8797617754145612,
#     'mean_points': -1.280364956127795e-15,
#     'points_per_unit_value': 1.3138293735148965},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -7.577217620623905,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.3370159604466452,
#      2: -2.6740319208932903,
#      3: -4.011047881339936},
#     'min_points': -4.011047881339936,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -5.75982396708274,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.0163330339611705},
#     'min_points': -1.0163330339611705,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -4.89459003045871,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.8636606889518746},
#     'min_points': -0.8636606889518746,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 9.02366780559784,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.5922451329647118},
#     'min_points': 0.0,
#     'max_points': 1.5922451329647118},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 4.876258000066617,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.8604259636940295, 3: 1.720851927388059},
#     'min_points': 0.0,
#     'max_points': 1.720851927388059},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -3.471147670992382,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.6124912955584187,
#      2: -1.2249825911168375,
#      3: -1.8374738866752562},
#     'min_points': -1.8374738866752562,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 2.4351924276448327,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.42969481748260313,
#      2: 0.8593896349652063,
#      3: 1.2890844524478093,
#      4: 1.7187792699304125,
#      5: 2.1484740874130157},
#     'min_points': 0.0,
#     'max_points': 2.1484740874130157},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 4.102823302901769,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.7239517872551756},
#     'min_points': 0.0,
#     'max_points': 0.7239517872551756},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 1.9271201105038394,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.3400443902295075,
#      2: 0.680088780459015,
#      3: 1.0201331706885226},
#     'min_points': 0.0,
#     'max_points': 1.0201331706885226}],
#   'intercept': 132.38148452990947,
#   'points_per_unit': 0.1764520998852552,
#   'min_possible_point': -201.96181046436087,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -157.91152700749578,
#   'max_total_points': 13.266633736172446,
#   'predicted_score_range': (-762.544260815053, 207.56695268132046),
#   'nomogram_file': 'step5_nomogram_fact_e_total.png',
#   'skipped': False},
#  'pwb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -127.59048538888473,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 30.717596876750562,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -90.90213012248849,
#     'max_points': 24.41579719748697,
#     'mean_points': 2.6852526850381295e-15,
#     'points_per_unit_value': 24.075146969717995},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 25.61949302097674,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -72.98531038005902,
#     'max_points': 22.865597540201957,
#     'mean_points': 1.6451179364620217e-14,
#     'points_per_unit_value': 20.079469831069886},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 25.879258034407925,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.62782972201517,
#     'max_points': 33.846265124980164,
#     'mean_points': 6.724340931158392e-15,
#     'points_per_unit_value': 20.283062608885132},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 36.71366773297946,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -75.24066843481613,
#     'max_points': 40.205329633558,
#     'mean_points': 2.6326065923817614e-15,
#     'points_per_unit_value': 28.77461248076562},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 60.68558833346758,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -106.39750394826092,
#     'max_points': 80.98676880628321,
#     'mean_points': 1.6037164911375106e-14,
#     'points_per_unit_value': 47.562785068575586},
#    {'feature': 'bmi_std',
#     'coefficient': 1.3180384272245722,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -2.1121137983141356,
#     'max_points': 3.4093052570207916,
#     'mean_points': 1.142637645476896e-15,
#     'points_per_unit_value': 1.0330225041524888},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 1.802418892535698,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -5.543289964377235,
#     'max_points': 3.096385584246472,
#     'mean_points': -1.3766776219389723e-15,
#     'points_per_unit_value': 1.412659327254757},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -2.035960647371672,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.595699429441185,
#      2: -3.19139885888237,
#      3: -4.787098288323555},
#     'min_points': -4.787098288323555,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.044178018652047,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.8183823546634242},
#     'min_points': -0.8183823546634242,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.0419543722841225,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.8166395551426393},
#     'min_points': -0.8166395551426393,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 1.917007339900998,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.5024688824234236},
#     'min_points': 0.0,
#     'max_points': 1.5024688824234236},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.539872255171872,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.42312892965834265, 3: 0.8462578593166853},
#     'min_points': 0.0,
#     'max_points': 0.8462578593166853},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.22196576363458198,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.17396733224899144,
#      2: -0.3479346644979829,
#      3: -0.5219019967469744},
#     'min_points': -0.5219019967469744,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.6907970765693747,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.5414173905396513,
#      2: 1.0828347810793026,
#      3: 1.6242521716189537,
#      4: 2.1656695621586053,
#      5: 2.7070869526982566},
#     'min_points': 0.0,
#     'max_points': 2.7070869526982566},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 1.1198904855060134,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.8777225684914391},
#     'min_points': 0.0,
#     'max_points': 0.8777225684914391},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.3782765411221062,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.29647707661676503,
#      2: 0.5929541532335301,
#      3: 0.889431229850295},
#     'min_points': 0.0,
#     'max_points': 0.889431229850295}],
#   'intercept': 22.705776608707616,
#   'points_per_unit': 0.7837575011585596,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -157.83140986397547,
#   'max_total_points': 13.686606172196806,
#   'predicted_score_range': (-178.67208533285876, 40.16858385707857),
#   'nomogram_file': 'step5_nomogram_pwb_subscale_score.png',
#   'skipped': False},
#  'swb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -73.49705860639142,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.92145870123224,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 15.671029462017245,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -80.50682169421563,
#     'max_points': 21.62367624225705,
#     'mean_points': 2.3781748439445744e-15,
#     'points_per_unit_value': 21.321981803302354},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 16.71280198834077,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -82.65374319802328,
#     'max_points': 25.894624785668785,
#     'mean_points': 1.8630482592007296e-14,
#     'points_per_unit_value': 22.73941611438502},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 14.536304893385925,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -52.29266258491646,
#     'max_points': 33.00359777963629,
#     'mean_points': 6.5569256343531804e-15,
#     'points_per_unit_value': 19.77807706732066},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 20.954173315705347,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -74.54932827726104,
#     'max_points': 39.835907624136354,
#     'mean_points': 2.608417191965489e-15,
#     'points_per_unit_value': 28.51022029047995},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 36.79979420602187,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -112.00556312275539,
#     'max_points': 85.25546473393953,
#     'mean_points': 1.6882460773370632e-14,
#     'points_per_unit_value': 50.06975095847129},
#    {'feature': 'bmi_std',
#     'coefficient': 0.3202706698100085,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.8909528891896551,
#     'max_points': 1.4381471165505733,
#     'mean_points': 4.81998797767e-16,
#     'points_per_unit_value': 0.43575984656093064},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 0.7362734686139462,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -3.9309665457258713,
#     'max_points': 2.195769700405378,
#     'mean_points': -9.762566473824229e-16,
#     'points_per_unit_value': 1.0017727002613934},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -0.1055945359408037,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.14367178488911805,
#      2: -0.2873435697782361,
#      3: -0.43101535466735413},
#     'min_points': -0.43101535466735413,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -0.7153699427837612,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.9733313908722213},
#     'min_points': -0.9733313908722213,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.9386584620491707,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -2.63773612006914},
#     'min_points': -2.63773612006914,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 0.15686887477775135,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.2134355819841065},
#     'min_points': 0.0,
#     'max_points': 0.2134355819841065},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.40923589909619285,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.5568058189754618, 3: 1.1136116379509235},
#     'min_points': 0.0,
#     'max_points': 1.1136116379509235},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': 0.5337182602797577,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.726176353720562,
#      2: 1.452352707441124,
#      3: 2.1785290611616857},
#     'min_points': 0.0,
#     'max_points': 2.1785290611616857},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.24831241054398512,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.33785353489288006,
#      2: 0.6757070697857601,
#      3: 1.01356060467864,
#      4: 1.3514141395715202,
#      5: 1.6892676744644002},
#     'min_points': 0.0,
#     'max_points': 1.6892676744644002},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': -0.1246392170479188,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.16958395262511905},
#     'min_points': -0.16958395262511905,
#     'max_points': -0.0},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.16735334188723025,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.22770073396199417,
#      2: 0.45540146792398833,
#      3: 0.6831022018859825},
#     'min_points': 0.0,
#     'max_points': 0.6831022018859825}],
#   'intercept': 22.259066377809475,
#   'points_per_unit': 1.3605986674316222,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.92145870123224,
#   'min_total_points': -155.12024642908895,
#   'max_total_points': 13.163323675680239,
#   'predicted_score_range': (-91.74975205055682, 31.93372209427318),
#   'nomogram_file': 'step5_nomogram_swb_subscale_score.png',
#   'skipped': False},
#  'ewb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -92.49285946237529,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.9618104643608,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 21.489268207443338,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -87.72402166356787,
#     'max_points': 23.562175269155205,
#     'mean_points': 2.591371229662336e-15,
#     'points_per_unit_value': 23.23343481037566},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 18.60133128683227,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -73.100279754445,
#     'max_points': 22.901616342211145,
#     'mean_points': 1.6477093919064293e-14,
#     'points_per_unit_value': 20.111099813493183},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 19.45985015819583,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -55.62729940308036,
#     'max_points': 35.10819538181676,
#     'mean_points': 6.975052471914206e-15,
#     'points_per_unit_value': 21.039299975488166},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 26.99935195551563,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -76.32877558805912,
#     'max_points': 40.786766610166836,
#     'mean_points': 2.670678530396599e-15,
#     'points_per_unit_value': 29.190741979923928},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 44.697394250029994,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -108.10310347461372,
#     'max_points': 82.28502289487545,
#     'mean_points': 1.6294247830258093e-14,
#     'points_per_unit_value': 48.325237764124076},
#    {'feature': 'bmi_std',
#     'coefficient': 0.8863478748284699,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -1.9593117042952217,
#     'max_points': 3.1626570968514462,
#     'mean_points': 1.0599728643116609e-15,
#     'points_per_unit_value': 0.9582878937687324},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 0.8718918078606408,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -3.6990018325721707,
#     'max_points': 2.0661982368018714,
#     'mean_points': -9.186481456207675e-16,
#     'points_per_unit_value': 0.9426585067524194},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -0.11999259344206337,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.12973173728170287,
#      2: -0.25946347456340574,
#      3: -0.3891952118451086},
#     'min_points': -0.3891952118451086,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -0.7083077682703864,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.7657972435791277},
#     'min_points': -0.7657972435791277,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': 0.1486302565532387,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.1606937631911999},
#     'min_points': 0.0,
#     'max_points': 0.1606937631911999},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 1.8063784762628465,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.9529923572074817},
#     'min_points': 0.0,
#     'max_points': 1.9529923572074817},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.6524099022061729,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.7053624528405498, 3: 1.4107249056810995},
#     'min_points': 0.0,
#     'max_points': 1.4107249056810995},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.6505706228672358,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.7033738892372314,
#      2: -1.4067477784744629,
#      3: -2.1101216677116943},
#     'min_points': -2.1101216677116943,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.5277291769023007,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.5705620736236109,
#      2: 1.1411241472472218,
#      3: 1.7116862208708328,
#      4: 2.2822482944944436,
#      5: 2.8528103681180546},
#     'min_points': 0.0,
#     'max_points': 2.8528103681180546},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 0.45684356745777477,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.4939230661839489},
#     'min_points': 0.0,
#     'max_points': 0.4939230661839489},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.4133998620051801,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.4469532722937871,
#      2: 0.8939065445875742,
#      3: 1.3408598168813612},
#     'min_points': 0.0,
#     'max_points': 1.3408598168813612}],
#   'intercept': 15.535944690116297,
#   'points_per_unit': 1.0811645415793258,
#   'min_possible_point': -201.9618104643608,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -153.8854488425372,
#   'max_total_points': 16.122825644781063,
#   'predicted_score_range': (-126.79710724085707, 30.44840715510745),
#   'nomogram_file': 'step5_nomogram_ewb_subscale_score.png',
#   'skipped': False},
#  'fwb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -99.21219459558627,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.9618104643608,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -99.99999999999999},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 23.467678146117407,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -89.31207512615312,
#     'max_points': 23.988717433007714,
#     'mean_points': 2.638282394655335e-15,
#     'points_per_unit_value': 23.654025840046714},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 20.161923575337664,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -73.86694287979054,
#     'max_points': 23.141804544217536,
#     'mean_points': 1.664990283803199e-14,
#     'points_per_unit_value': 20.322021559469285},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 19.436628971894738,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -51.79795077154409,
#     'max_points': 32.69136908638773,
#     'mean_points': 6.494894205652239e-15,
#     'points_per_unit_value': 19.590967674007516},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 29.771489092405965,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -78.4654848506699,
#     'max_points': 41.9285307919772,
#     'mean_points': 2.7454401587522215e-15,
#     'points_per_unit_value': 30.00789289437856},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 47.55011476406304,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -107.21379668046931,
#     'max_points': 81.60810773180685,
#     'mean_points': 1.6160203710938944e-14,
#     'points_per_unit_value': 47.927691709561714},
#    {'feature': 'bmi_std',
#     'coefficient': 0.42255074295288747,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.8708058629249974,
#     'max_points': 1.4056264433689205,
#     'mean_points': 4.710994084098618e-16,
#     'points_per_unit_value': 0.42590605386294494},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 2.0186858785915547,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -7.984244797649878,
#     'max_points': 4.459860597481017,
#     'mean_points': -1.982889441404518e-15,
#     'points_per_unit_value': 2.0347154770844686},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -2.207268704376985,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -2.224795765655991,
#      2: -4.449591531311982,
#      3: -6.674387296967972},
#     'min_points': -6.674387296967972,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.4950280415025827,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.5068994770216413},
#     'min_points': -1.5068994770216413,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -0.36703685844491507,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.36995135521500067},
#     'min_points': -0.36995135521500067,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 3.071869599604941,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 3.09626211992049},
#     'min_points': 0.0,
#     'max_points': 3.09626211992049},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 1.5922026048176092,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 1.604845665704529, 3: 3.209691331409058},
#     'min_points': 0.0,
#     'max_points': 3.209691331409058},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.8857402210451609,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.8927735392364413,
#      2: -1.7855470784728826,
#      3: -2.6783206177093235},
#     'min_points': -2.6783206177093235,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.4115801113723393,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.4148483087689399,
#      2: 0.8296966175378798,
#      3: 1.2445449263068198,
#      4: 1.6593932350757596,
#      5: 2.0742415438446997},
#     'min_points': 0.0,
#     'max_points': 2.0742415438446997},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 0.07711509621491008,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.07772743716561306},
#     'min_points': 0.0,
#     'max_points': 0.07772743716561306},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.4524586372085212,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.4560514350608368,
#      2: 0.9121028701216736,
#      3: 1.3681543051825105},
#     'min_points': 0.0,
#     'max_points': 1.3681543051825105}],
#   'intercept': 18.048590078259217,
#   'points_per_unit': 1.007940610603616,
#   'min_possible_point': -201.9618104643608,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -164.81940101488354,
#   'max_total_points': 17.088282901408544,
#   'predicted_score_range': (-145.47235478790674, 35.00225056344895),
#   'nomogram_file': 'step5_nomogram_fwb_subscale_score.png',
#   'skipped': False},
#  'ecs_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -173.9334429801583,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.92145870123224,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 40.98577169034402,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -88.97236521936972,
#     'max_points': 23.897473276475576,
#     'mean_points': 2.628247349952917e-15,
#     'points_per_unit_value': 23.564054725818043},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 35.94857359648,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -75.12453319304662,
#     'max_points': 23.53579552436998,
#     'mean_points': 1.6933368698529818e-14,
#     'points_per_unit_value': 20.668005520123515},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 35.44484277721786,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.87988387022153,
#     'max_points': 34.00534468442281,
#     'mean_points': 6.75594575340158e-15,
#     'points_per_unit_value': 20.378394269617992},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 48.690689460633735,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -73.19914224933,
#     'max_points': 39.11442713427839,
#     'mean_points': 2.5611753384304902e-15,
#     'points_per_unit_value': 27.99386283993021},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 83.10974585206074,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -106.8890022078803,
#     'max_points': 81.36088337141287,
#     'mean_points': 1.6111247839551715e-14,
#     'points_per_unit_value': 47.78249911464214},
#    {'feature': 'bmi_std',
#     'coefficient': 0.41770887247500577,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.4910188190811224,
#     'max_points': 0.7925865748926998,
#     'mean_points': 2.656374802188823e-16,
#     'points_per_unit_value': 0.2401544322460497},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 2.016543146853001,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -4.549404788588286,
#     'max_points': 2.5412185714281357,
#     'mean_points': -1.1298459589593423e-15,
#     'points_per_unit_value': 1.1593763179189414},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -3.1084011394923827,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.7871210310296552,
#      2: -3.5742420620593105,
#      3: -5.361363093088966},
#     'min_points': -5.361363093088966,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.7969401958739706,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.0331194306772615},
#     'min_points': -1.0331194306772615,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.695570594233738,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.974838745891532},
#     'min_points': -0.974838745891532,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 2.0715435150513084,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.19099782052128},
#     'min_points': 0.0,
#     'max_points': 1.19099782052128},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 1.6825373387747788,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.9673455029385675, 3: 1.934691005877135},
#     'min_points': 0.0,
#     'max_points': 1.934691005877135},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -2.2465893237251606,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.2916373557794998,
#      2: -2.5832747115589996,
#      3: -3.8749120673384994},
#     'min_points': -3.8749120673384994,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.5567736522568307,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.3201073023779248,
#      2: 0.6402146047558496,
#      3: 0.9603219071337744,
#      4: 1.2804292095116991,
#      5: 1.6005365118896238},
#     'min_points': 0.0,
#     'max_points': 1.6005365118896238},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 2.5736133707709925,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.479654129001851},
#     'min_points': 0.0,
#     'max_points': 1.479654129001851},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.5156317282808027,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.29645347061842736,
#      2: 0.5929069412368547,
#      3: 0.8893604118552821},
#     'min_points': 0.0,
#     'max_points': 0.8893604118552821}],
#   'intercept': 53.83210677501688,
#   'points_per_unit': 0.5749325620571292,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.92145870123224,
#   'min_total_points': -158.42812498328158,
#   'max_total_points': 10.381158552064786,
#   'predicted_score_range': (-221.7273856573131, 71.88841326585231),
#   'nomogram_file': 'step5_nomogram_ecs_subscale_score.png',
#   'skipped': False}}

# %% [raw]
# import pickle
# with open('nomogram_results.pkl', 'wb') as f:
#     pickle.dump(nomogram_results, f)

# %% [markdown]
# ### option 2: simplified

# %%
#Option 2: simplified
def create_nomograms_using_packages(score_comparison, ols_results):
    """
    Step 5 Alternative: Create nomograms using Python packages
    
    This provides alternative nomogram implementations using:
    1. scikit-survival (nomogram functionality)
    2. lifelines (has nomogram plotting capabilities)
    
    We'll adapt these for our regression context.
    """
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    from matplotlib.patches import Rectangle
    import warnings
    warnings.filterwarnings('ignore')
    
    print("="*80)
    print("STEP 5 ALTERNATIVE: NOMOGRAM CONSTRUCTION USING PYTHON PACKAGES")
    print("="*80)
    
    nomogram_results_packages = {}
    
    # ========== METHOD 2: Simplified clinical nomogram ==========
    print("\n" + "="*80)
    print("METHOD 2: Simplified clinical nomogram (easy to read)")
    print("="*80)
    
    for outcome_domain, ols_res in ols_results.items():
        if ols_res['skipped']:
            continue
            
        domain_name = outcome_domain.replace('_12mo', '')
        print(f"\nCreating simplified nomogram for {domain_name}...")
        
        # Get coefficients
        coef_table = ols_res['coefficients_table'].copy()
        coef_table_no_intercept = coef_table[coef_table['Feature'] != 'Intercept'].copy()
        intercept = coef_table[coef_table['Feature'] == 'Intercept']['Coefficient'].values[0]
        
        # Sort by absolute coefficient (most important first)
        coef_table_no_intercept = coef_table_no_intercept.copy()
        coef_table_no_intercept['abs_coef'] = coef_table_no_intercept['Coefficient'].abs()
        coef_table_no_intercept = coef_table_no_intercept.sort_values('abs_coef', ascending=False)
        
        # Create simplified figure
        # Adjust spacing for many predictors
        spacing = 1.0 if len(coef_table_no_intercept) > 12 else 0.8
        fig, axes = plt.subplots(len(coef_table_no_intercept) + 2, 1, 
                                figsize=(12, len(coef_table_no_intercept) * spacing + 3))
        
        fig.suptitle(f'{domain_name.upper()} Prediction Nomogram', 
                    fontsize=14, fontweight='bold')
        
        # Calculate point scale
        max_abs_coef = coef_table_no_intercept['Coefficient'].abs().max()
        points_per_unit = 100 / max_abs_coef
        
        total_min_pts = 0
        total_max_pts = 0
        
        # Each predictor
        for i, (idx, row) in enumerate(coef_table_no_intercept.iterrows()):
            ax = axes[i]
            ax.set_xlim(-10, 110)
            ax.set_ylim(0, 1)
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.spines['left'].set_visible(False)
            ax.set_yticks([])
            ax.set_xticks([])
            
            feature = row['Feature']
            coefficient = row['Coefficient']
            
            # Clean name
            display_name = feature.replace('_std', '').replace('_collapsed_imputed', '')
            display_name = display_name.replace('_imputed', '').replace('_', ' ').title()
            
            # Get feature data
            feature_values = score_comparison[feature].dropna()
            n_unique = feature_values.nunique()
            is_categorical = n_unique <= 10
            
            # Adjust font size for many predictors
            label_fontsize = 9 if len(coef_table_no_intercept) > 12 else 10
            value_fontsize = 7 if len(coef_table_no_intercept) > 12 else 8
                        
            if is_categorical:
                unique_vals = sorted(feature_values.unique())
                min_val = min(unique_vals)
                
                # Calculate points
                points_list = [(val, (val - min_val) * coefficient * points_per_unit) 
                              for val in unique_vals]
                
                min_pts = min([p for _, p in points_list])
                max_pts = max([p for _, p in points_list])
                
                total_min_pts += min_pts
                total_max_pts += max_pts
                
                # Plot
                ax.text(-8, 0.5, display_name, fontsize=label_fontsize, va='center', ha='left', fontweight='bold')
                
                pts_range = max_pts - min_pts if max_pts > min_pts else 1
                
                for val, pts in points_list:
                    x_pos = (pts - min_pts) / pts_range * 100 if pts_range > 0 else 50
                    ax.scatter(x_pos, 0.5, s=100, color='steelblue', zorder=3, edgecolors='black', linewidth=1.5)
                    ax.text(x_pos, 0.2, f'{int(val)}\n({pts:.0f} pts)', ha='center', fontsize=value_fontsize, va='top')
                
                ax.plot([0, 100], [0.5, 0.5], 'k-', alpha=0.3, linewidth=1)
            
            else:
                min_val = feature_values.min()
                max_val = feature_values.max()
                
                min_pts = min_val * coefficient * points_per_unit
                max_pts = max_val * coefficient * points_per_unit
                
                total_min_pts += min_pts
                total_max_pts += max_pts
                
                # Plot
                ax.text(-8, 0.5, display_name, fontsize=label_fontsize, va='center', ha='left', fontweight='bold')
                ax.plot([0, 100], [0.5, 0.5], 'k-', alpha=0.3, linewidth=1)
                
                # Show range
                ax.scatter(0, 0.5, s=100, color='steelblue', zorder=3, edgecolors='black', linewidth=1.5)
                ax.text(0, 0.2, f'{min_val:.1f}\n({min_pts:.0f} pts)', ha='center', fontsize=value_fontsize, va='top')
                
                ax.scatter(100, 0.5, s=100, color='steelblue', zorder=3, edgecolors='black', linewidth=1.5)
                ax.text(100, 0.2, f'{max_val:.1f}\n({max_pts:.0f} pts)', ha='center', fontsize=value_fontsize, va='top')
                
                # Show middle
                ax.scatter(50, 0.5, s=60, color='lightsteelblue', zorder=2, edgecolors='gray', linewidth=1)
        
        # Total points axis
        ax_total = axes[-2]
        ax_total.set_xlim(-10, 110)
        ax_total.set_ylim(0, 1)
        ax_total.spines['top'].set_visible(False)
        ax_total.spines['right'].set_visible(False)
        ax_total.spines['left'].set_visible(False)
        ax_total.set_yticks([])
        
        ax_total.text(-8, 0.5, 'Total Points →', fontsize=11, va='center', ha='left', 
                     fontweight='bold', color='darkred')
        
        # Total points scale
        total_pts_range = total_max_pts - total_min_pts
        ax_total.plot([0, 100], [0.5, 0.5], 'darkred', linewidth=2.5)
        
        n_ticks = 6
        for i in range(n_ticks):
            x_pos = i / (n_ticks - 1) * 100
            pts_val = total_min_pts + (i / (n_ticks - 1)) * total_pts_range
            ax_total.plot([x_pos, x_pos], [0.5, 0.3], 'darkred', linewidth=2)
            ax_total.text(x_pos, 0.15, f'{int(pts_val)}', ha='center', fontsize=9, 
                         fontweight='bold', color='darkred')
        
        ax_total.set_xticks([])
        
        # Predicted score axis
        ax_pred = axes[-1]
        ax_pred.set_xlim(-10, 110)
        ax_pred.set_ylim(0, 1)
        ax_pred.spines['top'].set_visible(False)
        ax_pred.spines['right'].set_visible(False)
        ax_pred.spines['left'].set_visible(False)
        ax_pred.set_yticks([])
        
        ax_pred.text(-8, 0.5, f'Predicted Score →', fontsize=11, va='center', ha='left', 
                    fontweight='bold', color='darkgreen')
        
        # Predicted scores
        points_range_vals = np.linspace(total_min_pts, total_max_pts, 100)
        predicted_scores = intercept + (points_range_vals / points_per_unit)
        
        ax_pred.plot([0, 100], [0.5, 0.5], 'darkgreen', linewidth=2.5)
        
        for i in range(n_ticks):
            x_pos = i / (n_ticks - 1) * 100
            idx = int(i / (n_ticks - 1) * 99)
            score = predicted_scores[idx]
            ax_pred.plot([x_pos, x_pos], [0.5, 0.3], 'darkgreen', linewidth=2)
            ax_pred.text(x_pos, 0.15, f'{score:.0f}', ha='center', fontsize=9, 
                        fontweight='bold', color='darkgreen')
        
        ax_pred.set_xticks([])
        
        plt.tight_layout()
        
        # Save
        filename = f"step5_nomogram_simplified_{domain_name}.png"
        plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
        print(f"✓ Saved simplified nomogram: {filename}")
        plt.close()
    
    print("\n" + "="*80)
    print("NOMOGRAM COMPARISON COMPLETE")
    print("="*80)
    print("\nYou now have THREE versions of nomograms for each domain:")
    print("  1. step5_nomogram_[domain].png - Original detailed version")
    print("  2. step5_nomogram_enhanced_[domain].png - Enhanced publication-ready version")
    print("  3. step5_nomogram_simplified_[domain].png - Simplified clinical version")
    print("\nCompare and choose the best style for your needs!")
    
    return nomogram_results_packages

# Run package-based nomogram creation
nomogram_results_packages = create_nomograms_using_packages(score_comparison, ols_results)
# Out:
# ================================================================================
# STEP 5 ALTERNATIVE: NOMOGRAM CONSTRUCTION USING PYTHON PACKAGES
# ================================================================================
#
# ================================================================================
# METHOD 2: Simplified clinical nomogram (easy to read)
# ================================================================================
#
# Creating simplified nomogram for fact_e_total...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_fact_e_total.png
#
# Creating simplified nomogram for pwb_subscale_score...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_pwb_subscale_score.png
#
# Creating simplified nomogram for swb_subscale_score...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_swb_subscale_score.png
#
# Creating simplified nomogram for ewb_subscale_score...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_ewb_subscale_score.png
#
# Creating simplified nomogram for fwb_subscale_score...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_fwb_subscale_score.png
#
# Creating simplified nomogram for ecs_subscale_score...
# ✓ Saved simplified nomogram: step5_nomogram_simplified_ecs_subscale_score.png
#
# ================================================================================
# NOMOGRAM COMPARISON COMPLETE
# ================================================================================
#
# You now have THREE versions of nomograms for each domain:
#   1. step5_nomogram_[domain].png - Original detailed version
#   2. step5_nomogram_enhanced_[domain].png - Enhanced publication-ready version
#   3. step5_nomogram_simplified_[domain].png - Simplified clinical version
#
# Compare and choose the best style for your needs!

# %% [markdown]
# ### option 3: enhanced

# %%
#Option 3: enhanced
def create_nomograms_using_packages(score_comparison, ols_results):
    """
    Step 5 Alternative: Create enhanced nomograms with proper negative points handling (FIXED)
    """
    import matplotlib.pyplot as plt
    import numpy as np
    import pandas as pd
    from matplotlib.patches import Rectangle
    import warnings
    warnings.filterwarnings('ignore')
    
    print("="*80)
    print("STEP 5: ENHANCED NOMOGRAM CONSTRUCTION (PUBLICATION-READY)")
    print("="*80)
    
    for outcome_domain, ols_res in ols_results.items():
        if ols_res['skipped']:
            continue
            
        domain_name = outcome_domain.replace('_12mo', '')
        print(f"\nCreating enhanced nomogram for {domain_name}...")
        
        # Get coefficients
        coef_table = ols_res['coefficients_table'].copy()
        coef_table_no_intercept = coef_table[coef_table['Feature'] != 'Intercept'].copy()
        intercept = coef_table[coef_table['Feature'] == 'Intercept']['Coefficient'].values[0]
        
        # Calculate point scale
        max_abs_coef = coef_table_no_intercept['Coefficient'].abs().max()
        points_per_unit = 100 / max_abs_coef
        
        # Collect all possible points to determine scale
        all_possible_points = []
        predictor_data = []
        
        for idx, row in coef_table_no_intercept.iterrows():
            feature = row['Feature']
            coefficient = row['Coefficient']
            
            feature_values = score_comparison[feature].dropna()
            n_unique = feature_values.nunique()
            is_categorical = n_unique <= 10
            
            if is_categorical:
                unique_vals = sorted(feature_values.unique())
                
                # FIXED: Calculate points relative to MINIMUM category (not 0)
                min_val = min(unique_vals)
                category_points = {}
                for val in unique_vals:
                    points = (val - min_val) * coefficient * points_per_unit
                    category_points[val] = points
                    all_possible_points.append(points)
                
                predictor_data.append({
                    'feature': feature,
                    'type': 'categorical',
                    'categories': category_points,
                    'coefficient': coefficient
                })
            else:
                min_val = feature_values.min()
                max_val = feature_values.max()
                mean_val = feature_values.mean()
                
                min_pts = min_val * coefficient * points_per_unit
                max_pts = max_val * coefficient * points_per_unit
                
                all_possible_points.extend([min_pts, max_pts])
                
                predictor_data.append({
                    'feature': feature,
                    'type': 'continuous',
                    'min': min_val,
                    'max': max_val,
                    'mean': mean_val,
                    'min_points': min_pts,
                    'max_points': max_pts,
                    'points_per_unit': coefficient * points_per_unit,
                    'coefficient': coefficient
                })
        
        # Determine overall points range
        min_possible_point = min(all_possible_points)
        max_possible_point = max(all_possible_points)
        points_scale_range = max_possible_point - min_possible_point
        
        print(f"Points scale range: [{min_possible_point:.1f}, {max_possible_point:.1f}]")
        
        # Create figure
        spacing = 1.3 if len(coef_table_no_intercept) > 15 else 1.2
        fig = plt.figure(figsize=(16, 2 + len(coef_table_no_intercept) * spacing))
        
        # Create grid layout
        gs = fig.add_gridspec(len(coef_table_no_intercept) + 3, 1, 
                             height_ratios=[1] + [1]*len(coef_table_no_intercept) + [1, 1.5],
                             hspace=0.4)
        
        # Title
        fig.suptitle(f'Clinical Nomogram: Predicting {domain_name.upper()} Score at 12 Months Post-Surgery',
                    fontsize=16, fontweight='bold', y=0.98)
        
        # Add subtitle with instructions
        fig.text(0.5, 0.95, 
                'Instructions: Locate patient values → Draw to points → Sum all points (can be negative) → Find predicted score',
                ha='center', fontsize=10, style='italic')
        
        # Row 0: Points scale
        ax_points = fig.add_subplot(gs[0])
        ax_points.set_xlim(0, 100)
        ax_points.set_ylim(0, 1)
        ax_points.axis('off')
        
        ax_points.text(-5, 0.5, 'Points', fontsize=12, fontweight='bold', 
                      va='center', ha='right')
        
        # Draw points axis
        ax_points.plot([0, 100], [0.3, 0.3], 'k-', linewidth=2.5)
        
        # Points markers - can be negative
        if points_scale_range > 0:
            interval = 10 if points_scale_range < 50 else 20 if points_scale_range < 100 else 50
            point_start = np.floor(min_possible_point / interval) * interval
            point_end = np.ceil(max_possible_point / interval) * interval
            point_positions = np.arange(point_start, point_end + interval, interval)
        else:
            point_positions = np.array([min_possible_point])
        
        for pt in point_positions:
            if min_possible_point <= pt <= max_possible_point:
                x_pos = ((pt - min_possible_point) / points_scale_range) * 100 if points_scale_range > 0 else 50
                ax_points.plot([x_pos, x_pos], [0.3, 0.15], 'k-', linewidth=2)
                ax_points.text(x_pos, 0.05, f'{int(pt)}', ha='center', fontsize=10, fontweight='bold')
        
        # Rows for each predictor
        for i, pred_data in enumerate(predictor_data, 1):
            ax = fig.add_subplot(gs[i])
            ax.set_xlim(0, 100)
            ax.set_ylim(0, 1)
            ax.axis('off')
            
            feature = pred_data['feature']
            
            # Clean display name
            display_name = feature.replace('_std', '').replace('_collapsed_imputed', '')
            display_name = display_name.replace('_imputed', '').replace('_', ' ').title()

            # Adaptive font size for many predictors
            label_fontsize = 10 if len(coef_table_no_intercept) > 15 else 11
            value_fontsize = 8 if len(coef_table_no_intercept) > 15 else 9

            ax.text(-5, 0.5, display_name, fontsize=label_fontsize, va='center', ha='right')
            
            # Draw axis
            ax.plot([0, 100], [0.5, 0.5], 'k-', linewidth=2)
            
            if pred_data['type'] == 'categorical':
                # Categorical variable
                category_points = pred_data['categories']
                
                for val, pts in category_points.items():
                    if points_scale_range > 0:
                        x_pos = ((pts - min_possible_point) / points_scale_range) * 100
                    else:
                        x_pos = 50
                    
                    ax.plot([x_pos, x_pos], [0.5, 0.3], 'k-', linewidth=2)
                    
                    # Add category label
                    label = f"{int(val)}" if val == int(val) else f"{val:.1f}"
                    ax.text(x_pos, 0.15, label, ha='center', fontsize=value_fontsize, 
                            bbox=dict(boxstyle='round,pad=0.3', facecolor='lightblue', alpha=0.5))
            
            else:
                # Continuous variable
                min_val = pred_data['min']
                max_val = pred_data['max']
                mean_val = pred_data['mean']
                min_pts = pred_data['min_points']
                max_pts = pred_data['max_points']
                
                if points_scale_range > 0:
                    # Plot min, max, and intermediate values
                    values_to_plot = np.linspace(min_val, max_val, 6)
                    
                    for val in values_to_plot:
                        val_pts = val * pred_data['coefficient'] * points_per_unit
                        x_pos = ((val_pts - min_possible_point) / points_scale_range) * 100
                        
                        # Longer tick for min/max
                        if val == min_val or val == max_val:
                            ax.plot([x_pos, x_pos], [0.5, 0.25], 'k-', linewidth=2)
                            ax.text(x_pos, 0.1, f'{val:.1f}', ha='center', fontsize=value_fontsize, fontweight='bold')
                        else:
                            ax.plot([x_pos, x_pos], [0.5, 0.35], 'k-', linewidth=1)
                            value_fontsize_small = 7 if len(coef_table_no_intercept) > 15 else 8
                            ax.text(x_pos, 0.2, f'{val:.1f}', ha='center', fontsize=value_fontsize_small)
                else:
                    # No variation
                    ax.plot([50, 50], [0.5, 0.3], 'k-', linewidth=2)
                    ax.text(50, 0.15, f'{mean_val:.1f}', ha='center', fontsize=9)
        
        # Total Points row
        ax_total = fig.add_subplot(gs[-2])
        ax_total.set_xlim(0, 100)
        ax_total.set_ylim(0, 1)
        ax_total.axis('off')
        
        ax_total.text(-5, 0.5, 'Total Points', fontsize=12, fontweight='bold', 
                     va='center', ha='right')
        
        # Calculate total points range
        min_total_pts = sum([
            min(d['categories'].values()) if d['type'] == 'categorical' 
            else d['min_points']
            for d in predictor_data
        ])
        max_total_pts = sum([
            max(d['categories'].values()) if d['type'] == 'categorical'
            else d['max_points']
            for d in predictor_data
        ])
        
        total_pts_range = max_total_pts - min_total_pts
        
        print(f"Total points range: [{min_total_pts:.1f}, {max_total_pts:.1f}]")
        
        # Draw total points axis
        ax_total.plot([0, 100], [0.5, 0.5], 'k-', linewidth=2.5)
        
        # Total points markers
        if total_pts_range > 0:
            n_markers = min(11, max(5, int(total_pts_range / 20) + 1))
            total_pts_values = np.linspace(min_total_pts, max_total_pts, n_markers)
            
            for tp in total_pts_values:
                x_pos = ((tp - min_total_pts) / total_pts_range) * 100
                ax_total.plot([x_pos, x_pos], [0.5, 0.3], 'k-', linewidth=2)
                ax_total.text(x_pos, 0.15, f'{int(tp)}', ha='center', fontsize=10, fontweight='bold')
        
        # Predicted Score row
        ax_pred = fig.add_subplot(gs[-1])
        ax_pred.set_xlim(0, 100)
        ax_pred.set_ylim(0, 1)
        ax_pred.axis('off')
        
        ax_pred.text(-5, 0.6, f'Predicted\n{domain_name.upper()}\nScore', 
                    fontsize=11, fontweight='bold', va='center', ha='right')
        
        # Draw predicted score axis with color
        ax_pred.plot([0, 100], [0.6, 0.6], color='#2E86AB', linewidth=3)
        
        # Calculate predicted scores
        points_range_vals = np.linspace(min_total_pts, max_total_pts, 100)
        predicted_scores = intercept + (points_range_vals / points_per_unit)
        
        # Plot predicted score markers
        if total_pts_range > 0:
            score_values = np.linspace(predicted_scores.min(), predicted_scores.max(), 11)
            
            for score in score_values:
                # Find corresponding total points
                idx = np.argmin(np.abs(predicted_scores - score))
                total_pts = points_range_vals[idx]
                x_pos = ((total_pts - min_total_pts) / total_pts_range) * 100
                
                ax_pred.plot([x_pos, x_pos], [0.6, 0.35], color='#2E86AB', linewidth=2)
                ax_pred.text(x_pos, 0.2, f'{score:.0f}', ha='center', fontsize=10, 
                           fontweight='bold', color='#2E86AB')
        
        # Add model performance info
        nested_cv_r2 = ols_res['nested_cv_r2']
        nested_cv_rmse = ols_res['nested_cv_rmse']
        
        info_text = f"Model Performance (Nested CV): R² = {nested_cv_r2:.3f}, RMSE = {nested_cv_rmse:.2f}\n"
        info_text += f"N = {ols_res['n_observations']} patients, {ols_res['n_stable_features']} predictors"
        
        fig.text(0.5, 0.02, info_text, ha='center', fontsize=9, 
                style='italic', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.3))
        
        # Save
        filename = f"step5_nomogram_enhanced_{domain_name}.png"
        plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
        print(f"✓ Saved enhanced nomogram: {filename}")
        plt.close()
    
    print("\n" + "="*80)
    print("ENHANCED NOMOGRAM CREATION COMPLETE")
    print("="*80)

# Run enhanced nomogram creation
create_nomograms_using_packages(score_comparison, ols_results)
# Out:
# ================================================================================
# STEP 5: ENHANCED NOMOGRAM CONSTRUCTION (PUBLICATION-READY)
# ================================================================================
#
# Creating enhanced nomogram for fact_e_total...
# Points scale range: [-202.0, 255.9]
# Total points range: [-157.9, 13.3]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_fact_e_total.png
#
# Creating enhanced nomogram for pwb_subscale_score...
# Points scale range: [-202.0, 255.9]
# Total points range: [-157.8, 13.7]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_pwb_subscale_score.png
#
# Creating enhanced nomogram for swb_subscale_score...
# Points scale range: [-202.0, 255.9]
# Total points range: [-155.1, 13.2]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_swb_subscale_score.png
#
# Creating enhanced nomogram for ewb_subscale_score...
# Points scale range: [-202.0, 255.9]
# Total points range: [-153.9, 16.1]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_ewb_subscale_score.png
#
# Creating enhanced nomogram for fwb_subscale_score...
# Points scale range: [-202.0, 255.9]
# Total points range: [-164.8, 17.1]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_fwb_subscale_score.png
#
# Creating enhanced nomogram for ecs_subscale_score...
# Points scale range: [-202.0, 255.9]
# Total points range: [-158.4, 10.4]
# ✓ Saved enhanced nomogram: step5_nomogram_enhanced_ecs_subscale_score.png
#
# ================================================================================
# ENHANCED NOMOGRAM CREATION COMPLETE
# ================================================================================

# %% [markdown]
# # Internal validation

# %%
import pickle
with open('ols_results.pkl', 'rb') as f:
    ols_results = pickle.load(f)
ols_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'coefficients_table':                                Feature  Coefficient   Std_Error  CI_Lower_95  \
#   0                            Interc
_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0.3572470628751296,
#   'nested_cv_rmse': 4.338335188936486,
#   'optimism_r2': 0.7042244401780513,
#   'optimism_rmse': -0.5898124141833021,
#   'durbin_watson': 1.987488743325376,
#   'skipped': False},
#  'fwb_subscale_score_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'coefficients_table':                                Feature  Coefficient  Std_Error  CI_Lower_95  \
#   0                            Intercept    18.048590   3.870508    10.359151
#   1            fact_e_total_Baseline_std   -99.212195  82.657535  -263.425816
#   2      pwb_subscale_score_Baseline_std    23.467678  18.662482   -13.608600
#   3      swb_subscale_score_Baseline_std    20.161924  17.249517   -14.107252
#   4      ewb_subscale_score_Baseline_std    19.436629  16.460759   -13.265542
#   5      fwb_subscale_score_Baseline_std    29.771489  23.020792   -15.963332
#   6      ecs_subscale_score_Baseline_std    47.550115  40.302075   -32.516991
#   7                              bmi_std     0.422551   0.726815    -1.021393
#   8                    age_diagnosis_std     2.018686   0.819610     0.390388
#   9                 cci_category_numeric    -2.207269   1.198518    -4.588334
#   10                              gender    -1.495028   1.615941    -4.705377
#   11           smoking_collapsed_imputed    -0.367037   1.421585    -3.191263
#   12           alcohol_collapsed_imputed     3.071870   1.412762     0.265171
#   13       level_tumor_collapsed_imputed     1.592203   1.087142    -0.567595
#   14    path_histology_collapsed_imputed    -0.885740   0.724209    -2.324507
#   15  path_esoph_stage_collapsed_imputed     0.411580   0.505343    -0.592371
#   16            surgery_approach_imputed     0.077115   1.373046    -2.650680
#   17             neotx_collapsed_imputed     0.452459   0.742632    -1.022910
#
#       CI_Upper_95  t_statistic   p_value Significance
#   0     25.738029     4.663107  0.000011          ***
#   1     65.001427    -1.200280  0.233180
#   2     60.543956     1.257479  0.211833
#   3     54.431100     1.168840  0.245555
#   4     52.138800     1.180786  0.240799
#   5     75.506310     1.293243  0.199237
#   6    127.617220     1.179843  0.241172
#   7      1.866495     0.581373  0.562442
#   8      3.646984     2.462985  0.015681            *
#   9      0.173796    -1.841665  0.068818
#   10     1.715321    -0.925175  0.357349
#   11     2.457189    -0.258189  0.796851
#   12     5.878568     2.174371  0.032301            *
#   13     3.752001     1.464576  0.146521
#   14     0.553027    -1.223046  0.224505
#   15     1.415531     0.814458  0.417533
#   16     2.804910     0.056164  0.955336
#   17     1.927827     0.609263  0.543885               ,
#   'model_performance': {'r2': 0.27732159106093324,
#    'adjusted_r2': 0.14081566937244272,
#    'rmse': 5.779932168621159,
#    'aic': 721.4393837420839,
#    'bic': 769.7177458303199,
#    'f_statistic': 2.031571873444342,
#    'f_pvalue': 0.017048816074695557},
#   'model': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7fc3df4ed9d0>,
#   'predictions': id
#   32      16.989237
#   76      13.223897
#   125     12.081169
#   160     12.415956
#   198     17.645758
#             ...
#   1566    16.430344
#   1571    17.933332
#   1572    16.558499
#   1615    11.553018
#   1653    18.810528
#   Length: 108, dtype: float64,
#   'residuals': id
#   32      8.010763
#   76     -3.223897
#   125     0.918831
#   160     9.584044
#   198     2.854242
#             ...
#   1566   -0.430344
#   1571   -7.933332
#   1572   -1.558499
#   1615    1.446982
#   1653    9.189472
#   Length: 108, dtype: float64,
#   'y_true': id
#   32      25.0
#   76      10.0
#   125     13.0
#   160     22.0
#   198     20.5
#           ...
#   1566    16.0
#   1571    10.0
#   1572    15.0
#   1615    13.0
#   1653    28.0
#   Name: fwb_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0
#   1615   -10.260341
#   1653     9.161215
#   Length: 108, dtype: float64,
#   'y_true': id
#   32      55.0
#   76      48.0
#   125     54.0
#   160     57.0
#   198     51.0
#           ...
#   1566    38.0
#   1571    35.0
#   1572    37.0
#   1615    37.0
#   1653    62.0
#   Name: ecs_subscale_score_12mo, Length: 108, dtype: float64,
#   'nested_cv_r2': -0.132366015063451,
#   'nested_cv_rmse': 10.072232023766755,
#   'optimism_r2': 0.2845348142016031,
#   'optimism_rmse': -0.6075414132671089,
#   'durbin_watson': 2.057877812829246,
#   'skipped': False}}

# %%
score_comparison=pd.read_csv("score_comparison_preprocessed.csv", index_col='id')
score_comparison
# Out:
#            baseline_type  fact_e_total_Baseline  fact_e_total_12mo  \
# id
# 32        baseline_arm_1                  117.5              159.0
# 76    preoperative_arm_1                   95.0               97.0
# 125       baseline_arm_1                  119.5              129.0
# 160       baseline_arm_1                  119.0              152.0
# 198       baseline_arm_1                  133.0              139.0
# ...                  ...                    ...                ...
# 1566  preoperative_arm_1                  150.0              107.0
# 1571      baseline_arm_1                  153.0              104.0
# 1572      baseline_arm_1                  141.0              115.0
# 1615      baseline_arm_1                  126.0              111.0
# 1653      baseline_arm_1                  112.0              153.0
#
#       pwb_subscale_score_Baseline  pwb_subscale_score_12mo  \
# id
# 32                           24.5                     27.0
# 76                            7.0                      7.0
# 125                          21.0                     22.0
# 160                          21.0                     28.0
# 198                          25.0                     26.5
# ...                           ...                      ...
# 1566                         23.0                     19.0
# 1571                         26.0                     16.0
# 1572                         27.0                     24.0
# 1615                         23.0                     19.0
# 1653                         21.0                     26.0
#
#       swb_subscale_score_Baseline  swb_subscale_score_12mo  \
# id
# 32                           22.0                     28.0
# 76                           23.0                     21.0
# 125                          17.5                     21.0
# 160                          20.0                     22.0
# 198                          13.0                     18.0
# ...                           ...                      ...
# 1566                         24.0                     19.0
# 1571                         28.0                     28.0
# 1572                         13.0                     21.0
# 1615                         24.0                     22.0
# 1653                         19.0                     21.0
#
#       ewb_subscale_score_Baseline  ewb_subscale_score_12mo  \
# id
# 32                            6.0                     24.0
# 76                           14.0                     11.0
# 125                          21.0                     19.0
# 160                          21.0                     23.0
# 198                          17.0                     23.0
# ...                           ...                      ...
# 1566                         18.0                     15.0
# 1571                         16.0                     15.0
# 1572                         19.0                     18.0
# 1615                         16.0                     20.0
# 1653                         18.0                     16.0
#
#       fwb_subscale_score_Baseline  ...  age_diagnosis_std  gender  cci_total  \
# id                                 ...
# 32                           19.0  ...          -3.924010     1.0        2.0
# 76                           15.0  ...          -0.759442     1.0        4.0
# 125                           8.0  ...          -0.019975     1.0        4.0
# 160                          20.0  ...          -1.530613     1.0        4.0
# 198                          21.0  ...           0.220608     2.0        4.0
# ...                           ...  ...                ...     ...        ...
# 1566                         18.0  ...           0.634635     1.0        4.0
# 1571                         25.0  ...           1.698298     1.0        6.0
# 1572                         20.0  ...          -0.426542     1.0        4.0
# 1615                         12.0  ...          -0.983551     1.0        4.0
# 1653                         24.0  ...           1.257229     1.0        4.0
#
#       cci_total_std  cci_category_numeric  pwb_subscale_score_Baseline_std  \
# id
# 32        -1.324120                     1                         0.348883
# 76         0.044349                     2                        -2.977447
# 125        0.044349                     2                        -0.316383
# 160        0.044349                     2                        -0.316383
# 198        0.044349                     2                         0.443921
# ...             ...                   ...                              ...
# 1566       0.044349                     2                         0.063769
# 1571       1.412817                     3                         0.633997
# 1572       0.044349                     2                         0.824073
# 1615       0.044349                     2                         0.063769
# 1653       0.044349                     2                        -0.316383
#
#       swb_subscale_score_Baseline_std  ewb_subscale_score_Baseline_std  \
# id
# 32                          -0.088736                        -2.212704
# 76                           0.115846                        -0.487638
# 125                         -1.009355                         1.021796
# 160                         -0.497900                         1.021796
# 198                         -1.929973                         0.159263
# ...                               ...                              ...
# 1566                         0.320427                         0.374896
# 1571                         1.138755                        -0.056371
# 1572                        -1.929973                         0.590529
# 1615                         0.320427                        -0.056371
# 1653                        -0.702482                         0.374896
#
#       fwb_subscale_score_Baseline_std  ecs_subscale_score_Baseline_std
# id
# 32                           0.008454                        -0.223354
# 76                          -0.608789                        -1.098848
# 125                         -1.688964                         0.301943
# 160                          0.162764                        -1.011299
# 198                          0.317075                         0.739690
# ...                               ...                              ...
# 1566                        -0.145857                         1.615185
# 1571                         0.934318                         0.827240
# 1572                         0.162764                         1.177437
# 1615                        -1.071721                         0.214394
# 1653                         0.780007                        -1.624145
#
# [108 rows x 34 columns]

# %%
import pickle
with open('ridge_results.pkl', 'rb') as f:  # Load
    ridge_results = pickle.load(f)
ridge_results
# Out:
# {'fact_e_total_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    'alcohol_collapsed_imputed',
#    'level_tumor_collapsed_imputed',
#    'path_histology_collapsed_imputed',
#    'path_esoph_stage_collapsed_imputed',
#    'surgery_approach_imputed',
#    'neotx_collapsed_imputed'],
#   'n_stable_features': 17,
#   'nested_cv_r2_mean': -0.0892303261691116,
#   'nested_cv_r2_std': 0.179699894686157,
#   'nested_cv_rmse_mean': 24.98610761225858,
#   'nested_cv_rmse_std': 5.685154078044437,
#   'nested_cv_r2_scores': [0.06605796459239899,
#    -0.23387173218283408,
#    0.14936370413742872,
#    -0.24507514223964777,
#    -0.3743969600695416,
#    -0.3214802893036435,
#    -0.07189048665166098,
#    0.09815831516858464,
#    -0.010813247435900841,
#    0.05164461229370043],
#   'nested_cv_rmse_scores': [24.921124545158474,
#    16.89916132953017,
#    24.049716234587596,
#    36.731576328693,
#    17.84886677594742,
#    23.483701016333548,
#    25.058639163379244,
#    28.625952207540443,
#    21.123865486614683,
#    31.11847303480122],
#   'nested_cv_predictions': [127.3436440723833,
#    129.46714702905075,
#    133.1750145256125,
#    117.61827096149601,
#    131.81993188022201,
#    128.6264897737146,
#    127.17058475210906,
#    130.26332235044507,
#    116.11435516726041,
#    114.35759568056405,
#    130.06031716814033,
#    119.79697493434973,
#    116.6669228128514,
#    122.69303896372544,
#    125.3428086067477,
#    120.1349033152396,
#    132.29497282011687,
#    132.2334038235585,
#    120.95697947843273,
#    127.42056230349007,
#    128.6822145542463,
#    123.16227474601244,
#    128.79202708131484,
#    120.5734675251542,
#    128.3269207789618,
#    129.0713639175489,
#    126.73153991294785,
#    111.78547207728326,
#    128.41871905421016,
#    129.54640901827875,
#    127.37825702273516,
#    119.72713852652986,
#    122.20547781621805,
#    128.28627336412757,
#    112.27772617446907,
#    118.5462150860884,
#   'nested_cv_true_values': [20.5,
#    19.0,
#    22.0,
#    13.0,
#    22.0,
#    24.0,
#    18.0,
#    13.0,
#    19.0,
#    16.0,
#    15.0,
#    25.0,
#    13.0,
#    11.0,
#    17.0,
#    11.0,
#    13.0,
#    21.0,
#    21.0,
#    21.0,
#    12.0,
#    13.0,
#    14.0,
#    11.0,
#    17.0,
#    23.0,
#    15.0,
#    8.0,
#    14.0,
#    27.0,
#    28.0,
#    22.0,
#    4.0,
#    4.0,
#    2.0,
#    27.0,
#    14.0,
#    9.0,
#    6.0,
#    22.0,
#    9.5,
#    15.0,
#    16.0,
#    28.0,
#    13.666666666666666,
#    19.0,
#    13.0,
#    10.0,
#    21.0,
#    16.0,
#    16.0,
#    19.0,
#    8.0,
#    16.0,
#    15.0,
#    22.0,
#    18.0,
#    21.0,
#    20.0,
#    18.0,
#    24.0,
#    16.333333333333332,
#    9.0,
#    21.0,
#    16.0,
#    23.0,
#    18.0,
#    7.0,
#    12.0,
#    18.0,
#    7.0,
#    21.0,
#    3.0,
#    22.666666666666664,
#    24.0,
#    16.0,
#    10.0,
#    5.0,
#    10.0,
#    24.0,
#    28.0,
#    16.0,
#    26.0,
#    18.0,
#    21.0,
#    27.0,
#    4.0,
#    8.0,
#    10.0,
#    13.0,
#    20.0,
#    27.0,
#    20.0,
#    13.0,
#    26.0,
#    28.0,
#    19.0,
#    18.0,
#    8.0,
#    22.0,
#    10.0,
#    28.0,
#    1.0,
#    26.0,
#    19.0,
#    2.0,
#    9.0,
#    22.0],
#   'final_ridge_coefficients':                                Feature  Coefficient  Abs_Coefficient
#   4      fwb_subscale_score_Baseline_std     0.658381         0.658381
#   1      pwb_subscale_score_Baseline_std     0.473705         0.473705
#   7                    age_diagnosis_std     0.399304         0.399304
#   16             neotx_collapsed_imputed     0.345340         0.345340
#   11           alcohol_collapsed_imputed     0.337755         0.337755
#   0            fact_e_total_Baseline_std     0.328041         0.328041
#   12       level_tumor_collapsed_imputed     0.311156         0.311156
#   3      ewb_subscale_score_Baseline_std     0.165986         0.165986
#   9                               gender    -0.129872         0.129872
#   6                              bmi_std     0.124933         0.124933
#   8                 cci_category_numeric    -0.123398         0.123398
#   13    path_histology_collapsed_imputed    -0.122329         0.122329
#   10           smoking_collapsed_imputed    -0.086824         0.086824
#   15            surgery_approach_imputed     0.055822         0.055822
#   2      swb_subscale_score_Baseline_std    -0.028389         0.028389
#   5      ecs_subscale_score_Baseline_std     0.025317         0.025317
#   14  path_esoph_stage_collapsed_imputed     0.009138         0.009138,
#   'final_ridge_best_alpha': 166.81005372000593,
#   'apparent_r2': 0.14918321315956884,
#   'apparent_rmse': 6.27145379393576},
#  'ecs_subscale_score_12mo': {'n_observations': 108,
#   'stable_features': ['fact_e_total_Baseline_std',
#    'pwb_subscale_score_Baseline_std',
#    'swb_subscale_score_Baseline_std',
#    'ewb_subscale_score_Baseline_std',
#    'fwb_subscale_score_Baseline_std',
#    'ecs_subscale_score_Baseline_std',
#    'bmi_std',
#    'age_diagnosis_std',
#    'cci_category_numeric',
#    'gender',
#    'smoking_collapsed_imputed',
#    48.0637061331375,
#    48.28699065278515,
#    47.997699607796406,
#    47.53975996226441,
#    47.654943301372896,
#    48.23316752766101,
#    48.804360680616014,
#    48.374692557199474,
#    48.49636805020226,
#    48.981817766172426,
#    48.83608853738952,
#    48.41067829085034,
#    47.75690618893234,
#    48.34583979394774],
#   'nested_cv_true_values': [51.0,
#    56.0,
#    59.0,
#    24.0,
#    51.0,
#    68.0,
#    49.5,
#    24.0,
#    41.0,
#    58.0,
#    27.0,
#    55.0,
#    59.0,
#    47.8125,
#    54.0,
#    41.0,
#    46.0,
#    50.0,
#    45.333333333333336,
#    59.0,
#    45.0,
#    37.0,
#    45.0,
#    44.0,
#    40.07142857142857,
#    56.0,
#    53.0,
#    52.0,
#    43.0,
#    67.0,
#    67.0,
#    43.0,
#    34.0,
#    17.0,
#    35.0,
#    64.0,
#    51.0,
#    37.4,
#    50.0,
#    47.0,
#    49.0,
#    54.0,
#    38.0,
#    62.0,
#    48.84848484848485,
#    56.0,
#    39.0,
#    32.0,
#    48.0,
#    39.0,
#    52.0,
#    49.9375,
#    36.0,
#    44.0,
#    37.0,
#    57.0,
#    55.0,
#    63.0,
#    55.0,
#    46.0,
#    51.0,
#    43.0,
#    30.0,
#    55.25,
#    52.0,
#    49.0,
#    47.0,
#    52.0,
#    59.0,
#    57.0,
#    44.0,
#    46.0,
#    29.0,
#    60.5,
#    42.0,
#    33.0,
#    35.0,
#    58.0,
#    46.0,
#    51.0,
#    55.0,
#    42.0,
#    59.0,
#    60.0,
#    61.625,
#    56.0,
#    23.0,
#    51.0,
#    48.0,
#    54.0,
#    59.0,
#    54.0,
#    52.0,
#    44.0,
#    60.0,
#    54.0,
#    48.0,
#    43.0,
#    50.0,
#    58.0,
#    49.0,
#    62.0,
#    27.0,
#    43.0,
#    50.0,
#    44.0,
#    41.0,
#    59.0],
#   'final_ridge_coefficients':                                Feature  Coefficient  Abs_Coefficient
#   1      pwb_subscale_score_Baseline_std     0.155392         0.155392
#   13    path_histology_collapsed_imputed    -0.130805         0.130805
#   3      ewb_subscale_score_Baseline_std     0.112623         0.112623
#   4      fwb_subscale_score_Baseline_std     0.096886         0.096886
#   16             neotx_collapsed_imputed     0.093093         0.093093
#   0            fact_e_total_Baseline_std     0.079642         0.079642
#   7                    age_diagnosis_std     0.068311         0.068311
#   10           smoking_collapsed_imputed    -0.068215         0.068215
#   15            surgery_approach_imputed     0.055980         0.055980
#   8                 cci_category_numeric    -0.046242         0.046242
#   12       level_tumor_collapsed_imputed     0.039226         0.039226
#   11           alcohol_collapsed_imputed     0.027644         0.027644
#   9                               gender    -0.018089         0.018089
#   6                              bmi_std     0.014583         0.014583
#   5      ecs_subscale_score_Baseline_std    -0.008989         0.008989
#   14  path_esoph_stage_collapsed_imputed    -0.005283         0.005283
#   2      swb_subscale_score_Baseline_std     0.002803         0.002803,
#   'final_ridge_best_alpha': 1000.0,
#   'apparent_r2': 0.01847279198050822,
#   'apparent_rmse': 10.183636661996854}}

# %%
import pickle
with open('nomogram_results.pkl', 'rb') as f:  # Load
    nomogram_results = pickle.load(f)
nomogram_results
# Out:
# {'fact_e_total_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -566.7260410333959,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.96181046436087,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 132.33134438267254,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -88.16468677427324,
#     'max_points': 23.680535421557494,
#     'mean_points': 2.60438849526579e-15,
#     'points_per_unit_value': 23.35014359696144},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 117.04412346796744,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -75.06883260850317,
#     'max_points': 23.51834506560928,
#     'mean_points': 1.6920813565143844e-14,
#     'points_per_unit_value': 20.652681365151935},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 114.75688483510226,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.53801586816904,
#     'max_points': 33.78958068473842,
#     'mean_points': 6.713079260180223e-15,
#     'points_per_unit_value': 20.24909330544419},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 163.12937155724012,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -75.26657532504892,
#     'max_points': 40.21917314509581,
#     'mean_points': 2.6335130522981036e-15,
#     'points_per_unit_value': 28.784520164237044},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 272.8426374056435,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -107.69690746194529,
#     'max_points': 81.97583798595119,
#     'mean_points': 1.6233022404850796e-14,
#     'points_per_unit_value': 48.14365630845707},
#    {'feature': 'bmi_std',
#     'coefficient': 3.364916587290946,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -1.2139719868667807,
#     'max_points': 1.959554016457083,
#     'mean_points': 6.567496949527806e-16,
#     'points_per_unit_value': 0.5937465977662141},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 7.445813194454839,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -5.15548019299331,
#     'max_points': 2.8797617754145612,
#     'mean_points': -1.280364956127795e-15,
#     'points_per_unit_value': 1.3138293735148965},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -7.577217620623905,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.3370159604466452,
#      2: -2.6740319208932903,
#      3: -4.011047881339936},
#     'min_points': -4.011047881339936,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -5.75982396708274,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.0163330339611705},
#     'min_points': -1.0163330339611705,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -4.89459003045871,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.8636606889518746},
#     'min_points': -0.8636606889518746,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 9.02366780559784,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.5922451329647118},
#     'min_points': 0.0,
#     'max_points': 1.5922451329647118},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 4.876258000066617,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.8604259636940295, 3: 1.720851927388059},
#     'min_points': 0.0,
#     'max_points': 1.720851927388059},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -3.471147670992382,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.6124912955584187,
#      2: -1.2249825911168375,
#      3: -1.8374738866752562},
#     'min_points': -1.8374738866752562,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 2.4351924276448327,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.42969481748260313,
#      2: 0.8593896349652063,
#      3: 1.2890844524478093,
#      4: 1.7187792699304125,
#      5: 2.1484740874130157},
#     'min_points': 0.0,
#     'max_points': 2.1484740874130157},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 4.102823302901769,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.7239517872551756},
#     'min_points': 0.0,
#     'max_points': 0.7239517872551756},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 1.9271201105038394,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.3400443902295075,
#      2: 0.680088780459015,
#      3: 1.0201331706885226},
#     'min_points': 0.0,
#     'max_points': 1.0201331706885226}],
#   'intercept': 132.38148452990947,
#   'points_per_unit': 0.1764520998852552,
#   'min_possible_point': -201.96181046436087,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -157.91152700749578,
#   'max_total_points': 13.266633736172446,
#   'predicted_score_range': (-762.544260815053, 207.56695268132046),
#   'nomogram_file': 'step5_nomogram_fact_e_total.png',
#   'skipped': False},
#  'pwb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -127.59048538888473,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 30.717596876750562,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -90.90213012248849,
#     'max_points': 24.41579719748697,
#     'mean_points': 2.6852526850381295e-15,
#     'points_per_unit_value': 24.075146969717995},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 25.61949302097674,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -72.98531038005902,
#     'max_points': 22.865597540201957,
#     'mean_points': 1.6451179364620217e-14,
#     'points_per_unit_value': 20.079469831069886},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 25.879258034407925,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.62782972201517,
#     'max_points': 33.846265124980164,
#     'mean_points': 6.724340931158392e-15,
#     'points_per_unit_value': 20.283062608885132},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 36.71366773297946,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -75.24066843481613,
#     'max_points': 40.205329633558,
#     'mean_points': 2.6326065923817614e-15,
#     'points_per_unit_value': 28.77461248076562},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 60.68558833346758,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -106.39750394826092,
#     'max_points': 80.98676880628321,
#     'mean_points': 1.6037164911375106e-14,
#     'points_per_unit_value': 47.562785068575586},
#    {'feature': 'bmi_std',
#     'coefficient': 1.3180384272245722,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -2.1121137983141356,
#     'max_points': 3.4093052570207916,
#     'mean_points': 1.142637645476896e-15,
#     'points_per_unit_value': 1.0330225041524888},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 1.802418892535698,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -5.543289964377235,
#     'max_points': 3.096385584246472,
#     'mean_points': -1.3766776219389723e-15,
#     'points_per_unit_value': 1.412659327254757},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -2.035960647371672,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.595699429441185,
#      2: -3.19139885888237,
#      3: -4.787098288323555},
#     'min_points': -4.787098288323555,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.044178018652047,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.8183823546634242},
#     'min_points': -0.8183823546634242,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.0419543722841225,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.8166395551426393},
#     'min_points': -0.8166395551426393,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 1.917007339900998,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.5024688824234236},
#     'min_points': 0.0,
#     'max_points': 1.5024688824234236},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.539872255171872,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.42312892965834265, 3: 0.8462578593166853},
#     'min_points': 0.0,
#     'max_points': 0.8462578593166853},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.22196576363458198,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.17396733224899144,
#      2: -0.3479346644979829,
#      3: -0.5219019967469744},
#     'min_points': -0.5219019967469744,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.6907970765693747,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.5414173905396513,
#      2: 1.0828347810793026,
#      3: 1.6242521716189537,
#      4: 2.1656695621586053,
#      5: 2.7070869526982566},
#     'min_points': 0.0,
#     'max_points': 2.7070869526982566},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 1.1198904855060134,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.8777225684914391},
#     'min_points': 0.0,
#     'max_points': 0.8777225684914391},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.3782765411221062,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.29647707661676503,
#      2: 0.5929541532335301,
#      3: 0.889431229850295},
#     'min_points': 0.0,
#     'max_points': 0.889431229850295}],
#   'intercept': 22.705776608707616,
#   'points_per_unit': 0.7837575011585596,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -157.83140986397547,
#   'max_total_points': 13.686606172196806,
#   'predicted_score_range': (-178.67208533285876, 40.16858385707857),
#   'nomogram_file': 'step5_nomogram_pwb_subscale_score.png',
#   'skipped': False},
#  'swb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -73.49705860639142,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.92145870123224,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 15.671029462017245,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -80.50682169421563,
#     'max_points': 21.62367624225705,
#     'mean_points': 2.3781748439445744e-15,
#     'points_per_unit_value': 21.321981803302354},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 16.71280198834077,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -82.65374319802328,
#     'max_points': 25.894624785668785,
#     'mean_points': 1.8630482592007296e-14,
#     'points_per_unit_value': 22.73941611438502},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 14.536304893385925,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -52.29266258491646,
#     'max_points': 33.00359777963629,
#     'mean_points': 6.5569256343531804e-15,
#     'points_per_unit_value': 19.77807706732066},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 20.954173315705347,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -74.54932827726104,
#     'max_points': 39.835907624136354,
#     'mean_points': 2.608417191965489e-15,
#     'points_per_unit_value': 28.51022029047995},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 36.79979420602187,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -112.00556312275539,
#     'max_points': 85.25546473393953,
#     'mean_points': 1.6882460773370632e-14,
#     'points_per_unit_value': 50.06975095847129},
#    {'feature': 'bmi_std',
#     'coefficient': 0.3202706698100085,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.8909528891896551,
#     'max_points': 1.4381471165505733,
#     'mean_points': 4.81998797767e-16,
#     'points_per_unit_value': 0.43575984656093064},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 0.7362734686139462,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -3.9309665457258713,
#     'max_points': 2.195769700405378,
#     'mean_points': -9.762566473824229e-16,
#     'points_per_unit_value': 1.0017727002613934},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -0.1055945359408037,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.14367178488911805,
#      2: -0.2873435697782361,
#      3: -0.43101535466735413},
#     'min_points': -0.43101535466735413,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -0.7153699427837612,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.9733313908722213},
#     'min_points': -0.9733313908722213,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.9386584620491707,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -2.63773612006914},
#     'min_points': -2.63773612006914,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 0.15686887477775135,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.2134355819841065},
#     'min_points': 0.0,
#     'max_points': 0.2134355819841065},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.40923589909619285,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.5568058189754618, 3: 1.1136116379509235},
#     'min_points': 0.0,
#     'max_points': 1.1136116379509235},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': 0.5337182602797577,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.726176353720562,
#      2: 1.452352707441124,
#      3: 2.1785290611616857},
#     'min_points': 0.0,
#     'max_points': 2.1785290611616857},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.24831241054398512,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.33785353489288006,
#      2: 0.6757070697857601,
#      3: 1.01356060467864,
#      4: 1.3514141395715202,
#      5: 1.6892676744644002},
#     'min_points': 0.0,
#     'max_points': 1.6892676744644002},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': -0.1246392170479188,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.16958395262511905},
#     'min_points': -0.16958395262511905,
#     'max_points': -0.0},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.16735334188723025,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.22770073396199417,
#      2: 0.45540146792398833,
#      3: 0.6831022018859825},
#     'min_points': 0.0,
#     'max_points': 0.6831022018859825}],
#   'intercept': 22.259066377809475,
#   'points_per_unit': 1.3605986674316222,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.92145870123224,
#   'min_total_points': -155.12024642908895,
#   'max_total_points': 13.163323675680239,
#   'predicted_score_range': (-91.74975205055682, 31.93372209427318),
#   'nomogram_file': 'step5_nomogram_swb_subscale_score.png',
#   'skipped': False},
#  'ewb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -92.49285946237529,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.9618104643608,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 21.489268207443338,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -87.72402166356787,
#     'max_points': 23.562175269155205,
#     'mean_points': 2.591371229662336e-15,
#     'points_per_unit_value': 23.23343481037566},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 18.60133128683227,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -73.100279754445,
#     'max_points': 22.901616342211145,
#     'mean_points': 1.6477093919064293e-14,
#     'points_per_unit_value': 20.111099813493183},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 19.45985015819583,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -55.62729940308036,
#     'max_points': 35.10819538181676,
#     'mean_points': 6.975052471914206e-15,
#     'points_per_unit_value': 21.039299975488166},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 26.99935195551563,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -76.32877558805912,
#     'max_points': 40.786766610166836,
#     'mean_points': 2.670678530396599e-15,
#     'points_per_unit_value': 29.190741979923928},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 44.697394250029994,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -108.10310347461372,
#     'max_points': 82.28502289487545,
#     'mean_points': 1.6294247830258093e-14,
#     'points_per_unit_value': 48.325237764124076},
#    {'feature': 'bmi_std',
#     'coefficient': 0.8863478748284699,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -1.9593117042952217,
#     'max_points': 3.1626570968514462,
#     'mean_points': 1.0599728643116609e-15,
#     'points_per_unit_value': 0.9582878937687324},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 0.8718918078606408,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -3.6990018325721707,
#     'max_points': 2.0661982368018714,
#     'mean_points': -9.186481456207675e-16,
#     'points_per_unit_value': 0.9426585067524194},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -0.11999259344206337,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.12973173728170287,
#      2: -0.25946347456340574,
#      3: -0.3891952118451086},
#     'min_points': -0.3891952118451086,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -0.7083077682703864,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -0.7657972435791277},
#     'min_points': -0.7657972435791277,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': 0.1486302565532387,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.1606937631911999},
#     'min_points': 0.0,
#     'max_points': 0.1606937631911999},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 1.8063784762628465,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.9529923572074817},
#     'min_points': 0.0,
#     'max_points': 1.9529923572074817},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 0.6524099022061729,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.7053624528405498, 3: 1.4107249056810995},
#     'min_points': 0.0,
#     'max_points': 1.4107249056810995},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.6505706228672358,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.7033738892372314,
#      2: -1.4067477784744629,
#      3: -2.1101216677116943},
#     'min_points': -2.1101216677116943,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.5277291769023007,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.5705620736236109,
#      2: 1.1411241472472218,
#      3: 1.7116862208708328,
#      4: 2.2822482944944436,
#      5: 2.8528103681180546},
#     'min_points': 0.0,
#     'max_points': 2.8528103681180546},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 0.45684356745777477,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.4939230661839489},
#     'min_points': 0.0,
#     'max_points': 0.4939230661839489},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.4133998620051801,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.4469532722937871,
#      2: 0.8939065445875742,
#      3: 1.3408598168813612},
#     'min_points': 0.0,
#     'max_points': 1.3408598168813612}],
#   'intercept': 15.535944690116297,
#   'points_per_unit': 1.0811645415793258,
#   'min_possible_point': -201.9618104643608,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -153.8854488425372,
#   'max_total_points': 16.122825644781063,
#   'predicted_score_range': (-126.79710724085707, 30.44840715510745),
#   'nomogram_file': 'step5_nomogram_ewb_subscale_score.png',
#   'skipped': False},
#  'fwb_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -99.21219459558627,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.9214587012322,
#     'max_points': -201.9618104643608,
#     'mean_points': 2.323244477456346e-14,
#     'points_per_unit_value': -99.99999999999999},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 23.467678146117407,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -89.31207512615312,
#     'max_points': 23.988717433007714,
#     'mean_points': 2.638282394655335e-15,
#     'points_per_unit_value': 23.654025840046714},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 20.161923575337664,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -73.86694287979054,
#     'max_points': 23.141804544217536,
#     'mean_points': 1.664990283803199e-14,
#     'points_per_unit_value': 20.322021559469285},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 19.436628971894738,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -51.79795077154409,
#     'max_points': 32.69136908638773,
#     'mean_points': 6.494894205652239e-15,
#     'points_per_unit_value': 19.590967674007516},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 29.771489092405965,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -78.4654848506699,
#     'max_points': 41.9285307919772,
#     'mean_points': 2.7454401587522215e-15,
#     'points_per_unit_value': 30.00789289437856},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 47.55011476406304,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -107.21379668046931,
#     'max_points': 81.60810773180685,
#     'mean_points': 1.6160203710938944e-14,
#     'points_per_unit_value': 47.927691709561714},
#    {'feature': 'bmi_std',
#     'coefficient': 0.42255074295288747,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.8708058629249974,
#     'max_points': 1.4056264433689205,
#     'mean_points': 4.710994084098618e-16,
#     'points_per_unit_value': 0.42590605386294494},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 2.0186858785915547,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -7.984244797649878,
#     'max_points': 4.459860597481017,
#     'mean_points': -1.982889441404518e-15,
#     'points_per_unit_value': 2.0347154770844686},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -2.207268704376985,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -2.224795765655991,
#      2: -4.449591531311982,
#      3: -6.674387296967972},
#     'min_points': -6.674387296967972,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.4950280415025827,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.5068994770216413},
#     'min_points': -1.5068994770216413,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -0.36703685844491507,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.36995135521500067},
#     'min_points': -0.36995135521500067,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 3.071869599604941,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 3.09626211992049},
#     'min_points': 0.0,
#     'max_points': 3.09626211992049},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 1.5922026048176092,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 1.604845665704529, 3: 3.209691331409058},
#     'min_points': 0.0,
#     'max_points': 3.209691331409058},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -0.8857402210451609,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -0.8927735392364413,
#      2: -1.7855470784728826,
#      3: -2.6783206177093235},
#     'min_points': -2.6783206177093235,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.4115801113723393,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.4148483087689399,
#      2: 0.8296966175378798,
#      3: 1.2445449263068198,
#      4: 1.6593932350757596,
#      5: 2.0742415438446997},
#     'min_points': 0.0,
#     'max_points': 2.0742415438446997},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 0.07711509621491008,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 0.07772743716561306},
#     'min_points': 0.0,
#     'max_points': 0.07772743716561306},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.4524586372085212,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.4560514350608368,
#      2: 0.9121028701216736,
#      3: 1.3681543051825105},
#     'min_points': 0.0,
#     'max_points': 1.3681543051825105}],
#   'intercept': 18.048590078259217,
#   'points_per_unit': 1.007940610603616,
#   'min_possible_point': -201.9618104643608,
#   'max_possible_point': 255.9214587012322,
#   'min_total_points': -164.81940101488354,
#   'max_total_points': 17.088282901408544,
#   'predicted_score_range': (-145.47235478790674, 35.00225056344895),
#   'nomogram_file': 'step5_nomogram_fwb_subscale_score.png',
#   'skipped': False},
#  'ecs_subscale_score_12mo': {'nomogram_data': [{'feature': 'fact_e_total_Baseline_std',
#     'coefficient': -173.9334429801583,
#     'is_categorical': False,
#     'min_val': -2.559214587012322,
#     'max_val': 2.0196181046436084,
#     'mean_val': -2.323244477456346e-16,
#     'std_val': 1.0,
#     'min_points': 255.92145870123224,
#     'max_points': -201.96181046436084,
#     'mean_points': 2.3232444774563462e-14,
#     'points_per_unit_value': -100.0},
#    {'feature': 'pwb_subscale_score_Baseline_std',
#     'coefficient': 40.98577169034402,
#     'is_categorical': False,
#     'min_val': -3.775766363413119,
#     'max_val': 1.0141494557934558,
#     'mean_val': 1.115362946035458e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -88.97236521936972,
#     'max_points': 23.897473276475576,
#     'mean_points': 2.628247349952917e-15,
#     'points_per_unit_value': 23.564054725818043},
#    {'feature': 'swb_subscale_score_Baseline_std',
#     'coefficient': 35.94857359648,
#     'is_categorical': False,
#     'min_val': -3.6348225821742313,
#     'max_val': 1.138755043463397,
#     'mean_val': 8.193034728020831e-16,
#     'std_val': 1.0,
#     'min_points': -75.12453319304662,
#     'max_points': 23.53579552436998,
#     'mean_points': 1.6933368698529818e-14,
#     'points_per_unit_value': 20.668005520123515},
#    {'feature': 'ewb_subscale_score_Baseline_std',
#     'coefficient': 35.44484277721786,
#     'is_categorical': False,
#     'min_val': -2.643971019372742,
#     'max_val': 1.668695984311244,
#     'mean_val': 3.3152493096445647e-16,
#     'std_val': 1.0,
#     'min_points': -53.87988387022153,
#     'max_points': 34.00534468442281,
#     'mean_points': 6.75594575340158e-15,
#     'points_per_unit_value': 20.378394269617992},
#    {'feature': 'fwb_subscale_score_Baseline_std',
#     'coefficient': 48.690689460633735,
#     'is_categorical': False,
#     'min_val': -2.614828209593117,
#     'max_val': 1.397250081488786,
#     'mean_val': 9.149060110336938e-17,
#     'std_val': 1.0,
#     'min_points': -73.19914224933,
#     'max_points': 39.11442713427839,
#     'mean_points': 2.5611753384304902e-15,
#     'points_per_unit_value': 27.99386283993021},
#    {'feature': 'ecs_subscale_score_Baseline_std',
#     'coefficient': 83.10974585206074,
#     'is_categorical': False,
#     'min_val': -2.236990617661644,
#     'max_val': 1.7027339481806465,
#     'mean_val': 3.371788445157883e-16,
#     'std_val': 0.9999999999999999,
#     'min_points': -106.8890022078803,
#     'max_points': 81.36088337141287,
#     'mean_points': 1.6111247839551715e-14,
#     'points_per_unit_value': 47.78249911464214},
#    {'feature': 'bmi_std',
#     'coefficient': 0.41770887247500577,
#     'is_categorical': False,
#     'min_val': -2.044596114628649,
#     'max_val': 3.300320412494644,
#     'mean_val': 1.1061110874969153e-15,
#     'std_val': 1.0,
#     'min_points': -0.4910188190811224,
#     'max_points': 0.7925865748926998,
#     'mean_points': 2.656374802188823e-16,
#     'points_per_unit_value': 0.2401544322460497},
#    {'feature': 'age_diagnosis_std',
#     'coefficient': 2.016543146853001,
#     'is_categorical': False,
#     'min_val': -3.924010451373012,
#     'max_val': 2.191884146805392,
#     'mean_val': -9.74529099393193e-16,
#     'std_val': 1.0,
#     'min_points': -4.549404788588286,
#     'max_points': 2.5412185714281357,
#     'mean_points': -1.1298459589593423e-15,
#     'points_per_unit_value': 1.1593763179189414},
#    {'feature': 'cci_category_numeric',
#     'coefficient': -3.1084011394923827,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.7871210310296552,
#      2: -3.5742420620593105,
#      3: -5.361363093088966},
#     'min_points': -5.361363093088966,
#     'max_points': -0.0},
#    {'feature': 'gender',
#     'coefficient': -1.7969401958739706,
#     'is_categorical': True,
#     'categories': [1.0, 2.0],
#     'points_dict': {1.0: -0.0, 2.0: -1.0331194306772615},
#     'min_points': -1.0331194306772615,
#     'max_points': -0.0},
#    {'feature': 'smoking_collapsed_imputed',
#     'coefficient': -1.695570594233738,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: -0.0, 1: -0.974838745891532},
#     'min_points': -0.974838745891532,
#     'max_points': -0.0},
#    {'feature': 'alcohol_collapsed_imputed',
#     'coefficient': 2.0715435150513084,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.19099782052128},
#     'min_points': 0.0,
#     'max_points': 1.19099782052128},
#    {'feature': 'level_tumor_collapsed_imputed',
#     'coefficient': 1.6825373387747788,
#     'is_categorical': True,
#     'categories': [1, 2, 3],
#     'points_dict': {1: 0.0, 2: 0.9673455029385675, 3: 1.934691005877135},
#     'min_points': 0.0,
#     'max_points': 1.934691005877135},
#    {'feature': 'path_histology_collapsed_imputed',
#     'coefficient': -2.2465893237251606,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: -0.0,
#      1: -1.2916373557794998,
#      2: -2.5832747115589996,
#      3: -3.8749120673384994},
#     'min_points': -3.8749120673384994,
#     'max_points': -0.0},
#    {'feature': 'path_esoph_stage_collapsed_imputed',
#     'coefficient': 0.5567736522568307,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3, 4, 5],
#     'points_dict': {0: 0.0,
#      1: 0.3201073023779248,
#      2: 0.6402146047558496,
#      3: 0.9603219071337744,
#      4: 1.2804292095116991,
#      5: 1.6005365118896238},
#     'min_points': 0.0,
#     'max_points': 1.6005365118896238},
#    {'feature': 'surgery_approach_imputed',
#     'coefficient': 2.5736133707709925,
#     'is_categorical': True,
#     'categories': [0, 1],
#     'points_dict': {0: 0.0, 1: 1.479654129001851},
#     'min_points': 0.0,
#     'max_points': 1.479654129001851},
#    {'feature': 'neotx_collapsed_imputed',
#     'coefficient': 0.5156317282808027,
#     'is_categorical': True,
#     'categories': [0, 1, 2, 3],
#     'points_dict': {0: 0.0,
#      1: 0.29645347061842736,
#      2: 0.5929069412368547,
#      3: 0.8893604118552821},
#     'min_points': 0.0,
#     'max_points': 0.8893604118552821}],
#   'intercept': 53.83210677501688,
#   'points_per_unit': 0.5749325620571292,
#   'min_possible_point': -201.96181046436084,
#   'max_possible_point': 255.92145870123224,
#   'min_total_points': -158.42812498328158,
#   'max_total_points': 10.381158552064786,
#   'predicted_score_range': (-221.7273856573131, 71.88841326585231),
#   'nomogram_file': 'step5_nomogram_ecs_subscale_score.png',
#   'skipped': False}}

# %%
def perform_internal_validation(score_comparison, ridge_results, ols_results, nomogram_results):
    """
    Step 6: Internal Validation
    
    Assess model accuracy, reliability, and potential optimism using:
    1. Nested CV performance estimates from Step 3 (primary measure of generalization)
    2. Calibration plots (predicted vs observed) using final OLS model
    3. Performance comparison: Nested CV vs Apparent OLS
    
    Args:
        score_comparison: DataFrame with all preprocessed data
        ridge_results: Dictionary from Step 3 containing nested CV results
        ols_results: Dictionary from Step 4 containing OLS model results
        nomogram_results: Dictionary from Step 5 containing nomogram data
    
    Returns:
        Dictionary with validation results for each domain
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
    import scipy.stats as stats
    
    print("="*80)
    print("STEP 6: INTERNAL VALIDATION")
    print("="*80)
    print("Purpose: Assess model accuracy, reliability, and optimism")
    print("Method: Nested CV estimates + Calibration plots + Performance comparison")
    
    validation_results = {}
    
    # Loop through each domain
    for outcome_domain in ridge_results.keys():
        print(f"\n{'='*80}")
        print(f"OUTCOME DOMAIN: {outcome_domain}")
        print(f"{'='*80}")
        
        # Check if domain was skipped
        if ols_results[outcome_domain]['skipped']:
            print("\n⚠ Skipping - no stable features for this domain")
            validation_results[outcome_domain] = {
                'skipped': True,
                'skip_reason': ols_results[outcome_domain]['skip_reason']
            }
            continue
        
        domain_name = outcome_domain.replace('_12mo', '')
        
        # Get results from previous steps
        ridge_res = ridge_results[outcome_domain]
        ols_res = ols_results[outcome_domain]
        
        # ========== 1. NESTED CV PERFORMANCE (PRIMARY MEASURE) ==========
        print(f"\n{'─'*80}")
        print("1. NESTED CV PERFORMANCE (Unbiased Estimates)")
        print(f"{'─'*80}")
        
        nested_cv_r2_mean = ridge_res['nested_cv_r2_mean']
        nested_cv_r2_std = ridge_res['nested_cv_r2_std']
        nested_cv_rmse_mean = ridge_res['nested_cv_rmse_mean']
        nested_cv_rmse_std = ridge_res['nested_cv_rmse_std']
        
        print(f"R² (mean ± SD): {nested_cv_r2_mean:.4f} ± {nested_cv_r2_std:.4f}")
        print(f"RMSE (mean ± SD): {nested_cv_rmse_mean:.4f} ± {nested_cv_rmse_std:.4f}")
        print(f"95% CI for R²: [{nested_cv_r2_mean - 1.96*nested_cv_r2_std:.4f}, {nested_cv_r2_mean + 1.96*nested_cv_r2_std:.4f}]")
        print(f"95% CI for RMSE: [{nested_cv_rmse_mean - 1.96*nested_cv_rmse_std:.4f}, {nested_cv_rmse_mean + 1.96*nested_cv_rmse_std:.4f}]")
        
        # ========== 2. APPARENT OLS PERFORMANCE ==========
        print(f"\n{'─'*80}")
        print("2. APPARENT OLS PERFORMANCE (Optimistic)")
        print(f"{'─'*80}")
        
        apparent_r2 = ols_res['model_performance']['r2']
        apparent_adj_r2 = ols_res['model_performance']['adjusted_r2']
        apparent_rmse = ols_res['model_performance']['rmse']
        
        # Calculate MAE from OLS predictions
        y_true_ols = ols_res['y_true']
        y_pred_ols = ols_res['predictions']
        apparent_mae = mean_absolute_error(y_true_ols, y_pred_ols)
        
        print(f"R²: {apparent_r2:.4f}")
        print(f"Adjusted R²: {apparent_adj_r2:.4f}")
        print(f"RMSE: {apparent_rmse:.4f}")
        print(f"MAE: {apparent_mae:.4f}")
        
        # ========== 3. OPTIMISM CALCULATION ==========
        print(f"\n{'─'*80}")
        print("3. OPTIMISM ASSESSMENT")
        print(f"{'─'*80}")
        
        optimism_r2 = apparent_r2 - nested_cv_r2_mean
        optimism_rmse = apparent_rmse - nested_cv_rmse_mean
        
        print(f"Optimism in R²: {optimism_r2:+.4f} ({optimism_r2/nested_cv_r2_mean*100:+.1f}%)")
        print(f"Optimism in RMSE: {optimism_rmse:+.4f} ({optimism_rmse/nested_cv_rmse_mean*100:+.1f}%)")
        
        if optimism_r2 > 0.05:
            print(f"⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)")
        else:
            print(f"✓ Acceptable optimism level")
        
        # ========== 4. CALIBRATION PLOT ==========
        print(f"\n{'─'*80}")
        print("4. CALIBRATION ANALYSIS (Predicted vs Observed)")
        print(f"{'─'*80}")
        
        # Create calibration plot
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))
        
        # Plot 1: Scatter plot with regression line
        ax1 = axes[0]
        
        # Scatter plot
        ax1.scatter(y_pred_ols, y_true_ols, alpha=0.5, s=50, edgecolors='k', linewidth=0.5)
        
        # Perfect calibration line (45-degree line)
        min_val = min(y_pred_ols.min(), y_true_ols.min())
        max_val = max(y_pred_ols.max(), y_true_ols.max())
        ax1.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='Perfect calibration')
        
        # Fitted calibration line (LOWESS smoothing)
        from scipy.interpolate import make_interp_spline
        sorted_idx = np.argsort(y_pred_ols)
        y_pred_sorted = y_pred_ols.iloc[sorted_idx]
        y_true_sorted = y_true_ols.iloc[sorted_idx]
        
        # Simple linear regression for calibration
        from scipy.stats import linregress
        slope, intercept_calib, r_value, p_value, std_err = linregress(y_pred_ols, y_true_ols)
        calibration_line = slope * y_pred_ols + intercept_calib
        
        ax1.plot(y_pred_ols, calibration_line, 'b-', linewidth=2, label=f'Calibration line (slope={slope:.3f})')
        
        ax1.set_xlabel('Predicted Score', fontsize=12, fontweight='bold')
        ax1.set_ylabel('Observed Score', fontsize=12, fontweight='bold')
        ax1.set_title(f'Calibration Plot: {domain_name.upper()}', fontsize=14, fontweight='bold')
        ax1.legend(loc='upper left', fontsize=10)
        ax1.grid(True, alpha=0.3)
        
        # Add performance metrics to plot
        textstr = f'R² = {apparent_r2:.3f}\nRMSE = {apparent_rmse:.2f}\nMAE = {apparent_mae:.2f}\nN = {len(y_true_ols)}'
        ax1.text(0.05, 0.95, textstr, transform=ax1.transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        # Calculate calibration metrics
        calibration_slope = slope
        calibration_intercept = intercept_calib
        
        print(f"Calibration slope: {calibration_slope:.4f} (ideal = 1.0)")
        print(f"Calibration intercept: {calibration_intercept:.4f} (ideal = 0.0)")
        
        if abs(calibration_slope - 1.0) < 0.1 and abs(calibration_intercept) < 5:
            print("✓ Good calibration")
        elif abs(calibration_slope - 1.0) < 0.2:
            print("⚠ Moderate calibration")
        else:
            print("⚠ Poor calibration - model may need recalibration")
        
        # Plot 2: Residuals plot
        ax2 = axes[1]
        
        residuals = y_true_ols - y_pred_ols
        
        ax2.scatter(y_pred_ols, residuals, alpha=0.5, s=50, edgecolors='k', linewidth=0.5)
        ax2.axhline(y=0, color='r', linestyle='--', linewidth=2)
        
        # Add smoothed residual line
        sorted_idx = np.argsort(y_pred_ols)
        y_pred_sorted = y_pred_ols.iloc[sorted_idx]
        residuals_sorted = residuals.iloc[sorted_idx]
        
        # Moving average for smoothing
        window = max(10, len(residuals) // 20)
        residuals_smooth = pd.Series(residuals_sorted).rolling(window=window, center=True).mean()
        ax2.plot(y_pred_sorted, residuals_smooth, 'b-', linewidth=2, label='Smoothed residuals')
        
        ax2.set_xlabel('Predicted Score', fontsize=12, fontweight='bold')
        ax2.set_ylabel('Residuals (Observed - Predicted)', fontsize=12, fontweight='bold')
        ax2.set_title(f'Residuals Plot: {domain_name.upper()}', fontsize=14, fontweight='bold')
        ax2.legend(loc='upper left', fontsize=10)
        ax2.grid(True, alpha=0.3)
        
        # Add residual statistics
        mean_residual = residuals.mean()
        std_residual = residuals.std()
        textstr = f'Mean residual = {mean_residual:.3f}\nSD residual = {std_residual:.2f}'
        ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        plt.tight_layout()
        
        # Save calibration plot
        calib_filename = f"step6_calibration_plot_{domain_name}.png"
        plt.savefig(calib_filename, dpi=300, bbox_inches='tight')
        print(f"\n✓ Saved calibration plot: {calib_filename}")
        plt.close()
        
        # ========== 5. NESTED CV PREDICTIONS CALIBRATION ==========
        print(f"\n{'─'*80}")
        print("5. NESTED CV PREDICTIONS ANALYSIS")
        print(f"{'─'*80}")
        
        # Get nested CV predictions
        nested_cv_predictions = np.array(ridge_res['nested_cv_predictions'])
        nested_cv_true_values = np.array(ridge_res['nested_cv_true_values'])
        
        # Calculate metrics on nested CV predictions
        nested_cv_mae = mean_absolute_error(nested_cv_true_values, nested_cv_predictions)
        
        print(f"Nested CV MAE: {nested_cv_mae:.4f}")
        
        # Create nested CV calibration plot
        fig, ax = plt.subplots(figsize=(8, 8))
        
        # Scatter plot
        ax.scatter(nested_cv_predictions, nested_cv_true_values, alpha=0.5, s=50, 
                  edgecolors='k', linewidth=0.5)
        
        # Perfect calibration line
        min_val = min(nested_cv_predictions.min(), nested_cv_true_values.min())
        max_val = max(nested_cv_predictions.max(), nested_cv_true_values.max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, 
               label='Perfect calibration')
        
        # Fitted calibration line
        slope_cv, intercept_cv, r_value_cv, p_value_cv, std_err_cv = linregress(
            nested_cv_predictions, nested_cv_true_values)
        calibration_line_cv = slope_cv * nested_cv_predictions + intercept_cv
        
        ax.plot(nested_cv_predictions, calibration_line_cv, 'b-', linewidth=2, 
               label=f'Calibration line (slope={slope_cv:.3f})')
        
        ax.set_xlabel('Predicted Score (Nested CV)', fontsize=12, fontweight='bold')
        ax.set_ylabel('Observed Score', fontsize=12, fontweight='bold')
        ax.set_title(f'Nested CV Calibration: {domain_name.upper()}', 
                    fontsize=14, fontweight='bold')
        ax.legend(loc='upper left', fontsize=10)
        ax.grid(True, alpha=0.3)
        
        # Add performance metrics
        textstr = f'R² = {nested_cv_r2_mean:.3f}\nRMSE = {nested_cv_rmse_mean:.2f}\nMAE = {nested_cv_mae:.2f}\nN = {len(nested_cv_true_values)}'
        ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=10,
               verticalalignment='top', bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))
        
        plt.tight_layout()
        
        # Save nested CV calibration plot
        nested_calib_filename = f"step6_nested_cv_calibration_{domain_name}.png"
        plt.savefig(nested_calib_filename, dpi=300, bbox_inches='tight')
        print(f"✓ Saved nested CV calibration plot: {nested_calib_filename}")
        plt.close()
        
        print(f"Nested CV calibration slope: {slope_cv:.4f}")
        print(f"Nested CV calibration intercept: {intercept_cv:.4f}")
        
        # ========== 6. PERFORMANCE COMPARISON VISUALIZATION ==========
        print(f"\n{'─'*80}")
        print("6. PERFORMANCE COMPARISON")
        print(f"{'─'*80}")
        
        # Create comparison bar plot
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        
        # R² comparison
        ax1 = axes[0]
        metrics = ['Apparent\nOLS', 'Nested CV\n(Unbiased)']
        r2_values = [apparent_r2, nested_cv_r2_mean]
        r2_errors = [0, nested_cv_r2_std]
        
        bars1 = ax1.bar(metrics, r2_values, yerr=r2_errors, capsize=10, 
                       color=['coral', 'lightblue'], edgecolor='black', linewidth=1.5)
        ax1.set_ylabel('R²', fontsize=12, fontweight='bold')
        ax1.set_title(f'R² Comparison: {domain_name.upper()}', fontsize=13, fontweight='bold')
        ax1.set_ylim(0, max(r2_values) * 1.2)
        ax1.grid(True, axis='y', alpha=0.3)
        
        # Add values on bars
        for i, (bar, val) in enumerate(zip(bars1, r2_values)):
            height = bar.get_height()
            ax1.text(bar.get_x() + bar.get_width()/2., height,
                    f'{val:.3f}',
                    ha='center', va='bottom', fontsize=11, fontweight='bold')
        
        # Add optimism annotation
        ax1.annotate('', xy=(0, apparent_r2), xytext=(1, nested_cv_r2_mean),
                    arrowprops=dict(arrowstyle='<->', color='red', lw=2))
        ax1.text(0.5, (apparent_r2 + nested_cv_r2_mean)/2, 
                f'Optimism\n{optimism_r2:+.3f}',
                ha='center', va='center', fontsize=10, color='red', fontweight='bold',
                bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.7))
        
        # RMSE comparison
        ax2 = axes[1]
        rmse_values = [apparent_rmse, nested_cv_rmse_mean]
        rmse_errors = [0, nested_cv_rmse_std]
        
        bars2 = ax2.bar(metrics, rmse_values, yerr=rmse_errors, capsize=10,
                       color=['coral', 'lightblue'], edgecolor='black', linewidth=1.5)
        ax2.set_ylabel('RMSE', fontsize=12, fontweight='bold')
        ax2.set_title(f'RMSE Comparison: {domain_name.upper()}', fontsize=13, fontweight='bold')
        ax2.set_ylim(0, max(rmse_values) * 1.2)
        ax2.grid(True, axis='y', alpha=0.3)
        
        # Add values on bars
        for i, (bar, val) in enumerate(zip(bars2, rmse_values)):
            height = bar.get_height()
            ax2.text(bar.get_x() + bar.get_width()/2., height,
                    f'{val:.2f}',
                    ha='center', va='bottom', fontsize=11, fontweight='bold')
        
        # Add optimism annotation
        if optimism_rmse > 0:
            ax2.annotate('', xy=(0, apparent_rmse), xytext=(1, nested_cv_rmse_mean),
                        arrowprops=dict(arrowstyle='<->', color='red', lw=2))
            ax2.text(0.5, (apparent_rmse + nested_cv_rmse_mean)/2,
                    f'Optimism\n{optimism_rmse:+.2f}',
                    ha='center', va='center', fontsize=10, color='red', fontweight='bold',
                    bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.7))
        
        plt.tight_layout()
        
        # Save comparison plot
        comparison_filename = f"step6_performance_comparison_{domain_name}.png"
        plt.savefig(comparison_filename, dpi=300, bbox_inches='tight')
        print(f"✓ Saved performance comparison plot: {comparison_filename}")
        plt.close()
        
        # ========== STORE VALIDATION RESULTS ==========
        validation_results[outcome_domain] = {
            'skipped': False,
            'n_observations': ols_res['n_observations'],
            'n_stable_features': ols_res['n_stable_features'],
            
            # Nested CV performance (unbiased)
            'nested_cv_r2_mean': nested_cv_r2_mean,
            'nested_cv_r2_std': nested_cv_r2_std,
            'nested_cv_rmse_mean': nested_cv_rmse_mean,
            'nested_cv_rmse_std': nested_cv_rmse_std,
            'nested_cv_mae': nested_cv_mae,
            
            # Apparent OLS performance (optimistic)
            'apparent_r2': apparent_r2,
            'apparent_adj_r2': apparent_adj_r2,
            'apparent_rmse': apparent_rmse,
            'apparent_mae': apparent_mae,
            
            # Optimism
            'optimism_r2': optimism_r2,
            'optimism_rmse': optimism_rmse,
            
            # Calibration metrics
            'calibration_slope_ols': calibration_slope,
            'calibration_intercept_ols': calibration_intercept,
            'calibration_slope_nested_cv': slope_cv,
            'calibration_intercept_nested_cv': intercept_cv,
            
            # Plots
            'calibration_plot': calib_filename,
            'nested_cv_calibration_plot': nested_calib_filename,
            'comparison_plot': comparison_filename
        }
        
        print(f"\n{'='*80}")
        print(f"✓ COMPLETED: {outcome_domain}")
        print(f"{'='*80}")
    
    # ========== FINAL SUMMARY ==========
    print(f"\n{'='*80}")
    print("STEP 6 COMPLETE: INTERNAL VALIDATION")
    print(f"{'='*80}")
    
    # Create summary table
    print("\nVALIDATION SUMMARY TABLE:")
    print("="*120)
    
    summary_rows = []
    for domain, res in validation_results.items():
        if res['skipped']:
            summary_rows.append({
                'Domain': domain.replace('_12mo', ''),
                'N': 'N/A',
                'Features': 'N/A',
                'Nested CV R²': 'N/A',
                'Apparent R²': 'N/A',
                'Optimism': 'N/A',
                'Calibration': 'N/A'
            })
        else:
            calib_quality = 'Good' if abs(res['calibration_slope_ols'] - 1.0) < 0.1 else 'Moderate' if abs(res['calibration_slope_ols'] - 1.0) < 0.2 else 'Poor'
            
            summary_rows.append({
                'Domain': domain.replace('_12mo', ''),
                'N': res['n_observations'],
                'Features': res['n_stable_features'],
                'Nested CV R²': f"{res['nested_cv_r2_mean']:.3f}±{res['nested_cv_r2_std']:.3f}",
                'Apparent R²': f"{res['apparent_r2']:.3f}",
                'Optimism': f"{res['optimism_r2']:+.3f}",
                'Calibration': calib_quality
            })
    
    summary_df = pd.DataFrame(summary_rows)
    print(summary_df.to_string(index=False))
    print("="*120)
    
    print("\nKEY INTERPRETATION NOTES:")
    print("  • Nested CV R² = Primary performance metric (unbiased estimate)")
    print("  • Apparent R² = Performance on training data (optimistic)")
    print("  • Optimism = Apparent - Nested CV (quantifies overfitting)")
    print("  • Calibration slope close to 1.0 = Good agreement between predicted and observed")
    print("  • Use Nested CV performance for reporting expected model performance")
    
    # Save validation summary
    summary_df.to_csv("step6_validation_summary.csv", index=False)
    print("\n✓ Saved validation summary to 'step6_validation_summary.csv'")
    
    # Save detailed results
    for domain, res in validation_results.items():
        if not res['skipped']:
            domain_name = domain.replace('_12mo', '')
            
            detailed_results = pd.DataFrame({
                'Metric': [
                    'N_observations', 'N_features',
                    'Nested_CV_R2_mean', 'Nested_CV_R2_std', 'Nested_CV_RMSE_mean', 'Nested_CV_RMSE_std', 'Nested_CV_MAE',
                    'Apparent_R2', 'Apparent_Adjusted_R2', 'Apparent_RMSE', 'Apparent_MAE',
                    'Optimism_R2', 'Optimism_RMSE',
                    'Calibration_Slope_OLS', 'Calibration_Intercept_OLS',
                    'Calibration_Slope_Nested_CV', 'Calibration_Intercept_Nested_CV'
                ],
                'Value': [
                    res['n_observations'], res['n_stable_features'],
                    res['nested_cv_r2_mean'], res['nested_cv_r2_std'], res['nested_cv_rmse_mean'], res['nested_cv_rmse_std'], res['nested_cv_mae'],
                    res['apparent_r2'], res['apparent_adj_r2'], res['apparent_rmse'], res['apparent_mae'],
                    res['optimism_r2'], res['optimism_rmse'],
                    res['calibration_slope_ols'], res['calibration_intercept_ols'],
                    res['calibration_slope_nested_cv'], res['calibration_intercept_nested_cv']
                ]
            })
            
            detailed_filename = f"step6_validation_detailed_{domain_name}.csv"
            detailed_results.to_csv(detailed_filename, index=False)
            print(f"✓ Saved detailed validation results for {domain_name}")
    
    return validation_results

# Run internal validation
validation_results = perform_internal_validation(score_comparison, ridge_results, ols_results, nomogram_results)

print("\n" + "="*80)
print("✓ ALL STEPS COMPLETE!")
print("="*80)
print("\nYou now have:")
print("  Step 1: ✓ Outcome data prepared")
print("  Step 2: ✓ Predictors preprocessed")
print("  Step 3: ✓ Ridge regression with nested CV (all 17 predictors retained)")
print("  Step 4: ✓ Final OLS models fitted")
print("  Step 5: ✓ Nomograms created")
print("  Step 6: ✓ Internal validation completed")
print("\nAll results saved and ready for manuscript preparation!")
# Out:
# ================================================================================
# STEP 6: INTERNAL VALIDATION
# ================================================================================
# Purpose: Assess model accuracy, reliability, and optimism
# Method: Nested CV estimates + Calibration plots + Performance comparison
#
# ================================================================================
# OUTCOME DOMAIN: fact_e_total_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): -0.0892 ± 0.1797
# RMSE (mean ± SD): 24.9861 ± 5.6852
# 95% CI for R²: [-0.4414, 0.2630]
# 95% CI for RMSE: [13.8432, 36.1290]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.2763
# Adjusted R²: 0.1396
# RMSE: 22.1596
# MAE: 17.2611
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.3656 (-409.7%)
# Optimism in RMSE: -2.8265 (-11.3%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: 0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_fact_e_total.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 20.0665
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_fact_e_total.png
# Nested CV calibration slope: 0.8188
# Nested CV calibration intercept: 22.7532
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_fact_e_total.png
#
# ================================================================================
# ✓ COMPLETED: fact_e_total_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: pwb_subscale_score_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): -0.0453 ± 0.4415
# RMSE (mean ± SD): 5.4073 ± 1.4801
# 95% CI for R²: [-0.9108, 0.8201]
# 95% CI for RMSE: [2.5062, 8.3084]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.3735
# Adjusted R²: 0.2551
# RMSE: 4.6081
# MAE: 3.7315
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.4188 (-923.6%)
# Optimism in RMSE: -0.7993 (-14.8%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: -0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_pwb_subscale_score.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 4.3949
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_pwb_subscale_score.png
# Nested CV calibration slope: 0.8084
# Nested CV calibration intercept: 3.9637
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_pwb_subscale_score.png
#
# ================================================================================
# ✓ COMPLETED: pwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: swb_subscale_score_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): 0.0155 ± 0.2532
# RMSE (mean ± SD): 4.6257 ± 1.0994
# 95% CI for R²: [-0.4808, 0.5117]
# 95% CI for RMSE: [2.4709, 6.7805]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.2774
# Adjusted R²: 0.1409
# RMSE: 4.1658
# MAE: 3.2418
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.2619 (+1692.4%)
# Optimism in RMSE: -0.4599 (-9.9%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: -0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_swb_subscale_score.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 3.7122
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_swb_subscale_score.png
# Nested CV calibration slope: 0.9248
# Nested CV calibration intercept: 1.7048
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_swb_subscale_score.png
#
# ================================================================================
# ✓ COMPLETED: swb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ewb_subscale_score_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): -0.3572 ± 0.6888
# RMSE (mean ± SD): 4.3383 ± 1.1301
# 95% CI for R²: [-1.7073, 0.9928]
# 95% CI for RMSE: [2.1233, 6.5533]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.3470
# Adjusted R²: 0.2236
# RMSE: 3.7485
# MAE: 3.0351
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.7042 (-197.1%)
# Optimism in RMSE: -0.5898 (-13.6%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: -0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_ewb_subscale_score.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 3.6792
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_ewb_subscale_score.png
# Nested CV calibration slope: 0.7528
# Nested CV calibration intercept: 4.4210
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_ewb_subscale_score.png
#
# ================================================================================
# ✓ COMPLETED: ewb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: fwb_subscale_score_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): -0.1192 ± 0.2053
# RMSE (mean ± SD): 6.4602 ± 1.8981
# 95% CI for R²: [-0.5217, 0.2832]
# 95% CI for RMSE: [2.7400, 10.1804]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.2773
# Adjusted R²: 0.1408
# RMSE: 5.7799
# MAE: 4.6175
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.3966 (-332.6%)
# Optimism in RMSE: -0.6802 (-10.5%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: -0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_fwb_subscale_score.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 5.5471
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_fwb_subscale_score.png
# Nested CV calibration slope: 0.7495
# Nested CV calibration intercept: 4.0927
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_fwb_subscale_score.png
#
# ================================================================================
# ✓ COMPLETED: fwb_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# OUTCOME DOMAIN: ecs_subscale_score_12mo
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 1. NESTED CV PERFORMANCE (Unbiased Estimates)
# ────────────────────────────────────────────────────────────────────────────────
# R² (mean ± SD): -0.1324 ± 0.1524
# RMSE (mean ± SD): 10.0722 ± 2.4067
# 95% CI for R²: [-0.4310, 0.1663]
# 95% CI for RMSE: [5.3551, 14.7894]
#
# ────────────────────────────────────────────────────────────────────────────────
# 2. APPARENT OLS PERFORMANCE (Optimistic)
# ────────────────────────────────────────────────────────────────────────────────
# R²: 0.1522
# Adjusted R²: -0.0080
# RMSE: 9.4647
# MAE: 7.4339
#
# ────────────────────────────────────────────────────────────────────────────────
# 3. OPTIMISM ASSESSMENT
# ────────────────────────────────────────────────────────────────────────────────
# Optimism in R²: +0.2845 (-215.0%)
# Optimism in RMSE: -0.6075 (-6.0%)
# ⚠ WARNING: Substantial optimism detected (R² optimism > 0.05)
#
# ────────────────────────────────────────────────────────────────────────────────
# 4. CALIBRATION ANALYSIS (Predicted vs Observed)
# ────────────────────────────────────────────────────────────────────────────────
# Calibration slope: 1.0000 (ideal = 1.0)
# Calibration intercept: -0.0000 (ideal = 0.0)
# ✓ Good calibration
#
# ✓ Saved calibration plot: step6_calibration_plot_ecs_subscale_score.png
#
# ────────────────────────────────────────────────────────────────────────────────
# 5. NESTED CV PREDICTIONS ANALYSIS
# ────────────────────────────────────────────────────────────────────────────────
# Nested CV MAE: 8.1998
# ✓ Saved nested CV calibration plot: step6_nested_cv_calibration_ecs_subscale_score.png
# Nested CV calibration slope: -3.3435
# Nested CV calibration intercept: 209.0787
#
# ────────────────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE COMPARISON
# ────────────────────────────────────────────────────────────────────────────────
# ✓ Saved performance comparison plot: step6_performance_comparison_ecs_subscale_score.png
#
# ================================================================================
# ✓ COMPLETED: ecs_subscale_score_12mo
# ================================================================================
#
# ================================================================================
# STEP 6 COMPLETE: INTERNAL VALIDATION
# ================================================================================
#
# VALIDATION SUMMARY TABLE:
# ========================================================================================================================
#             Domain   N  Features Nested CV R² Apparent R² Optimism Calibration
#       fact_e_total 108        17 -0.089±0.180       0.276   +0.366        Good
# pwb_subscale_score 108        17 -0.045±0.442       0.373   +0.419        Good
# swb_subscale_score 108        17  0.015±0.253       0.277   +0.262        Good
# ewb_subscale_score 108        17 -0.357±0.689       0.347   +0.704        Good
# fwb_subscale_score 108        17 -0.119±0.205       0.277   +0.397        Good
# ecs_subscale_score 108        17 -0.132±0.152       0.152   +0.285        Good
# ========================================================================================================================
#
# KEY INTERPRETATION NOTES:
#   • Nested CV R² = Primary performance metric (unbiased estimate)
#   • Apparent R² = Performance on training data (optimistic)
#   • Optimism = Apparent - Nested CV (quantifies overfitting)
#   • Calibration slope close to 1.0 = Good agreement between predicted and observed
#   • Use Nested CV performance for reporting expected model performance
#
# ✓ Saved validation summary to 'step6_validation_summary.csv'
# ✓ Saved detailed validation results for fact_e_total
# ✓ Saved detailed validation results for pwb_subscale_score
# ✓ Saved detailed validation results for swb_subscale_score
# ✓ Saved detailed validation results for ewb_subscale_score
# ✓ Saved detailed validation results for fwb_subscale_score
# ✓ Saved detailed validation results for ecs_subscale_score
#
# ================================================================================
# ✓ ALL STEPS COMPLETE!
# ================================================================================
#
# You now have:
#   Step 1: ✓ Outcome data prepared
#   Step 2: ✓ Predictors preprocessed
#   Step 3: ✓ Ridge regression with nested CV (all 17 predictors retained)
#   Step 4: ✓ Final OLS models fitted
#   Step 5: ✓ Nomograms created
#   Step 6: ✓ Internal validation completed
#
# All results saved and ready for manuscript preparation!
